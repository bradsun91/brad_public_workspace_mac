# %%
import pandas as pd, numpy as np
from datetime import datetime
# import yfinance as yf
import tushare as ts
import time, urllib
ts.set_token('2f31c3932ead9fcc3830879132cc3ec8df3566550f711889d4a30f67')
import glob
import os

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)

# %%
ch_etfs_df = pd.read_csv("/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/"+"CH_ETFs.csv")
ch_etfs_df.dropna(inplace = True)
ch_etfs_df['基金规模\n[单位] 元'] = ch_etfs_df['基金规模\n[单位] 元'].apply(lambda x: float(x.replace(",","")))
ch_etfs_df['机构投资者持有份额\n[报告期] 2019中报\n[单位] 份'] = ch_etfs_df['机构投资者持有份额\n[报告期] 2019中报\n[单位] 份'].apply(lambda x: float(x.replace(",","")))
ch_etfs_df.sort_values("基金规模\n[单位] 元", ascending=False, inplace =True)
ch_etfs_df = ch_etfs_df

# %%
ch_etfs_df
# Out:
#           证券代码            证券简称 投资类型(一级分类) 投资类型(二级分类)  基金规模\n[单位] 元  \
# 152  510500.OF      南方中证500ETF      股票型基金    被动指数型基金  4.349555e+10
# 180  510050.OF       华夏上证50ETF      股票型基金    被动指数型基金  4.166154e+10
# 162  510300.OF    华泰柏瑞沪深300ETF      股票型基金    被动指数型基金  3.451196e+10
# 160  510330.OF      华夏沪深300ETF      股票型基金    被动指数型基金  2.701163e+10
# 245  159919.OF      嘉实沪深300ETF      股票型基金    被动指数型基金  2.264881e+10
# ..         ...             ...        ...        ...           ...
# 164  510270.OF       中银上证国企ETF      股票型基金    被动指数型基金  1.651702e+07
# 86   512610.OF     嘉实中证医药卫生ETF      股票型基金    被动指数型基金  1.587683e+07
# 220  159951.OF      嘉实中关村A股ETF      股票型基金    被动指数型基金  1.541933e+07
# 240  159926.OF     嘉实中证中期国债ETF      债券型基金  被动指数型债券基金  8.222069e+06
# 44   513680.OF  建信港股通恒生中国企业ETF      股票型基金    被动指数型基金  6.359485e+06
#
#      机构投资者持有份额\n[报告期] 2019中报\n[单位] 份  机构投资者持有比例\n[报告期] 2019中报\n[单位] %  \
# 152                     6.869517e+09                            76.03
# 180                     1.220778e+10                            73.10
# 162                     6.917064e+09                            73.10
# 160                     6.727655e+09                            96.86
# 245                     6.276555e+09                            92.26
# ..                               ...                              ...
# 164                     3.290950e+05                             2.08
# 86                      3.517788e+06                            33.06
# 220                     5.060470e+05                             2.22
# 240                     5.364000e+04                            73.78
# 44                      2.707000e+05                            15.50
#
#      管理费率\n[单位] %  托管费率\n[单位] %  \
# 152           0.5           0.1
# 180           0.5           0.1
# 162           0.5           0.1
# 160           0.5           0.1
# 245           0.5           0.1
# ..            ...           ...
# 164           0.5           0.1
# 86            0.5           0.1
# 220           0.5           0.1
# 240           0.3           0.1
# 44            0.5           0.1
#
#                                        认购费率\n[收费类型] 前端
# 152  500万份以上 1000元/笔\n100万份以下 1%\n100~300万份 0.6%\n3...
# 180       100万份以下 1%\n100~1000万份 0.8%\n1000万份以上 0.5%\n
# 162        100万份以上 1000元/笔\n50万份以下 1%\n50~100万份 0.5%\n
# 160      100万份以上 1000元/笔\n50万份以下 0.8%\n50~100万份 0.5%\n
# 245        100万份以上 1000元/笔\n50万份以下 1%\n50~100万份 0.5%\n
# ..                                                 ...
# 164        100万份以上 1000元/笔\n50万份以下 1%\n50~100万份 0.5%\n
# 86       100万份以上 1000元/笔\n50万份以下 0.8%\n50~100万份 0.5%\n
# 220      100万份以上 1000元/笔\n50万份以下 0.8%\n50~100万份 0.5%\n
# 240  500万份以上 1000元/笔\n50万份以下 0.4%\n50~100万份 0.3%\n1...
# 44   500万份以上 1000元/笔\n100万份以下 1%\n100~300万份 0.6%\n3...
#
# [169 rows x 10 columns]
