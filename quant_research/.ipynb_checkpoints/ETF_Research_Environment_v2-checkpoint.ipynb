# %%
import pandas as pd, numpy as np
from datetime import datetime
pd.set_option('max_colwidth',200)
# import yfinance as yf
import tushare as ts
import time, urllib
ts.set_token('2f31c3932ead9fcc3830879132cc3ec8df3566550f711889d4a30f67')
import glob
import os

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)

from plotly.graph_objs import Scatter,Layout
import plotly
import plotly.offline as py
import numpy as np
import plotly.graph_objs as go

#setting offilne
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # 读取数据

# %%
ch_etfs_df = pd.read_csv("/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/"+"CH_ETFs.csv")
ch_etfs_df.dropna(inplace = True)
ch_etfs_df['基金规模\n[单位] 元'] = ch_etfs_df['基金规模\n[单位] 元'].apply(lambda x: float(x.replace(",","")))
ch_etfs_df['机构投资者持有份额\n[报告期] 2019中报\n[单位] 份'] = ch_etfs_df['机构投资者持有份额\n[报告期] 2019中报\n[单位] 份'].apply(lambda x: float(x.replace(",","")))
ch_etfs_df.sort_values("基金规模\n[单位] 元", ascending=False, inplace =True)
ch_etfs_df = ch_etfs_df.head(50)
ch_etfs = ch_etfs_df.copy()
ch_etfs['code'] =ch_etfs['证券代码'].apply(lambda x: str(x)[:6])
ch_etfs_ticker = list(ch_etfs['code'].unique())
# Add the sp500 etf
etf_tickers = ['513500']+ch_etfs_ticker

# %%
len(set(etf_tickers))
# Out:
# 51

# %% [markdown]
# # 1. Correlation Analysis for ETFs and Filter Targets
#
# - Function 1. Plot correlation matrix heatmap of multiple assets from: to-be-made func: etf_corr_heatmap(ticker, list, path, price_col, date_col)
#
# - Function 2. Filter assets with lowest correlations among them

# %%
# This part is for generating correlation heatmaps

today = str(datetime.now().date())
start = '2010-01-01'
end = today

ch_db_path = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/CH_database/"
ticker_df_list = []
for ticker in etf_tickers:
    print("Reading ETF: ", ticker)
    try:
        ticker_df = pd.read_csv(ch_db_path+ticker+".csv")
        ticker_df = ticker_df.sort_values('date')
        ticker_df = ticker_df[['date','close','code']]
        ticker_df['pct_chg'] = ticker_df['close'].pct_change()
        ticker_df = ticker_df[['date', 'pct_chg']].dropna()
        ticker_df.columns = ['date',ticker]
        ticker_df['date'] = pd.to_datetime(ticker_df['date'])
    #     stock.set_index('date', inplace=True)
        ticker_df_list.append(ticker_df)
#     except FileNotFoundError:
#         print("Does not have ETF {}, start downloading now...".format(ticker))
#         data = GetHistoryData(ticker, start, today)
#         data.to_csv(ch_db_path+ticker+".csv", index = False)
#         print("ETF {} downloaded.".format(ticker))
    except:
        pass
# Out:
# Reading ETF:  513500
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/pandas/compat/_optional.py:106: UserWarning:
#
# Pandas requires version '2.6.2' or newer of 'numexpr' (version '2.6.1' currently installed).
# Reading ETF:  510500
# Reading ETF:  510050
# Reading ETF:  510300
# Reading ETF:  510330
# Reading ETF:  159919
# Reading ETF:  510180
# Reading ETF:  159915
# Reading ETF:  512960
# Reading ETF:  512950
# Reading ETF:  510810
# Reading ETF:  512880
# Reading ETF:  510900
# Reading ETF:  518880
# Reading ETF:  510310
# Reading ETF:  159901
# Reading ETF:  512500
# Reading ETF:  159920
# Reading ETF:  159949
# Reading ETF:  510230
# Reading ETF:  510850
# Reading ETF:  159959
# Reading ETF:  511030
# Reading ETF:  510390
# Reading ETF:  510510
# Reading ETF:  510380
# Reading ETF:  512000
# Reading ETF:  159962
# Reading ETF:  510360
# Reading ETF:  159928
# Reading ETF:  159922
# Reading ETF:  510880
# Reading ETF:  159938
# Reading ETF:  510590
# Reading ETF:  159902
# Reading ETF:  512660
# Reading ETF:  512070
# Reading ETF:  159939
# Reading ETF:  511220
# Reading ETF:  512900
# Reading ETF:  512380
# Reading ETF:  512800
# Reading ETF:  512580
# Reading ETF:  159905
# Reading ETF:  159952
# Reading ETF:  159910
# Reading ETF:  511270
# Reading ETF:  513050
# Reading ETF:  159948
# Reading ETF:  512980
# Reading ETF:  511020

# %%
# 一次性merge多个pct_chg
from functools import reduce

# 先为之后使用reduce铺路：创造一个merge的函数：
def merge_df(df1, df2):
    df1.sort_values('date', inplace = True)
    merged = df1.merge(df2, on = 'date', how = 'outer')
    merged.sort_values('date', inplace = True)
    return merged

# 重要知识点：reduce
# stock_list里都是一个个dataframe
merged_all = reduce(merge_df, ticker_df_list)
merged_all.set_index('date', inplace=True)
merged_all.dropna(how="all", axis = 1, inplace = True)

# %%
# 最后一步：plot heatmap:
fig, ax = plt.subplots(figsize = (15, 8))
sns.heatmap(merged_all.corr()[abs(merged_all.corr())>-2], ax = ax, cmap = 'Blues', vmax = 1.0, vmin = -1.0, annot=True)
plt.xlabel('ETF', fontsize = 10)
plt.ylabel('ETF', fontsize = 10)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10);

# %%
# Create ETFs' correlation matrix dataframe
merged_all_corr = merged_all.corr()
merged_all_corr_abs = abs(merged_all_corr)

corr_mean_dict = {}

for row in merged_all_corr_abs.iterrows():
    row_list = list(row)
    print(row_list[0])
    print(np.mean(row_list[1]))
    corr_mean_dict[row_list[0]] = np.mean(row_list[1])
    print("========")

# %%
corr_mean_df = pd.DataFrame()
corr_mean_df['etf'] = corr_mean_dict.keys()
corr_mean_df['abs_corr_mean'] = corr_mean_dict.values()
corr_mean_df_10_etf = corr_mean_df.sort_values("abs_corr_mean", ascending=True)

# %%
corr_mean_df_10_etf.head(20)
# Out:
#        etf  abs_corr_mean
# 36  511220       0.045357
# 4   511030       0.067088
# 31  518880       0.106749
# 23  511270       0.218832
# 25  511020       0.244008
# 48  510380       0.407293
# 38  159920       0.448760
# 34  510500       0.480180
# 0   159901       0.485395
# 13  510180       0.486460
# 28  513050       0.490270
# 19  510900       0.495961
# 10  159928       0.554118
# 18  159910       0.566667
# 1   510230       0.568087
# 9   512800       0.578287
# 3   512660       0.580082
# 44  159919       0.584585
# 20  510050       0.616136
# 24  159939       0.616976

# %%
selected_10_etf_list = list(corr_mean_df_10_etf['etf'])[:10]

# %%
selected_10_etf_list
# Out:
# ['511220',
#  '511030',
#  '518880',
#  '511270',
#  '511020',
#  '510380',
#  '159920',
#  '510500',
#  '159901',
#  '510180']

# %% [markdown]
# # 2. Select Target Data from Database Folder

# %%
ch_db_path = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/CH_database/"
csv_path = ch_db_path+"*.csv"
files = glob.glob(csv_path)

# %%
tickers_data = []
for ticker in selected_10_etf_list:
    print("Reading: ", ticker)
    ticker_df = pd.read_csv(ch_db_path+ticker+".csv")
    tickers_data.append(ticker_df)
# Out:
# Reading:  511220
# Reading:  511030
# Reading:  518880
# Reading:  511270
# Reading:  511020
# Reading:  510380
# Reading:  159920
# Reading:  510500
# Reading:  510180

# %%
tickers_data_concated = pd.concat(tickers_data)
tickers_data_concated.reset_index(inplace=True)
del tickers_data_concated['index']

# %%
tickers_data_concated
# Out:
#             date    open   close    high     low    volume    code
# 0     2014-12-16  96.000  94.930  96.000  94.902    1652.0  511220
# 1     2014-12-17  94.931  94.911  95.038  94.602    1462.0  511220
# 2     2014-12-18  85.911  94.131  94.801  85.911     926.0  511220
# 3     2014-12-19  94.000  94.130  94.299  93.500     426.0  511220
# 4     2014-12-22  93.001  93.475  93.980  92.004      16.0  511220
# ...          ...     ...     ...     ...     ...       ...     ...
# 9651  2019-12-23   3.478   3.435   3.490   3.432  284488.0  510180
# 9652  2019-12-24   3.450   3.460   3.460   3.436  206568.0  510180
# 9653  2019-12-25   3.458   3.458   3.463   3.441  263552.0  510180
# 9654  2019-12-26   3.458   3.480   3.482   3.451  241315.0  510180
# 9655  2019-12-27   3.481   3.489   3.524   3.481  306505.0  510180
#
# [9656 rows x 7 columns]

# %% [markdown]
# # 2. Technical Analysis Building & Signal Generation

# %%
def MACD(df, n_fast, n_slow, n_macd): # n_fast = 12, n_slow = 26
    """
    
    http://stockcharts.com/docs/doku.php?id=scans:indicators

    """
    """
    MACD, MACD Signal and MACD difference, rationale CHECKED, code CHECKED, updated
    # Conventional look-back window for calculating MACDsign is 9
    """
    EMAfast = df['close'].ewm(span = n_fast, min_periods = n_fast - 1).mean()
    EMAslow = df['close'].ewm(span = n_slow, min_periods = n_slow - 1).mean()
    MACD = pd.Series(EMAfast - EMAslow, name = 'MACD_' + str(n_fast) + '_' + str(n_slow))
    MACDsign = MACD.ewm(span = n_macd, min_periods = n_macd-1).mean().rename('MACDsign_' + str(n_fast) + '_' + str(n_slow))
    MACDdiff = pd.Series(MACD - MACDsign, name = 'MACDdiff_' + str(n_fast) + '_' + str(n_slow))
    df['MACD_Diff'] = MACD
    df['MACD_Diff_EMA'] = MACDsign
    df['MACD'] = MACDdiff
    df['SIGNAL_STATUS'] = df['MACD'].apply(lambda x: "多头状态" if x>0 else ("空头状态" if x<0 else "无信号状态"))
#     return MACD, MACDsign, MACDdiff
    return df

# %%
signal_record = []
signal_data = []
for ticker in selected_10_etf_list:
    print("Calculating Signal for: ", ticker)
    try:
        single_ticker_df = tickers_data_concated[tickers_data_concated['code']==float(ticker)]
        signal_df = MACD(single_ticker_df, 12, 26, 9)
        last_signal = signal_df[['code','SIGNAL_STATUS']].values[-1]
        signal_data.append(signal_df)
        signal_record.append(last_signal)
    except:
        pass
# Out:
# Calculating Signal for:  511220
# Calculating Signal for:  511030
# Calculating Signal for:  518880
# Calculating Signal for:  511270
# Calculating Signal for:  511020
# Calculating Signal for:  510380
# Calculating Signal for:  159920
# Calculating Signal for:  510500
# Calculating Signal for:  510180
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
signal_data_df = pd.concat(signal_data)
signal_data_df
# Out:
#             date    open   close    high     low    volume    code  MACD_Diff  \
# 0     2014-12-16  96.000  94.930  96.000  94.902    1652.0  511220        NaN
# 1     2014-12-17  94.931  94.911  95.038  94.602    1462.0  511220        NaN
# 2     2014-12-18  85.911  94.131  94.801  85.911     926.0  511220        NaN
# 3     2014-12-19  94.000  94.130  94.299  93.500     426.0  511220        NaN
# 4     2014-12-22  93.001  93.475  93.980  92.004      16.0  511220        NaN
# ...          ...     ...     ...     ...     ...       ...     ...        ...
# 9651  2019-12-23   3.478   3.435   3.490   3.432  284488.0  510180   0.003743
# 9652  2019-12-24   3.450   3.460   3.460   3.436  206568.0  510180   0.004702
# 9653  2019-12-25   3.458   3.458   3.463   3.441  263552.0  510180   0.005240
# 9654  2019-12-26   3.458   3.480   3.482   3.451  241315.0  510180   0.007357
# 9655  2019-12-27   3.481   3.489   3.524   3.481  306505.0  510180   0.009649
#
#       MACD_Diff_EMA      MACD SIGNAL_STATUS
# 0               NaN       NaN         无信号状态
# 1               NaN       NaN         无信号状态
# 2               NaN       NaN         无信号状态
# 3               NaN       NaN         无信号状态
# 4               NaN       NaN         无信号状态
# ...             ...       ...           ...
# 9651      -0.009911  0.013655          多头状态
# 9652      -0.006989  0.011691          多头状态
# 9653      -0.004543  0.009783          多头状态
# 9654      -0.002163  0.009520          多头状态
# 9655       0.000199  0.009450          多头状态
#
# [9656 rows x 11 columns]

# %%
def make_numeric_signals(series):
    for item in series:
        print(item)
        if item =="多":
            return 1
        elif item =="空":
            return -1
        else:
            return 0

# %%
signal_data_df['SIGNAL_DIRECTION'] = signal_data_df['SIGNAL_STATUS'].apply(lambda x: make_numeric_signals(x))
# Out:
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 多
# 空
# 多
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 多
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 多
# 空
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 多
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 无
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 空
# 空
# 多
# 多
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 空
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 多
# 多
# 空
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 空
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多
# 多

# %%
signal_data_df.tail(10)
# Out:
#             date   open  close   high    low    volume    code  MACD_Diff  \
# 9646  2019-12-16  3.454  3.457  3.460  3.438  205809.0  510180  -0.017635
# 9647  2019-12-17  3.456  3.502  3.531  3.456  272509.0  510180  -0.008704
# 9648  2019-12-18  3.507  3.489  3.515  3.487  234619.0  510180  -0.002645
# 9649  2019-12-19  3.494  3.487  3.497  3.474  197493.0  510180   0.001973
# 9650  2019-12-20  3.488  3.480  3.505  3.475  225319.0  510180   0.005011
# 9651  2019-12-23  3.478  3.435  3.490  3.432  284488.0  510180   0.003743
# 9652  2019-12-24  3.450  3.460  3.460  3.436  206568.0  510180   0.004702
# 9653  2019-12-25  3.458  3.458  3.463  3.441  263552.0  510180   0.005240
# 9654  2019-12-26  3.458  3.480  3.482  3.451  241315.0  510180   0.007357
# 9655  2019-12-27  3.481  3.489  3.524  3.481  306505.0  510180   0.009649
#
#       MACD_Diff_EMA      MACD SIGNAL_STATUS  SIGNAL_DIRECTION
# 9646      -0.032747  0.015112          多头状态                 1
# 9647      -0.027938  0.019234          多头状态                 1
# 9648      -0.022880  0.020235          多头状态                 1
# 9649      -0.017909  0.019882          多头状态                 1
# 9650      -0.013325  0.018336          多头状态                 1
# 9651      -0.009911  0.013655          多头状态                 1
# 9652      -0.006989  0.011691          多头状态                 1
# 9653      -0.004543  0.009783          多头状态                 1
# 9654      -0.002163  0.009520          多头状态                 1
# 9655       0.000199  0.009450          多头状态                 1

# %%
signal_data_df['SIGNAL_DIRECTION_DIFF'] = signal_data_df.groupby(['code'])['SIGNAL_DIRECTION'].diff()

# %%
signal_data_df.tail(2)
# Out:
#             date   open  close   high    low    volume    code  MACD_Diff  \
# 9654  2019-12-26  3.458  3.480  3.482  3.451  241315.0  510180   0.007357
# 9655  2019-12-27  3.481  3.489  3.524  3.481  306505.0  510180   0.009649
#
#       MACD_Diff_EMA     MACD SIGNAL_STATUS  SIGNAL_DIRECTION  \
# 9654      -0.002163  0.00952          多头状态                 1
# 9655       0.000199  0.00945          多头状态                 1
#
#       SIGNAL_DIRECTION_DIFF SIGNAL_ACTION
# 9654                    0.0           NaN
# 9655                    0.0           NaN

# %%
# signal_data_df['SIGNAL_DIFF'] = signal_data_df.groupby(['code'])['MACD'].diff()
signal_data_df['SIGNAL_ACTION'] = signal_data_df['SIGNAL_DIRECTION_DIFF'].apply(lambda x: "LONG" if x==2 else("SHORT" if x==-2 else "NO CHANGE"))
# signal_data_df['SIGNAL_ACTION'] = signal_data_df.groupby(['code'].apply(lambda x: "LONG" if ))

# %%
signal_data_df.groupby(['code'])[['date','code','SIGNAL_STATUS','SIGNAL_ACTION']].tail(1)
# Out:
#             date    code SIGNAL_STATUS SIGNAL_ACTION
# 1219  2019-12-27  511220          多头状态     NO CHANGE
# 1401  2019-12-27  511030          空头状态     NO CHANGE
# 2968  2019-12-27  518880          多头状态     NO CHANGE
# 3236  2019-12-27  511270          空头状态         SHORT
# 3428  2019-12-26  511020          多头状态     NO CHANGE
# 3824  2019-12-27  510380          多头状态     NO CHANGE
# 5575  2019-12-27  159920          多头状态     NO CHANGE
# 7228  2019-12-27  510500          多头状态     NO CHANGE
# 9655  2019-12-27  510180          多头状态     NO CHANGE

# %%
signal_data_df[signal_data_df['code']==510180][['MACD','MACD_Diff','MACD_Diff_EMA']].tail(100).plot()

# %% [markdown]
# # 2. ETF plotting

# %%
# This part is for looking up charts and market data
ch_db_path = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/CH_database/"
list_10_etfs_to_concat = []
for ticker in selected_10_etf_list:
    print("Reading ETF: ", ticker)
    try:
        ticker_df = pd.read_csv(ch_db_path+ticker+".csv")
        list_10_etfs_to_concat.append(ticker_df)
#     except FileNotFoundError:
#         print("Does not have ETF {}, start downloading now...".format(ticker))
#         data = GetHistoryData(ticker, start, today)
#         data.to_csv(ch_db_path+ticker+".csv", index = False)
#         print("ETF {} downloaded.".format(ticker))
    except:
        pass

df_10_etfs = pd.concat(list_10_etfs_to_concat)
# Out:
# Reading ETF:  511220
# Reading ETF:  511030
# Reading ETF:  518880
# Reading ETF:  511270
# Reading ETF:  511020
# Reading ETF:  510380
# Reading ETF:  159920
# Reading ETF:  510500
# Reading ETF:  159901
# Reading ETF:  510180

# %%
df_10_etfs.tail()
# Out:
#             date   open  close   high    low    volume    code
# 2422  2019-12-23  3.478  3.435  3.490  3.432  284488.0  510180
# 2423  2019-12-24  3.450  3.460  3.460  3.436  206568.0  510180
# 2424  2019-12-25  3.458  3.458  3.463  3.441  263552.0  510180
# 2425  2019-12-26  3.458  3.480  3.482  3.451  241315.0  510180
# 2426  2019-12-27  3.481  3.489  3.524  3.481  306505.0  510180

# %%
def plot_individual(ticker, df_10_etfs):    
    dt = df_10_etfs[df_10_etfs['code']==ticker]
    y_close = dt['close']
    x_dt = dt['date']
    etf = go.Scatter(
            x = x_dt,
            y = y_close,
    #         mode = 'lines',
            name = str(ticker)
    )
    data_etf = [etf]
    py.iplot(data_etf)

# %%
selected_10_etf_list.remove("159901")

# %%
selected_10_etf_list
# Out:
# ['511220',
#  '511030',
#  '518880',
#  '511270',
#  '511020',
#  '510380',
#  '159920',
#  '510500',
#  '510180']

# %%
def data_to_plot_multiples(df_10_etfs, selected_10_etf_list):
    data_etfs = []
    num = 1
    for ticker in selected_10_etf_list:
        dt = df_10_etfs[df_10_etfs['code']==int(ticker)]
        y_close = dt['close']
        x_dt = dt['date']
        etf = go.Scatter(
                x = x_dt,
                y = y_close,
                name = str(ticker),
                xaxis = 'x{}'.format(num),
                yaxis = 'y{}'.format(num)
        )
        data_etfs.append(etf)
        num+=1
    return data_etfs

# %%
data_etfs = data_to_plot_multiples(df_10_etfs, selected_10_etf_list)

layout = go.Layout(
    xaxis=dict(
        domain=[0, 0.3]
    ),
    yaxis=dict(
        domain=[0, 0.3]
    ),
    
    xaxis2=dict(
        domain=[0.35, 0.65],
        anchor='y2'
    ),
    yaxis2=dict(
        domain=[0, 0.3],
        anchor='x2'
    ),
    
    xaxis3=dict(
        domain=[0.7, 1],
        anchor='y3'
    ),
    yaxis3=dict(
        domain=[0, 0.3],
        anchor='x3'
    ),
    
    

    xaxis4=dict(
        domain=[0, 0.3],
        anchor='y4'
    ),
    yaxis4=dict(
        domain=[0.35, 0.65],
        anchor='x4'
    ),
    
    xaxis5=dict(
        domain=[0.35, 0.65],
        anchor='y5'
    ),
    yaxis5=dict(
        domain=[0.35, 0.65],
        anchor='x5'
    ),
    
    xaxis6=dict(
        domain=[0.7, 1],
        anchor='y6'
    ),
    yaxis6=dict(
        domain=[0.35, 0.65],
        anchor='x6'
    ),
    
    
    xaxis7=dict(
        domain=[0, 0.3],
        anchor='y7'
    ),
    yaxis7=dict(
        domain=[0.7, 1],
        anchor='x7'
    ),
    
    xaxis8=dict(
        domain=[0.35, 0.65],
        anchor='y8'
    ),
    yaxis8=dict(
        domain=[0.7, 1],
        anchor='x8'
    ),
    
    xaxis9=dict(
        domain=[0.7, 1],
        anchor='y9'
    ),
    yaxis9=dict(
        domain=[0.7, 1],
        anchor='x9'
    ),
    
)

# %%
fig = go.Figure(data=data_etfs, layout=layout)

# %%
py.plot(fig, filename='multiple-subplots')
# Out:
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/plotly/offline/offline.py:526: UserWarning:
#
# Your filename `multiple-subplots` didn't end with .html. Adding .html to the end of your file.
# 'multiple-subplots.html'

# %%
plot(510180)
# Out:
# <div>
#
#
#             <div id="4aba7654-a2bd-4102-ab7f-db207165b30c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4aba7654-a2bd-4102-ab7f-db207165b30c")) {
#                     Plotly.newPlot(
#                         '4aba7654-a2bd-4102-ab7f-db207165b30c',
#                         [{"name": "510180", "type": "scatter", "uid": "5999a6fc-6cd4-4135-983c-a0c1bdf84de9", "x": ["2010-01-04", "2010-01-05", "2010-01-06", "2010-01-07", "2010-01-08", "2010-01-11", "2010-01-12", "2010-01-13", "2010-01-14", "2010-01-15", "2010-01-18", "2010-01-19", "2010-01-20", "2010-01-21", "2010-01-22", "2010-01-25", "2010-01-26", "2010-01-27", "2010-01-28", "2010-01-29", "2010-02-01", "2010-02-02", "2010-02-03", "2010-02-04", "2010-02-05", "2010-02-08", "2010-02-09", "2010-02-10", "2010-02-11", "2010-02-12", "2010-02-22", "2010-02-23", "2010-02-24", "2010-02-25", "2010-02-26", "2010-03-01", "2010-03-02", "2010-03-03", "2010-03-04", "2010-03-05", "2010-03-08", "2010-03-09", "2010-03-10", "2010-03-11", "2010-03-12", "2010-03-15", "2010-03-16", "2010-03-17", "2010-03-18", "2010-03-19", "2010-03-22", "2010-03-23", "2010-03-24", "2010-03-25", "2010-03-26", "2010-03-29", "2010-03-30", "2010-03-31", "2010-04-01", "2010-04-02", "2010-04-06", "2010-04-07", "2010-04-08", "2010-04-09", "2010-04-12", "2010-04-13", "2010-04-14", "2010-04-15", "2010-04-16", "2010-04-19", "2010-04-20", "2010-04-21", "2010-04-22", "2010-04-23", "2010-04-26", "2010-04-27", "2010-04-28", "2010-04-29", "2010-04-30", "2010-05-04", "2010-05-05", "2010-05-06", "2010-05-07", "2010-05-10", "2010-05-11", "2010-05-12", "2010-05-13", "2010-05-14", "2010-05-17", "2010-05-18", "2010-05-19", "2010-05-20", "2010-05-21", "2010-05-24", "2010-05-25", "2010-05-26", "2010-05-27", "2010-05-28", "2010-05-31", "2010-06-01", "2010-06-02", "2010-06-03", "2010-06-04", "2010-06-07", "2010-06-08", "2010-06-09", "2010-06-10", "2010-06-11", "2010-06-17", "2010-06-18", "2010-06-21", "2010-06-22", "2010-06-23", "2010-06-24", "2010-06-25", "2010-06-28", "2010-06-29", "2010-06-30", "2010-07-01", "2010-07-02", "2010-07-05", "2010-07-06", "2010-07-07", "2010-07-08", "2010-07-09", "2010-07-12", "2010-07-13", "2010-07-14", "2010-07-15", "2010-07-16", "2010-07-19", "2010-07-20", "2010-07-21", "2010-07-22", "2010-07-23", "2010-07-26", "2010-07-27", "2010-07-28", "2010-07-29", "2010-07-30", "2010-08-02", "2010-08-03", "2010-08-04", "2010-08-05", "2010-08-06", "2010-08-09", "2010-08-10", "2010-08-11", "2010-08-12", "2010-08-13", "2010-08-16", "2010-08-17", "2010-08-18", "2010-08-19", "2010-08-20", "2010-08-23", "2010-08-24", "2010-08-25", "2010-08-26", "2010-08-27", "2010-08-30", "2010-08-31", "2010-09-01", "2010-09-02", "2010-09-03", "2010-09-06", "2010-09-07", "2010-09-08", "2010-09-09", "2010-09-10", "2010-09-13", "2010-09-14", "2010-09-15", "2010-09-16", "2010-09-17", "2010-09-20", "2010-09-21", "2010-09-27", "2010-09-28", "2010-09-29", "2010-09-30", "2010-10-08", "2010-10-11", "2010-10-12", "2010-10-13", "2010-10-14", "2010-10-15", "2010-10-18", "2010-10-19", "2010-10-20", "2010-10-21", "2010-10-22", "2010-10-25", "2010-10-26", "2010-10-27", "2010-10-28", "2010-10-29", "2010-11-01", "2010-11-02", "2010-11-03", "2010-11-04", "2010-11-05", "2010-11-08", "2010-11-09", "2010-11-10", "2010-11-11", "2010-11-12", "2010-11-15", "2010-11-16", "2010-11-17", "2010-11-18", "2010-11-19", "2010-11-22", "2010-11-23", "2010-11-24", "2010-11-25", "2010-11-26", "2010-11-29", "2010-11-30", "2010-12-01", "2010-12-02", "2010-12-03", "2010-12-06", "2010-12-07", "2010-12-08", "2010-12-09", "2010-12-10", "2010-12-13", "2010-12-14", "2010-12-15", "2010-12-16", "2010-12-17", "2010-12-20", "2010-12-21", "2010-12-22", "2010-12-23", "2010-12-24", "2010-12-27", "2010-12-28", "2010-12-29", "2010-12-30", "2010-12-31", "2011-01-04", "2011-01-05", "2011-01-06", "2011-01-07", "2011-01-10", "2011-01-11", "2011-01-12", "2011-01-13", "2011-01-14", "2011-01-17", "2011-01-18", "2011-01-19", "2011-01-20", "2011-01-21", "2011-01-24", "2011-01-25", "2011-01-26", "2011-01-27", "2011-01-28", "2011-01-31", "2011-02-01", "2011-02-09", "2011-02-10", "2011-02-11", "2011-02-14", "2011-02-15", "2011-02-16", "2011-02-17", "2011-02-18", "2011-02-21", "2011-02-22", "2011-02-23", "2011-02-24", "2011-02-25", "2011-02-28", "2011- ...

# %%
selected_10_etf_list
# Out:
# ['511220',
#  '511030',
#  '518880',
#  '511270',
#  '511020',
#  '510380',
#  '159920',
#  '510500',
#  '510180']

# %%
filtered__info = ch_etfs_df[ch_etfs_df['证券代码'].map(lambda x: x[:6] in selected_10_etf_list)]

# %%
filtered__info
# Out:
#           证券代码                 证券简称  投资类型(一级分类)     投资类型(二级分类)  基金规模\n[单位] 元  \
# 152  510500.OF           南方中证500ETF       股票型基金        被动指数型基金  4.349555e+10
# 169  510180.OF           华安上证180ETF       股票型基金        被动指数型基金  1.958375e+10
# 0    518880.OF              华安黄金ETF      另类投资基金          商品型基金  8.597897e+09
# 244  159920.OF              华夏恒生ETF  国际(QDII)基金  国际(QDII)股票型基金  5.946218e+09
# 131  511030.OF  平安中债-中高等级公司债利差因子ETF       债券型基金      被动指数型债券基金  5.206926e+09
# 157  510380.OF         国寿安保沪深300ETF       股票型基金        被动指数型基金  4.684516e+09
# 129  511220.OF          海富通上证城投债ETF       债券型基金      被动指数型债券基金  1.885463e+09
# 127  511270.OF    海富通上证10年期地方政府债ETF       债券型基金      被动指数型债券基金  1.239962e+09
# 132  511020.OF     平安5-10年期国债活跃券ETF       债券型基金      被动指数型债券基金  1.141506e+09
#
#      机构投资者持有份额\n[报告期] 2019中报\n[单位] 份  机构投资者持有比例\n[报告期] 2019中报\n[单位] %  \
# 152                     6.869517e+09                            76.03
# 169                     5.378177e+09                            95.37
# 0                       1.167058e+09                            65.07
# 244                     2.499516e+09                            91.04
# 131                     5.108587e+07                            99.99
# 157                     4.732370e+09                            99.82
# 129                     1.957374e+07                            95.07
# 127                     1.223830e+07                            98.80
# 132                     1.117982e+07                            99.80
#
#      管理费率\n[单位] %  托管费率\n[单位] %  \
# 152          0.50          0.10
# 169          0.50          0.10
# 0            0.50          0.10
# 244          0.60          0.15
# 131          0.25          0.08
# 157          0.50          0.10
# 129          0.30          0.10
# 127          0.25          0.10
# 132          0.25          0.05
#
#                                                                        认购费率\n[收费类型] 前端
# 152                      500万份以上 1000元/笔\n100万份以下 1%\n100~300万份 0.6%\n300~500万份 0.3%\n
# 169                                       100万份以下 1%\n100~1000万份 0.8%\n1000万份以上 0.5%\n
# 0    500元/笔,通过基金管理人现金认购本基金份额的养老金客户认购费率。\n100万份以上 1000元/笔\n50万份以下 0.5%\n50~100万份 0.3%\n
# 244                                                      50万份以上 1000元/笔\n50万份以下 0.8%\n
# 131                                      100万份以上 1000元/笔\n50万份以下 0.4%\n50~100万份 0.2%\n
# 157                                                       50万份以上 500元/笔\n50万份以下 0.8%\n
# 129                                      100万份以上 1000元/笔\n50万份以下 0.4%\n50~100万份 0.2%\n
# 127                                      100万份以上 1000元/笔\n50万份以下 0.4%\n50~100万份 0.2%\n
# 132                                      100万份以上 1000元/笔\n50万份以下 0.4%\n50~100万份 0.2%\n

# %% [markdown]
# # Plotly application example
#
# https://www.jianshu.com/p/f8423ad5e06e

# %%
N = 100
random_x = np.linspace(0,1,N)
random_y0 = np.random.randn(N)+5
random_y1 = np.random.randn(N)
random_y2 = np.random.randn(N)-5

#Create traces
trace0 = go.Scatter(
    x = random_x,
    y = random_y0,
    mode = 'markers',
    name = 'markers'
)
trace1 = go.Scatter(
    x = random_x,
    y = random_y1,
    mode = 'lines+markers',
    name = 'lines+markers'
)
trace2 = go.Scatter(
    x = random_x,
    y = random_y2,
    mode = 'lines',
    name = 'lines'
)
data = [trace0,trace1,trace2]
# py.plot(data)

# %%
etf_513500
# Out:
# Scatter({
#     'mode': 'lines',
#     'name': 'lines',
#     'x': array(['2014-01-15', '2014-01-16', '2014-01-17', ..., '2019-12-18',
#                 '2019-12-19', '2019-12-20'], dtype=object),
#     'y': array([0.986, 0.991, 0.987, ..., 2.091, 2.084, 2.097])
# })
