# %%
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
from datetime import datetime
import tushare as ts
import pandas as pd
import numpy as np
import pymysql
import csv
import time
pd.set_option('max_colwidth',200)
# %matplotlib inline

# ts.set_token('2f31c3932ead9fcc3830879132cc3ec8df3566550f711889d4a30f67')

# %% [markdown]
# # 确定还未到期的合约代码ts_code

# %%
all_exchanges = ["DCE", "CFFEX", "CZCE" ,"SHFE", "INE"]
pro = ts.pro_api("2f31c3932ead9fcc3830879132cc3ec8df3566550f711889d4a30f67")

# %%
pro.fut_basic(exchange="DCE", fut_type='1', fields=
                             'ts_code,symbol,name,delist_date,last_ddate,trade_time_desc,per_unit,trade_unit,multiplier', 
                              last_ddate="Y", 
                              trade_time_desc="Y",
                              per_unit = "Y",
                              trade_unit = "Y",
                              multiplier = "Y"
                              )
# Out:
#          ts_code  symbol      name multiplier trade_unit  per_unit  \
# 0     FB1508.DCE  FB1508   纤维板1508       None          张     500.0
# 1      M1508.DCE   M1508    豆粕1508       None          吨      10.0
# 2      Y1508.DCE   Y1508    豆油1508       None          吨      10.0
# 3     BB1508.DCE  BB1508   胶合板1508       None          张     500.0
# 4     JM1508.DCE  JM1508    焦煤1508       None          吨      60.0
# 5      I1508.DCE   I1508   铁矿石1508       None          吨     100.0
# 6      A0407.DCE   A0407    豆一0407       None          吨      10.0
# 7      L1510.DCE   L1510    塑料1510       None          吨       5.0
# 8      J1510.DCE   J1510    焦炭1510       None          吨     100.0
# 9      I1510.DCE   I1510   铁矿石1510       None          吨     100.0
# 10     B0607.DCE   B0607    豆二0607       None          吨      10.0
# 11     M1511.DCE   M1511    豆粕1511       None          吨      10.0
# 12    BB1511.DCE  BB1511   胶合板1511       None          张     500.0
# 13     I1511.DCE   I1511   铁矿石1511       None          吨     100.0
# 14    PP1511.DCE  PP1511   聚丙烯1511       None          吨       5.0
# 15     P1511.DCE   P1511   棕榈油1511       None          吨      10.0
# 16    JD1511.DCE  JD1511    鸡蛋1511       None          吨       5.0
# 17     L0904.DCE   L0904    塑料0904       None          吨       5.0
# 18     M0609.DCE   M0609    豆粕0609       None          吨      10.0
# 19     L1512.DCE   L1512    塑料1512       None          吨       5.0
# 20     V1512.DCE   V1512   PVC1512       None          吨       5.0
# 21     I1512.DCE   I1512   铁矿石1512       None          吨     100.0
# 22    FB1512.DCE  FB1512   纤维板1512       None          张     500.0
# 23    CS1505.DCE  CS1505  玉米淀粉1505       None          吨      10.0
# 24    CS1503.DCE  CS1503  玉米淀粉1503       None          吨      10.0
# 25     C0605.DCE   C0605    玉米0605       None          吨      10.0
# 26     A0601.DCE   A0601    豆一0601       None          吨      10.0
# 27    CS1601.DCE  CS1601  玉米淀粉1601       None          吨      10.0
# 28     Y1601.DCE   Y1601    豆油1601       None          吨      10.0
# 29     V1601.DCE   V1601   PVC1601       None          吨       5.0
# ...          ...     ...       ...        ...        ...       ...
# 1660  JD1411.DCE  JD1411    鸡蛋1411       None          吨       5.0
# 1661   C1411.DCE   C1411    玉米1411       None          吨      10.0
# 1662  BB1406.DCE  BB1406   胶合板1406       None          张     500.0
上午9:00-11:30,下午13:30-15:00,下午21:00-23:00(夜盘)
# 1681    20150612   20150617  上午9:00-11:30,下午13:30-15:00,下午21:00-23:00(夜盘)
# 1682    20150612   20150617  上午9:00-11:30,下午13:30-15:00,下午21:00-23:00(夜盘)
# 1683    20150612   20150617  上午9:00-11:30,下午13:30-15:00,下午21:00-23:00(夜盘)
# 1684    20150612   20150617  上午9:00-11:30,下午13:30-15:00,下午21:00-23:00(夜盘)
# 1685    20150612   20150617  上午9:00-11:30,下午13:30-15:00,下午21:00-23:00(夜盘)
# 1686    20070914   20070921  上午9:00-11:30,下午13:30-15:00,下午21:00-23:00(夜盘)
# 1687    20160115   20160120  上午9:00-11:30,下午13:30-15:00,下午21:00-23:00(夜盘)
# 1688    20150714   20150717  上午9:00-11:30,下午13:30-15:00,下午21:00-23:00(夜盘)
# 1689    20150714   20150717       上午9:00-11:30，下午13:30-15:00，以及交易所规定的其他时间
#
# [1690 rows x 9 columns]

# %%
df = []
for exchange in all_exchanges:
    print("Processing Info of {}..".format(exchange))
    # fut_type = 1 代表普通合约
    # delist_date为最后交易日
    df_exchg = pro.fut_basic(exchange=exchange, fut_type='1', fields=
                             'ts_code,symbol,name,delist_date,last_ddate,trade_time_desc,per_unit,trade_unit,multiplier', 
                              last_ddate="Y", 
                              trade_time_desc="Y",
                              per_unit = "Y",
                              trade_unit = "Y",
                              multiplier = "Y"
                              )
    df_exchg["exchange"] = exchange
    df.append(df_exchg)
    print("Done.Wait for 5 secs...")
    # Okay we just have to wait for a little bit every time.
    time.sleep(5)
df = pd.concat(df)
# Out:
# Processing Info of DCE..
# Done.Wait for 5 secs...
# Processing Info of CFFEX..
# Done.Wait for 5 secs...
# Processing Info of CZCE..
# Done.Wait for 5 secs...
# Processing Info of SHFE..
# Done.Wait for 5 secs...
# Processing Info of INE..
# Done.Wait for 5 secs...

# %%
# 证明df里面是有金融期货的：
df[df['ts_code']=="IF1909.CFX"]

# %%
current_date = datetime.now().date().strftime('%Y%m%d')
trading_contracts = df[df['delist_date']>current_date]
trading_ts_code = list(trading_contracts['ts_code'].unique())

# %%
trading_ts_code[184]
# Out:
# 'RR2006.DCE'

# %% [markdown]
# # 下载数据

# %%
import os

def create_csv(path, head):
    with open(path, "w+", newline='') as file:
        csv_file = csv.writer(file)
#         head = ["name","sex"]
        csv_file.writerow(head)

def append_csv(path, data):
    with open(path, "a+", newline='') as file: # 处理csv读写时不同换行符  linux:\n    windows:\r\n    mac:\r
        csv_file = csv.writer(file)
#         data = [val0, val1, val2, val3, val4, val5, val6, val7, val8]
        csv_file.writerows(data)
    
def execute(path, head):
    if os.path.exists(path):
        append_csv(path, data)
    else:
        create_csv(path, head)

# def read_csv(path):
#     with open(path,"r+") as file:
#         csv_file = csv.reader(file)
#         for data in csv_file:
#             print("data:", data)
        
path = "example_20191006.csv"
head = ['ts_code','trade_date','pre_close','pre_settle','open','high','low','close','settle','change1','change2','vol','amount','oi','oi_chg']
# date_list = list(pd.date_range("2019-02-18 09:00:00", "2019-02-20 9:00:00").astype(str))

# %%
len(trading_ts_code)
# Out:
# 588

# %%
# 日线数据：

for ticker in trading_ts_code[184:]:
#     df_list = []
    try:
        df_ticker = ts.pro_bar(ts_code=ticker,asset="FT")
        df_ticker.sort_values("trade_date", inplace = True)
        df_ticker.reset_index(inplace =True)
    #     df_list.append(df_ticker)
    #     df_sample = pd.concat(df_list)
        del df_ticker['index']
        df_ticker.reset_index(inplace = True)
        del df_ticker['index']
        print("Data Processed for {}.".format(ticker))

        for i in range(len(df_ticker)):
            val0 = df_ticker.iloc[i, :15][0]
            val1 = df_ticker.iloc[i, :15][1]
            val2 = df_ticker.iloc[i, :15][2]
            val3 = df_ticker.iloc[i, :15][3]
            val4 = df_ticker.iloc[i, :15][4]
            val5 = df_ticker.iloc[i, :15][5]
            val6 = df_ticker.iloc[i, :15][6]
            val7 = df_ticker.iloc[i, :15][7]
            val8 = df_ticker.iloc[i, :15][8]
            val9 = df_ticker.iloc[i, :15][9]
            val10 = df_ticker.iloc[i, :15][10]
            val11 = df_ticker.iloc[i, :15][11]
            val12 = df_ticker.iloc[i, :15][12]
            val13 = df_ticker.iloc[i, :15][13]
            val14 = df_ticker.iloc[i, :15][14]


            data = [[val0, val1, val2, val3, val4, val5, val6, val7, val8, val9, val10, val11, val12, val13, val14]]

            if __name__ == "__main__":
                execute(path, head)
        current_index = trading_ts_code.index(ticker)+1
        total_num = len(trading_ts_code)
        print("{} out of {} Finished.".format(current_index, total_num))
        print("=======================================")
        print("Chill and relax for 13 seconds...")
        time.sleep(13)
        print("Let's get started again.")
    except:
        print("Error, Next")
        continue
    
print("Task Finished.")
# Out:
# Data Processed for RR2006.DCE.
# 185 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RR2007.DCE.
# 186 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RR2008.DCE.
# 187 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for EB2004.DCE.
# 188 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for EB2005.DCE.
# 189 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for EB2006.DCE.
# 190 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for EB2007.DCE.
# 191 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for EB2008.DCE.
# 192 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for EB2009.DCE.
# 193 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for IF1912.CFX.
# 194 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for IC1912.CFX.
# 195 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for IH1912.CFX.
# 196 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for T2003.CFX.
# 197 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TF2003.CFX.
# 198 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TS2003.CFX.
# 199 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for IC2003.CFX.
# 200 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for IH2003.CFX.
# 201 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for IF2003.CFX.
# 202 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TF2006.CFX.
# 203 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TS2006.CFX.
# 204 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for T2006.CFX.
# 205 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TF1912.CFX.
# 206 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for T1912.CFX.
# 207 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TS1912.CFX.
# 208 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for IF1911.CFX.
# 209 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for IC1911.CFX.
# 210 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for IH1911.CFX.
# 211 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for IH1910.CFX.
# 212 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for IF1910.CFX.
# 213 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for IC1910.CFX.
# 214 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SR1911.ZCE.
# 215 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RM1911.ZCE.
# 216 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for OI1911.ZCE.
# 217 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SF1911.ZCE.
# 218 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for MA1911.ZCE.
# 219 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for JR1911.ZCE.
# 220 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TA1911.ZCE.
# 221 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SM1911.ZCE.
# 222 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CY1911.ZCE.
# 223 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FG1911.ZCE.
# 224 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PM1911.ZCE.
# 225 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for LR1911.ZCE.
# 226 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AP1911.ZCE.
# 227 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CF1911.ZCE.
# 228 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WH1911.ZCE.
# 229 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RS1911.ZCE.
# 230 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RI1911.ZCE.
# 231 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TA1912.ZCE.
# 232 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for MA1912.ZCE.
# 233 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FG1912.ZCE.
# 234 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SF1912.ZCE.
# 235 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SM1912.ZCE.
# 236 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CY1912.ZCE.
# 237 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AP1912.ZCE.
# 238 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CF2001.ZCE.
# 239 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for JR2001.ZCE.
# 240 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for LR2001.ZCE.
# 241 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for OI2001.ZCE.
# 242 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PM2001.ZCE.
# 243 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RI2001.ZCE.
# 244 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SR2001.ZCE.
# 245 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WH2001.ZCE.
# 246 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RM2001.ZCE.
# 247 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AP2001.ZCE.
# 248 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FG2001.ZCE.
# 249 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SM2001.ZCE.
# 250 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for MA2001.ZCE.
# 251 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SF2001.ZCE.
# 252 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TA2001.ZCE.
# 253 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CY2001.ZCE.
# 254 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CY2002.ZCE.
# 255 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FG2002.ZCE.
# 256 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for MA2002.ZCE.
# 257 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SF2002.ZCE.
# 258 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SM2002.ZCE.
# 259 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TA2002.ZCE.
# 260 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PM2003.ZCE.
# 261 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WH2003.ZCE.
# 262 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CF2003.ZCE.
# 263 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SR2003.ZCE.
# 264 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TA2003.ZCE.
# 265 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for OI2003.ZCE.
# 266 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RI2003.ZCE.
# 267 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for MA2003.ZCE.
# 268 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FG2003.ZCE.
# 269 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RM2003.ZCE.
# 270 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for JR2003.ZCE.
# 271 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for LR2003.ZCE.
# 272 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SF2003.ZCE.
# 273 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SM2003.ZCE.
# 274 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CY2003.ZCE.
# 275 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AP2003.ZCE.
# 276 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZC2004.ZCE.
# 277 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CJ1912.ZCE.
# 278 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CJ2001.ZCE.
# 279 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CJ2003.ZCE.
# 280 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CJ2005.ZCE.
# 281 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZC2005.ZCE.
# 282 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZC2007.ZCE.
# 283 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FG2007.ZCE.
# 284 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CY2007.ZCE.
# 285 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TA2007.ZCE.
# 286 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SF2007.ZCE.
# 287 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for MA2007.ZCE.
# 288 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SM2007.ZCE.
# 289 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AP2007.ZCE.
# 290 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RM2007.ZCE.
# 291 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CF2007.ZCE.
# 292 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SR2007.ZCE.
# 293 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for OI2007.ZCE.
# 294 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WH2007.ZCE.
# 295 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PM2007.ZCE.
# 296 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for LR2007.ZCE.
# 297 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for JR2007.ZCE.
# 298 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RI2007.ZCE.
# 299 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RS2007.ZCE.
# 300 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CJ2007.ZCE.
# 301 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for UR2001.ZCE.
# 302 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for UR2002.ZCE.
# 303 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for UR2003.ZCE.
# 304 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for UR2004.ZCE.
# 305 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for UR2005.ZCE.
# 306 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for UR2006.ZCE.
# 307 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for UR2007.ZCE.
# 308 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZC2008.ZCE.
# 309 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for UR2008.ZCE.
# 310 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZC2009.ZCE.
# 311 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PM2009.ZCE.
# 312 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CY2009.ZCE.
# 313 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SM2009.ZCE.
# 314 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SF2009.ZCE.
# 315 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for JR2009.ZCE.
# 316 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RM2009.ZCE.
# 317 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RS2009.ZCE.
# 318 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FG2009.ZCE.
# 319 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RI2009.ZCE.
# 320 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for OI2009.ZCE.
# 321 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for MA2009.ZCE.
# 322 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TA2009.ZCE.
# 323 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CF2009.ZCE.
# 324 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WH2009.ZCE.
# 325 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SR2009.ZCE.
# 326 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CJ2009.ZCE.
# 327 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZC1910.ZCE.
# 328 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TA1910.ZCE.
# 329 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for MA1910.ZCE.
# 330 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FG1910.ZCE.
# 331 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SF1910.ZCE.
# 332 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SM1910.ZCE.
# 333 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CY1910.ZCE.
# 334 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AP1910.ZCE.
# 335 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZC1911.ZCE.
# 336 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZC1912.ZCE.
# 337 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZC2001.ZCE.
# 338 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TA2004.ZCE.
# 339 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for MA2004.ZCE.
# 340 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FG2004.ZCE.
# 341 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SF2004.ZCE.
# 342 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SM2004.ZCE.
# 343 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CY2004.ZCE.
# 344 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PM2005.ZCE.
# 345 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WH2005.ZCE.
# 346 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CF2005.ZCE.
# 347 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SR2005.ZCE.
# 348 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TA2005.ZCE.
# 349 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for OI2005.ZCE.
# 350 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RI2005.ZCE.
# 351 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for MA2005.ZCE.
# 352 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FG2005.ZCE.
# 353 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RM2005.ZCE.
# 354 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for JR2005.ZCE.
# 355 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for LR2005.ZCE.
# 356 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SF2005.ZCE.
# 357 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SM2005.ZCE.
# 358 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CY2005.ZCE.
# 359 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AP2005.ZCE.
# 360 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CY2006.ZCE.
# 361 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FG2006.ZCE.
# 362 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for MA2006.ZCE.
# 363 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SF2006.ZCE.
# 364 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SM2006.ZCE.
# 365 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TA2006.ZCE.
# 366 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for UR2009.ZCE.
# 367 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZC2002.ZCE.
# 368 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZC2003.ZCE.
# 369 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZC2006.ZCE.
# 370 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for TA2008.ZCE.
# 371 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SM2008.ZCE.
# 372 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for MA2008.ZCE.
# 373 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SF2008.ZCE.
# 374 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FG2008.ZCE.
# 375 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CY2008.ZCE.
# 376 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RM2008.ZCE.
# 377 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RS2008.ZCE.
# 378 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for BU1912.SHF.
# 379 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AL1910.SHF.
# 380 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CU1910.SHF.
# 381 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZN1910.SHF.
# 382 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PB1910.SHF.
# 383 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for NI1910.SHF.
# 384 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SN1910.SHF.
# 385 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RU1910.SHF.
# 386 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AG1910.SHF.
# 387 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RB1910.SHF.
# 388 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WR1910.SHF.
# 389 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for HC1910.SHF.
# 390 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FU1911.SHF.
# 391 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SP1910.SHF.
# 392 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SP1911.SHF.
# 393 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AG2002.SHF.
# 394 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AL2002.SHF.
# 395 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CU2002.SHF.
# 396 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for HC2002.SHF.
# 397 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for NI2002.SHF.
# 398 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PB2002.SHF.
# 399 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RB2002.SHF.
# 400 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SN2002.SHF.
# 401 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZN2002.SHF.
# 402 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FU2003.SHF.
# 403 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FU2005.SHF.
# 404 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FU2007.SHF.
# 405 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FU2008.SHF.
# 406 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SN2008.SHF.
# 407 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for NI2008.SHF.
# 408 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZN2008.SHF.
# 409 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AL2008.SHF.
# 410 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CU2008.SHF.
# 411 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for HC2008.SHF.
# 412 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RB2008.SHF.
# 413 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AG2008.SHF.
# 414 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PB2008.SHF.
# 415 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WR2008.SHF.
# 416 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SP2008.SHF.
# 417 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RU2008.SHF.
# 418 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for BU2002.SHF.
# 419 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AU1911.SHF.
# 420 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FU2009.SHF.
# 421 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AU2010.SHF.
# 422 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SP2009.SHF.
# 423 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WR2009.SHF.
# 424 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CU2009.SHF.
# 425 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RU2009.SHF.
# 426 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for HC2009.SHF.
# 427 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RB2009.SHF.
# 428 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AG2009.SHF.
# 429 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SN2009.SHF.
# 430 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for NI2009.SHF.
# 431 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PB2009.SHF.
# 432 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZN2009.SHF.
# 433 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AL2009.SHF.
# 434 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for BU2109.SHF.
# 435 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for BU2003.SHF.
# 436 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for BU2006.SHF.
# 437 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AU1910.SHF.
# 438 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for BU2009.SHF.
# 439 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CU1911.SHF.
# 440 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AL1911.SHF.
# 441 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZN1911.SHF.
# 442 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PB1911.SHF.
# 443 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for NI1911.SHF.
# 444 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SN1911.SHF.
# 445 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AU1912.SHF.
# 446 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AG1911.SHF.
# 447 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RB1911.SHF.
# 448 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WR1911.SHF.
# 449 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for HC1911.SHF.
# 450 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RU1911.SHF.
# 451 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FU1912.SHF.
# 452 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RU2001.SHF.
# 453 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AG2001.SHF.
# 454 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SN2001.SHF.
# 455 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for NI2001.SHF.
# 456 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PB2001.SHF.
# 457 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZN2001.SHF.
# 458 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AL2001.SHF.
# 459 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CU2001.SHF.
# 460 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for HC2001.SHF.
# 461 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RB2001.SHF.
# 462 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SP2001.SHF.
# 463 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AU2002.SHF.
# 464 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WR2001.SHF.
# 465 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SP2002.SHF.
# 466 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WR2002.SHF.
# 467 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AL2003.SHF.
# 468 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CU2003.SHF.
# 469 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZN2003.SHF.
# 470 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PB2003.SHF.
# 471 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for NI2003.SHF.
# 472 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SN2003.SHF.
# 473 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RU2003.SHF.
# 474 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for BU2103.SHF.
# 475 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AU2004.SHF.
# 476 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AG2003.SHF.
# 477 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RB2003.SHF.
# 478 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WR2003.SHF.
# 479 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for HC2003.SHF.
# 480 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SP2003.SHF.
# 481 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FU2004.SHF.
# 482 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AL2004.SHF.
# 483 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CU2004.SHF.
# 484 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZN2004.SHF.
# 485 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PB2004.SHF.
# 486 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for NI2004.SHF.
# 487 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SN2004.SHF.
# 488 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RU2004.SHF.
# 489 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for BU1910.SHF.
# 490 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AG2004.SHF.
# 491 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RB2004.SHF.
# 492 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WR2004.SHF.
# 493 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for HC2004.SHF.
# 494 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SP2004.SHF.
# 495 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AL2005.SHF.
# 496 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CU2005.SHF.
# 497 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZN2005.SHF.
# 498 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PB2005.SHF.
# 499 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for NI2005.SHF.
# 500 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SN2005.SHF.
# 501 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SP2005.SHF.
# 502 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for BU1911.SHF.
# 503 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RU2005.SHF.
# 504 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AU2006.SHF.
# 505 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AG2005.SHF.
# 506 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RB2005.SHF.
# 507 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WR2005.SHF.
# 508 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for HC2005.SHF.
# 509 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AG2006.SHF.
# 510 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AL2006.SHF.
# 511 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for BU2106.SHF.
# 512 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CU2006.SHF.
# 513 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for HC2006.SHF.
# 514 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for NI2006.SHF.
# 515 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PB2006.SHF.
# 516 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RB2006.SHF.
# 517 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RU2006.SHF.
# 518 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SN2006.SHF.
# 519 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SP2006.SHF.
# 520 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WR2006.SHF.
# 521 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZN2006.SHF.
# 522 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SS2002.SHF.
# 523 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SS2003.SHF.
# 524 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SS2004.SHF.
# 525 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SS2005.SHF.
# 526 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SS2006.SHF.
# 527 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SS2007.SHF.
# 528 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SS2008.SHF.
# 529 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SS2009.SHF.
# 530 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AL1912.SHF.
# 531 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CU1912.SHF.
# 532 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZN1912.SHF.
# 533 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PB1912.SHF.
# 534 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for NI1912.SHF.
# 535 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SN1912.SHF.
# 536 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for BU2012.SHF.
# 537 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AG1912.SHF.
# 538 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RB1912.SHF.
# 539 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WR1912.SHF.
# 540 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for HC1912.SHF.
# 541 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SP1912.SHF.
# 542 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FU2001.SHF.
# 543 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FU2002.SHF.
# 544 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FU2006.SHF.
# 545 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RB2007.SHF.
# 546 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for HC2007.SHF.
# 547 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for CU2007.SHF.
# 548 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AL2007.SHF.
# 549 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for ZN2007.SHF.
# 550 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for PB2007.SHF.
# 551 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for NI2007.SHF.
# 552 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SN2007.SHF.
# 553 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for WR2007.SHF.
# 554 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AG2007.SHF.
# 555 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SP2007.SHF.
# 556 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for RU2007.SHF.
# 557 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for AU2008.SHF.
# 558 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for BU2001.SHF.
# 559 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for FU2010.SHF.
# 560 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SC2006.INE.
# 561 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SC2009.INE.
# 562 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SC1911.INE.
# 563 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SC2002.INE.
# 564 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for NR2008.INE.
# 565 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SC1912.INE.
# 566 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SC2003.INE.
# 567 out of 588 Finished.
# =======================================
# Chill and relax for 13 seconds...
# Let's get started again.
# Data Processed for SC