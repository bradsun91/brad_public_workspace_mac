# %%
import pandas as pd, numpy as np
from datetime import datetime
pd.set_option('max_colwidth',200)
# import yfinance as yf
import time, urllib
import glob
import os

# %%
import tushare as ts
ts.set_token('8ef5ec61cdd848715c57c11d58dd71da1271f76b2420d2bac8aef123')

# %% [markdown]
# # Tushare Example

# %% [markdown]
# ## 取个股

# %%
pro = ts.pro_api()

#获取单一股票行情
df = pro.us_daily(ts_code='AAPL', start_date='20190101', end_date='20190904')

#获取某一日所有股票
df = pro.us_daily(trade_date='20190904')

# %%
df.sort_values('ts_code')

# %%
from datetime import datetime

# %%
# current list of S&P 500 from Wikipedia Api
def call_sp500_list(vpn):
    if vpn==1:
        table = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
        df = table[0]
        list_ = pd.concat([df.Symbol,df.loc[:, 'GICS Sector']], axis=1)
        pd.set_option('display.max_rows', None)
        list_.to_csv("most_recent_sp500_list.csv", index = False)
#         print(list_)
    elif vpn==0:
        list_ = pd.read_csv("most_recent_sp500_list.csv")
    return list_

# %%
list_.to_csv("most_recent_sp500_list.csv", index = False)
# Out:
#     Symbol             GICS Sector
# 0      MMM             Industrials
# 1      ABT             Health Care
# 2     ABBV             Health Care
# 3     ABMD             Health Care
# 4      ACN  Information Technology
# 5     ATVI  Communication Services
# 6     ADBE  Information Technology
# 7      AMD  Information Technology
# 8      AAP  Consumer Discretionary
# 9      AES               Utilities
# 10     AFL              Financials
# 11       A             Health Care
# 12     APD               Materials
# 13    AKAM  Information Technology
# 14     ALK             Industrials
# 15     ALB               Materials
# 16     ARE             Real Estate
# 17    ALXN             Health Care
# 18    ALGN             Health Care
# 19    ALLE             Industrials
# 20     LNT               Utilities
# 21     ALL              Financials
# 22   GOOGL  Communication Services
# 23    GOOG  Communication Services
# 24      MO        Consumer Staples
# 25    AMZN  Consumer Discretionary
# 26    AMCR               Materials
# 27     AEE               Utilities
# 28     AAL             Industrials
# 29     AEP               Utilities
# 30     AXP              Financials
# 31     AIG              Financials
# 32     AMT             Real Estate
# 33     AWK               Utilities
# 34     AMP              Financials
# 35     ABC             Health Care
# 36     AME             Industrials
# 37    AMGN             Health Care
# 38     APH  Information Technology
# 39     ADI  Information Technology
# 40    ANSS  Information Technology
# 41    ANTM             Health Care
# 42     AON              Financials
# 43     AOS             Industrials
# 44     APA                  Energy
# 45     AIV             Real Estate
# 46    AAPL  Information Technology
# 47    AMAT  Information Technology
# 48    APTV  Consumer Discretionary
# 49     ADM        Consumer Staples
# 50    ANET  Information Technology
# 51     AJG              Financials
# 52     AIZ              Financials
# 53       T  Communication Services
# 54     ATO               Utilities
# 55    ADSK  Information Technology
# 56     ADP  Information Technology
# 57     AZO  Consumer Discretionary
# 58     AVB             Real Estate
# 59     AVY               Materials
# 60     BKR                  Energy
# 61     BLL               Materials
# 62     BAC              Financials
# 63      BK              Financials
# 64     BAX             Health Care
# 65     BDX             Health Care
# 66   BRK.B              Financials
# 67     BBY  Consumer Discretionary
# 68     BIO             Health Care
# 69    BIIB             Health Care
# 70     BLK              Financials
# 71      BA             Industrials
# 72    BKNG  Consumer Discretionary
# 73     BWA  Consumer Discretionary
# 74     BXP             Real Estate
# 75     BSX             Health Care
# 76     BMY             Health Care
# 77    AVGO  Information Technology
# 78      BR  Information Technology
# 79    BF.B        Consumer Staples
# 80    CHRW             Industrials
# 81     COG                  Energy
# 82    CDNS  Information Technology
# 83     CPB        Consumer Staples
# 84     COF              Financials
# 85     CAH             Health Care
# 86     KMX  Consumer Discretionary
# 87     CCL  Consumer Discretionary
# 88    CARR             Industrials
# 89     CAT             Industrials
# 90    CBOE              Financials
# 91    CBRE             Real Estate
# 92     CDW  Information Technology
# 93      CE               Materials
# 94     CNC             Health Care
# 95     CNP               Utilities
# 96     CTL  Communication Services
# 97    CERN             Health Care
# 98      CF               Materials
# 99    SCHW              Financials
# 100   CHTR  Communication Services
# 101    CVX                  Energy
# 102    CMG  Consumer Discretionary
# 103     CB              Financials
# 104    CHD        Consumer Staples
# 105     CI             Health Care
# 106   CINF              Financials
# 107   CTAS             Industrials
# 108   CSCO  Information Technology
# 109      C              Financials
# 110    CFG              Financials
# 111   CTXS  Information Technology
# 112    CLX        Consumer Staples
# 113    CME              Financials
# 114    CMS               Utilities
# 115     KO        Consumer Staples
# 116   CTSH  Information Technology
# 117     CL        Consumer Staples
# 118  CMCSA  Communication Services
# 119    CMA              Financials
# 120    CAG        Consumer Staples
# 121    CXO                  Energy
# 122    COP                  Energy
# 123     ED               Utilities
# 124    STZ        Consumer Staples
# 125    COO             Health Care
# 126   CPRT             Industrials
# 127    GLW  Information Technology
# 128   CTVA               Materials
# 129   COST        Consumer Staples
# 130   COTY        Consumer Staples
# 131    CCI             Real Estate
# 132    CSX             Industrials
# 133    CMI             Industrials
# 134    CVS             Health Care
# 135    DHI  Consumer Discretionary
# 136    DHR             Health Care
# 137    DRI  Consumer Discretionary
# 138    DVA             Health Care
# 139     DE             Industrials
# 140    DAL             Industrials
# 141   XRAY             Health Care
# 142    DVN                  Energy
# 143   DXCM             Health Care
# 144   FANG                  Energy
# 145    DLR             Real Estate
# 146    DFS              Financials
# 147  DISCA  Communication Services
# 148  DISCK  Communication Services
# 149   DISH  Communication Services
# 150     DG  Consumer Discretionary
# 151   DLTR  Consumer Discretionary
# 152      D               Utilities
# 153    DPZ  Consumer Discretionary
# 154    DOV             Industrials
# 155    DOW               Materials
# 156    DTE               Utilities
# 157    DUK               Utilities
# 158    DRE             Real Estate
# 159     DD               Materials
# 160    DXC  Information Technology
# 161   ETFC              Financials
# 162    EMN               Materials
# 163    ETN             Industrials
# 164   EBAY  Consumer Discretionary
# 165    ECL               Materials
# 166    EIX               Utilities
# 167     EW             Health Care
# 168     EA  Communication Services
# 169    EMR             Industrials
# 170    ETR               Utilities
# 171    EOG                  Energy
# 172    EFX             Industrials
# 173   EQIX             Real Estate
# 174    EQR             Real Estate
# 175    ESS             Real Estate
# 176     EL        Consumer Staples
# 177   EVRG               Utilities
# 178     ES               Utilities
# 179     RE              Financials
# 180    EXC               Utilities
# 181   EXPE  Consumer Discretionary
# 182   EXPD             Industrials
# 183    EXR             Real Estate
# 184    XOM                  Energy
# 185   FFIV  Information Technology
# 186     FB  Communication Services
# 187   FAST             Industrials
# 188    FRT             Real Estate
# 189    FDX             Industrials
# 190    FIS  Information Technology
# 191   FITB              Financials
# 192     FE               Utilities
# 193    FRC              Financials
# 194   FISV  Information Technology
# 195    FLT  Information Technology
# 196   FLIR  Information Technology
# 197    FLS             Industrials
# 198    FMC               Materials
# 199      F  Consumer Discretionary
# 200   FTNT  Information Technology
# 201    FTV             Industrials
# 202   FBHS             Industrials
# 203   FOXA  Communication Services
# 204    FOX  Communication Services
# 205    BEN              Financials
# 206    FCX               Materials
# 207    GPS  Consumer Discretionary
# 208   GRMN  Consumer Discretionary
# 209     IT  Information Technology
# 210     GD             Industrials
# 211     GE             Industrials
# 212    GIS        Consumer Staples
# 213     GM  Consumer Discretionary
# 214    GPC  Consumer Discretionary
# 215   GILD             Health Care
# 216     GL              Financials
# 217    GPN  Information Technology
# 218     GS              Financials
# 219    GWW             Industrials
# 220    HRB  Consumer Discretionary
# 221    HAL                  Energy
# 222    HBI  Consumer Discretionary
# 223    HIG              Financials
# 224    HAS  Consumer Discretionary
# 225    HCA             Health Care
# 226   PEAK             Real Estate
# 227   HSIC             Health Care
# 228    HSY        Consumer Staples
# 229    HES                  Energy
# 230    HPE  Information Technology
# 231    HLT  Consumer Discretionary
# 232    HFC                  Energy
# 233   HOLX             Health Care
# 234     HD  Consumer Discretionary
# 235    HON             Industrials
# 236    HRL        Consumer Staples
# 237    HST             Real Estate
# 238    HWM             Industrials
# 239    HPQ  Information Technology
# 240    HUM             Health Care
# 241   HBAN              Financials
# 242    HII             Industrials
# 243    IEX             Industrials
# 244   IDXX             Health Care
# 245   INFO             Industrials
# 246    ITW             Industrials
# 247   ILMN             Health Care
# 248   INCY             Health Care
# 249     IR             Industrials
# 250   INTC  Information Technology
# 251    ICE              Financials
# 252    IBM  Information Technology
# 253     IP               Materials
# 254    IPG  Communication Services
# 255    IFF               Materials
# 256   INTU  Information Technology
# 257   ISRG             Health Care
# 258    IVZ              Financials
# 259   IPGP  Information Technology
# 260    IQV             Health Care
# 261    IRM             Real Estate
# 262   JKHY  Information Technology
# 263      J             Industrials
# 264   JBHT             Industrials
# 265    SJM        Consumer Staples
# 266    JNJ             Health Care
# 267    JCI             Industrials
# 268    JPM              Financials
# 269   JNPR  Information Technology
# 270    KSU             Industrials
# 271      K        Consumer Staples
# 272    KEY              Financials
# 273   KEYS  Information Technology
# 274    KMB        Consumer Staples
# 275    KIM             Real Estate
# 276    KMI                  Energy
# 277   KLAC  Information Technology
# 278    KSS  Consumer Discretionary
# 279    KHC        Consumer Staples
# 280     KR        Consumer Staples
# 281     LB  Consumer Discretionary
# 282    LHX             Industrials
# 283     LH             Health Care
# 284   LRCX  Information Technology
# 285     LW        Consumer Staples
# 286    LVS  Consumer Discretionary
# 287    LEG  Consumer Discretionary
# 288   LDOS  Information Technology
# 289    LEN  Consumer Discretionary
# 290    LLY             Health Care
# 291    LNC              Financials
# 292    LIN               Materials
# 293    LYV  Communication Services
# 294    LKQ  Consumer Discretionary
# 295    LMT             Industrials
# 296      L              Financials
# 297    LOW  Consumer Discretionary
# 298    LYB               Materials
# 299    MTB              Financials
# 300    MRO                  Energy
# 301    MPC                  Energy
# 302   MKTX              Financials
# 303    MAR  Consumer Discretionary
# 304    MMC              Financials
# 305    MLM               Materials
# 306    MAS             Industrials
# 307     MA  Information Technology
# 308    MKC        Consumer Staples
# 309   MXIM  Information Technology
# 310    MCD  Consumer Discretionary
# 311    MCK             Health Care
# 312    MDT             Health Care
# 313    MRK             Health Care
# 314    MET              Financials
# 315    MTD             Health Care
# 316    MGM  Consumer Discretionary
# 317   MCHP  Information Technology
# 318     MU  Information Technology
# 319   MSFT  Information Technology
# 320    MAA             Real Estate
# 321    MHK  Consumer Discretionary
# 322    TAP        Consumer Staples
# 323   MDLZ        Consumer Staples
# 324   MNST        Consumer Staples
# 325    MCO              Financials
# 326     MS              Financials
# 327    MOS               Materials
# 328    MSI  Information Technology
# 329   MSCI              Financials
# 330    MYL             Health Care
# 331   NDAQ              Financials
# 332    NOV                  Energy
# 333   NTAP  Information Technology
# 334   NFLX  Communication Services
# 335    NWL  Consumer Discretionary
# 336    NEM               Materials
# 337   NWSA  Communication Services
# 338    NWS  Communication Services
# 339    NEE               Utilities
# 340   NLSN             Industrials
# 341    NKE  Consumer Discretionary
# 342     NI               Utilities
# 343    NBL                  Energy
# 344    NSC             Industrials
# 345   NTRS              Financials
# 346    NOC             Industrials
# 347   NLOK  Information Technology
# 348   NCLH  Consumer Discretionary
# 349    NRG               Utilities
# 350    NUE               Materials
# 351   NVDA  Information Technology
# 352    NVR  Consumer Discretionary
# 353   ORLY  Consumer Discretionary
# 354    OXY                  Energy
# 355   ODFL             Industrials
# 356    OMC  Communication Services
# 357    OKE                  Energy
# 358   ORCL  Information Technology
# 359   OTIS             Industrials
# 360   PCAR             Industrials
# 361    PKG               Materials
# 362     PH             Industrials
# 363   PAYX  Information Technology
# 364   PAYC  Information Technology
# 365   PYPL  Information Technology
# 366    PNR             Industrials
# 367   PBCT              Financials
# 368    PEP        Consumer Staples
# 369    PKI             Health Care
# 370   PRGO             Health Care
# 371    PFE             Health Care
# 372     PM        Consumer Staples
# 373    PSX                  Energy
# 374    PNW               Utilities
# 375    PXD                  Energy
# 376    PNC              Financials
# 377    PPG               Materials
# 378    PPL               Utilities
# 379    PFG              Financials
# 380     PG        Consumer Staples
# 381    PGR              Financials
# 382    PLD             Real Estate
# 383    PRU              Financials
# 384    PEG               Utilities
# 385    PSA             Real Estate
# 386    PHM  Consumer Discretionary
# 387    PVH  Consumer Discretionary
# 388   QRVO  Information Technology
# 389    PWR             Industrials
# 390   QCOM  Information Technology
# 391    DGX             Health Care
# 392     RL  Consumer Discretionary
# 393    RJF              Financials
# 394    RTX             Industrials
# 395      O             Real Estate
# 396    REG             Real Estate
# 397   REGN             Health Care
# 398     RF              Financials
# 399    RSG             Industrials
# 400    RMD             Health Care
# 401    RHI             Industrials
# 402    ROK             Industrials
# 403    ROL             Industrials
# 404    ROP             Industrials
# 405   ROST  Consumer Discretionary
# 406    RCL  Consumer Discretionary
# 407   SPGI              Financials
# 408    CRM  Information Technology
# 409   SBAC             Real Estate
# 410    SLB                  Energy
# 411    STX  Information Technology
# 412    SEE               Materials
# 413    SRE               Utilities
# 414    NOW  Information Technology
# 415    SHW               Materials
# 416    SPG             Real Estate
# 417   SWKS  Information Technology
# 418    SLG             Real Estate
# 419    SNA             Industrials
# 420     SO               Utilities
# 421    LUV             Industrials
# 422    SWK             Industrials
# 423   SBUX  Consumer Discretionary
# 424    STT              Financials
# 425    STE             Health Care
# 426    SYK             Health Care
# 427   SIVB              Financials
# 428    SYF              Financials
# 429   SNPS  Information Technology
# 430    SYY        Consumer Staples
# 431   TMUS  Communication Services
# 432   TROW              Financials
# 433   TTWO  Communication Services
# 434    TPR  Consumer Discretionary
# 435    TGT  Consumer Discretionary
# 436    TEL  Information Technology
# 437    FTI                  Energy
# 438    TDY             Industrials
# 439    TFX             Health Care
# 440    TXN  Information Technology
# 441    TXT             Industrials
# 442    TMO             Health Care
# 443    TIF  Consumer Discretionary
# 444    TJX  Consumer Discretionary
# 445   TSCO  Consumer Discretionary
# 446     TT             Industrials
# 447    TDG             Industrials
# 448    TRV              Financials
# 449    TFC              Financials
# 450   TWTR  Communication Services
# 451    TYL  Information Technology
# 452    TSN        Consumer Staples
# 453    UDR             Real Estate
# 454   ULTA  Consumer Discretionary
# 455    USB              Financials
# 456    UAA  Consumer Discretionary
# 457     UA  Consumer Discretionary
# 458    UNP             Industrials
# 459    UAL             Industrials
# 460    UNH             Health Care
# 461    UPS             Industrials
# 462    URI             Industrials
# 463    UHS             Health Care
# 464    UNM              Financials
# 465    VFC  Consumer Discretionary
# 466    VLO                  Energy
# 467    VAR             Health Care
# 468    VTR             Real Estate
# 469   VRSN  Information Technology
# 470   VRSK             Industrials
# 471     VZ  Communication Services
# 472   VRTX             Health Care
# 473   VIAC  Communication Services
# 474      V  Information Technology
# 475    VNO             Real Estate
# 476    VMC               Materials
# 477    WRB              Financials
# 478    WAB             Industrials
# 479    WMT        Consumer Staples
# 480    WBA        Consumer Staples
# 481    DIS  Communication Services
# 482     WM             Industrials
# 483    WAT             Health Care
# 484    WEC               Utilities
# 485    WFC              Financials
# 486   WELL             Real Estate
# 487    WST             Health Care
# 488    WDC  Information Technology
# 489     WU  Information Technology
# 490    WRK               Materials
# 491     WY             Real Estate
# 492    WHR  Consumer Discretionary
# 493    WMB                  Energy
# 494   WLTW              Financials
# 495   WYNN  Consumer Discretionary
# 496    XEL               Utilities
# 497    XRX  Information Technology
# 498   XLNX  Information Technology
# 499    XYL             Industrials
# 500    YUM  Consumer Discretionary
# 501   ZBRA  Information Technology
# 502    ZBH             Health Care
# 503   ZION              Financials
# 504    ZTS             Health Care

# %%
def all_weather():
    all_weather_portfolio = ["VTI","TLT","IEF","GLD","DBC","SHY","IEI"]
    return all_weather_portfolio

def us_sectors_etf():
    us_sectors = ["IYM","IYZ","FCL","FCD","IYE","IYG","IYH","IYJ","IYR","IYW","IDU"]
    return us_sectors
    
def today_dt():
    today = str(datetime.now().date())
    return today

def download_yf_data(start, end, us_db_path, ticker_list):
    for ticker in ticker_list:
    #     print("testing")
        # Initial downloading:
        if not os.path.exists(us_db_path+ticker+".csv"):
            print("{} is new, start downloading now...".format(ticker))
            with eventlet.Timeout(60,False):
                try:
                    data = yf.download(ticker, start=start, end=end)
                    data.reset_index(inplace = True)
                    data['Ticker'] = ticker
                    data.to_csv(us_db_path+ticker+".csv", index = False)
                    print("{} data file created: {}".format(ticker, end))
                except Exception as e:
                    print(e)

    #         print("Timed Out: Download Failed!")
        # Check for updates:
        else:
            print("Already have data csv for {}".format(ticker))
            hist_data = pd.read_csv(us_db_path+ticker+".csv")
            try:
                hist_data_first_date = hist_data['Date'].values[0]
                if start >= hist_data_first_date:
                    hist_data_last_date = hist_data['Date'].values[-1]
                    if today > hist_data_last_date:
                        print("Needs to update, start updating new data for {} now...".format(ticker))
                        update_start = hist_data_last_date
                        update_end = today
                        with eventlet.Timeout(60,False):
                            try:
                                new_data = yf.download(ticker, start=update_start, end=update_end)
                                new_data.reset_index(inplace = True)
                                new_data['Ticker'] = ticker
                                new_data.to_csv(us_db_path+ticker+".csv", mode='a', header=False, index = False)
                                updated_duplicated_df = pd.read_csv(us_db_path+ticker+".csv")
                                updated_df = updated_duplicated_df.drop_duplicates("Date")
                                updated_df.sort_values("Date", inplace = True)
                                updated_df.to_csv(us_db_path+ticker+".csv", index = False)
                                print("New data updated till today for {}!".format(ticker))
                            except Exception as e:
                                print(e)
            #             print("Timed Out: Update Failed!")
                    else:
                        print("There's no new data to update for {}.".format(ticker))

                else:
                    print("Setup start date earlier than existing data's, trying to pull data from before...")
                    hist_data_last_date = hist_data['Date'].values[-1]
                    if today > hist_data_last_date:
                        print("Needs to update, start updating new data for {} now...".format(ticker))
                        update_start = start
                        update_end = today
                        with eventlet.Timeout(60,False):
                            try:
                                new_data = yf.download(ticker, start=update_start, end=update_end)
                                new_data.reset_index(inplace = True)
                                new_date = new_data['Date'].values[0]
                                print("New data's first pulled date is {}".format(new_date))
                                new_data['Ticker'] = ticker

                                new_data.to_csv(us_db_path+ticker+".csv", mode='a', header=False, index = False)
                                updated_duplicated_df = pd.read_csv(us_db_path+ticker+".csv")
                                updated_df = updated_duplicated_df.drop_duplicates("Date")
                                updated_df.sort_values("Date", inplace = True)
                                updated_df.to_csv(us_db_path+ticker+".csv", index = False)
                                print("New data updated till today for {}!".format(ticker))
                            except Exception as e:
                                print(e)
                    else:
                        print("There's no new data to update for {}.".format(ticker))
            except Exception as e:
                print(e)

    #     print("Data Download/Update for {} is Finished.".format(ticker))
        print("===============================================")
    print("【Updated Finished for today!】")


start = "2005-01-01"
today = today_dt()
end = today
us_db_path = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/US_database/"
mkt_etf = ["SPY","VXXB","QQQ","VXX","^VIX"]
other_tickers = ["YELP",'UBER','TSLA']
us_sectors = us_sectors_etf()
all_weather = all_weather()
data_path = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/quant_research/data_pipeline/"
tickers_df = pd.read_csv(data_path+"most_recent_sp500_tickers.csv")
sp500_tickers = list(tickers_df['sp500_tickers'])
ticker_list = sp500_tickers+all_weather+us_sectors+mkt_etf+other_tickers
# ticker_list = ['ROKU']

import eventlet
eventlet.monkey_patch()

download_yf_data(start, end, us_db_path, ticker_list)
