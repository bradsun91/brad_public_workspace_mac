# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="darkgrid")

# %%
# 1. backtest.py

#!/usr/bin/python
# -*- coding: utf-8 -*-


from __future__ import print_function

import datetime
import pprint
try:
    import Queue as queue
except ImportError:
    import queue
import time

print("Executing backtest.py")
class Backtest(object):
    """
    Enscapsulates the settings and components for carrying out
    an event-driven backtest.
    """

    def __init__(
        self, csv_dir, symbol_list, initial_capital,
        heartbeat, start_date, data_handler, 
        execution_handler, portfolio, strategy
    ):
        """
        Initialises the backtest.
        Parameters:
        csv_dir - The hard root to the CSV data directory.
        symbol_list - The list of symbol strings.
        intial_capital - The starting capital for the portfolio.
        heartbeat - Backtest "heartbeat" in seconds
        start_date - The start datetime of the strategy.
        data_handler - (Class) Handles the market data feed.
        execution_handler - (Class) Handles the orders/fills for trades.
        portfolio - (Class) Keeps track of portfolio current and prior positions.
        strategy - (Class) Generates signals based on market data.
        """
        self.csv_dir = csv_dir
        self.symbol_list = symbol_list
        self.initial_capital = initial_capital
        self.heartbeat = heartbeat
        self.start_date = start_date

        self.data_handler_cls = data_handler
        self.execution_handler_cls = execution_handler
        self.portfolio_cls = portfolio
        self.strategy_cls = strategy

        # Added by Brad on 20191006
        # self.plots_cls = plots

        self.events = queue.Queue()
        
        self.signals = 0
        self.orders = 0
        self.fills = 0
        self.num_strats = 1
       
        self._generate_trading_instances()

    def _generate_trading_instances(self):
        # function1: call0 classes of 1)DataHandler, 2)strategy, 3)portfolion, 4)ExecutionHandler
        """
        Generates the trading instance objects from 
        their class types.
        """
        print(
            "Creating DataHandler, Strategy, Portfolio and ExecutionHandler"
        )
        self.data_handler = self.data_handler_cls(self.events, self.csv_dir, self.symbol_list)
        self.strategy = self.strategy_cls(self.data_handler, self.events)
        self.portfolio = self.portfolio_cls(self.data_handler, self.events, self.start_date, 
                                            self.initial_capital)
        self.execution_handler = self.execution_handler_cls(self.events)

    def _run_backtest(self): # 
        # function1: update market bars
        # function2: identify the current event, including 1)market, 2)signal, 3)order, 4)
        """
        Executes the backtest.
        """
        print("Running Backtest...")
        i = 0
        while True:
            i += 1
            # print(i)

            # Update the market bars
            if self.data_handler.continue_backtest == True:
                self.data_handler.update_bars()
            else:
                break

            # Handle the events
            while True:
                try:
                    event = self.events.get(False)
                except queue.Empty:
                    break
                else:
                    if event is not None:
                        if event.type == 'MARKET':
                            self.strategy.calculate_signals(event)
                            self.portfolio.update_timeindex(event)

                        elif event.type == 'SIGNAL':
                            self.signals += 1                            
                            self.portfolio.update_signal(event)

                        elif event.type == 'ORDER':
                            self.orders += 1
                            self.execution_handler.execute_order(event)

                        elif event.type == 'FILL':
                            self.fills += 1
                            self.portfolio.update_fill(event)

            time.sleep(self.heartbeat)

	# OG version
    # def _output_performance(self):
    #     """
    #     Outputs the strategy performance from the backtest.
    #     """
    #     self.portfolio.create_equity_curve_dataframe()
        
    #     print("Creating summary stats...")
    #     stats = self.portfolio.output_summary_stats()
        
    #     print("Creating equity curve...")
    #     print(self.portfolio.equity_curve.tail(10))
    #     pprint.pprint(stats)

    #     print("Signals: %s" % self.signals)
    #     print("Orders: %s" % self.orders)
    #     print("Fills: %s" % self.fills)


    def _output_performance(self):
        """
        Outputs the strategy performance from the backtest.
        """
        self.portfolio.create_equity_curve_dataframe()
        
        print("Creating summary stats...")
        stats = self.portfolio.output_summary_stats()
        
        print("Creating equity curve...")
        print(self.portfolio.equity_curve.tail(10))
        pprint.pprint(stats)

        print("Signals: %s" % self.signals)
        print("Orders: %s" % self.orders)
        print("Fills: %s" % self.fills)

    def simulate_trading(self):
        # function 1: call 1)_run _backtest, 2__output_formance
        """
        Simulates the backtest and outputs portfolio performance.
        """
        self._run_backtest()
        self._output_performance()
# Out:
# Executing backtest.py

# %%
# 2. event.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

print("Executing event.py")
class Event(object):
    """
    Event is base class providing an interface for all subsequent 
    (inherited) events, that will trigger further events in the 
    trading infrastructure.   
    """
    pass


class MarketEvent(Event):
    """
    Handles the event of receiving a new market update with 
    corresponding bars.
    """

    def __init__(self):
        """
        Initialises the MarketEvent.
        """
        self.type = 'MARKET'


class SignalEvent(Event):
    """
    Handles the event of sending a Signal from a Strategy object.
    This is received by a Portfolio object and acted upon.
    """
    
    def __init__(self, strategy_id, symbol, datetime, signal_type, strength):
        """
        Initialises the SignalEvent.
        Parameters:
        strategy_id - The unique ID of the strategy sending the signal.
        symbol - The ticker symbol, e.g. 'GOOG'.
        datetime - The timestamp at which the signal was generated.
        signal_type - 'LONG' or 'SHORT'.
        strength - An adjustment factor "suggestion" used to scale 
            quantity at the portfolio level. Useful for pairs strategies.
        """
        self.strategy_id = strategy_id
        self.type = 'SIGNAL'
        self.symbol = symbol
        self.datetime = datetime
        self.signal_type = signal_type
        self.strength = strength


class OrderEvent(Event):
    """
    Handles the event of sending an Order to an execution system.
    The order contains a symbol (e.g. GOOG), a type (market or limit),
    quantity and a direction.
    """

    def __init__(self, symbol, order_type, quantity, direction):
        """
        Initialises the order type, setting whether it is
        a Market order ('MKT') or Limit order ('LMT'), has
        a quantity (integral) and its direction ('BUY' or
        'SELL').
        TODO: Must handle error checking here to obtain 
        rational orders (i.e. no negative quantities etc).
        Parameters:
        symbol - The instrument to trade.
        order_type - 'MKT' or 'LMT' for Market or Limit.
        quantity - Non-negative integer for quantity.
        direction - 'BUY' or 'SELL' for long or short.
        """
        self.type = 'ORDER'
        self.symbol = symbol
        self.order_type = order_type
        self.quantity = quantity
        self.direction = direction

    def print_order(self):
        """
        Outputs the values within the Order.
        """
        print(
            "Order: Symbol=%s, Type=%s, Quantity=%s, Direction=%s" % 
            (self.symbol, self.order_type, self.quantity, self.direction)
        )


class FillEvent(Event):
    """
    Encapsulates the notion of a Filled Order, as returned
    from a brokerage. Stores the quantity of an instrument
    actually filled and at what price. In addition, stores
    the commission of the trade from the brokerage.
    
    TODO: Currently does not support filling positions at
    different prices. This will be simulated by averaging
    the cost.
    """

    def __init__(self, timeindex, symbol, exchange, quantity, 
                 direction, fill_cost, commission=None):
        """
        Initialises the FillEvent object. Sets the symbol, exchange,
        quantity, direction, cost of fill and an optional 
        commission.
        If commission is not provided, the Fill object will
        calculate it based on the trade size and Interactive
        Brokers fees.
        Parameters:
        timeindex - The bar-resolution when the order was filled.
        symbol - The instrument which was filled.
        exchange - The exchange where the order was filled.
        quantity - The filled quantity.
        direction - The direction of fill ('BUY' or 'SELL')
        fill_cost - The holdings value in dollars.
        commission - An optional commission sent from IB.
        """
        self.type = 'FILL'
        self.timeindex = timeindex
        self.symbol = symbol
        self.exchange = exchange
        self.quantity = quantity
        self.direction = direction
        self.fill_cost = fill_cost

        # Calculate commission
        if commission is None:
            self.commission = self.calculate_ib_commission()
        else:
            self.commission = commission

    def calculate_ib_commission(self):
        """
        Calculates the fees of trading based on an Interactive
        Brokers fee structure for API, in USD.
        This does not include exchange or ECN fees.
        Based on "US API Directed Orders":
        https://www.interactivebrokers.com/en/index.php?f=commission&p=stocks2
        """
#         full_cost = 1.3
#         if self.quantity <= 500:
#             full_cost = max(1.3, 0.013 * self.quantity)
#         else: # Greater than 500
#             full_cost = max(1.3, 0.008 * self.quantity)
        full_cost = 0
        return full_cost
# Out:
# Executing event.py

# %%
# 3. data.py
#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

from abc import ABCMeta, abstractmethod
import datetime
import os, os.path

import numpy as np
import pandas as pd

# from event import MarketEvent

print("Executing data.py")
class DataHandler(object):
    """
    DataHandler is an abstract base class providing an interface for
    all subsequent (inherited) data handlers (both live and historic).
    The goal of a (derived) DataHandler object is to output a generated
    set of bars (OHLCVI) for each symbol requested. 
    This will replicate how a live strategy would function as current
    market data would be sent "down the pipe". Thus a historic and live
    system will be treated identically by the rest of the backtesting suite.
    """

    __metaclass__ = ABCMeta

    @abstractmethod
    def get_latest_bar(self, symbol):
        """
        Returns the last bar updated.
        """
        raise NotImplementedError("Should implement get_latest_bar()")

    @abstractmethod
    def get_latest_bars(self, symbol, N=1):
        """
        Returns the last N bars updated.
        """
        raise NotImplementedError("Should implement get_latest_bars()")

    @abstractmethod
    def get_latest_bar_datetime(self, symbol):
        """
        Returns a Python datetime object for the last bar.
        """
        raise NotImplementedError("Should implement get_latest_bar_datetime()")

    @abstractmethod
    def get_latest_bar_value(self, symbol, val_type):
        """
        Returns one of the Open, High, Low, Close, Volume or OI
        from the last bar.
        """
        raise NotImplementedError("Should implement get_latest_bar_value()")

    @abstractmethod
    def get_latest_bars_values(self, symbol, val_type, N=1):
        """
        Returns the last N bar values from the 
        latest_symbol list, or N-k if less available.
        """
        raise NotImplementedError("Should implement get_latest_bars_values()")

    @abstractmethod
    def update_bars(self):
        """
        Pushes the latest bars to the bars_queue for each symbol
        in a tuple OHLCVI format: (datetime, open, high, low, 
        close, volume, open interest).
        """
        raise NotImplementedError("Should implement update_bars()")


class HistoricCSVDataHandler(DataHandler):
    """
    HistoricCSVDataHandler is designed to read CSV files for
    each requested symbol from disk and provide an interface
    to obtain the "latest" bar in a manner identical to a live
    trading interface. 
    """

    def __init__(self, events, csv_dir, symbol_list):
        """
        Initialises the historic data handler by requesting
        the location of the CSV files and a list of symbols.
        It will be assumed that all files are of the form
        'symbol.csv', where symbol is a string in the list.
        Parameters:
        events - The Event Queue.
        csv_dir - Absolute directory path to the CSV files.
        symbol_list - A list of symbol strings.
        """
        self.events = events
        self.csv_dir = csv_dir
        self.symbol_list = symbol_list

        self.symbol_data = {}
        self.latest_symbol_data = {}
        self.continue_backtest = True       
        self.bar_index = 0

        self._open_convert_csv_files()

    def _open_convert_csv_files(self):
        """
        Opens the CSV files from the data directory, converting
        them into pandas DataFrames within a symbol dictionary.
        For this handler it will be assumed that the data is
        taken from Yahoo. Thus its format will be respected.
        """
        comb_index = None

        for s in self.symbol_list:
            # Load the CSV file with no header information, indexed on date
            self.symbol_data[s] = pd.io.parsers.read_csv(
                os.path.join(self.csv_dir, '%s.csv' % s),
                header=0, index_col=0, parse_dates=True,
                names=['Date', 'Open', 'High','Low', 'Close', 'Adj Close', 'Volume','Ticker'
                ]
            )
            # ).sort_values('date')

            # Combine the index to pad forward values
            if comb_index is None:
                comb_index = self.symbol_data[s].index
            else:
                comb_index.union(self.symbol_data[s].index)

            # Set the latest symbol_data to None
            self.latest_symbol_data[s] = []

        # Reindex the dataframes
        for s in self.symbol_list:
            self.symbol_data[s] = self.symbol_data[s].\
                reindex(index=comb_index, method='pad').iterrows()

    def _get_new_bar(self, symbol):
        """
        Returns the latest bar from the data feed.
        """
        for b in self.symbol_data[symbol]:
            yield b

    def get_latest_bar(self, symbol):
        """
        Returns the last bar from the latest_symbol list.
        """
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return bars_list[-1]

    def get_latest_bars(self, symbol, N=1):
        """
        Returns the last N bars from the latest_symbol list,
        or N-k if less available.
        """
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return bars_list[-N:]

    def get_latest_bar_datetime(self, symbol):
        """
        Returns a Python datetime object for the last bar.
        """
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return bars_list[-1][0]

    def get_latest_bar_value(self, symbol, val_type):
        """
        Returns one of the Open, High, Low, Close, Volume or OI
        values from the pandas Bar series object.
        """
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return getattr(bars_list[-1][1], val_type)

    def get_latest_bars_values(self, symbol, val_type, N=1):
        """
        Returns the last N bar values from the 
        latest_symbol list, or N-k if less available.
        """
        try:
            bars_list = self.get_latest_bars(symbol, N)
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return np.array([getattr(b[1], val_type) for b in bars_list])

    def update_bars(self):
        """
        Pushes the latest bar to the latest_symbol_data structure
        for all symbols in the symbol list.
        """
        for s in self.symbol_list:
            try:
                bar = next(self._get_new_bar(s))
            except StopIteration:
                self.continue_backtest = False
            else:
                if bar is not None:
                    self.latest_symbol_data[s].append(bar)
        self.events.put(MarketEvent())
# Out:
# Executing data.py

# %%
# 4. execution.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

from abc import ABCMeta, abstractmethod
import datetime
try:
    import Queue as queue
except ImportError:
    import queue

# from event import FillEvent, OrderEvent

print("Executing execution.py")
class ExecutionHandler(object):
    """
    The ExecutionHandler abstract class handles the interaction
    between a set of order objects generated by a Portfolio and
    the ultimate set of Fill objects that actually occur in the
    market. 
    The handlers can be used to subclass simulated brokerages
    or live brokerages, with identical interfaces. This allows
    strategies to be backtested in a very similar manner to the
    live trading engine.
    """

    __metaclass__ = ABCMeta

    @abstractmethod
    def execute_order(self, event):
        """
        Takes an Order event and executes it, producing
        a Fill event that gets placed onto the Events queue.
        Parameters:
        event - Contains an Event object with order information.
        """
        raise NotImplementedError("Should implement execute_order()")


class SimulatedExecutionHandler(ExecutionHandler):
    """
    The simulated execution handler simply converts all order
    objects into their equivalent fill objects automatically
    without latency, slippage or fill-ratio issues.
    This allows a straightforward "first go" test of any strategy,
    before implementation with a more sophisticated execution
    handler.
    """
    
    def __init__(self, events):
        """
        Initialises the handler, setting the event queues
        up internally.
        Parameters:
        events - The Queue of Event objects.
        """
        self.events = events

    def execute_order(self, event):
        """
        Simply converts Order objects into Fill objects naively,
        i.e. without any latency, slippage or fill ratio problems.
        Parameters:
        event - Contains an Event object with order information.
        """
        if event.type == 'ORDER':
            fill_event = FillEvent(
                datetime.datetime.utcnow(), event.symbol,
                'ARCA', event.quantity, event.direction, None
            )
            self.events.put(fill_event)
# Out:
# Executing execution.py

# %%
# 5. strategy.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

from abc import ABCMeta, abstractmethod
import datetime
try:
    import Queue as queue
except ImportError:
    import queue

import numpy as np
import pandas as pd

# from event import SignalEvent

print("Executing strategy.py")
class Strategy(object):
    """
    Strategy is an abstract base class providing an interface for
    all subsequent (inherited) strategy handling objects.
    The goal of a (derived) Strategy object is to generate Signal
    objects for particular symbols based on the inputs of Bars 
    (OHLCV) generated by a DataHandler object.
    This is designed to work both with historic and live data as
    the Strategy object is agnostic to where the data came from,
    since it obtains the bar tuples from a queue object.
    """

    __metaclass__ = ABCMeta

    @abstractmethod
    def calculate_signals(self):
        """
        Provides the mechanisms to calculate the list of signals.
        """
        raise NotImplementedError("Should implement calculate_signals()")
# Out:
# Executing strategy.py

# %%
# 6. portfolio.py

#!/usr/bin/python
# -*- coding: utf-8 -*-


from __future__ import print_function

import datetime
from math import floor
try:
    import Queue as queue
except ImportError:
    import queue

import numpy as np
import pandas as pd

# from event import FillEvent, OrderEvent
# from performance import create_sharpe_ratio, create_drawdowns


print("Executing portfolio.py")
class Portfolio(object):
    """
    The Portfolio class handles the positions and market
    value of all instruments at a resolution of a "bar",
    i.e. secondly, minutely, 5-min, 30-min, 60 min or EOD.
    The positions DataFrame stores a time-index of the 
    quantity of positions held. 
    The holdings DataFrame stores the cash and total market
    holdings value of each symbol for a particular 
    time-index, as well as the percentage change in 
    portfolio total across bars.
    """

    def __init__(self, bars, events, start_date, initial_capital=100000.0):
        """
        Initialises the portfolio with bars and an event queue. 
        Also includes a starting datetime index and initial capital 
        (USD unless otherwise stated).
        Parameters:
        bars - The DataHandler object with current market data.
        events - The Event Queue object.
        start_date - The start date (bar) of the portfolio.
        initial_capital - The starting capital in USD.
        """
        self.bars = bars
        self.events = events
        self.symbol_list = self.bars.symbol_list
        self.start_date = start_date
        self.initial_capital = initial_capital
        
        self.all_positions = self.construct_all_positions()
        self.current_positions = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        self.all_holdings = self.construct_all_holdings()
        self.current_holdings = self.construct_current_holdings()
        
        # Brad's add on 20191117
#         fill.direction = "None"
#         self.fill_cost = self.update_holdings_from_fill(self, fill)
        
        # =============brad's added on 20191117:===============
        self.len_symbol_list = len(symbol_list)
        print("Number of assets in the portfolio： ",self.len_symbol_list)
        print("Position Value for each asset: ", self.initial_capital/self.len_symbol_list)

        
    def construct_all_positions(self):
        """
        Constructs the positions list using the start_date
        to determine when the time index will begin.
        """
        d = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        d['datetime'] = self.start_date
        return [d]

    def construct_all_holdings(self):
        """
        Constructs the holdings list using the start_date
        to determine when the time index will begin.
        """
        d = dict( (k,v) for k, v in [(s, 0.0) for s in self.symbol_list] )
        d['datetime'] = self.start_date
        d['cash'] = self.initial_capital
        d['commission'] = 0.0
        d['total'] = self.initial_capital
        return [d]

    def construct_current_holdings(self):
        """
        This constructs the dictionary which will hold the instantaneous
        value of the portfolio across all symbols.
        """
        d = dict( (k,v) for k, v in [(s, 0.0) for s in self.symbol_list] )
        d['cash'] = self.initial_capital
        d['commission'] = 0.0
        d['total'] = self.initial_capital
        return d

    def update_timeindex(self, event):
        """
        Adds a new record to the positions matrix for the current 
        market data bar. This reflects the PREVIOUS bar, i.e. all
        current market data at this stage is known (OHLCV).
        Makes use of a MarketEvent from the events queue.
        """
        latest_datetime = self.bars.get_latest_bar_datetime(self.symbol_list[0])

        # Update positions
        # ================
        dp = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        dp['datetime'] = latest_datetime

        for s in self.symbol_list:
            dp[s] = self.current_positions[s]

        # Append the current positions
        self.all_positions.append(dp)

        # Update holdings
        # ===============
        dh = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        dh['datetime'] = latest_datetime
        dh['cash'] = self.current_holdings['cash']
        dh['commission'] = self.current_holdings['commission']
        dh['total'] = self.current_holdings['cash']

        for s in self.symbol_list:
            # Approximation to the real value
            market_value = self.current_positions[s] * \
                self.bars.get_latest_bar_value(s, "Adj Close")
            dh[s] = market_value
            dh['total'] += market_value

        # Append the current holdings
        self.all_holdings.append(dh)

    # ======================
    # FILL/POSITION HANDLING
    # ======================

    def update_positions_from_fill(self, fill):
        """
        Takes a Fill object and updates the position matrix to
        reflect the new position.
        Parameters:
        fill - The Fill object to update the positions with.
        """
        # Check whether the fill is a buy or sell
        fill_dir = 0
        if fill.direction == 'BUY':
            fill_dir = 1
        if fill.direction == 'SELL':
            fill_dir = -1

        # Update positions list with new quantities
        self.current_positions[fill.symbol] += fill_dir*fill.quantity

    def update_holdings_from_fill(self, fill):
        """
        Takes a Fill object and updates the holdings matrix to
        reflect the holdings value.
        Parameters:
        fill - The Fill object to update the holdings with.
        """
        # Check whether the fill is a buy or sell
        fill_dir = 0
        if fill.direction == 'BUY':
            fill_dir = 1
        if fill.direction == 'SELL':
            fill_dir = -1

        # Update holdings list with new quantities
        fill_cost = self.bars.get_latest_bar_value(
            fill.symbol, "Adj Close"
        )
        cost = fill_dir * fill_cost * fill.quantity
        self.current_holdings[fill.symbol] += cost
        self.current_holdings['commission'] += fill.commission
        self.current_holdings['cash'] -= (cost + fill.commission)
        self.current_holdings['total'] -= (cost + fill.commission)
        # Brad's add on 20191117
        return fill_cost

    def update_fill(self, event):
        """
        Updates the portfolio current positions and holdings 
        from a FillEvent.
        """
        if event.type == 'FILL':
            self.update_positions_from_fill(event)
            self.update_holdings_from_fill(event)

    def generate_naive_order(self, signal):
        """
        Simply files an Order object as a constant quantity
        sizing of the signal object, without risk management or
        position sizing considerations.
        Parameters:
        signal - The tuple containing Signal information.
        """
        order = None

        symbol = signal.symbol
        direction = signal.signal_type
        strength = signal.strength
        # ================ Brad's change on 20191117 =================
#         mkt_quantity = 100
        symbol_value = self.bars.get_latest_bar_value(symbol, "Adj Close")
        mkt_quantity = int(self.initial_capital/self.len_symbol_list/symbol_value)
        print("Asset: ", symbol, "symbol_value: ",symbol_value,  "mkt_quantity: ", mkt_quantity)
        cur_quantity = self.current_positions[symbol]
        order_type = 'MKT'

        if direction == 'LONG' and cur_quantity == 0:
            order = OrderEvent(symbol, order_type, mkt_quantity, 'BUY')
        if direction == 'SHORT' and cur_quantity == 0:
            order = OrderEvent(symbol, order_type, mkt_quantity, 'SELL')   
    
        if direction == 'EXIT' and cur_quantity > 0:
            order = OrderEvent(symbol, order_type, abs(cur_quantity), 'SELL')
        if direction == 'EXIT' and cur_quantity < 0:
            order = OrderEvent(symbol, order_type, abs(cur_quantity), 'BUY')
        return order

    def update_signal(self, event):
        """
        Acts on a SignalEvent to generate new orders 
        based on the portfolio logic.
        """
        if event.type == 'SIGNAL':
            order_event = self.generate_naive_order(event)
            self.events.put(order_event)

    # ========================
    # POST-BACKTEST STATISTICS
    # ========================

    def create_equity_curve_dataframe(self):
        """
        Creates a pandas DataFrame from the all_holdings
        list of dictionaries.
        """
        curve = pd.DataFrame(self.all_holdings)
        curve.set_index('datetime', inplace=True)
        curve['returns'] = curve['total'].pct_change()
        curve['equity_curve'] = (1.0+curve['returns']).cumprod()
        self.equity_curve = curve

    def output_summary_stats(self):
        """
        Creates a list of summary statistics for the portfolio.
        """
        total_return = self.equity_curve['equity_curve'][-1]
        returns = self.equity_curve['returns']
        pnl = self.equity_curve['equity_curve']

        sharpe_ratio = create_sharpe_ratio(returns, periods=252*60*6.5)
        drawdown, max_dd, dd_duration = create_drawdowns(pnl)
        self.equity_curve['drawdown'] = drawdown

        stats = [("Total Return", "%0.2f%%" % ((total_return - 1.0) * 100.0)),
                 ("Sharpe Ratio", "%0.2f" % sharpe_ratio),
                 ("Max Drawdown", "%0.2f%%" % (max_dd * 100.0)),
                 ("Drawdown Duration", "%d" % dd_duration)]

        self.equity_curve.to_csv('equity.csv')
        return stats

    # Added by Brad on 20191007:
    def draw_summary_plots(self):
        print("Testing draw_summary_plots")
        self.equity_curve['equity_curve'].plot(figsize = (18,6))
# Out:
# Executing portfolio.py

# %%
# 7. performance.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

import numpy as np
import pandas as pd

print("Executing performance.py")
def create_sharpe_ratio(returns, periods=252):
    """
    Create the Sharpe ratio for the strategy, based on a 
    benchmark of zero (i.e. no risk-free rate information).
    Parameters:
    returns - A pandas Series representing period percentage returns.
    periods - Daily (252), Hourly (252*6.5), Minutely(252*6.5*60) etc.
    """
    return np.sqrt(periods) * (np.mean(returns)) / np.std(returns)


def create_drawdowns(pnl):
    """
    Calculate the largest peak-to-trough drawdown of the PnL curve
    as well as the duration of the drawdown. Requires that the 
    pnl_returns is a pandas Series.
    Parameters:
    pnl - A pandas Series representing period percentage returns.
    Returns:
    drawdown, duration - Highest peak-to-trough drawdown and duration.
    """

    # Calculate the cumulative returns curve 
    # and set up the High Water Mark
    hwm = [0]

    # Create the drawdown and duration series
    idx = pnl.index
    drawdown = pd.Series(index = idx)
    duration = pd.Series(index = idx)

    # Loop over the index range
    for t in range(1, len(idx)):
        hwm.append(max(hwm[t-1], pnl[t]))
        drawdown[t]= (hwm[t]-pnl[t])
        duration[t]= (0 if drawdown[t] == 0 else duration[t-1]+1)
    return drawdown, drawdown.max(), duration.max()
# Out:
# Executing performance.py

# %%
# mac.py
print("Executing mac.py")
class MovingAverageCrossStrategy(Strategy):
    """
    Carries out a basic Moving Average Crossover strategy with a
    short/long simple weighted moving average. Default short/long
    windows are 12/26 periods respectively.
    """

    def __init__(self, bars, events, short_window=12, long_window=26):
        """
        Initialises the buy and hold strategy.

        Parameters:
        bars - The DataHandler object that provides bar information
        events - The Event Queue object.
        short_window - The short moving average lookback.
        long_window - The long moving average lookback.
        """
        self.bars = bars
        self.symbol_list = self.bars.symbol_list
        self.events = events
        self.short_window = short_window
        self.long_window = long_window

        # Set to True if a symbol is in the market
        self.bought = self._calculate_initial_bought()

    def _calculate_initial_bought(self):
        """
        Adds keys to the bought dictionary for all symbols
        and sets them to 'OUT'.
        """
        bought = {}
        for s in self.symbol_list:
            bought[s] = 'OUT'
        return bought

    def calculate_signals(self, event):
        """
        Generates a new set of signals based on the MAC
        SMA with the short window crossing the long window
        meaning a long entry and vice versa for a short entry.    

        Parameters
        event - A MarketEvent object. 
        """
        if event.type == 'MARKET':
            for symbol in self.symbol_list:
                bars = self.bars.get_latest_bars_values(symbol, "Adj Close", N=self.long_window)

                if bars is not None and bars != []:
                    short_sma = np.mean(bars[-self.short_window:])
                    long_sma = np.mean(bars[-self.long_window:])

                    dt = self.bars.get_latest_bar_datetime(symbol)
                    sig_dir = ""
                    strength = 1.0
                    strategy_id = 1

                    if short_sma > long_sma and self.bought[symbol] == "OUT":
                        sig_dir = 'LONG'
                        signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
                        self.events.put(signal)
                        self.bought[symbol] = 'LONG'

                    elif short_sma < long_sma and self.bought[symbol] == "LONG":
                        sig_dir = 'EXIT'
                        signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
                        self.events.put(signal)
                        self.bought[symbol] = 'OUT'


if __name__ == "__main__":
    # csv_dir = REPLACE_WITH_YOUR_CSV_DIR_HERE
    csv_dir = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/US_database"
    symbol_list = ["IYM","IYZ","FCL","FCD","IYE","IYG","IYH","IYJ","IYR","IYW","IDU"]
#     symbol_list = ['TSLA','AMZN','AAPL']
#     symbol_list = ['SPY']
#     symbol_list = ["VTI","TLT","IEF","GLD","DBC"]
#     symbol_list = ['jd000d']
    initial_capital = 100000.0
    start_date = datetime.datetime(2010,4,1,0,0,0)
    start_date_str = str(start_date)
    heartbeat = 0.0

    backtest = Backtest(csv_dir, 
                        symbol_list, 
                        initial_capital, 
                        heartbeat,
                        start_date,
                        HistoricCSVDataHandler, 
                        SimulatedExecutionHandler, 
                        Portfolio, 
                        MovingAverageCrossStrategy)
    
    backtest.simulate_trading()
# Out:
# Executing mac.py
# Creating DataHandler, Strategy, Portfolio and ExecutionHandler
# Number of assets in the portfolio：  11
# Position Value for each asset:  9090.90909090909
# Running Backtest...
# Asset:  IYM symbol_value:  52.34482955932617 mkt_quantity:  173
# Asset:  FCL symbol_value:  41.70000076293945 mkt_quantity:  218
# Asset:  IYE symbol_value:  27.641231536865234 mkt_quantity:  328
# Asset:  IYG symbol_value:  49.81139373779297 mkt_quantity:  182
# Asset:  IYH symbol_value:  57.90069580078125 mkt_quantity:  157
# Asset:  IYJ symbol_value:  47.46982955932617 mkt_quantity:  191
# Asset:  IYR symbol_value:  32.018905639648445 mkt_quantity:  283
# Asset:  IYW symbol_value:  52.42425537109375 mkt_quantity:  173
# Asset:  IDU symbol_value:  54.2877082824707 mkt_quantity:  167
# Asset:  IYW symbol_value:  51.90393829345703 mkt_quantity:  175
# Asset:  IDU symbol_value:  53.53491592407226 mkt_quantity:  169
# Asset:  IYR symbol_value:  30.39507102966309 mkt_quantity:  299
# Asset:  IYM symbol_value:  49.26276016235352 mkt_quantity:  184
# Asset:  IYE symbol_value:  26.52359962463379 mkt_quantity:  342
# Asset:  IYG symbol_value:  47.35124206542969 mkt_quantity:  191
# Asset:  IYJ symbol_value:  45.10802459716797 mkt_quantity:  201
# Asset:
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:52: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
# /Users/miaoyuesun/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:52: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#  IYH symbol_value:  54.67821884155274 mkt_quantity:  166
# Asset:  FCL symbol_value:  38.88999938964844 mkt_quantity:  233
# Asset:  IYM symbol_value:  49.25433349609375 mkt_quantity:  184
# Asset:  IYZ symbol_value:  14.468355178833008 mkt_quantity:  628
# Asset:  IYJ symbol_value:  46.58740615844727 mkt_quantity:  195
# Asset:  IYR symbol_value:  31.85929298400879 mkt_quantity:  285
# Asset:  IYW symbol_value:  50.22431945800781 mkt_quantity:  181
# Asset:  FCD symbol_value:  7.489999771118164 mkt_quantity:  1213
# Asset:  IYE symbol_value:  26.21583747863769 mkt_quantity:  346
# Asset:  IYG symbol_value:  48.0125732421875 mkt_quantity:  189
# Asset:  IYH symbol_value:  56.25922393798828 mkt_quantity:  161
# Asset:  IDU symbol_value:  52.18859481811523 mkt_quantity:  174
# Asset:  FCL symbol_value:  40.0 mkt_quantity:  227
# Asset:  IYE symbol_value:  27.941951751708984 mkt_quantity:  325
# Asset:  IYE symbol_value:  27.82817268371582 mkt_quantity:  326
# Asset:  IYH symbol_value:  57.221534729003906 mkt_quantity:  158
# Asset:  FCL symbol_value:  41.5 mkt_quantity:  219
# Asset:  IYM symbol_value:  54.00811767578125 mkt_quantity:  168
# Asset:  IYG symbol_value:  52.42508316040039 mkt_quantity:  173
# Asset:  IYZ symbol_value:  15.191817283630373 mkt_quantity:  598
# Asset:  IYE symbol_value:  25.861337661743164 mkt_quantity:  351
# Asset:  IYW symbol_value:  50.284950256347656 mkt_quantity:  180
# Asset:  IDU symbol_value:  53.47954559326172 mkt_quantity:  169
# Asset:  IYJ symbol_value:  51.2864990234375 mkt_quantity:  177
# Asset:  FCD symbol_value:  8.076999664306639 mkt_quantity:  1125
# Asset:  IYR symbol_value:  35.077529907226555 mkt_quantity:  259
# Asset:  FCL symbol_value:  40.599998474121094 mkt_quantity:  223
# Asset:  IYZ symbol_value:  15.597976684570312 mkt_quantity:  582
# Asset:  IYR symbol_value:  36.31778335571289 mkt_quantity:  250
# Asset:  IDU symbol_value:  54.01304626464844 mkt_quantity:  168
# Asset:  IYE symbol_value:  26.056398391723643 mkt_quantity:  348
# Asset:  IYM symbol_value:  48.997840881347656 mkt_quantity:  185
# Asset:  IYH symbol_value:  52.51589584350586 mkt_quantity:  173
# Asset:  IYW symbol_value:  51.07078170776367 mkt_quantity:  178
# Asset:  IYJ symbol_value:  47.55500030517578 mkt_quantity:  191
# Asset:  IYG symbol_value:  46.85449981689453 mkt_quantity:  194
# Asset:  IYG symbol_value:  44.53032684326172 mkt_quantity:  204
# Asset:  IYJ symbol_value:  44.38686752319336 mkt_quantity:  204
# Asset:  IYM symbol_value:  44.74591827392578 mkt_quantity:  203
# Asset:  IYZ symbol_value:  14.638348579406738 mkt_quantity:  621
# Asset:  IYE symbol_value:  23.260883331298828 mkt_quantity:  390
# Asset:  IYR symbol_value:  32.66620635986328 mkt_quantity:  278
# Asset:  IYW symbol_value:  46.90320587158203 mkt_quantity:  193
# Asset:  FCL symbol_value:  38.81999969482422 mkt_quantity:  234
# Asset:  IYH symbol_value:  50.400169372558594 mkt_quantity:  180
# Asset:  IDU symbol_value:  52.65989303588867 mkt_quantity:  172
# Asset:  IDU symbol_value:  53.12487030029297 mkt_quantity:  171
# Asset:  IYM symbol_value:  49.84280776977539 mkt_quantity:  182
# Asset:  IYZ symbol_value:  15.656322479248047 mkt_quantity:  580
# Asset:  FCL symbol_value:  42.20000076293945 mkt_quantity:  215
# Asset:  FCD symbol_value:  7.46999979019165 mkt_quantity:  1216
# Asset:  IYE symbol_value:  25.105426788330078 mkt_quantity:  362
# Asset:  IYG symbol_value:  46.13868713378906 mkt_quantity:  197
# Asset:  IYW symbol_value:  51.19457626342773 mkt_quantity:  177
# Asset:  IYJ symbol_value:  48.74978637695313 mkt_quantity:  186
# Asset:  IYR symbol_value:  35.83953094482422 mkt_quantity:  253
# Asset:  IYH symbol_value:  51.88893127441406 mkt_quantity:  175
# Asset:  IYH symbol_value:  51.24468612670898 mkt_quantity:  177
# Asset:  IYH symbol_value:  53.2906379699707 mkt_quantity:  170
# Asset:  FCD symbol_value:  6.742000102996826 mkt_quantity:  1348
# Asset:  IYG symbol_value:  44.512657165527344 mkt_quantity:  204
# Asset:  IYW symbol_value:  48.72404861450195 mkt_quantity:  186
# Asset:  IYJ symbol_value:  46.83392333984375 mkt_quantity:  194
# Asset:  IYE symbol_value:  24.56675148010254 mkt_quantity:  370
# Asset:  IYR symbol_value:  35.35892868041992 mkt_quantity:  257
# Asset:  IYM symbol_value:  48.30188369750977 mkt_quantity:  188
# Asset:  IYZ symbol_value:  15.624762535095215 mkt_quantity:  581
# Asset:  IDU symbol_value:  54.8076171875 mkt_quantity:  165
# Asset:  IYH symbol_value:  50.68748474121094 mkt_quantity:  179
# Asset:  IDU symbol_value:  56.14348983764648 mkt_quantity:  161
# Asset:  IYZ symbol_value:  16.55592918395996 mkt_quantity:  549
# Asset:  IYR symbol_value:  37.337852478027344 mkt_quantity:  243
# Asset:  IYM symbol_value:  52.44203186035156 mkt_quantity:  173
# Asset:  IYE symbol_value:  25.79916763305664 mkt_quantity:  352
# Asset:  IYG symbol_value:  46.03264236450195 mkt_quantity:  197
# Asset:  IYH symbol_value:  53.8391227722168 mkt_quantity:  168
# Asset:  IYJ symbol_value:  49.27230072021485 mkt_quantity:  184
# Asset:  IYW symbol_value:  50.9292221069336 mkt_quantity:  178
# Asset:  FCD symbol_value:  6.763999938964844 mkt_quantity:  1344
# Asset:  FCL symbol_value:  44.25 mkt_quantity:  205
# Asset:  IYG symbol_value:  45.69007873535156 mkt_quantity:  198
# Asset:  IYG symbol_value:  47.86665344238281 mkt_quantity:  189
# Asset:  IDU symbol_value:  56.71229553222656 mkt_quantity:  160
# Asset:  IYH symbol_value:  55.19482803344727 mkt_quantity:  164
# Asset:  IYR symbol_value:  38.12617874145508 mkt_quantity:  238
# Asset:  IYW symbol_value:  57.11677169799805 mkt_quantity:  159
# Asset:  IYZ symbol_value:  17.483518600463867 mkt_quantity:  519
# Asset:  IYG symbol_value:  45.95551300048828 mkt_quantity:  197
# Asset:  IYJ symbol_value:  53.22563171386719 mkt_quantity:  170
# Asset:  IYJ symbol_value:  54.59376525878906 mkt_quantity:  166
# Asset:  IYZ symbol_value:  18.00754737854004 mkt_quantity:  504
# Asset:  IYW symbol_value:  58.55500793457031 mkt_quantity:  155
# Asset:  IYG symbol_value:  50.46789932250977 mkt_quantity:  180
# Asset:  IYR symbol_value:  39.0743408203125 mkt_quantity:  232
# Asset:  IYH symbol_value:  57.38128280639648 mkt_quantity:  158
# Asset:  IDU symbol_value:  57.45753860473633 mkt_quantity:  158
# Asset:  FCL symbol_value:  40.0 mkt_quantity:  227
# Asset:  FCL symbol_value:  39.4900016784668 mkt_quantity:  230
# Asset:  IYZ symbol_value:  18.21823501586914 mkt_quantity:  499
# Asset:  IYM symbol_value:  66.15386962890625 mkt_quantity:  137
# Asset:  IYM symbol_value:  68.05641937255861 mkt_quantity:  133
# Asset:  IYZ symbol_value:  18.867462158203125 mkt_quantity:  481
# Asset:  IDU symbol_value:  59.3003921508789 mkt_quantity:  153
# Asset:  IYZ symbol_value:  18.30640411376953 mkt_quantity:  496
# Asset:  IYW symbol_value:  62.92328262329102 mkt_quantity:  144
# Asset:  IDU symbol_value:  60.196144104003906 mkt_quantity:  151
# Asset:  IYG symbol_value:  52.36330032348633 mkt_quantity:  173
# Asset:  IYM symbol_value:  66.56338500976561 mkt_quantity:  136
# Asset:  FCD symbol_value:  13.3149995803833 mkt_quantity:  682
# Asset:  IYJ symbol_value:  60.84160995483398 mkt_quantity:  149
# Asset:  IYR symbol_value:  41.8381233215332 mkt_quantity:  217
# Asset:  IYE symbol_value:  35.583229064941406 mkt_quantity:  255
# Asset:  IYH symbol_value:  59.18816375732422 mkt_quantity:  153
# Asset:  IDU symbol_value:  59.09715270996094 mkt_quantity:  153
# Asset:  IYM symbol_value:  69.05694580078125 mkt_quantity:  131
# Asset:  IYZ symbol_value:  19.203821182250977 mkt_quantity:  473
# Asset:  IYE symbol_value:  37.55018997192383 mkt_quantity:  242
# Asset:  IYJ symbol_value:  62.73429870605469 mkt_quantity:  144
# Asset:  IYH symbol_value:  61.25405883789063 mkt_quantity:  148
# Asset:  IYR symbol_value:  43.24211883544922 mkt_quantity:  210
# Asset:  FCD symbol_value:  13.0 mkt_quantity:  699
# Asset:  IDU symbol_value:  60.54289245605469 mkt_quantity:  150
# Asset:  IYG symbol_value:  53.2916145324707 mkt_quantity:  170
# Asset:  IYW symbol_value:  60.91953659057617 mkt_quantity:  149
# Asset:  IYE symbol_value:  37.24510192871094 mkt_quantity:  244
# Asset:  IYG symbol_value:  50.8882064819336 mkt_quantity:  178
# Asset:  IYM symbol_value:  71.0490951538086 mkt_quantity:  127
# Asset:  IYM symbol_value:  71.77581024169922 mkt_quantity:  126
# Asset:  FCL symbol_value:  32.0 mkt_quantity:  284
# Asset:  IYM symbol_value:  66.76560974121094 mkt_quantity:  136
# Asset:  FCL symbol_value:  30.63999938964844 mkt_quantity:  296
# Asset:  IYJ symbol_value:  62.38115692138672 mkt_quantity:  145
# Asset:  IYW symbol_value:  60.00151443481445 mkt_quantity:  151
# Asset:  IYR symbol_value:  44.2088623046875 mkt_quantity:  205
# Asset:  FCD symbol_value:  12.454999923706055 mkt_quantity:  729
# Asset:  FCL symbol_value:  34.610000610351555 mkt_quantity:  262
# Asset:  IYH symbol_value:  63.9942855834961 mkt_quantity:  142
# Asset:  IDU symbol_value:  61.8270263671875 mkt_quantity:  147
# Asset:  IYE symbol_value:  34.746700286865234 mkt_quantity:  261
# Asset:  IYZ symbol_value:  19.46212577819824 mkt_quantity:  467
# Asset:  IYE symbol_value:  34.68898391723633 mkt_quantity:  262
# Asset:  FCL symbol_value:  32.0 mkt_quantity:  284
# Asset:  IDU symbol_value:  63.40001678466797 mkt_quantity:  143
# Asset:  IYJ symbol_value:  63.25158309936523 mkt_quantity:  143
# Asset:  IYM symbol_value:  68.80641937255861 mkt_quantity:  132
# Asset:  IYZ symbol_value:  20.47212219238281 mkt_quantity:  444
# Asset:  IYG symbol_value:  49.10091400146485 mkt_quantity:  185
# Asset:  IYH symbol_value:  65.91345977783203 mkt_quantity:  137
# Asset:  IYR symbol_value:  45.30118942260742 mkt_quantity:  200
# Asset:  IYE symbol_value:  36.088462829589844 mkt_quantity:  251
# Asset:  IYW symbol_value:  61.211143493652344 mkt_quantity:  148
# Asset:  FCD symbol_value:  11.779999732971193 mkt_quantity:  771
# Asset:  IYZ symbol_value:  19.63735580444336 mkt_quantity:  462
# Asset:  IYG symbol_value:  48.22031021118164 mkt_quantity:  188
# Asset:  IYH symbol_value:  64.34828948974611 mkt_quantity:  141
# Asset:  IYJ symbol_value:  60.5053596496582 mkt_quantity:  150
# Asset:  FCD symbol_value:  11.225000381469727 mkt_quantity:  809
# Asset:  IYM symbol_value:  64.03092193603516 mkt_quantity:  141
# Asset:  IYR symbol_value:  42.45518493652344 mkt_quantity:  214
# Asset:  IDU symbol_value:  61.84337997436523 mkt_quantity:  146
# Asset:  IYE symbol_value:  32.36459732055664 mkt_quantity:  280
# Asset:  IYW symbol_value:  56.383033752441406 mkt_quantity:  161
# Asset:  IDU symbol_value:  63.25431823730469 mkt_quantity:  143
# Asset:  IYH symbol_value:  58.9719352722168 mkt_quantity:  154
# Asset:  IYZ symbol_value:  17.327558517456055 mkt_quantity:  524
# Asset:  FCL symbol_value:  25.70000076293945 mkt_quantity:  353
# Asset:  IYR symbol_value:  41.530982971191406 mkt_quantity:  218
# Asset:  IYM symbol_value:  58.93765640258789 mkt_quantity:  154
# Asset:  IYE symbol_value:  31.7191219329834 mkt_quantity:  286
# Asset:  IYJ symbol_value:  51.76176834106445 mkt_quantity:  175
# Asset:  IYG symbol_value:  37.973140716552734 mkt_quantity:  239
# Asset:  IYW symbol_value:  54.2310905456543 mkt_quantity:  167
# Asset:  FCD symbol_value:  9.131999969482422 mkt_quantity:  995
# Asset:  FCL symbol_value:  23.70000076293945 mkt_quantity:  383
# Asset:  IYG symbol_value:  40.39261245727539 mkt_quantity:  225
# Asset:  IYZ symbol_value:  17.562583923339847 mkt_quantity:  517
# Asset:  IYE symbol_value:  31.297075271606445 mkt_quantity:  290
# Asset:  IYM symbol_value:  50.81247329711914 mkt_quantity:  178
# Asset:  IYR symbol_value:  37.72410202026367 mkt_quantity:  240
# Asset:  IYJ symbol_value:  50.149574279785156 mkt_quantity:  181
# Asset:  IYH symbol_value:  59.44769287109375 mkt_quantity:  152
# Asset:  FCD symbol_value:  7.76200008392334 mkt_quantity:  1171
# Asset:  IYW symbol_value:  55.69522094726562 mkt_quantity:  163
# Asset:  IDU symbol_value:  61.61885070800781 mkt_quantity:  147
# Asset:  IYW symbol_value:  58.59696960449219 mkt_quantity:  155
# Asset:  IYJ symbol_value:  52.55207443237305 mkt_quantity:  172
# Asset:  FCL symbol_value:  22.60000038146973 mkt_quantity:  402
# Asset:  IYE symbol_value:  31.81207275390625 mkt_quantity:  285
# Asset:  IYG symbol_value:  39.18478775024414 mkt_quantity:  232
# Asset:  IYH symbol_value:  59.41214370727539 mkt_quantity:  153
# Asset:  IDU symbol_value:  64.50553131103516 mkt_quantity:  140
# Asset:  IYM symbol_value:  53.661399841308594 mkt_quantity:  169
# Asset:  FCD symbol_value:  9.314000129699707 mkt_quantity:  976
# Asset:  IYZ symbol_value:  17.420902252197266 mkt_quantity:  521
# Asset:  IYR symbol_value:  40.30349349975586 mkt_quantity:  225
# Asset:  FCL symbol_value:  22.5 mkt_quantity:  404
# Asset:  IYZ symbol_value:  17.31462287902832 mkt_quantity:  525
# Asset:  IYG symbol_value:  38.53305435180664 mkt_quantity:  235
# Asset:  IYH symbol_value:  59.11006546020508 mkt_quantity:  153
# Asset:  IYR symbol_value:  39.28033447265625 mkt_quantity:  231
# Asset:  IYW symbol_value:  57.66656112670898 mkt_quantity:  157
# Asset:  IYM symbol_value:  52.39155578613281 mkt_quantity:  173
# Asset:  FCD symbol_value:  9.085000038146973 mkt_quantity:  1000
# Asset:  IYE symbol_value:  30.59875297546387 mkt_quantity:  297
# Asset:  IYJ symbol_value:  52.124961853027344 mkt_quantity:  174
# Asset:  IDU symbol_value:  63.15119934082031 mkt_quantity:  143
# Asset:  FCL symbol_value:  22.5 mkt_quantity:  404
# Asset:  IYH symbol_value:  61.78435516357422 mkt_quantity:  147
# Asset:  IYG symbol_value:  39.791900634765625 mkt_quantity:  228
# Asset:  IYJ symbol_value:  55.80876159667969 mkt_quantity:  162
# Asset:  IDU symbol_value:  65.73606109619139 mkt_quantity:  138
# Asset:  IYM symbol_value:  54.60297775268555 mkt_quantity:  166
# Asset:  IYZ symbol_value:  16.864997863769528 mkt_quantity:  539
# Asset:  IYE symbol_value:  32.418731689453125 mkt_quantity:  280
# Asset:  IYW symbol_value:  59.16809844970703 mkt_quantity:  153
# Asset:  IYR symbol_value:  40.22193908691406 mkt_quantity:  226
# Asset:  IYM symbol_value:  55.7691535949707 mkt_quantity:  163
# Asset:  FCL symbol_value:  22.200000762939453 mkt_quantity:  409
# Asset:  IYE symbol_value:  33.20540237426758 mkt_quantity:  273
# Asset:  IYE symbol_value:  33.51395034790039 mkt_quantity:  271
# Asset:  IYE symbol_value:  32.88019180297852 mkt_quantity:  276
# Asset:  IYW symbol_value:  58.61661911010742 mkt_quantity:  155
# Asset:  FCL symbol_value:  22.79999923706055 mkt_quantity:  398
# Asset:  IYE symbol_value:  34.07265090942383 mkt_quantity:  266
# Asset:  IYM symbol_value:  58.15022659301758 mkt_quantity:  156
# Asset:  IYW symbol_value:  60.48991012573242 mkt_quantity:  150
# Asset:  FCD symbol_value:  10.074999809265137 mkt_quantity:  902
# Asset:  IDU symbol_value:  66.30620574951172 mkt_quantity:  137
# Asset:  IDU symbol_value:  66.62598419189453 mkt_quantity:  136
# Asset:  IYM symbol_value:  63.33598709106445 mkt_quantity:  143
# Asset:  IYR symbol_value:  45.11567687988281 mkt_quantity:  201
# Asset:  FCL symbol_value:  26.489999771118164 mkt_quantity:  343
# Asset:  FCD symbol_value:  10.4399995803833 mkt_quantity:  870
# Asset:  IYJ symbol_value:  62.85287475585938 mkt_quantity:  144
# Asset:  IYE symbol_value:  35.66538619995117 mkt_quantity:  254
# Asset:  IYR symbol_value:  46.32186508178711 mkt_quantity:  196
# Asset:  IYJ symbol_value:  64.70358276367189 mkt_quantity:  140
# Asset:  FCL symbol_value:  27.959999084472656 mkt_quantity:  325
# Asset:  FCD symbol_value:  11.074999809265137 mkt_quantity:  820
# Asset:  IYM symbol_value:  61.32122421264648 mkt_quantity:  148
# Asset:  IDU symbol_value:  67.57781219482422 mkt_quantity:  134
# Asset:  IDU symbol_value:  68.11302185058594 mkt_quantity:  133
# Asset:  IYZ symbol_value:  18.120975494384766 mkt_quantity:  501
# Asset:  IYM symbol_value:  58.4365348815918 mkt_quantity:  155
# Asset:  IYJ symbol_value:  61.741416931152344 mkt_quantity:  147
# Asset:  IDU symbol_value:  66.49166107177734 mkt_quantity:  136
# Asset:  FCL symbol_value:  23.51000022888184 mkt_quantity:  386
# Asset:  IYG symbol_value:  49.47844696044922 mkt_quantity:  183
# Asset:  IYR symbol_value:  47.02718734741211 mkt_quantity:  193
# Asset:  IYW symbol_value:  71.08448791503906 mkt_quantity:  127
# Asset:  FCD symbol_value:  10.8100004196167 mkt_quantity:  840
# Asset:  IYH symbol_value:  69.15266418457031 mkt_quantity:  131
# Asset:  IYR symbol_value:  48.1305160522461 mkt_quantity:  188
# Asset:  IDU symbol_value:  68.81349182128906 mkt_quantity:  132
# Asset:  IYM symbol_value:  61.57471466064453 mkt_quantity:  147
# Asset:  IYH symbol_value:  70.20137023925781 mkt_quantity:  129
# Asset:  IYJ symbol_value:  63.73310089111328 mkt_quantity:  142
# Asset:  IYE symbol_value:  32.85333633422852 mkt_quantity:  276
# Asset:  IYM symbol_value:  58.74247741699219 mkt_quantity:  154
# Asset:  IYM symbol_value:  58.49771499633789 mkt_quantity:  155
# Asset:  IYZ symbol_value:  17.855466842651367 mkt_quantity:  509
# Asset:  IYM symbol_value:  58.10437393188477 mkt_quantity:  156
# Asset:  IYE symbol_value:  31.907737731933594 mkt_quantity:  284
# Asset:  IYJ symbol_value:  60.35084915161133 mkt_quantity:  150
# Asset:  IYZ symbol_value:  17.581661224365234 mkt_quantity:  517
# Asset:  IYH symbol_value:  67.92464447021484 mkt_quantity:  133
# Asset:  IYR symbol_value:  46.13546371459961 mkt_quantity:  197
# Asset:  FCD symbol_value:  10.720000267028807 mkt_quantity:  848
# Asset:  IDU symbol_value:  68.412109375 mkt_quantity:  132
# Asset:  IDU symbol_value:  69.83670806884766 mkt_quantity:  130
# Asset:  IYZ symbol_value:  17.98822021484375 mkt_quantity:  505
# Asset:  FCD symbol_value:  10.68000030517578 mkt_quantity:  851
# Asset:  IYM symbol_value:  57.5146484375 mkt_quantity:  158
# Asset:  IYH symbol_value:  70.54039001464844 mkt_quantity:  128
# Asset:  IYR symbol_value:  47.79315948486328 mkt_quantity:  190
# Asset:  FCD symbol_value:  11.005000114440918 mkt_quantity:  826
# Asset:  IYE symbol_value:  31.94451332092285 mkt_quantity:  284
# Asset:  IYG symbol_value:  46.631103515625 mkt_quantity:  194
# Asset:  IYJ symbol_value:  60.697792053222656 mkt_quantity:  149
# Asset:  IYW symbol_value:  66.45932769775389 mkt_quantity:  136
# Asset:  FCL symbol_value:  20.5 mkt_quantity:  443
# Asset:  IYW symbol_value:  65.52445220947266 mkt_quantity:  138
# Asset:  IYM symbol_value:  55.53743743896485 mkt_quantity:  163
# Asset:  FCD symbol_value:  10.864999771118164 mkt_quantity:  836
# Asset:  IYJ symbol_value:  60.0674819946289 mkt_quantity:  151
# Asset:  IYG symbol_value:  45.18658447265625 mkt_quantity:  201
# Asset:  IYG symbol_value:  47.145729064941406 mkt_quantity:  192
# Asset:  IYJ symbol_value:  61.81431198120117 mkt_quantity:  147
# Asset:  IYW symbol_value:  66.20012664794922 mkt_quantity:  137
# Asset:  IYG symbol_value:  46.37831497192383 mkt_quantity:  196
# Asset:  FCD symbol_value:  11.53499984741211 mkt_quantity:  788
# Asset:  IYG symbol_value:  47.66937255859375 mkt_quantity:  190
# Asset:  IYM symbol_value:  58.43733596801758 mkt_quantity:  155
# Asset:  IYR symbol_value:  49.61521911621094 mkt_quantity:  183
# Asset:  IDU symbol_value:  72.20899963378906 mkt_quantity:  125
# Asset:  FCL symbol_value:  21.399999618530273 mkt_quantity:  424
# Asset:  IYR symbol_value:  49.88967895507813 mkt_quantity:  182
# Asset:  FCD symbol_value:  11.18000030517578 mkt_quantity:  813
# Asset:  IYM symbol_value:  60.06303024291992 mkt_quantity:  151
# Asset:  FCL symbol_value:  22.649999618530273 mkt_quantity:  401
# Asset:  IYE symbol_value:  35.232295989990234 mkt_quantity:  258
# Asset:  IYJ symbol_value:  63.77724838256836 mkt_quantity:  142
# Asset:  IYJ symbol_value:  64.04737854003906 mkt_quantity:  141
# Asset:  IYM symbol_value:  60.27394104003906 mkt_quantity:  150
# Asset:  IYE symbol_value:  35.73680877685547 mkt_quantity:  254
# Asset:  IDU symbol_value:  71.36650848388672 mkt_quantity:  127
# Asset:  IYR symbol_value:  49.12177276611328 mkt_quantity:  185
# Asset:  IYW symbol_value:  69.97231292724611 mkt_quantity:  129
# Asset:  IYM symbol_value:  60.25232315063477 mkt_quantity:  150
# Asset:  IYE symbol_value:  35.66566848754883 mkt_quantity:  254
# Asset:  IYJ symbol_value:  63.850746154785156 mkt_quantity:  142
# Asset:  IYZ symbol_value:  21.188411712646484 mkt_quantity:  429
# Asset:  IYH symbol_value:  76.57914733886719 mkt_quantity:  118
# Asset:  IYM symbol_value:  59.316795349121094 mkt_quantity:  153
# Asset:  IYJ symbol_value:  64.89079284667969 mkt_quantity:  140
# Asset:  IYM symbol_value:  60.24348831176758 mkt_quantity:  150
# Asset:  IYJ symbol_value:  65.34298706054689 mkt_quantity:  139
# Asset:  IDU symbol_value:  70.49365234375 mkt_quantity:  128
# Asset:  IYG symbol_value:  50.5318603515625 mkt_quantity:  179
# Asset:  FCD symbol_value:  9.656000137329102 mkt_quantity:  941
# Asset:  FCL symbol_value:  28.29999923706055 mkt_quantity:  321
# Asset:  FCL symbol_value:  28.399999618530273 mkt_quantity:  320
# Asset:  IYJ symbol_value:  64.37530517578125 mkt_quantity:  141
# Asset:  IYH symbol_value:  76.04585266113281 mkt_quantity:  119
# Asset:  IYW symbol_value:  65.55671691894531 mkt_quantity:  138
# Asset:  IYE symbol_value:  34.340347290039055 mkt_quantity:  264
# Asset:  IYG symbol_value:  51.36470413208008 mkt_quantity:  176
# Asset:  IYR symbol_value:  48.84513473510742 mkt_quantity:  186
# Asset:  IYM symbol_value:  58.05474090576172 mkt_quantity:  156
# Asset:  IYZ symbol_value:  20.15421485900879 mkt_quantity:  451
# Asset:  IDU symbol_value:  69.89305877685547 mkt_quantity:  130
# Asset:  FCL symbol_value:  32.0 mkt_quantity:  284
# Asset:  FCL symbol_value:  32.779998779296875 mkt_quantity:  277
# Asset:  IYH symbol_value:  78.13330078125 mkt_quantity:  116
# Asset:  IYH symbol_value:  78.05157470703125 mkt_quantity:  116
# Asset:  FCD symbol_value:  11.029999732971193 mkt_quantity:  824
# Asset:  IYW symbol_value:  67.33464813232422 mkt_quantity:  135
# Asset:  IYW symbol_value:  68.11685180664061 mkt_quantity:  133
# Asset:  IYM symbol_value:  63.88227081298828 mkt_quantity:  142
# Asset:  FCD symbol_value:  11.395000457763672 mkt_quantity:  797
# Asset:  IYZ symbol_value:  20.373167037963867 mkt_quantity:  446
# Asset:  IYW symbol_value:  66.90631866455078 mkt_quantity:  135
# Asset:  IYE symbol_value:  37.54441833496094 mkt_quantity:  242
# Asset:  FCD symbol_value:  10.65999984741211 mkt_quantity:  852
# Asset:  IYW symbol_value:  68.74076843261719 mkt_quantity:  132
# Asset:  IYE symbol_value:  38.62123107910156 mkt_quantity:  235
# Asset:  IYM symbol_value:  63.97116088867188 mkt_quantity:  142
# Asset:  IYZ symbol_value:  20.644582748413086 mkt_quantity:  440
# Asset:  FCL symbol_value:  39.20000076293945 mkt_quantity:  231
# Asset:  FCL symbol_value:  42.29999923706055 mkt_quantity:  214
# Asset:  IYM symbol_value:  60.43449020385742 mkt_quantity:  150
# Asset:  IYJ symbol_value:  72.81759643554688 mkt_quantity:  124
# Asset:  IYW symbol_value:  66.48949432373047 mkt_quantity:  136
# Asset:  IYG symbol_value:  59.68449401855469 mkt_quantity:  152
# Asset:  IYE symbol_value:  38.25800704956055 mkt_quantity:  237
# Asset:  FCL symbol_value:  49.79999923706055 mkt_quantity:  182
# Asset:  IYG symbol_value:  60.73303985595703 mkt_quantity:  149
# Asset:  IYM symbol_value:  62.78225708007813 mkt_quantity:  144
# Asset:  IYE symbol_value:  38.82850646972656 mkt_quantity:  234
# Asset:  IYJ symbol_value:  75.32574462890625 mkt_quantity:  120
# Asset:  IYW symbol_value:  70.37373352050781 mkt_quantity:  129
# Asset:  FCL symbol_value:  52.38000106811523 mkt_quantity:  173
# Asset:  FCD symbol_value:  11.225000381469727 mkt_quantity:  809
# Asset:  IDU symbol_value:  80.84197235107422 mkt_quantity:  112
# Asset:  FCL symbol_value:  50.68000030517578 mkt_quantity:  179
# Asset:  IYR symbol_value:  53.892250061035156 mkt_quantity:  168
# Asset:  IYZ symbol_value:  22.19955444335937 mkt_quantity:  409
# Asset:  FCD symbol_value:  10.484999656677246 mkt_quantity:  867
# Asset:  IYM symbol_value:  62.79118347167969 mkt_quantity:  144
# Asset:  IYE symbol_value:  38.74335479736328 mkt_quantity:  234
# Asset:  IYH symbol_value:  92.70646667480469 mkt_quantity:  98
# Asset:  IYJ symbol_value:  76.67555236816406 mkt_quantity:  118
# Asset:  FCL symbol_value:  54.9900016784668 mkt_quantity:  165
# Asset:  IYW symbol_value:  71.33544921875 mkt_quantity:  127
# Asset:  IYG symbol_value:  65.75688171386719 mkt_quantity:  138
# Asset:  FCL symbol_value:  51.4900016784668 mkt_quantity:  176
# Asset:  FCD symbol_value:  11.3100004196167 mkt_quantity:  803
# Asset:  IYZ symbol_value:  22.89580154418945 mkt_quantity:  397
# Asset:  IYG symbol_value:  67.54470825195311 mkt_quantity:  134
# Asset:  IDU symbol_value:  78.35130310058594 mkt_quantity:  116
# Asset:  IYE symbol_value:  39.80543899536133 mkt_quantity:  228
# Asset:  IYH symbol_value:  95.58644104003906 mkt_quantity:  95
# Asset:  IYJ symbol_value:  79.76597595214844 mkt_quantity:  113
# Asset:  IYR symbol_value:  54.49296188354492 mkt_quantity:  166
# Asset:  IYW symbol_value:  72.57711791992188 mkt_quantity:  125
# Asset:  IYM symbol_value:  63.25268936157226 mkt_quantity:  143
# Asset:  FCD symbol_value:  9.61400032043457 mkt_quantity:  945
# Asset:  IYR symbol_value:  51.99835968017578 mkt_quantity:  174
# Asset:  FCL symbol_value:  51.9000015258789 mkt_quantity:  175
# Asset:  IYZ symbol_value:  23.808534622192386 mkt_quantity:  381
# Asset:  IYE symbol_value:  39.78833770751953 mkt_quantity:  228
# Asset:  IDU symbol_value:  78.11328887939453 mkt_quantity:  116
# Asset:  IYG symbol_value:  67.58126831054689 mkt_quantity:  134
# Asset:  IYH symbol_value:  95.63213348388672 mkt_quantity:  95
# Asset:  IYJ symbol_value:  79.54634094238281 mkt_quantity:  114
# Asset:  IYM symbol_value:  63.747230529785156 mkt_quantity:  142
# Asset:  IYW symbol_value:  71.90276336669922 mkt_quantity:  126
# Asset:  FCL symbol_value:  51.18999862670898 mkt_quantity:  177
# Asset:  FCD symbol_value:  9.600000381469727 mkt_quantity:  946
# Asset:  IYM symbol_value:  65.81516265869139 mkt_quantity:  138
# Asset:  IYE symbol_value:  40.558265686035156 mkt_quantity:  224
# Asset:  IYH symbol_value:  98.6666259765625 mkt_quantity:  92
# Asset:  IYJ symbol_value:  82.4931640625 mkt_quantity:  110
# Asset:  IYZ symbol_value:  23.713825225830078 mkt_quantity:  383
# Asset:  IYW symbol_value:  73.51371002197266 mkt_quantity:  123
# Asset:  IYG symbol_value:  69.93122863769531 mkt_quantity:  129
# Asset:  IYR symbol_value:  51.21435165405274 mkt_quantity:  177
# Asset:  FCL symbol_value:  52.08000183105469 mkt_quantity:  174
# Asset:  IDU symbol_value:  78.8519287109375 mkt_quantity:  115
# Asset:  IYG symbol_value:  67.44734191894531 mkt_quantity:  134
# Asset:  IYE symbol_value:  39.926231384277344 mkt_quantity:  227
# Asset:  IYH symbol_value:  96.24066162109376 mkt_quantity:  94
# Asset:  FCD symbol_value:  9.71399974822998 mkt_quantity:  935
# Asset:  IYJ symbol_value:  83.75926208496094 mkt_quantity:  108
# Asset:  IYM symbol_value:  67.92936706542969 mkt_quantity:  133
# Asset:  IYR symbol_value:  52.12561798095703 mkt_quantity:  174
# Asset:  IYW symbol_value:  75.29132843017578 mkt_quantity:  120
# Asset:  IYR symbol_value:  52.90097427368164 mkt_quantity:  171
# Asset:  IYW symbol_value:  75.53559112548828 mkt_quantity:  120
# Asset:  IYM symbol_value:  69.13852691650389 mkt_quantity:  131
# Asset:  IYE symbol_value:  41.85857772827149 mkt_quantity:  217
# Asset:  IYG symbol_value:  71.52754211425781 mkt_quantity:  127
# Asset:  IYH symbol_value:  100.88726043701172 mkt_quantity:  90
# Asset:  IYJ symbol_value:  86.3116226196289 mkt_quantity:  105
# Asset:  IYR symbol_value:  50.93458938598633 mkt_quantity:  178
# Asset:  IYZ symbol_value:  25.020294189453125 mkt_quantity:  363
# Asset:  FCD symbol_value:  9.175000190734863 mkt_quantity:  990
# Asset:  IDU symbol_value:  80.21324157714844 mkt_quantity:  113
# Asset:  IYE symbol_value:  42.21927261352539 mkt_quantity:  215
# Asset:  IYM symbol_value:  69.86042022705078 mkt_quantity:  130
# Asset:  FCL symbol_value:  69.48000335693361 mkt_quantity:  130
# Asset:  IYH symbol_value:  105.34141540527344 mkt_quantity:  86
# Asset:  IYM symbol_value:  71.77340698242188 mkt_quantity:  126
# Asset:  IYZ symbol_value:  25.667903900146484 mkt_quantity:  354
# Asset:  IYE symbol_value:  43.17707824707031 mkt_quantity:  210
# Asset:  IYR symbol_value:  50.89531326293945 mkt_quantity:  178
# Asset:  IDU symbol_value:  79.97273254394531 mkt_quantity:  113
# Asset:  IYH symbol_value:  106.55152893066406 mkt_quantity:  85
# Asset:  IYE symbol_value:  42.59943008422852 mkt_quantity:  213
# Asset:  IYM symbol_value:  69.72628021240234 mkt_quantity:  130
# Asset:  IYJ symbol_value:  89.0980453491211 mkt_quantity:  102
# Asset:  IYZ symbol_value:  25.39716911315918 mkt_quantity:  357
# Asset:  IYG symbol_value:  74.36214447021484 mkt_quantity:  122
# Asset:  IYW symbol_value:  79.9945297241211 mkt_quantity:  113
# Asset:  FCD symbol_value:  8.977999687194824 mkt_quantity:  1012
# Asset:  IYH symbol_value:  107.39740753173828 mkt_quantity:  84
# Asset:  FCL symbol_value:  62.20000076293945 mkt_quantity:  146
# Asset:  IYH symbol_value:  114.35741424560548 mkt_quantity:  79
# Asset:  IYW symbol_value:  85.03659057617188 mkt_quantity:  106
# Asset:  IYM symbol_value:  73.8534164428711 mkt_quantity:  123
# Asset:  IYE symbol_value:  43.04776382446289 mkt_quantity:  211
# Asset:  IYG symbol_value:  76.08336639404297 mkt_quantity:  119
# Asset:  IYJ symbol_value:  92.32289123535156 mkt_quantity:  98
# Asset:  IYZ symbol_value:  25.46703147888184 mkt_quantity:  356
# Asset:  FCD symbol_value:  9.68299961090088 mkt_quantity:  938
# Asset:  FCL symbol_value:  56.20000076293945 mkt_quantity:  161
# Asset:  FCD symbol_value:  9.946000099182127 mkt_quantity:  914
# Asset:  IYH symbol_value:  112.95071411132812 mkt_quantity:  80
# Asset:  IYR symbol_value:  54.50187683105469 mkt_quantity:  166
# Asset:  IYE symbol_value:  43.15171813964844 mkt_quantity:  210
# Asset:  IYJ symbol_value:  91.73414611816406 mkt_quantity:  99
# Asset:  IYW symbol_value:  84.75483703613281 mkt_quantity:  107
# Asset:  IYE symbol_value:  44.086036682128906 mkt_quantity:  206
# Asset:  IYW symbol_value:  87.28738403320312 mkt_quantity:  104
# Asset:  FCL symbol_value:  53.5 mkt_quantity:  169
# Asset:  IYR symbol_value:  55.66811752319336 mkt_quantity:  163
# Asset:  IYW symbol_value:  83.9610824584961 mkt_quantity:  108
# Asset:  IYM symbol_value:  75.2098388671875 mkt_quantity:  120
# Asset:  IYG symbol_value:  75.77334594726562 mkt_quantity:  119
# Asset:  IYM symbol_value:  76.3104019165039 mkt_quantity:  119
# Asset:  FCD symbol_value:  10.140000343322754 mkt_quantity:  896
# Asset:  IYJ symbol_value:  90.89188385009766 mkt_quantity:  100
# Asset:  FCL symbol_value:  50.13000106811523 mkt_quantity:  181
# Asset:  IYZ symbol_value:  25.872257232666016 mkt_quantity:  351
# Asset:  IYJ symbol_value:  93.45570373535156 mkt_quantity:  97
# Asset:  IYM symbol_value:  76.1739730834961 mkt_quantity:  119
# Asset:  FCD symbol_value:  9.357999801635742 mkt_quantity:  971
# Asset:  IYJ symbol_value:  92.99292755126952 mkt_quantity:  97
# Asset:  IYM symbol_value:  76.3194808959961 mkt_quantity:  119
# Asset:  IYH symbol_value:  112.04348754882812 mkt_quantity:  81
# Asset:  IYW symbol_value:  85.56754302978516 mkt_quantity:  106
# Asset:  IYZ symbol_value:  26.14441108703613 mkt_quantity:  347
# Asset:  IDU symbol_value:  87.83565521240234 mkt_quantity:  103
# Asset:  FCD symbol_value:  9.791999816894533 mkt_quantity:  928
# Asset:  IYG symbol_value:  75.98554992675781 mkt_quantity:  119
# Asset:  IDU symbol_value:  91.15895080566406 mkt_quantity:  99
# Asset:  IYZ symbol_value:  26.030282974243164 mkt_quantity:  349
# Asset:  FCL symbol_value:  52.97000122070313 mkt_quantity:  171
# Asset:  IYZ symbol_value:  26.51313781738281 mkt_quantity:  342
# Asset:  IYJ symbol_value:  95.96691131591795 mkt_quantity:  94
# Asset:  FCL symbol_value:  47.79999923706055 mkt_quantity:  190
# Asset:  FCD symbol_value:  11.395000457763672 mkt_quantity:  797
# Asset:  IDU symbol_value:  90.07113647460938 mkt_quantity:  100
# Asset:  IYE symbol_value:  48.91980743408203 mkt_quantity:  185
# Asset:  FCD symbol_value:  12.664999961853027 mkt_quantity:  717
# Asset:  IYG symbol_value:  78.86257934570312 mkt_quantity:  115
# Asset:  IYG symbol_value:  79.2049789428711 mkt_quantity:  114
# Asset:  IYH symbol_value:  120.84757995605469 mkt_quantity:  75
# Asset:  IYM symbol_value:  78.00272369384766 mkt_quantity:  116
# Asset:  IYG symbol_value:  76.2714614868164 mkt_quantity:  119
# Asset:  IYH symbol_value:  118.85010528564452 mkt_quantity:  76
# Asset:  IYH symbol_value:  117.81439208984376 mkt_quantity:  77
# Asset:  IYR symbol_value:  58.92783737182617 mkt_quantity:  154
# Asset:  FCD symbol_value:  10.923999786376953 mkt_quantity:  832
# Asset:  IYW symbol_value:  92.13166046142578 mkt_quantity:  98
# Asset:  IYZ symbol_value:  26.42186546325684 mkt_quantity:  344
# Asset:  IYR symbol_value:  61.21579360961914 mkt_quantity:  148
# Asset:  IYM symbol_value:  80.7132339477539 mkt_quantity:  112
# Asset:  IYH symbol_value:  122.45667266845705 mkt_quantity:  74
# Asset:  IYJ symbol_value:  96.2639389038086 mkt_quantity:  94
# Asset:  IYW symbol_value:  96.20703125 mkt_quantity:  94
# Asset:  IDU symbol_value:  91.09671783447266 mkt_quantity:  99
# Asset:  FCD symbol_value:  12.670000076293945 mkt_quantity:  717
# Asset:  IYG symbol_value:  79.91754150390625 mkt_quantity:  113
# Asset:  FCL symbol_value:  50.0 mkt_quantity:  181
# Asset:  IYE symbol_value:  48.7894172668457 mkt_quantity:  186
# Asset:  IYZ symbol_value:  27.119503021240234 mkt_quantity:  335
# Asset:  IYE symbol_value:  46.29475021362305 mkt_quantity:  196
# Asset:  IYR symbol_value:  58.829078674316406 mkt_quantity:  154
# Asset:  IYM symbol_value:  80.74974822998047 mkt_quantity:  112
# Asset:  IYJ symbol_value:  94.7416763305664 mkt_quantity:  95
# Asset:  IDU symbol_value:  90.03724670410156 mkt_quantity:  100
# Asset:  FCD symbol_value:  12.50100040435791 mkt_quantity:  727
# Asset:  IYZ symbol_value:  26.603464126586914 mkt_quantity:  341
# Asset:  IYW symbol_value:  95.71216583251952 mkt_quantity:  94
# Asset:  IYG symbol_value:  78.5165786743164 mkt_quantity:  115
# Asset:  IYH symbol_value:  122.89356994628906 mkt_quantity:  73
# Asset:  IDU symbol_value:  92.45060729980469 mkt_quantity:  98
# Asset:  IYR symbol_value:  58.99855041503906 mkt_quantity:  154
# Asset:  FCL symbol_value:  51.4000015258789 mkt_quantity:  176
# Asset:  IYH symbol_value:  130.77493286132812 mkt_quantity:  69
# Asset:  IYJ symbol_value:  96.25946044921876 mkt_quantity:  94
# Asset:  IYZ symbol_value:  27.047298431396484 mkt_quantity:  336
# Asset:  IYM symbol_value:  76.28717803955078 mkt_quantity:  119
# Asset:  IYG symbol_value:  82.470703125 mkt_quantity:  110
# Asset:  IYW symbol_value:  96.93814086914062 mkt_quantity:  93
# Asset:  FCD symbol_value:  11.984999656677244 mkt_quantity:  758
# Asset:  IYE symbol_value:  42.364540100097656 mkt_quantity:  214
# Asset:  IYE symbol_value:  39.35971450805664 mkt_quantity:  230
# Asset:  IDU symbol_value:  98.49037170410156 mkt_quantity:  92
# Asset:  IDU symbol_value:  99.19088745117188 mkt_quantity:  91
# Asset:  IYZ symbol_value:  26.42592430114746 mkt_quantity:  344
# Asset:  IYM symbol_value:  75.17825317382812 mkt_quantity:  120
# Asset:  IYJ symbol_value:  95.87791442871094 mkt_quantity:  94
# Asset:  IYW symbol_value:  95.27497863769531 mkt_quantity:  95
# Asset:  IYH symbol_value:  135.6358642578125 mkt_quantity:  67
# Asset:  IYJ symbol_value:  99.69005584716795 mkt_quantity:  91
# Asset:  IYE symbol_value:  39.52116775512695 mkt_quantity:  230
# Asset:  IYW symbol_value:  99.24397277832031 mkt_quantity:  91
# Asset:  IYZ symbol_value:  25.659364700317386 mkt_quantity:  354
# Asset:  IYM symbol_value:  73.30748748779297 mkt_quantity:  124
# Asset:  FCL symbol_value:  49.099998474121094 mkt_quantity:  185
# Asset:  IYG symbol_value:  81.30384063720703 mkt_quantity:  111
# Asset:  IYM symbol_value:  74.11022186279297 mkt_quantity:  122
# Asset:  IYH symbol_value:  137.38412475585938 mkt_quantity:  66
# Asset:  IYW symbol_value:  97.81340026855469 mkt_quantity:  92
# Asset:  IYE symbol_value:  36.78285598754883 mkt_quantity:  247
# Asset:  IYJ symbol_value:  96.59434509277344 mkt_quantity:  94
# Asset:  IYZ symbol_value:  26.09683990478516 mkt_quantity:  348
# Asset:  IYZ symbol_value:  25.90934944152832 mkt_quantity:  350
# Asset:  IYE symbol_value:  39.04723739624024 mkt_quantity:  232
# Asset:  IYM symbol_value:  77.52415466308594 mkt_quantity:  117
# Asset:  IYJ symbol_value:  99.85841369628906 mkt_quantity:  91
# Asset:  IYW symbol_value:  98.27117919921876 mkt_quantity:  92
# Asset:  FCD symbol_value:  13.755000114440918 mkt_quantity:  660
# Asset:  IYW symbol_value:  98.11859893798828 mkt_quantity:  92
# Asset:  IYG symbol_value:  82.89656829833984 mkt_quantity:  109
# Asset:  IYH symbol_value:  137.9049072265625 mkt_quantity:  65
# Asset:  IDU symbol_value:  99.39718627929688 mkt_quantity:  91
# Asset:  IYR symbol_value:  67.76087951660156 mkt_quantity:  134
# Asset:  IYW symbol_value:  101.79993438720705 mkt_quantity:  89
# Asset:  IYH symbol_value:  140.50885009765622 mkt_quantity:  64
# Asset:  FCD symbol_value:  14.020000457763672 mkt_quantity:  648
# Asset:  IYE symbol_value:  38.090579986572266 mkt_quantity:  238
# Asset:  IYM symbol_value:  77.35809326171875 mkt_quantity:  117
# Asset:  IYZ symbol_value:  26.980722427368164 mkt_quantity:  336
# Asset:  IYJ symbol_value:  102.03759002685548 mkt_quantity:  89
# Asset:  IYW symbol_value:  100.9988250732422 mkt_quantity:  90
# Asset:  IYZ symbol_value:  27.20967674255371 mkt_quantity:  334
# Asset:  IYR symbol_value:  66.99650573730469 mkt_quantity:  135
# Asset:  IYG symbol_value:  83.91211700439453 mkt_quantity:  108
# Asset:  IDU symbol_value:  97.05158996582031 mkt_quantity:  93
# Asset:  FCL symbol_value:  60.38999938964844 mkt_quantity:  150
# Asset:  IYE symbol_value:  38.69758605957031 mkt_quantity:  234
# Asset:  IYH symbol_value:  146.54818725585938 mkt_quantity:  62
# Asset:  IYH symbol_value:  145.86798095703125 mkt_quantity:  62
# Asset:  IYM symbol_value:  77.19599151611328 mkt_quantity:  117
# Asset:  FCD symbol_value:  17.420000076293945 mkt_quantity:  521
# Asset:  IYJ symbol_value:  102.69548797607422 mkt_quantity:  88
# Asset:  IYH symbol_value:  146.3524932861328 mkt_quantity:  62
# Asset:  IYR symbol_value:  65.90512084960939 mkt_quantity:  137
# Asset:  IYG symbol_value:  84.46324157714844 mkt_quantity:  107
# Asset:  IYW symbol_value:  102.25077056884766 mkt_quantity:  88
# Asset:  IYH symbol_value:  147.01405334472656 mkt_quantity:  61
# Asset:  FCD symbol_value:  18.3799991607666 mkt_quantity:  494
# Asset:  IDU symbol_value:  97.66787719726562 mkt_quantity:  93
# Asset:  IDU symbol_value:  98.60533142089844 mkt_quantity:  92
# Asset:  IYJ symbol_value:  101.88863372802734 mkt_quantity:  89
# Asset:  IYH symbol_value:  141.90798950195312 mkt_quantity:  64
# Asset:  IDU symbol_value:  94.79478454589844 mkt_quantity:  95
# Asset:  IYZ symbol_value:  26.66224670410156 mkt_quantity:  340
# Asset:  FCD symbol_value:  16.940000534057614 mkt_quantity:  536
# Asset:  FCL symbol_value:  56.5 mkt_quantity:  160
# Asset:  IYE symbol_value:  40.216529846191406 mkt_quantity:  226
# Asset:  IYJ symbol_value:  103.38036346435548 mkt_quantity:  87
# Asset:  IYH symbol_value:  148.57940673828125 mkt_quantity:  61
# Asset:  FCD symbol_value:  18.459999084472656 mkt_quantity:  492
# Asset:  IYM symbol_value:  78.58441925048828 mkt_quantity:  115
# Asset:  IYR symbol_value:  64.28079223632811 mkt_quantity:  141
# Asset:  IDU symbol_value:  96.93875122070312 mkt_quantity:  93
# Asset:  IYR symbol_value:  62.16572952270508 mkt_quantity:  146
# Asset:  IDU symbol_value:  92.50324249267578 mkt_quantity:  98
# Asset:  IYJ symbol_value:  101.0066909790039 mkt_quantity:  90
# Asset:  IYZ symbol_value:  27.075061798095703 mkt_quantity:  335
# Asset:  FCD symbol_value:  16.815000534057614 mkt_quantity:  540
# Asset:  FCL symbol_value:  56.58000183105469 mkt_quantity:  160
# Asset:  IYW symbol_value:  102.62370300292969 mkt_quantity:  88
# Asset:  IYZ symbol_value:  26.11325645446777 mkt_quantity:  348
# Asset:  IYG symbol_value:  86.06454467773438 mkt_quantity:  105
# Asset:  IDU symbol_value:  93.99757385253906 mkt_quantity:  96
# Asset:  IYH symbol_value:  152.6295928955078 mkt_quantity:  59
# Asset:  IYH symbol_value:  153.42361450195312 mkt_quantity:  59
# Asset:  IYR symbol_value:  63.7485580444336 mkt_quantity:  142
# Asset:  IYG symbol_value:  92.1089324951172 mkt_quantity:  98
# Asset:  IYW symbol_value:  103.12134552001952 mkt_quantity:  88
# Asset:  IYH symbol_value:  150.86410522460938 mkt_quantity:  60
# Asset:  IYW symbol_value:  102.67089080810548 mkt_quantity:  88
# Asset:  IYZ symbol_value:  26.48384666442871 mkt_quantity:  343
# Asset:  FCL symbol_value:  55.0 mkt_quantity:  165
# Asset:  IYH symbol_value:  149.92990112304688 mkt_quantity:  60
# Asset:  IYH symbol_value:  149.67770385742188 mkt_quantity:  60
# Asset:  IYG symbol_value:  89.81298065185547 mkt_quantity:  101
# Asset:  IYJ symbol_value:  98.65862274169922 mkt_quantity:  92
# Asset:  IYJ symbol_value:  96.50199127197266 mkt_quantity:  94
# Asset:  IYR symbol_value:  60.24015808105469 mkt_quantity:  150
# Asset:  IYZ symbol_value:  25.15513610839844 mkt_quantity:  361
# Asset:  IDU symbol_value:  90.18399047851562 mkt_quantity:  100
# Asset:  IYW symbol_value:  97.56224822998048 mkt_quantity:  93
# Asset:  IYJ symbol_value:  91.0868682861328 mkt_quantity:  99
# Asset:  IYZ symbol_value:  25.236370086669922 mkt_quantity:  360
# Asset:  IYR symbol_value:  61.21274948120117 mkt_quantity:  148
# Asset:  IYZ symbol_value:  24.40030860900879 mkt_quantity:  372
# Asset:  IDU symbol_value:  93.70206451416016 mkt_quantity:  97
# Asset:  IYJ symbol_value:  89.66214752197266 mkt_quantity:  101
# Asset:  FCD symbol_value:  12.095000267028807 mkt_quantity:  751
# Asset:  IYW symbol_value:  95.0993194580078 mkt_quantity:  95
# Asset:  FCD symbol_value:  12.164999961853027 mkt_quantity:  747
# Asset:  IYE symbol_value:  34.99755477905273 mkt_quantity:  259
# Asset:  IYW symbol_value:  100.11821746826172 mkt_quantity:  90
# Asset:  FCD symbol_value:  12.614999771118164 mkt_quantity:  720
# Asset:  IYJ symbol_value:  97.48065948486328 mkt_quantity:  93
# Asset:  IYM symbol_value:  66.35378265380861 mkt_quantity:  137
# Asset:  IYG symbol_value:  83.15886688232422 mkt_quantity:  109
# Asset:  IYZ symbol_value:  26.1269588470459 mkt_quantity:  347
# Asset:  FCL symbol_value:  62.79999923706055 mkt_quantity:  144
# Asset:  IYH symbol_value:  136.45181274414062 mkt_quantity:  66
# Asset:  FCL symbol_value:  63.11999893188477 mkt_quantity:  144
# Asset:  IDU symbol_value:  93.4811019897461 mkt_quantity:  97
# Asset:  IYR symbol_value:  63.08255386352539 mkt_quantity:  144
# Asset:  FCL symbol_value:  59.13000106811523 mkt_quantity:  153
# Asset:  IYZ symbol_value:  26.97210693359375 mkt_quantity:  337
# Asset:  IYE symbol_value:  33.615970611572266 mkt_quantity:  270
# Asset:  IYW symbol_value:  106.06974029541016 mkt_quantity:  85
# Asset:  IYM symbol_value:  69.09239959716797 mkt_quantity:  131
# Asset:  IYM symbol_value:  69.29804992675781 mkt_quantity:  131
# Asset:  IYH symbol_value:  140.4813232421875 mkt_quantity:  64
# Asset:  IYH symbol_value:  141.58712768554688 mkt_quantity:  64
# Asset:  IYW symbol_value:  106.51202392578124 mkt_quantity:  85
# Asset:  IYR symbol_value:  63.4186019897461 mkt_quantity:  143
# Asset:  IYG symbol_value:  85.47093963623047 mkt_quantity:  106
# Asset:  IYJ symbol_value:  98.07624053955078 mkt_quantity:  92
# Asset:  IYM symbol_value:  65.4190673828125 mkt_quantity:  138
# Asset:  IYH symbol_value:  138.81329345703122 mkt_quantity:  65
# Asset:  IYR symbol_value:  64.93514251708984 mkt_quantity:  139
# Asset:  IYW symbol_value:  101.71427154541016 mkt_quantity:  89
# Asset:  IDU symbol_value:  97.31082916259766 mkt_quantity:  93
# Asset:  IYH symbol_value:  142.46322631835938 mkt_quantity:  63
# Asset:  IYR symbol_value:  66.31632995605469 mkt_quantity:  137
# Asset:  FCD symbol_value:  18.3799991607666 mkt_quantity:  494
# Asset:  FCD symbol_value:  19.40999984741211 mkt_quantity:  468
# Asset:  IYH symbol_value:  132.45797729492188 mkt_quantity:  68
# Asset:  IYR symbol_value:  61.56013107299805 mkt_quantity:  147
# Asset:  FCD symbol_value:  18.690000534057614 mkt_quantity:  486
# Asset:  FCL symbol_value:  52.5 mkt_quantity:  173
# Asset:  IYZ symbol_value:  24.04135131835937 mkt_quantity:  378
# Asset:  IYE symbol_value:  27.750078201293945 mkt_quantity:  327
# Asset:  IYM symbol_value:  60.02943420410156 mkt_quantity:  151
# Asset:  IYJ symbol_value:  88.26973724365234 mkt_quantity:  102
# Asset:  FCL symbol_value:  50.599998474121094 mkt_quantity:  179
# Asset:  IYW symbol_value:  96.77374267578124 mkt_quantity:  93
# Asset:  IYH symbol_value:  129.68797302246094 mkt_quantity:  70
# Asset:  IYG symbol_value:  75.0384750366211 mkt_quantity:  121
# Asset:  IYR symbol_value:  63.98622512817383 mkt_quantity:  142
# Asset:  FCD symbol_value:  18.11000061035156 mkt_quantity:  501
# Asset:  FCD symbol_value:  17.549999237060547 mkt_quantity:  518
# Asset:  IYE symbol_value:  31.85380744934082 mkt_quantity:  285
# Asset:  IYG symbol_value:  74.83870697021484 mkt_quantity:  121
# Asset:  IYE symbol_value:  32.80914688110352 mkt_quantity:  277
# Asset:  IYG symbol_value:  79.57772827148438 mkt_quantity:  114
# Asset:  FCL symbol_value:  42.79999923706055 mkt_quantity:  212
# Asset:  IDU symbol_value:  108.48970794677734 mkt_quantity:  83
# Asset:  FCL symbol_value:  42.5 mkt_quantity:  213
# Asset:  IYW symbol_value:  102.35202026367188 mkt_quantity:  88
# Asset:  IYR symbol_value:  67.61038208007811 mkt_quantity:  134
# Asset:  FCD symbol_value:  17.424999237060547 mkt_quantity:  521
# Asset:  IYR symbol_value:  70.78956604003906 mkt_quantity:  128
# Asset:  FCD symbol_value:  17.424999237060547 mkt_quantity:  521
# Asset:  IYH symbol_value:  138.91500854492188 mkt_quantity:  65
# Asset:  IDU symbol_value:  111.34849548339844 mkt_quantity:  81
# Asset:  IYZ symbol_value:  28.059648513793945 mkt_quantity:  323
# Asset:  IYM symbol_value:  70.6453628540039 mkt_quantity:  128
# Asset:  IYG symbol_value:  78.25080871582031 mkt_quantity:  116
# Asset:  IYJ symbol_value:  102.1519546508789 mkt_quantity:  88
# Asset:  FCL symbol_value:  45.88999938964844 mkt_quantity:  198
# Asset:  IYE symbol_value:  33.89187240600586 mkt_quantity:  268
# Asset:  IYR symbol_value:  68.79374694824219 mkt_quantity:  132
# Asset:  IYW symbol_value:  103.90104675292969 mkt_quantity:  87
# Asset:  FCD symbol_value:  17.780000686645508 mkt_quantity:  511
# Asset:  IYE symbol_value:  34.082935333251946 mkt_quantity:  266
# Asset:  IYG symbol_value:  82.86662292480469 mkt_quantity:  109
# Asset:  IDU symbol_value:  111.25804901123048 mkt_quantity:  81
# Asset:  IYM symbol_value:  72.71178436279297 mkt_quantity:  125
# Asset:  IYH symbol_value:  141.3309326171875 mkt_quantity:  64
# Asset:  IYZ symbol_value:  28.371013641357425 mkt_quantity:  320
# Asset:  IYJ symbol_value:  104.72528076171876 mkt_quantity:  86
# Asset:  IDU symbol_value:  113.24834442138672 mkt_quantity:  80
# Asset:  IYR symbol_value:  70.19786834716797 mkt_quantity:  129
# Asset:  FCL symbol_value:  43.11000061035156 mkt_quantity:  210
# ...
# Asset:  IYR symbol_value:  74.69168090820312 mkt_quantity:  121
# Asset:  IYZ symbol_value:  30.468074798583984 mkt_quantity:  298
# Asset:  IYR symbol_value:  75.97415161132812 mkt_quantity:  119
# Asset:  IDU symbol_value:  128.91255187988278 mkt_quantity:  70
# Asset:  IYZ symbol_value:  28.815731048583984 mkt_quantity:  315
# Asset:  IYE symbol_value:  34.589649200439446 mkt_quantity:  262
# Asset:  IYR symbol_value:  74.86954498291016 mkt_quantity:  121
# Asset:  IYH symbol_value:  165.16783142089844 mkt_quantity:  55
# Asset:  IYE symbol_value:  36.35037231445313 mkt_quantity:  250
# Asset:  IYR symbol_value:  77.23788452148438 mkt_quantity:  117
# Asset:  IYJ symbol_value:  136.23680114746094 mkt_quantity:  66
# Asset:  IYM symbol_value:  93.55976104736328 mkt_quantity:  97
# Asset:  IYG symbol_value:  118.08660888671876 mkt_quantity:  76
# Asset:  IYE symbol_value:  34.816837310791016 mkt_quantity:  261
# Asset:  IYG symbol_value:  124.03785705566406 mkt_quantity:  73
# Asset:  IYH symbol_value:  170.38954162597656 mkt_quantity:  53
# Asset:  IYJ symbol_value:  142.12245178222656 mkt_quantity:  63
# Asset:  IYM symbol_value:  96.20968627929688 mkt_quantity:  94
# Asset:  IYZ symbol_value:  28.80617904663086 mkt_quantity:  315
# Asset:  IYR symbol_value:  76.36731719970703 mkt_quantity:  119
# Asset:  IYW symbol_value:  159.4385528564453 mkt_quantity:  57
# Asset:  IYE symbol_value:  36.20837783813477 mkt_quantity:  251
# Asset:  IDU symbol_value:  131.08050537109378 mkt_quantity:  69
# Asset:  IYW symbol_value:  162.4380645751953 mkt_quantity:  55
# Asset:  IYZ symbol_value:  28.07619285583496 mkt_quantity:  323
# Asset:  IYZ symbol_value:  28.471364974975586 mkt_quantity:  319
# Asset:  IYZ symbol_value:  28.481000900268555 mkt_quantity:  319
# Asset:  IYZ symbol_value:  28.452083587646484 mkt_quantity:  319
# Asset:  IYM symbol_value:  98.3431625366211 mkt_quantity:  92
# Asset:  IYZ symbol_value:  27.03526496887207 mkt_quantity:  336
# Asset:  IYE symbol_value:  36.40025329589844 mkt_quantity:  249
# Asset:  IYJ symbol_value:  138.39593505859378 mkt_quantity:  65
# Asset:  IYW symbol_value:  155.63986206054688 mkt_quantity:  58
# Asset:  IYG symbol_value:  127.25653839111328 mkt_quantity:  71
# Asset:  IYH symbol_value:  168.25985717773438 mkt_quantity:  54
# Asset:  IYW symbol_value:  172.60585021972656 mkt_quantity:  52
# Asset:  IYG symbol_value:  131.07423400878906 mkt_quantity:  69
# Asset:  IDU symbol_value:  119.34140014648438 mkt_quantity:  76
# Asset:  IYM symbol_value:  99.604736328125 mkt_quantity:  91
# Asset:  IYJ symbol_value:  145.7637176513672 mkt_quantity:  62
# Asset:  IYZ symbol_value:  27.6617488861084 mkt_quantity:  328
# Asset:  IYH symbol_value:  175.4217071533203 mkt_quantity:  51
# Asset:  IYR symbol_value:  71.77522277832031 mkt_quantity:  126
# Asset:  IYM symbol_value:  96.02384185791016 mkt_quantity:  94
# Asset:  IYE symbol_value:  36.05767059326172 mkt_quantity:  252
# Asset:  IYZ symbol_value:  25.95863342285156 mkt_quantity:  350
# Asset:  IYG symbol_value:  124.20460510253906 mkt_quantity:  73
# Asset:  IYJ symbol_value:  139.37040710449222 mkt_quantity:  65
# Asset:  IYH symbol_value:  168.3215789794922 mkt_quantity:  54
# Asset:  IYE symbol_value:  34.71453094482422 mkt_quantity:  261
# Asset:  IYW symbol_value:  162.52224731445312 mkt_quantity:  55
# Asset:  IYE symbol_value:  35.39520263671875 mkt_quantity:  256
# Asset:  IYM symbol_value:  99.62122344970705 mkt_quantity:  91
# Asset:  IYZ symbol_value:  27.09486961364746 mkt_quantity:  335
# Asset:  IYJ symbol_value:  144.35877990722656 mkt_quantity:  62
# Asset:  IYR symbol_value:  70.56770324707031 mkt_quantity:  128
# Asset:  IYW symbol_value:  167.360107421875 mkt_quantity:  54
# Asset:  IYH symbol_value:  168.60418701171875 mkt_quantity:  53
# Asset:  IYG symbol_value:  127.79952239990234 mkt_quantity:  71
# Asset:  IYR symbol_value:  72.15113067626953 mkt_quantity:  125
# Asset:  IYJ symbol_value:  137.88076782226562 mkt_quantity:  65
# Asset:  IYR symbol_value:  72.43730926513672 mkt_quantity:  125
# Asset:  IYR symbol_value:  73.20040130615234 mkt_quantity:  124
# Asset:  IYM symbol_value:  96.04803466796876 mkt_quantity:  94
# Asset:  IYZ symbol_value:  26.453916549682607 mkt_quantity:  343
# Asset:  IYH symbol_value:  166.21670532226562 mkt_quantity:  54
# Asset:  IYM symbol_value:  99.9230499267578 mkt_quantity:  90
# Asset:  IDU symbol_value:  119.3550033569336 mkt_quantity:  76
# Asset:  IYJ symbol_value:  145.2701873779297 mkt_quantity:  62
# Asset:  IYH symbol_value:  172.59951782226562 mkt_quantity:  52
# Asset:  IYZ symbol_value:  26.706411361694336 mkt_quantity:  340
# Asset:  IYE symbol_value:  40.53384017944336 mkt_quantity:  224
# Asset:  IYG symbol_value:  133.22598266601562 mkt_quantity:  68
# Asset:  IYG symbol_value:  131.11189270019528 mkt_quantity:  69
# Asset:  IYM symbol_value:  95.83383178710938 mkt_quantity:  94
# Asset:  IYG symbol_value:  127.73130798339844 mkt_quantity:  71
# Asset:  IDU symbol_value:  126.62899780273438 mkt_quantity:  71
# Asset:  IYJ symbol_value:  141.50111389160156 mkt_quantity:  64
# Asset:  IYW symbol_value:  176.59336853027344 mkt_quantity:  51
# Asset:  IYH symbol_value:  180.7348937988281 mkt_quantity:  50
# Asset:  IYE symbol_value:  41.21143341064453 mkt_quantity:  220
# Asset:  IYH symbol_value:  182.28884887695312 mkt_quantity:  49
# Asset:  IYW symbol_value:  186.1314697265625 mkt_quantity:  48
# Asset:  IYM symbol_value:  97.56588745117188 mkt_quantity:  93
# Asset:  IYG symbol_value:  131.18051147460938 mkt_quantity:  69
# Asset:  IYJ symbol_value:  146.5747528076172 mkt_quantity:  62
# Asset:  IYR symbol_value:  76.8310546875 mkt_quantity:  118
# Asset:  IYZ symbol_value:  27.007610321044922 mkt_quantity:  336
# Asset:  IYR symbol_value:  78.4780502319336 mkt_quantity:  115
# Asset:  IYZ symbol_value:  27.907211303710927 mkt_quantity:  325
# Asset:  IYE symbol_value:  39.47581100463867 mkt_quantity:  230
# Asset:  IYW symbol_value:  186.3194274902344 mkt_quantity:  48
# Asset:  IYW symbol_value:  187.4770812988281 mkt_quantity:  48
# Asset:  IYM symbol_value:  96.65633392333984 mkt_quantity:  94
# Asset:  IYG symbol_value:  134.06541442871094 mkt_quantity:  67
# Asset:  IYG symbol_value:  135.52255249023438 mkt_quantity:  67
# Asset:  IYM symbol_value:  99.16980743408205 mkt_quantity:  91
# Asset:  IYE symbol_value:  38.63692474365234 mkt_quantity:  235
# Asset:  IYE symbol_value:  38.62728500366211 mkt_quantity:  235
# Asset:  IYG symbol_value:  135.12158203125 mkt_quantity:  67
# Asset:  IYR symbol_value:  78.15057373046875 mkt_quantity:  116
# Asset:  IYW symbol_value:  190.81146240234366 mkt_quantity:  47
# Asset:  IYE symbol_value:  40.89323425292969 mkt_quantity:  222
# Asset:  IDU symbol_value:  127.29358673095705 mkt_quantity:  71
# Asset:  IYM symbol_value:  97.07585906982422 mkt_quantity:  93
# Asset:  IYW symbol_value:  193.32192993164062 mkt_quantity:  47
# Asset:  IYZ symbol_value:  27.858238220214844 mkt_quantity:  326
# Asset:  IYJ symbol_value:  145.65573120117188 mkt_quantity:  62
# Asset:  IYW symbol_value:  177.01434326171875 mkt_quantity:  51
# Asset:  IYH symbol_value:  188.215576171875 mkt_quantity:  48
# Asset:  IDU symbol_value:  131.1654052734375 mkt_quantity:  69
# Asset:  IYE symbol_value:  38.736366271972656 mkt_quantity:  234
# Asset:  IYR symbol_value:  76.71089172363281 mkt_quantity:  118
# Asset:  IYM symbol_value:  88.54786682128906 mkt_quantity:  102
# Asset:  IYZ symbol_value:  27.65173530578613 mkt_quantity:  328
# Asset:  IYG symbol_value:  124.39060974121094 mkt_quantity:  73
# Asset:  IYH symbol_value:  186.7752990722656 mkt_quantity:  48
# Asset:  IYJ symbol_value:  140.94189453125 mkt_quantity:  64
# Asset:  IYZ symbol_value:  27.65173530578613 mkt_quantity:  328
# Asset:  IYJ symbol_value:  137.11558532714844 mkt_quantity:  66
# Asset:  IYM symbol_value:  88.9894790649414 mkt_quantity:  102
# Asset:  IYG symbol_value:  121.37727355957031 mkt_quantity:  74
# Asset:  IYH symbol_value:  178.6324462890625 mkt_quantity:  50
# Asset:  IYR symbol_value:  75.09014129638672 mkt_quantity:  121
# Asset:  IDU symbol_value:  129.5987548828125 mkt_quantity:  70
# Asset:  IYM symbol_value:  85.8260726928711 mkt_quantity:  105
# Asset:  IYZ symbol_value:  27.24856185913086 mkt_quantity:  333
# Asset:  IYG symbol_value:  116.54653930664062 mkt_quantity:  78
# Asset:  IYJ symbol_value:  133.72297668457028 mkt_quantity:  67
# Asset:  IYE symbol_value:  33.098392486572266 mkt_quantity:  274
# Asset:  IYH symbol_value:  183.9874420166016 mkt_quantity:  49
# Asset:  IYW symbol_value:  165.1595001220703 mkt_quantity:  55
# Asset:  IYR symbol_value:  77.64369201660156 mkt_quantity:  117
# Asset:  IDU symbol_value:  134.33351135253906 mkt_quantity:  67
# Asset:  IYH symbol_value:  192.1109313964844 mkt_quantity:  47
# Asset:  IYJ symbol_value:  149.299072265625 mkt_quantity:  60
# Asset:  IYM symbol_value:  90.68824005126952 mkt_quantity:  100
# Asset:  IYZ symbol_value:  28.98257064819336 mkt_quantity:  313
# Asset:  IYZ symbol_value:  29.16062164306641 mkt_quantity:  311
# Asset:  IYG symbol_value:  121.2874984741211 mkt_quantity:  74
# Asset:  IYH symbol_value:  191.31320190429688 mkt_quantity:  47
# Asset:  IYJ symbol_value:  153.4373779296875 mkt_quantity:  59
# Asset:  IYM symbol_value:  94.61486053466795 mkt_quantity:  96
# Asset:  IYG symbol_value:  127.80982208251952 mkt_quantity:  71
# Asset:  IDU symbol_value:  144.562744140625 mkt_quantity:  62
# Asset:  IYH symbol_value:  185.27381896972656 mkt_quantity:  49
# Asset:  IYR symbol_value:  84.93633270263672 mkt_quantity:  107
# Asset:  IYE symbol_value:  33.985599517822266 mkt_quantity:  267
# Asset:  IYM symbol_value:  91.42015075683594 mkt_quantity:  99
# Asset:  IYZ symbol_value:  29.496936798095703 mkt_quantity:  308
# Asset:  IDU symbol_value:  144.80914306640625 mkt_quantity:  62
# Asset:  IYJ symbol_value:  149.30303955078125 mkt_quantity:  60
# Asset:  IYR symbol_value:  85.862548828125 mkt_quantity:  105
# Asset:  IYW symbol_value:  190.5080718994141 mkt_quantity:  47
# Asset:  IYH symbol_value:  183.70437622070312 mkt_quantity:  49
# Asset:  IYG symbol_value:  129.48501586914062 mkt_quantity:  70
# Asset:  IYH symbol_value:  186.94259643554688 mkt_quantity:  48
# Asset:  IYH symbol_value:  190.48873901367188 mkt_quantity:  47
# Asset:  IYM symbol_value:  91.70697784423828 mkt_quantity:  99
# Asset:  IYJ symbol_value:  153.61627197265625 mkt_quantity:  59
# Asset:  IYZ symbol_value:  29.19668388366699 mkt_quantity:  311
# Asset:  IYG symbol_value:  129.74465942382812 mkt_quantity:  70
# Asset:  IYW symbol_value:  196.0495758056641 mkt_quantity:  46
# Asset:  IYE symbol_value:  33.745986938476555 mkt_quantity:  269
# Asset:  IYR symbol_value:  90.31548309326172 mkt_quantity:  100
# Asset:  IYR symbol_value:  89.14384460449219 mkt_quantity:  101
# Asset:  IYH symbol_value:  193.5808868408203 mkt_quantity:  46
# Asset:  IYE symbol_value:  33.240245819091804 mkt_quantity:  273
# Asset:  IYR symbol_value:  88.1608657836914 mkt_quantity:  103
# Asset:  IDU symbol_value:  150.4009246826172 mkt_quantity:  60
# Asset:  IYM symbol_value:  89.15234375 mkt_quantity:  101
# Asset:  IYZ symbol_value:  28.34088516235352 mkt_quantity:  320
# Asset:  IYJ symbol_value:  152.9951934814453 mkt_quantity:  59
# Asset:  IYG symbol_value:  133.34867858886722 mkt_quantity:  68
# Asset:  IYW symbol_value:  201.92697143554688 mkt_quantity:  45
# Asset:  IYR symbol_value:  90.80200958251952 mkt_quantity:  100
# Asset:  IDU symbol_value:  153.58847045898438 mkt_quantity:  59
# Asset:  IYJ symbol_value:  158.42832946777344 mkt_quantity:  57
# Asset:  IYW symbol_value:  205.23985290527344 mkt_quantity:  44
# Asset:  IYG symbol_value:  136.55445861816406 mkt_quantity:  66
# Asset:  IYM symbol_value:  92.44470977783205 mkt_quantity:  98
# Asset:  IYZ symbol_value:  29.71414375305176 mkt_quantity:  305
# Asset:  IYE symbol_value:  32.486587524414055 mkt_quantity:  279
# Asset:  IYH symbol_value:  191.81781005859366 mkt_quantity:  47
# Asset:  IYH symbol_value:  184.3600006103516 mkt_quantity:  49
# Asset:  IYJ symbol_value:  153.50999450683594 mkt_quantity:  59
# Asset:  IYE symbol_value:  30.770000457763672 mkt_quantity:  295
# Asset:  IYG symbol_value:  133.74000549316406 mkt_quantity:  67
# Asset:  IYW symbol_value:  204.4199981689453 mkt_quantity:  44
# Asset:  IYM symbol_value:  88.91999816894531 mkt_quantity:  102
# Asset:  IYZ symbol_value:  28.71999931335449 mkt_quantity:  316
# Asset:  IYW symbol_value:  205.5500030517578 mkt_quantity:  44
# Asset:  IDU symbol_value:  160.6300048828125 mkt_quantity:  56
# Asset:  IYZ symbol_value:  29.59000015258789 mkt_quantity:  307
# Asset:  IYH symbol_value:  192.57000732421875 mkt_quantity:  47
# Asset:  IYG symbol_value:  139.27000427246094 mkt_quantity:  65
# Asset:  IYJ symbol_value:  159.67999267578125 mkt_quantity:  56
# Asset:  IYM symbol_value:  92.18000030517578 mkt_quantity:  98
# Asset:  IYE symbol_value:  31.81999969482422 mkt_quantity:  285
# Asset:  IYR symbol_value:  91.33000183105469 mkt_quantity:  99
# Asset:  IYE symbol_value:  31.670000076293945 mkt_quantity:  287
# Creating summary stats...
# Creating equity curve...
#                     FCD  FCL  IDU          IYE          IYG          IYH  \
# datetime
# 2019-11-15  9194.085079  0.0  0.0  9151.350174  9485.449524  9617.139771
# 2019-11-18  9194.085079  0.0  0.0  9034.500217  9495.200119  9586.590057
# 2019-11-19  9194.085079  0.0  0.0  8903.399935  9543.950119  9662.729828
# 2019-11-20  9194.085079  0.0  0.0  8997.449913  9500.400238  9656.149857
# 2019-11-21  9194.085079  0.0  0.0  9139.949913  9495.849762  9678.239914
# 2019-11-22  9194.085079  0.0  0.0  9108.599739  9549.799881  9712.549713
# 2019-11-25  9194.085079  0.0  0.0  9131.400261  9638.199921  9842.270172
# 2019-11-26  9194.085079  0.0  0.0  9025.950022  9620.000000  9830.049713
# 2019-11-27  9194.085079  0.0  0.0     0.000000  9672.649841  9887.860229
# 2019-11-27  9194.085079  0.0  0.0     0.000000  9672.649841  9887.860229
#
#                     IYJ          IYM  IYR          IYW          IYZ  \
# datetime
# 2019-11-15  9368.800171  9442.299850  0.0  9776.799866  9154.739906
# 2019-11-18  9352.000000  9414.859970  0.0  9797.040161  9176.229813
# 2019-11-19  9361.519897  9375.659821  0.0  9809.799866  9099.479813
# 2019-11-20  9299.359863  9268.840179  0.0  9752.159973  9025.799883
# 2019-11-21  9271.359863  9266.879761  0.0  9716.080322  9025.799883
# 2019-11-22  9297.679932  9281.579910  0.0  9713.880188  9062.640141
# 2019-11-25  9382.239624  9337.439880  0.0  9848.080322  9068.780281
# 2019-11-26  9431.519897  9359.980209  0.0  9842.799866  9071.849766
# 2019-11-27  9442.719727  9398.200150  0.0  9889.000000  9105.619953
# 2019-11-27  9442.719727  9398.200150  0.0  9889.000000  9105.619953
#
#                     cash  commission          total   returns  equity_curve  \
# datetime
# 2019-11-15  77952.158229         0.0  153142.822570  0.003421      1.531428
# 2019-11-18  77952.158229         0.0  153002.663646 -0.000915      1.530027
# 2019-11-19  77952.158229         0.0  152902.782586 -0.000653      1.529028
# 2019-11-20  77952.158229         0.0  152646.403214 -0.001677      1.526464
# 2019-11-21  77952.158229         0.0  152740.402726  0.000616      1.527404
# 2019-11-22  77952.158229         0.0  152872.972812  0.000868      1.528730
# 2019-11-25  77952.158229         0.0  153394.653769  0.003413      1.533947
# 2019-11-26  77952.158229         0.0  153328.392781 -0.000432      1.533284
# 2019-11-27  86978.108251         0.0  153568.243230  0.001564      1.535682
# 2019-11-27  86978.108251         0.0  153568.243230  0.000000      1.535682
#
#             drawdown
# datetime
# 2019-11-15  0.025738
# 2019-11-18  0.027140
# 2019-11-19  0.028139
# 2019-11-20  0.030703
# 2019-11-21  0.029763
# 2019-11-22  0.028437
# 2019-11-25  0.023220
# 2019-11-26  0.023883
# 2019-11-27  0.021484
# 2019-11-27  0.021484
# [('Total Return', '53.57%'),
#  ('Sharpe Ratio', '13.42'),
#  ('Max Drawdown', '17.24%'),
#  ('Drawdown Duration', '464')]
# Signals: 1091
# Orders: 1091
# Fills: 1091

# %%
53.57/9
# Out:
# 5.952222222222222

# %% [markdown]
# https://www.xuebuyuan.com/3244260.html
#
#
# - VOX	Vanguard Telecommunication Services ETF
# - ======================
# - IYM	iShares Dow Jones U.S. Basic Materials Sector Index Fund
# - IYZ	iShares Dow Jones U.S. Telecommunications Sector Index Fund
# - FCL	Focus Morningstar Consumer Cyclical Index ETF
# - FCD	Focus Morningstar Consumer Defensive Index ETF
# - IYE	iShares Dow Jones U.S. Energy Sector Index Fund
# - IYG	iShares Dow Jones U.S. Financial Services Index Fund
# - IYH	iShares Dow Jones U.S. Healthcare Sector Index Fund
# - IYJ	iShares Dow Jones U.S. Industrial Sector Index Fund
# - IYR	iShares Dow Jones U.S. Real Estate Index Fund
# - IYW	iShares Dow Jones U.S. Technology Sector Index Fund
# - IDU	iShares Dow Jones U.S. Utilities Sector Index Fund

# %%
df_equity
# Out:
#               datetime           FCD           FCL          IDU          IYE  \
# datetime
# 2010-04-05  2010-04-05   9422.584153   9988.000000  9362.664780  9667.915306
# 2010-04-06  2010-04-06   9888.376518   9947.139931  9441.501228     0.000000
# 2010-04-07  2010-04-07   9830.152111   9988.000000  9361.391693     0.000000
# 2010-04-08  2010-04-08   9949.025593   9988.000000  9306.715347     0.000000
# 2010-04-09  2010-04-09   9429.862204   9988.000000  9357.576416  9162.066940
# 2010-04-12  2010-04-12   9525.689199   9988.000000  9398.270050  9183.263332
# 2010-04-13  2010-04-13   9528.115023   9988.000000  9365.205643  9135.572849
# 2010-04-14  2010-04-14   9522.049884   9988.000000  9375.379715  9241.554188
# 2010-04-15  2010-04-15   9522.049884   9761.000000  9369.022247  9249.497627
# 2010-04-16  2010-04-16  10806.617481   9704.250000  9272.380508  9098.478386
# 2010-04-19  2010-04-19  10680.465370   9974.379688  9282.553917  9111.724499
# 2010-04-20  2010-04-20  10568.869361  10078.800346  9389.366409  9307.788483
# 2010-04-21  2010-04-21  10800.552342   9799.589584  9395.721886  9268.046413
# 2010-04-22  2010-04-22  10644.074537   9647.500000  9437.686615  9289.242184
# 2010-04-23  2010-04-23  10850.284630   9647.500000  9507.621414  9501.205482
# 2010-04-26  2010-04-26  10767.800824   9647.500000  9483.463303  9456.162605
# 2010-04-27  2010-04-27  11134.126880   9577.129688  9319.428955  9185.910938
# 2010-04-28  2010-04-28  10705.938259   9420.500000  9396.994972  9297.190598
# 2010-04-29  2010-04-29  10695.021472      0.000000  9432.600243  9283.943241
# 2010-04-30  2010-04-30  10770.226648      0.000000  9451.673973  9183.263332
# 2010-05-03  2010-05-03  10134.614445      0.000000  9586.461182  9275.996693
# 2010-05-04  2010-05-04  10173.431102      0.000000  9421.156403  9026.939552
# 2010-05-05  2010-05-05   9843.494722      0.000000  9334.689400  8894.464745
# 2010-05-06  2010-05-06   9843.494722      0.000000  9072.743546  8571.221165
# 2010-05-07  2010-05-07   9575.422065      0.000000  9000.261246  8430.796078
# 2010-05-10  2010-05-10   9236.994722      0.000000  9305.440933     0.000000
# 2010-05-11  2010-05-11   9218.799884      0.000000     0.000000     0.000000
# 2010-05-12  2010-05-12   9797.400593      0.000000     0.000000     0.000000
# 2010-05-13  2010-05-13      0.000000      0.000000     0.000000     0.000000
# 2010-05-14  2010-05-14      0.000000      0.000000     0.000000     0.000000
# ...                ...           ...           ...          ...          ...
# 2019-10-17  2019-10-17   9194.085079      0.000000  9441.180252     0.000000
# 2019-10-18  2019-10-18   9194.085079      0.000000  9477.170288     0.000000
# 2019-10-21  2019-10-21   9194.085079      0.000000     0.000000     0.000000
# 2019-10-22  2019-10-22   9194.085079      0.000000     0.000000     0.000000
# 2019-10-23  2019-10-23   9194.085079      0.000000     0.000000     0.000000
# 2019-10-24  2019-10-24   9194.085079      0.000000     0.000000     0.000000
# 2019-10-25  2019-10-25   9194.085079      0.000000     0.000000     0.000000
# 2019-10-28  2019-10-28   9194.085079      0.000000     0.000000     0.000000
# 2019-10-29  2019-10-29   9194.085079      0.000000     0.000000     0.000000
# 2019-10-30  2019-10-30   9194.085079      0.000000     0.000000  8880.599957
# 2019-10-31  2019-10-31   9194.085079      0.000000     0.000000  8843.550196
# 2019-11-01  2019-11-01   9194.085079      0.000000     0.000000  9057.300196
# 2019-11-04  2019-11-04   9194.085079      0.000000     0.000000  9342.299652
# 2019-11-05  2019-11-05   9194.085079      0.000000     0.000000  9382.199478
# 2019-11-06  2019-11-06   9194.085079      0.000000     0.000000  9165.599957
# 2019-11-07  2019-11-07   9194.085079      0.000000     0.000000  9308.099957
# 2019-11-08  2019-11-08   9194.085079      0.000000     0.000000  9268.200130
# 2019-11-11  2019-11-11   9194.085079      0.000000     0.000000  9208.350391
# 2019-11-12  2019-11-12   9194.085079      0.000000     0.000000  9151.350174
# 2019-11-13  2019-11-13   9194.085079      0.000000     0.000000  9105.750217
# 2019-11-14  2019-11-14   9194.085079      0.000000     0.000000  9080.100174
# 2019-11-15  2019-11-15   9194.085079      0.000000     0.000000  9151.350174
# 2019-11-18  2019-11-18   9194.085079      0.000000     0.000000  9034.500217
# 2019-11-19  2019-11-19   9194.085079      0.000000     0.000000  8903.399935
# 2019-11-20  2019-11-20   9194.085079      0.000000     0.000000  8997.449913
# 2019-11-21  2019-11-21   9194.085079      0.000000     0.000000  9139.949913
# 2019-11-22  2019-11-22   9194.085079      0.000000     0.000000  9108.599739
# 2019-11-25  2019-11-25   9194.085079      0.000000     0.000000  9131.400261
# 2019-11-26  2019-11-26   9194.085079      0.000000     0.000000  9025.950022
# 2019-11-27  2019-11-27   9194.085079      0.000000     0.000000     0.000000
#
#                      IYG          IYH           IYJ           IYM  \
# datetime
# 2010-04-05  10076.815922  9290.798866  10029.635582  10227.718445
# 2010-04-06  10208.596241  9274.054852  10027.943287  10261.860474
# 2010-04-07  10181.905643  9234.987122   9977.176666  10205.989594
# 2010-04-08  10285.326302  9215.456635  10004.251156  10223.060608
# 2010-04-09  10322.021908  9251.728680  10073.632278  10255.654938
# 2010-04-12  10392.081482  9239.172665  10095.632114  10226.165833
# 2010-04-13  10367.060669  9246.152050  10119.319782  10198.229340
# 2010-04-14  10683.993851  9222.431721  10258.080540  10289.799072
# 2010-04-15  10672.317616  9212.667091  10332.537060  10268.071625
# 2010-04-16  10246.960911     0.000000  10192.085495  10041.477966
# 2010-04-19  10332.031242     0.000000  10173.473225  10005.780518
# 2010-04-20  10467.145363     0.000000  10276.694298  10039.925354
# 2010-04-21  10418.771358     0.000000  10354.533920  10029.061981
# 2010-04-22  10487.161148     0.000000  10445.913391  10100.454071
# 2010-04-23  10502.174068     0.000000  10532.215977  10271.176147
# 2010-04-26  10290.329166     0.000000  10550.830479  10268.071625
# 2010-04-27   9975.062885     0.000000  10266.541271   9937.493652
# 2010-04-28  10108.508663     0.000000  10354.533920  10050.790131
# 2010-04-29  10323.690971     0.000000  10545.755081  10150.117310
# 2010-04-30  10073.482121     0.000000  10313.926277   9937.493652
# 2010-05-03  10245.291126     0.000000  10503.449192   9937.493652
# 2010-05-04   9970.060741     0.000000  10173.473225      0.000000
# 2010-05-05   9908.340717     0.000000  10024.558697      0.000000
# 2010-05-06      0.000000     0.000000   9725.038834      0.000000
# 2010-05-07      0.000000     0.000000   9488.132401      0.000000
# 2010-05-10      0.000000     0.000000  10005.944939      0.000000
# 2010-05-11      0.000000     0.000000  10000.867310      0.000000
# 2010-05-12      0.000000     0.000000      0.000000      0.000000
# 2010-05-13      0.000000     0.000000      0.000000      0.000000
# 2010-05-14      0.000000     0.000000      0.000000      0.000000
# ...                  ...          ...           ...           ...
# 2019-10-17      0.000000     0.000000      0.000000      0.000000
# 2019-10-18      0.000000     0.000000      0.000000      0.000000
# 2019-10-21      0.000000     0.000000      0.000000      0.000000
# 2019-10-22      0.000000     0.000000      0.000000      0.000000
# 2019-10-23      0.000000  9104.840057      0.000000      0.000000
# 2019-10-24   9091.549683  9050.319885      0.000000      0.000000
# 2019-10-25   9152.649841  9071.000000   8990.239624      0.000000
# 2019-10-28   9233.899841  9170.639771   9013.760376   9076.760269
# 2019-10-29   9235.849762  9285.790344   9036.719727   9144.379761
# 2019-10-30   9227.400436  9332.790344   9066.399658   9118.900299
# 2019-10-31   9166.949921  9320.100143   8980.719727   9038.540329
# 2019-11-01   9305.400238  9352.059799   9145.359863   9198.280060
# 2019-11-04   9381.450119  9326.680115   9218.160034   9309.019791
# 2019-11-05   9380.149841  9243.959656   9208.640137   9361.939880
# 2019-11-06   9388.600159  9280.620316   9213.679932   9334.500000
# 2019-11-07   9470.499802  9305.530258   9245.600342   9441.319641
# 2019-11-08   9485.449524  9393.420029   9264.640137   9476.599701
# 2019-11-11   9473.100357  9356.760086   9275.839966   9460.920090
# 2019-11-12   9473.750000  9405.170029   9280.879761   9492.280060
# 2019-11-13   9419.799881  9417.389771   9269.120239   9409.959671
# 2019-11-14   9443.849564  9415.510086   9311.679932   9449.159821
# 2019-11-15   9485.449524  9617.139771   9368.800171   9442.299850
# 2019-11-18   9495.200119  9586.590057   9352.000000   9414.859970
# 2019-11-19   9543.950119  9662.729828   9361.519897   9375.659821
# 2019-11-20   9500.400238  9656.149857   9299.359863   9268.840179
# 2019-11-21   9495.849762  9678.239914   9271.359863   9266.879761
# 2019-11-22   9549.799881  9712.549713   9297.679932   9281.579910
# 2019-11-25   9638.199921  9842.270172   9382.239624   9337.439880
# 2019-11-26   9620.000000  9830.049713   9431.519897   9359.980209
# 2019-11-27   9672.649841  9887.860229   9442.719727   9398.200150
#
#                      IYR           IYW           IYZ           cash  \
# datetime
# 2010-04-05  10194.800205   9782.995316  10030.971863   -3445.364504
# 2010-04-06  10400.493050   9799.533218   9996.634102    6222.550802
# 2010-04-07  10176.823540   9774.724983   9908.344959    6222.550802
# 2010-04-08  10180.817871   9779.685249   9986.828190    6222.550802
# 2010-04-09  10342.582855   9855.765678  10045.688217   -2849.433493
# 2010-04-12  10274.681396   9897.117340  10084.932228   -2849.433493
# 2010-04-13  10508.333473   9925.233570  10080.024780   -2849.433493
# 2010-04-14  10518.316040  10102.203354  10148.696709   -2849.433493
# 2010-04-15  10256.709080  10151.821896  10153.601761   -2849.433493
# 2010-04-16  10043.029747  10017.853283  10021.164753    6363.233599
# 2010-04-19  10080.969372  10022.814930  10050.593269    6363.233599
# 2010-04-20  10238.734589  10074.086433  10129.076500    6363.233599
# 2010-04-21  10430.448360  10113.781681  10065.307228    6363.233599
# 2010-04-22  10582.224255  10155.127129  10089.832489    6363.233599
# 2010-04-23  10720.016727  10174.976479  10104.551239    6363.233599
# 2010-04-26  10787.917099  10165.053875  10030.971863    6363.233599
# 2010-04-27  10446.426773   9973.195698   9878.914047    6363.233599
# 2010-04-28  10482.373581   9989.733601   9962.300533    6363.233599
# 2010-04-29  10915.725918  10080.701042  10109.456291   15783.733599
# 2010-04-30  10576.230583   9850.807484   9996.634102   15783.733599
# 2010-05-03  10903.742924   9988.081329  10133.981552   15783.733599
# 2010-05-04  10648.123112   9696.990902   9874.009594   25721.227251
# 2010-05-05  10498.347645   9644.065056   9834.767380   25721.227251
# 2010-05-06  10076.975040   9321.547642   9540.461254   35629.567968
# 2010-05-07   9907.225742   9101.575996      0.000000   45170.029222
# 2010-05-10  10560.255432      0.000000      0.000000   62702.401297
# 2010-05-11  10572.236252      0.000000      0.000000   72007.842230
# 2010-05-12  10743.982716      0.000000      0.000000   82008.709539
# 2010-05-13  10602.191563      0.000000      0.000000   91806.110132
# 2010-05-14  10274.681396      0.000000      0.000000   91806.110132
# ...                  ...           ...           ...            ...
# 2019-10-17   9391.999817      0.000000      0.000000  122618.078094
# 2019-10-18   9466.999817      0.000000      0.000000  122618.078094
# 2019-10-21   9536.000061   9138.799866      0.000000  123051.048247
# 2019-10-22   9505.000305   9042.880188      0.000000  123051.048247
# 2019-10-23   9518.000031   9064.880188   9077.989906  104916.127856
# 2019-10-24   9505.999756   9155.520081   8958.260094   95863.577579
# 2019-10-25   9408.999634   9265.959839   8995.099766   86921.497989
# 2019-10-28   9358.000183   9392.240295   9099.479813   77887.857959
# 2019-10-29   9390.000153   9289.720215   9065.710211   77887.857959
# 2019-10-30   9441.999817   9335.040161   9142.460211   68819.158046
# 2019-10-31   9426.000214   9328.439758   9148.599766   68819.158046
# 2019-11-01   9419.000244   9446.799866   9077.989906   68819.158046
# 2019-11-04   9345.999908   9527.319946   9068.780281   68819.158046
# 2019-11-05   9194.000244   9535.240295   9087.200117   68819.158046
# 2019-11-06   9220.999908   9519.400269   9084.130047   68819.158046
# 2019-11-07   9133.000183   9591.560242   9200.789789   68819.158046
# 2019-11-08      0.000000   9647.439758   9200.789789   77952.158229
# 2019-11-11      0.000000   9636.880188   9191.580164   77952.158229
# 2019-11-12      0.000000   9676.040161   9157.809977   77952.158229
# 2019-11-13      0.000000   9691.439758   9157.809977   77952.158229
# 2019-11-14      0.000000   9677.799866   9096.409742   77952.158229
# 2019-11-15      0.000000   9776.799866   9154.739906   77952.158229
# 2019-11-18      0.000000   9797.040161   9176.229813   77952.158229
# 2019-11-19      0.000000   9809.799866   9099.479813   77952.158229
# 2019-11-20      0.000000   9752.159973   9025.799883   77952.158229
# 2019-11-21      0.000000   9716.080322   9025.799883   77952.158229
# 2019-11-22      0.000000   9713.880188   9062.640141   77952.158229
# 2019-11-25      0.000000   9848.080322   9068.780281   77952.158229
# 2019-11-26      0.000000   9842.799866   9071.849766   77952.158229
# 2019-11-27      0.000000   9889.000000   9105.619953   86978.108251
#
#             commission          total   returns  equity_curve  drawdown
# datetime
# 2010-04-05         0.0  104629.535933  0.009601      1.046295  0.000000
# 2010-04-06         0.0  105468.683702  0.008020      1.054687  0.000000
# 2010-04-07         0.0  104862.047113 -0.005752      1.048620  0.006066
# 2010-04-08         0.0  105141.717752  0.002667      1.051417  0.003270
# 2010-04-09         0.0  105235.146622  0.000889      1.052351  0.002335
# 2010-04-12         0.0  105455.572147  0.002095      1.054556  0.000131
# 2010-04-13         0.0  105611.813687  0.001482      1.056118  0.000000
# 2010-04-14         0.0  106501.071580  0.008420      1.065011  0.000000
# 2010-04-15         0.0  106099.862394 -0.003767      1.060999  0.004012
# 2010-04-16         0.0  105807.532129 -0.002755      1.058075  0.006935
# 2010-04-19         0.0  106078.019629  0.002556      1.060780  0.004231
# 2010-04-20         0.0  106933.720735  0.008067      1.069337  0.000000
# 2010-04-21         0.0  107039.048354  0.000985      1.070390  0.000000
# 2010-04-22         0.0  107242.449417  0.001900      1.072424  0.000000
# 2010-04-23         0.0  108174.955763  0.008695      1.081750  0.000000
# 2010-04-26         0.0  107811.334437 -0.003361      1.078113  0.003636
# 2010-04-27         0.0  106057.464387 -0.016268      1.060575  0.021175
# 2010-04-28         0.0  106132.097857  0.000704      1.061321  0.020429
# 2010-04-29         0.0  107320.745168  0.011200      1.073207  0.008542
# 2010-04-30         0.0  105937.471771 -0.012889      1.059375  0.022375
# 2010-05-03         0.0  106492.845694  0.005242      1.064928  0.016821
# 2010-05-04         0.0  104705.411881 -0.016785      1.047054  0.034695
# 2010-05-05         0.0  103703.955612 -0.009565      1.037040  0.044710
# 2010-05-06         0.0  101781.050171 -0.018542      1.017811  0.063939
# 2010-05-07         0.0  100673.442750 -0.010882      1.006734  0.075015
# 2010-05-10         0.0  101811.037323  0.011300      1.018110  0.063639
# 2010-05-11         0.0  101799.745676 -0.000111      1.017997  0.063752
# 2010-05-12         0.0  102550.092848  0.007371      1.025501  0.056249
# 2010-05-13         0.0  102408.301695 -0.001383      1.024083  0.057667
# 2010-05-14         0.0  102080.791529 -0.003198      1.020808  0.060942
# ...                ...            ...       ...           ...       ...
# 2019-10-17         0.0  150645.343242  0.000475      1.506453  0.050713
# 2019-10-18         0.0  150756.333278  0.000737      1.507563  0.049603
# 2019-10-21         0.0  150919.933253  0.001085      1.509199  0.047967
# 2019-10-22         0.0  150793.013820 -0.000841      1.507930  0.049237
# 2019-10-23         0.0  150875.923118  0.000550      1.508759  0.048407
# 2019-10-24         0.0  150819.312156 -0.000375      1.508193  0.048974
# 2019-10-25         0.0  150999.531772  0.001195      1.509995  0.047171
# 2019-10-28         0.0  151426.723586  0.002829      1.514267  0.042899
# 2019-10-29         0.0  151530.113210  0.000683      1.515301  0.041866
# 2019-10-30         0.0  151558.834008  0.000190      1.515588  0.041578
# 2019-10-31         0.0  151266.143178 -0.001931      1.512661  0.044505
# 2019-11-01         0.0  152015.433297  0.004953      1.520154  0.037012
# 2019-11-04         0.0  152532.952971  0.003404      1.525330  0.031837
# 2019-11-05         0.0  152406.572774 -0.000829      1.524066  0.033101
# 2019-11-06         0.0  152220.773711 -0.001219      1.522208  0.034959
# 2019-11-07         0.0  152709.643338  0.003212      1.527096  0.030070
# 2019-11-08         0.0  152882.782376  0.001134      1.528828  0.028339
# 2019-11-11         0.0  152749.674550 -0.000871      1.527497  0.029670
# 2019-11-12         0.0  152783.523469  0.000222      1.527835  0.029331
# 2019-11-13         0.0  152617.512822 -0.001087      1.526175  0.030992
# 2019-11-14         0.0  152620.752492  0.000021      1.526208  0.030959
# 2019-11-15         0.0  153142.822570  0.003421      1.531428  0.025738
# 2019-11-18         0.0  153002.663646 -0.000915      1.530027  0.027140
# 2019-11-19         0.0  152902.782586 -0.000653      1.529028  0.028139
# 2019-11-20         0.0  152646.403214 -0.001677      1.526464  0.030703
# 2019-11-21         0.0  152740.402726  0.000616      1.527404  0.029763
# 2019-11-22         0.0  152872.972812  0.000868      1.528730  0.028437
# 2019-11-25         0.0  153394.653769  0.003413      1.533947  0.023220
# 2019-11-26         0.0  153328.392781 -0.000432      1.533284  0.023883
# 2019-11-27         0.0  153568.243230  0.001564      1.535682  0.021484
#
# [2432 rows x 18 columns]

# %%
df_equity = pd.read_csv("equity.csv")
df_equity.drop_duplicates("datetime", inplace = True)
df_equity =df_equity[df_equity['datetime']>start_date_str]
df_equity.index = df_equity['datetime']
df_equity = df_equity[df_equity['total'].map(lambda x: str(x)!="nan")]
del df_equity['datetime']
df_equity['equity_curve'].plot(figsize = (16, 7))

# %%
df_equity
# Out:
#                      FCD           FCL          IDU          IYE  \
# datetime
# 2010-04-05   9422.584153   9988.000000  9362.664780  9667.915306
# 2010-04-06   9888.376518   9947.139931  9441.501228     0.000000
# 2010-04-07   9830.152111   9988.000000  9361.391693     0.000000
# 2010-04-08   9949.025593   9988.000000  9306.715347     0.000000
# 2010-04-09   9429.862204   9988.000000  9357.576416  9162.066940
# 2010-04-12   9525.689199   9988.000000  9398.270050  9183.263332
# 2010-04-13   9528.115023   9988.000000  9365.205643  9135.572849
# 2010-04-14   9522.049884   9988.000000  9375.379715  9241.554188
# 2010-04-15   9522.049884   9761.000000  9369.022247  9249.497627
# 2010-04-16  10806.617481   9704.250000  9272.380508  9098.478386
# 2010-04-19  10680.465370   9974.379688  9282.553917  9111.724499
# 2010-04-20  10568.869361  10078.800346  9389.366409  9307.788483
# 2010-04-21  10800.552342   9799.589584  9395.721886  9268.046413
# 2010-04-22  10644.074537   9647.500000  9437.686615  9289.242184
# 2010-04-23  10850.284630   9647.500000  9507.621414  9501.205482
# 2010-04-26  10767.800824   9647.500000  9483.463303  9456.162605
# 2010-04-27  11134.126880   9577.129688  9319.428955  9185.910938
# 2010-04-28  10705.938259   9420.500000  9396.994972  9297.190598
# 2010-04-29  10695.021472      0.000000  9432.600243  9283.943241
# 2010-04-30  10770.226648      0.000000  9451.673973  9183.263332
# 2010-05-03  10134.614445      0.000000  9586.461182  9275.996693
# 2010-05-04  10173.431102      0.000000  9421.156403  9026.939552
# 2010-05-05   9843.494722      0.000000  9334.689400  8894.464745
# 2010-05-06   9843.494722      0.000000  9072.743546  8571.221165
# 2010-05-07   9575.422065      0.000000  9000.261246  8430.796078
# 2010-05-10   9236.994722      0.000000  9305.440933     0.000000
# 2010-05-11   9218.799884      0.000000     0.000000     0.000000
# 2010-05-12   9797.400593      0.000000     0.000000     0.000000
# 2010-05-13      0.000000      0.000000     0.000000     0.000000
# 2010-05-14      0.000000      0.000000     0.000000     0.000000
# ...                  ...           ...          ...          ...
# 2019-10-17   9194.085079      0.000000  9441.180252     0.000000
# 2019-10-18   9194.085079      0.000000  9477.170288     0.000000
# 2019-10-21   9194.085079      0.000000     0.000000     0.000000
# 2019-10-22   9194.085079      0.000000     0.000000     0.000000
# 2019-10-23   9194.085079      0.000000     0.000000     0.000000
# 2019-10-24   9194.085079      0.000000     0.000000     0.000000
# 2019-10-25   9194.085079      0.000000     0.000000     0.000000
# 2019-10-28   9194.085079      0.000000     0.000000     0.000000
# 2019-10-29   9194.085079      0.000000     0.000000     0.000000
# 2019-10-30   9194.085079      0.000000     0.000000  8880.599957
# 2019-10-31   9194.085079      0.000000     0.000000  8843.550196
# 2019-11-01   9194.085079      0.000000     0.000000  9057.300196
# 2019-11-04   9194.085079      0.000000     0.000000  9342.299652
# 2019-11-05   9194.085079      0.000000     0.000000  9382.199478
# 2019-11-06   9194.085079      0.000000     0.000000  9165.599957
# 2019-11-07   9194.085079      0.000000     0.000000  9308.099957
# 2019-11-08   9194.085079      0.000000     0.000000  9268.200130
# 2019-11-11   9194.085079      0.000000     0.000000  9208.350391
# 2019-11-12   9194.085079      0.000000     0.000000  9151.350174
# 2019-11-13   9194.085079      0.000000     0.000000  9105.750217
# 2019-11-14   9194.085079      0.000000     0.000000  9080.100174
# 2019-11-15   9194.085079      0.000000     0.000000  9151.350174
# 2019-11-18   9194.085079      0.000000     0.000000  9034.500217
# 2019-11-19   9194.085079      0.000000     0.000000  8903.399935
# 2019-11-20   9194.085079      0.000000     0.000000  8997.449913
# 2019-11-21   9194.085079      0.000000     0.000000  9139.949913
# 2019-11-22   9194.085079      0.000000     0.000000  9108.599739
# 2019-11-25   9194.085079      0.000000     0.000000  9131.400261
# 2019-11-26   9194.085079      0.000000     0.000000  9025.950022
# 2019-11-27   9194.085079      0.000000     0.000000     0.000000
#
#                      IYG          IYH           IYJ           IYM  \
# datetime
# 2010-04-05  10076.815922  9290.798866  10029.635582  10227.718445
# 2010-04-06  10208.596241  9274.054852  10027.943287  10261.860474
# 2010-04-07  10181.905643  9234.987122   9977.176666  10205.989594
# 2010-04-08  10285.326302  9215.456635  10004.251156  10223.060608
# 2010-04-09  10322.021908  9251.728680  10073.632278  10255.654938
# 2010-04-12  10392.081482  9239.172665  10095.632114  10226.165833
# 2010-04-13  10367.060669  9246.152050  10119.319782  10198.229340
# 2010-04-14  10683.993851  9222.431721  10258.080540  10289.799072
# 2010-04-15  10672.317616  9212.667091  10332.537060  10268.071625
# 2010-04-16  10246.960911     0.000000  10192.085495  10041.477966
# 2010-04-19  10332.031242     0.000000  10173.473225  10005.780518
# 2010-04-20  10467.145363     0.000000  10276.694298  10039.925354
# 2010-04-21  10418.771358     0.000000  10354.533920  10029.061981
# 2010-04-22  10487.161148     0.000000  10445.913391  10100.454071
# 2010-04-23  10502.174068     0.000000  10532.215977  10271.176147
# 2010-04-26  10290.329166     0.000000  10550.830479  10268.071625
# 2010-04-27   9975.062885     0.000000  10266.541271   9937.493652
# 2010-04-28  10108.508663     0.000000  10354.533920  10050.790131
# 2010-04-29  10323.690971     0.000000  10545.755081  10150.117310
# 2010-04-30  10073.482121     0.000000  10313.926277   9937.493652
# 2010-05-03  10245.291126     0.000000  10503.449192   9937.493652
# 2010-05-04   9970.060741     0.000000  10173.473225      0.000000
# 2010-05-05   9908.340717     0.000000  10024.558697      0.000000
# 2010-05-06      0.000000     0.000000   9725.038834      0.000000
# 2010-05-07      0.000000     0.000000   9488.132401      0.000000
# 2010-05-10      0.000000     0.000000  10005.944939      0.000000
# 2010-05-11      0.000000     0.000000  10000.867310      0.000000
# 2010-05-12      0.000000     0.000000      0.000000      0.000000
# 2010-05-13      0.000000     0.000000      0.000000      0.000000
# 2010-05-14      0.000000     0.000000      0.000000      0.000000
# ...                  ...          ...           ...           ...
# 2019-10-17      0.000000     0.000000      0.000000      0.000000
# 2019-10-18      0.000000     0.000000      0.000000      0.000000
# 2019-10-21      0.000000     0.000000      0.000000      0.000000
# 2019-10-22      0.000000     0.000000      0.000000      0.000000
# 2019-10-23      0.000000  9104.840057      0.000000      0.000000
# 2019-10-24   9091.549683  9050.319885      0.000000      0.000000
# 2019-10-25   9152.649841  9071.000000   8990.239624      0.000000
# 2019-10-28   9233.899841  9170.639771   9013.760376   9076.760269
# 2019-10-29   9235.849762  9285.790344   9036.719727   9144.379761
# 2019-10-30   9227.400436  9332.790344   9066.399658   9118.900299
# 2019-10-31   9166.949921  9320.100143   8980.719727   9038.540329
# 2019-11-01   9305.400238  9352.059799   9145.359863   9198.280060
# 2019-11-04   9381.450119  9326.680115   9218.160034   9309.019791
# 2019-11-05   9380.149841  9243.959656   9208.640137   9361.939880
# 2019-11-06   9388.600159  9280.620316   9213.679932   9334.500000
# 2019-11-07   9470.499802  9305.530258   9245.600342   9441.319641
# 2019-11-08   9485.449524  9393.420029   9264.640137   9476.599701
# 2019-11-11   9473.100357  9356.760086   9275.839966   9460.920090
# 2019-11-12   9473.750000  9405.170029   9280.879761   9492.280060
# 2019-11-13   9419.799881  9417.389771   9269.120239   9409.959671
# 2019-11-14   9443.849564  9415.510086   9311.679932   9449.159821
# 2019-11-15   9485.449524  9617.139771   9368.800171   9442.299850
# 2019-11-18   9495.200119  9586.590057   9352.000000   9414.859970
# 2019-11-19   9543.950119  9662.729828   9361.519897   9375.659821
# 2019-11-20   9500.400238  9656.149857   9299.359863   9268.840179
# 2019-11-21   9495.849762  9678.239914   9271.359863   9266.879761
# 2019-11-22   9549.799881  9712.549713   9297.679932   9281.579910
# 2019-11-25   9638.199921  9842.270172   9382.239624   9337.439880
# 2019-11-26   9620.000000  9830.049713   9431.519897   9359.980209
# 2019-11-27   9672.649841  9887.860229   9442.719727   9398.200150
#
#                      IYR           IYW           IYZ           cash  \
# datetime
# 2010-04-05  10194.800205   9782.995316  10030.971863   -3445.364504
# 2010-04-06  10400.493050   9799.533218   9996.634102    6222.550802
# 2010-04-07  10176.823540   9774.724983   9908.344959    6222.550802
# 2010-04-08  10180.817871   9779.685249   9986.828190    6222.550802
# 2010-04-09  10342.582855   9855.765678  10045.688217   -2849.433493
# 2010-04-12  10274.681396   9897.117340  10084.932228   -2849.433493
# 2010-04-13  10508.333473   9925.233570  10080.024780   -2849.433493
# 2010-04-14  10518.316040  10102.203354  10148.696709   -2849.433493
# 2010-04-15  10256.709080  10151.821896  10153.601761   -2849.433493
# 2010-04-16  10043.029747  10017.853283  10021.164753    6363.233599
# 2010-04-19  10080.969372  10022.814930  10050.593269    6363.233599
# 2010-04-20  10238.734589  10074.086433  10129.076500    6363.233599
# 2010-04-21  10430.448360  10113.781681  10065.307228    6363.233599
# 2010-04-22  10582.224255  10155.127129  10089.832489    6363.233599
# 2010-04-23  10720.016727  10174.976479  10104.551239    6363.233599
# 2010-04-26  10787.917099  10165.053875  10030.971863    6363.233599
# 2010-04-27  10446.426773   9973.195698   9878.914047    6363.233599
# 2010-04-28  10482.373581   9989.733601   9962.300533    6363.233599
# 2010-04-29  10915.725918  10080.701042  10109.456291   15783.733599
# 2010-04-30  10576.230583   9850.807484   9996.634102   15783.733599
# 2010-05-03  10903.742924   9988.081329  10133.981552   15783.733599
# 2010-05-04  10648.123112   9696.990902   9874.009594   25721.227251
# 2010-05-05  10498.347645   9644.065056   9834.767380   25721.227251
# 2010-05-06  10076.975040   9321.547642   9540.461254   35629.567968
# 2010-05-07   9907.225742   9101.575996      0.000000   45170.029222
# 2010-05-10  10560.255432      0.000000      0.000000   62702.401297
# 2010-05-11  10572.236252      0.000000      0.000000   72007.842230
# 2010-05-12  10743.982716      0.000000      0.000000   82008.709539
# 2010-05-13  10602.191563      0.000000      0.000000   91806.110132
# 2010-05-14  10274.681396      0.000000      0.000000   91806.110132
# ...                  ...           ...           ...            ...
# 2019-10-17   9391.999817      0.000000      0.000000  122618.078094
# 2019-10-18   9466.999817      0.000000      0.000000  122618.078094
# 2019-10-21   9536.000061   9138.799866      0.000000  123051.048247
# 2019-10-22   9505.000305   9042.880188      0.000000  123051.048247
# 2019-10-23   9518.000031   9064.880188   9077.989906  104916.127856
# 2019-10-24   9505.999756   9155.520081   8958.260094   95863.577579
# 2019-10-25   9408.999634   9265.959839   8995.099766   86921.497989
# 2019-10-28   9358.000183   9392.240295   9099.479813   77887.857959
# 2019-10-29   9390.000153   9289.720215   9065.710211   77887.857959
# 2019-10-30   9441.999817   9335.040161   9142.460211   68819.158046
# 2019-10-31   9426.000214   9328.439758   9148.599766   68819.158046
# 2019-11-01   9419.000244   9446.799866   9077.989906   68819.158046
# 2019-11-04   9345.999908   9527.319946   9068.780281   68819.158046
# 2019-11-05   9194.000244   9535.240295   9087.200117   68819.158046
# 2019-11-06   9220.999908   9519.400269   9084.130047   68819.158046
# 2019-11-07   9133.000183   9591.560242   9200.789789   68819.158046
# 2019-11-08      0.000000   9647.439758   9200.789789   77952.158229
# 2019-11-11      0.000000   9636.880188   9191.580164   77952.158229
# 2019-11-12      0.000000   9676.040161   9157.809977   77952.158229
# 2019-11-13      0.000000   9691.439758   9157.809977   77952.158229
# 2019-11-14      0.000000   9677.799866   9096.409742   77952.158229
# 2019-11-15      0.000000   9776.799866   9154.739906   77952.158229
# 2019-11-18      0.000000   9797.040161   9176.229813   77952.158229
# 2019-11-19      0.000000   9809.799866   9099.479813   77952.158229
# 2019-11-20      0.000000   9752.159973   9025.799883   77952.158229
# 2019-11-21      0.000000   9716.080322   9025.799883   77952.158229
# 2019-11-22      0.000000   9713.880188   9062.640141   77952.158229
# 2019-11-25      0.000000   9848.080322   9068.780281   77952.158229
# 2019-11-26      0.000000   9842.799866   9071.849766   77952.158229
# 2019-11-27      0.000000   9889.000000   9105.619953   86978.108251
#
#             commission          total   returns  equity_curve  drawdown
# datetime
# 2010-04-05         0.0  104629.535933  0.009601      1.046295  0.000000
# 2010-04-06         0.0  105468.683702  0.008020      1.054687  0.000000
# 2010-04-07         0.0  104862.047113 -0.005752      1.048620  0.006066
# 2010-04-08         0.0  105141.717752  0.002667      1.051417  0.003270
# 2010-04-09         0.0  105235.146622  0.000889      1.052351  0.002335
# 2010-04-12         0.0  105455.572147  0.002095      1.054556  0.000131
# 2010-04-13         0.0  105611.813687  0.001482      1.056118  0.000000
# 2010-04-14         0.0  106501.071580  0.008420      1.065011  0.000000
# 2010-04-15         0.0  106099.862394 -0.003767      1.060999  0.004012
# 2010-04-16         0.0  105807.532129 -0.002755      1.058075  0.006935
# 2010-04-19         0.0  106078.019629  0.002556      1.060780  0.004231
# 2010-04-20         0.0  106933.720735  0.008067      1.069337  0.000000
# 2010-04-21         0.0  107039.048354  0.000985      1.070390  0.000000
# 2010-04-22         0.0  107242.449417  0.001900      1.072424  0.000000
# 2010-04-23         0.0  108174.955763  0.008695      1.081750  0.000000
# 2010-04-26         0.0  107811.334437 -0.003361      1.078113  0.003636
# 2010-04-27         0.0  106057.464387 -0.016268      1.060575  0.021175
# 2010-04-28         0.0  106132.097857  0.000704      1.061321  0.020429
# 2010-04-29         0.0  107320.745168  0.011200      1.073207  0.008542
# 2010-04-30         0.0  105937.471771 -0.012889      1.059375  0.022375
# 2010-05-03         0.0  106492.845694  0.005242      1.064928  0.016821
# 2010-05-04         0.0  104705.411881 -0.016785      1.047054  0.034695
# 2010-05-05         0.0  103703.955612 -0.009565      1.037040  0.044710
# 2010-05-06         0.0  101781.050171 -0.018542      1.017811  0.063939
# 2010-05-07         0.0  100673.442750 -0.010882      1.006734  0.075015
# 2010-05-10         0.0  101811.037323  0.011300      1.018110  0.063639
# 2010-05-11         0.0  101799.745676 -0.000111      1.017997  0.063752
# 2010-05-12         0.0  102550.092848  0.007371      1.025501  0.056249
# 2010-05-13         0.0  102408.301695 -0.001383      1.024083  0.057667
# 2010-05-14         0.0  102080.791529 -0.003198      1.020808  0.060942
# ...                ...            ...       ...           ...       ...
# 2019-10-17         0.0  150645.343242  0.000475      1.506453  0.050713
# 2019-10-18         0.0  150756.333278  0.000737      1.507563  0.049603
# 2019-10-21         0.0  150919.933253  0.001085      1.509199  0.047967
# 2019-10-22         0.0  150793.013820 -0.000841      1.507930  0.049237
# 2019-10-23         0.0  150875.923118  0.000550      1.508759  0.048407
# 2019-10-24         0.0  150819.312156 -0.000375      1.508193  0.048974
# 2019-10-25         0.0  150999.531772  0.001195      1.509995  0.047171
# 2019-10-28         0.0  151426.723586  0.002829      1.514267  0.042899
# 2019-10-29         0.0  151530.113210  0.000683      1.515301  0.041866
# 2019-10-30         0.0  151558.834008  0.000190      1.515588  0.041578
# 2019-10-31         0.0  151266.143178 -0.001931      1.512661  0.044505
# 2019-11-01         0.0  152015.433297  0.004953      1.520154  0.037012
# 2019-11-04         0.0  152532.952971  0.003404      1.525330  0.031837
# 2019-11-05         0.0  152406.572774 -0.000829      1.524066  0.033101
# 2019-11-06         0.0  152220.773711 -0.001219      1.522208  0.034959
# 2019-11-07         0.0  152709.643338  0.003212      1.527096  0.030070
# 2019-11-08         0.0  152882.782376  0.001134      1.528828  0.028339
# 2019-11-11         0.0  152749.674550 -0.000871      1.527497  0.029670
# 2019-11-12         0.0  152783.523469  0.000222      1.527835  0.029331
# 2019-11-13         0.0  152617.512822 -0.001087      1.526175  0.030992
# 2019-11-14         0.0  152620.752492  0.000021      1.526208  0.030959
# 2019-11-15         0.0  153142.822570  0.003421      1.531428  0.025738
# 2019-11-18         0.0  153002.663646 -0.000915      1.530027  0.027140
# 2019-11-19         0.0  152902.782586 -0.000653      1.529028  0.028139
# 2019-11-20         0.0  152646.403214 -0.001677      1.526464  0.030703
# 2019-11-21         0.0  152740.402726  0.000616      1.527404  0.029763
# 2019-11-22         0.0  152872.972812  0.000868      1.528730  0.028437
# 2019-11-25         0.0  153394.653769  0.003413      1.533947  0.023220
# 2019-11-26         0.0  153328.392781 -0.000432      1.533284  0.023883
# 2019-11-27         0.0  153568.243230  0.001564      1.535682  0.021484
#
# [2432 rows x 17 columns]
