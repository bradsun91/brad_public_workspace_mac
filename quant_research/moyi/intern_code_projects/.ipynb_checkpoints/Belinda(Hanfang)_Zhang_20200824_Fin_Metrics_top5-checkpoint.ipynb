# %%
import yfinance as yf
import pandas as pd
import requests
from tqdm import tqdm

url = 'https://www.slickcharts.com/sp500'
headers = {"User-Agent" : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'}
request = requests.get(url, headers = headers)
data = pd.read_html(request.text)[0]
stk_list = data.Symbol
stk_list = data.Symbol.apply(lambda x: x.replace('.', '-'))
# S&P 500 companies

# %%
# stk_list = list(stk_list)

# %%
tickers = yf.Tickers(' '.join(stk_list.tolist()))

# %%
getattr(tickers.tickers, "AMZN").info
# Out:
# {'zip': '98109-5210',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 798000,
#  'longBusinessSummary': 'Amazon.com, Inc. engages in the retail sale of consumer products and subscriptions in North America and internationally. The company operates through three segments: North America, International, and Amazon Web Services (AWS). It sells merchandise and content purchased for resale from third-party sellers through physical and online stores. The company also manufactures and sells electronic devices, including Kindle, Fire tablets, Fire TVs, Rings, and Echo and other devices; provides Kindle Direct Publishing, an online service that allows independent authors and publishers to make their books available in the Kindle Store; and develops and produces media content. In addition, it offers programs that enable sellers to sell their products on its Websites, as well as its stores; and programs that allow authors, musicians, filmmakers, skill and app developers, and others to publish and sell content. Further, the company provides compute, storage, database, and other AWS services, as well as fulfillment, advertising, publishing, and digital content subscriptions. Additionally, it offers Amazon Prime, a membership program, which provides free shipping of various items; access to streaming of movies and TV episodes; and other services. The company also operates in the food delivery business in Bengaluru, India. It serves consumers, sellers, developers, enterprises, and content creators. The company also has utility-scale solar projects in China, Australia, and the United States. Amazon.com, Inc. was founded in 1994 and is headquartered in Seattle, Washington.',
#  'city': 'Seattle',
#  'phone': '206-266-1000',
#  'state': 'WA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.amazon.com',
#  'maxAge': 1,
#  'address1': '410 Terry Avenue North',
#  'industry': 'Internet Retail',
#  'previousClose': 3307.46,
#  'regularMarketOpen': 3294.99,
#  'twoHundredDayAverage': 2493.7239,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 3357.4,
#  'navPrice': None,
#  'averageDailyVolume10Day': 3969042,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 3307.46,
#  'fiftyDayAverage': 3136.0686,
#  'trailingAnnualDividendRate': None,
#  'open': 3294.99,
#  'toCurrency': None,
#  'averageVolume10days': 3969042,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': 1.325274,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 3267.275,
#  'priceHint': 2,
#  'currency': 'USD',
#  'trailingPE': 128.52824,
#  'regularMarketVolume': 3992842,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1676223315968,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 4558918,
#  'priceToSalesTrailing12Months': 5.2091894,
#  'dayLow': 3267.275,
#  'ask': 3349,
#  'ytdReturn': None,
#  'askSize': 800,
#  'volume': 3992842,
#  'fiftyTwoWeekHigh': 3380.32,
#  'forwardPE': 75.832535,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 1626.03,
#  'bid': 3350,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 1200,
#  'dayHigh': 3357.4,
#  'exchange': 'NMS',
#  'shortName': 'Amazon.com, Inc.',
#  'longName': 'Amazon.com, Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'AMZN',
#  'messageBoardId': 'finmb_18749',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 5.271,
#  'beta3Year': None,
#  'profitMargins': 0.040960003,
#  'enterpriseToEbitda': 42.861,
#  '52WeekChange': 0.8968344,
#  'morningStarRiskRating': None,
#  'forwardEps': 44.13,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 500889984,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': 147.162,
#  'sharesShort': 2207816,
#  'sharesPercentSharesOut': 0.0044,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1577750400,
#  'heldPercentInstitutions': 0.57689,
#  'netIncomeToCommon': 13180000256,
#  'trailingEps': 26.037,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.19241405,
#  'priceToBook': 22.740177,
#  'heldPercentInsiders': 0.15122,
#  'nextFiscalYearEnd': 1640908800,
#  'mostRecentQuarter': 1593475200,
#  'shortRatio': 0.46,
#  'sharesShortPreviousMonthDate': 1594771200,
#  'floatShares': 425250305,
#  'enterpriseValue': 1696232243200,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 936230400,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.997,
#  'dateShortInterest': 1597363200,
#  'pegRatio': 2.94,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0052,
#  'sharesShortPriorMonth': 3618861,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 3294.99,
#  'logo_url': 'https://logo.clearbit.com/amazon.com'}

# %%
getattr(tickers.tickers, "AAPL").info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 137000,
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, iPod touch, and other Apple-branded and third-party accessories. It also provides digital content stores and streaming services; AppleCare support services; and iCloud, a cloud service, which stores music, photos, contacts, calendars, mail, documents, and others. In addition, the company offers various service, such as Apple Arcade, a game subscription service; Apple Card, a co-branded credit card; Apple News+, a subscription news and magazine service; and Apple Pay, a cashless payment service, as well as licenses its intellectual property, and provides other related services. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It sells and delivers third-party applications for its products through the App Store, Mac App Store, and Watch App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. has a collaboration with Google to develop COVID-19 tracking system for Android and iOS devices. Apple Inc. was founded in 1977 and is headquartered in Cupertino, California.',
#  'city': 'Cupertino',
#  'phone': '408-996-1010',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.apple.com',
#  'maxAge': 1,
#  'address1': 'One Apple Park Way',
#  'industry': 'Consumer Electronics',
#  'previousClose': 503.43,
#  'regularMarketOpen': 498.79,
#  'twoHundredDayAverage': 332.33884,
#  'trailingAnnualDividendYield': 0.0062173493,
#  'payoutRatio': 0.2373,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 500.7,
#  'navPrice': None,
#  'averageDailyVolume10Day': 49740728,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 503.43,
#  'fiftyDayAverage': 420.53946,
#  'trailingAnnualDividendRate': 3.13,
#  'open': 498.79,
#  'toCurrency': None,
#  'averageVolume10days': 49740728,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': 3.28,
#  'exDividendDate': 1596758400,
#  'beta': 1.226373,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 492.21,
#  'priceHint': 2,
#  'currency': 'USD',
#  'trailingPE': 37.86879,
#  'regularMarketVolume': 51572516,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 2134822092800,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 38950670,
#  'priceToSalesTrailing12Months': 7.7953897,
#  'dayLow': 492.21,
#  'ask': 500,
#  'ytdReturn': None,
#  'askSize': 1000,
#  'volume': 51572516,
#  'fiftyTwoWeekHigh': 515.14,
#  'forwardPE': 32.17139,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 1.56,
#  'fiftyTwoWeekLow': 203.32,
#  'bid': 501.66,
#  'tradeable': False,
#  'dividendYield': 0.0066000004,
#  'bidSize': 900,
#  'dayHigh': 500.7,
#  'exchange': 'NMS',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'AAPL',
#  'messageBoardId': 'finmb_24937',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 7.902,
#  'beta3Year': None,
#  'profitMargins': 0.21334,
#  'enterpriseToEbitda': 27.507,
#  '52WeekChange': 1.4293289,
#  'morningStarRiskRating': None,
#  'forwardEps': 15.52,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 4275630080,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': 16.873,
#  'sharesShort': 23658754,
#  'sharesPercentSharesOut': 0.0055,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1569628800,
#  'heldPercentInstitutions': 0.62115,
#  'netIncomeToCommon': 58424000512,
#  'trailingEps': 13.185,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.19241405,
#  'priceToBook': 29.591656,
#  'heldPercentInsiders': 0.00066,
#  'nextFiscalYearEnd': 1632787200,
#  'mostRecentQuarter': 1593216000,
#  'shortRatio': 0.57,
#  'sharesShortPreviousMonthDate': 1594771200,
#  'floatShares': 4271358366,
#  'enterpriseValue': 2163985088512,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1402272000,
#  'lastSplitFactor': '7:1',
#  'legalType': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.12,
#  'dateShortInterest': 1597363200,
#  'pegRatio': 3.09,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0055,
#  'sharesShortPriorMonth': 35234606,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 498.79,
#  'logo_url': 'https://logo.clearbit.com/apple.com'}

# %%
info_ = getattr(tickers.tickers, "AMZN").info
print("info assigned")
sector = info_['sector']
print("sector assigned")
market_cap = info_['marketCap']
# print("mkt cap assigned")
# sectors.append(sector)
# print("sector appended")
# market_caps.append(market_cap)
# print("mkt cap appended")
# ticker_lst.append(t)
# print("ticker list appended")

# %%
sectors = []
market_caps = []
probs = []
ticker_lst = []
for t in tqdm(stk_list):
    print(t)
    try:
        info_ = getattr(tickers.tickers, t).info
        print("info assigned")
        sector = info_['sector']
        print("sector assigned")
        market_cap = info_['marketCap']
        print("mkt cap assigned")
        sectors.append(sector)
        print("sector appended")
        market_caps.append(market_cap)
        print("mkt cap appended")
        ticker_lst.append(t)
        print("ticker list appended")
    except (AttributeError, IndexError, ValueError, Exception) as e:
        probs.append((t, e))
        continue
# Out:
#   0%|          | 0/506 [00:00<?, ?it/s]
# AAPL
#   0%|          | 0/506 [00:26<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-502f59cf9063> in <module>
#       6     print(t)
#       7     try:
# ----> 8         info_ = getattr(tickers.tickers, t).info
#       9         print("info assigned")
#      10         sector = info_['sector']
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/yfinance/ticker.py in info(self)
#     136     @property
#     137     def info(self):
# --> 138         return self.get_info()
#     139
#     140     @property
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/yfinance/base.py in get_info(self, proxy, as_dict, *args, **kwargs)
#     413
#     414     def get_info(self, proxy=None, as_dict=False, *args, **kwargs):
# --> 415         self._get_fundamentals(proxy)
#     416         data = self._info
#     417         if as_dict:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/yfinance/base.py in _get_fundamentals(self, kind, proxy)
#     282         # holders
#     283         url = "{}/{}/holders".format(self._scrape_url, self.ticker)
# --> 284         holders = _pd.read_html(url)
#     285         self._major_holders = holders[0]
#     286         self._institutional_holders = holders[1]
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1099         na_values=na_values,
#    1100         keep_default_na=keep_default_na,
# -> 1101         displayed_only=displayed_only,
#    1102     )
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     896
#     897         try:
# --> 898             tables = p.parse_tables()
#     899         except ValueError as caught:
#     900             # if `io` is an io-like object, check if it's seekable
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/io/html.py in parse_tables(self)
#     215         list of parsed (header, body, footer) tuples from tables.
#     216         """
# --> 217         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     218         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     219
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/io/html.py in _build_doc(self)
#     716             if is_url(self.io):
#     717                 with urlopen(self.io) as f:
# --> 718                     r = parse(f, parser=parser)
#     719             else:
#     720                 # try to parse the input in the simplest way
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/lxml/html/__init__.py in parse(filename_or_url, parser, base_url, **kw)
#     937     if parser is None:
#     938         parser = html_parser
# --> 939     return etree.parse(filename_or_url, parser, base_url=base_url, **kw)
#     940
#     941
#
# src/lxml/etree.pyx in lxml.etree.parse()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseFilelikeDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseDocFromFilelike()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDocFromFilelike()
#
# src/lxml/parser.pxi in lxml.etree._ParserContext._handleParseResultDoc()
#
# src/lxml/parser.pxi in lxml.etree._handleParseResult()
#
# src/lxml/etree.pyx in lxml.etree._ExceptionContext._raise_if_stored()
#
# src/lxml/parser.pxi in lxml.etree._FileReaderContext.copyToBuffer()
#
# ~/anaconda3/envs/py37/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/anaconda3/envs/py37/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~/anaconda3/envs/py37/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     589
#     590                 if len(mvb) <= chunk_left:
# --> 591                     n = self._safe_readinto(mvb)
#     592                     self.chunk_left = chunk_left - n
#     593                     return total_bytes + n
#
# ~/anaconda3/envs/py37/lib/python3.7/http/client.py in _safe_readinto(self, b)
#     634                 n = self.fp.readinto(temp_mvb)
#     635             else:
# --> 636                 n = self.fp.readinto(mvb)
#     637             if not n:
#     638                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#
# ~/anaconda3/envs/py37/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/envs/py37/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/envs/py37/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
probs
# Out:
# [('AAPL', NameError("name 'tickers' is not defined")),
#  ('MSFT', NameError("name 'tickers' is not defined")),
#  ('AMZN', NameError("name 'tickers' is not defined")),
#  ('FB', NameError("name 'tickers' is not defined")),
#  ('GOOGL', NameError("name 'tickers' is not defined")),
#  ('GOOG', NameError("name 'tickers' is not defined")),
#  ('BRK-B', NameError("name 'tickers' is not defined")),
#  ('JNJ', NameError("name 'tickers' is not defined")),
#  ('V', NameError("name 'tickers' is not defined")),
#  ('PG', NameError("name 'tickers' is not defined")),
#  ('NVDA', NameError("name 'tickers' is not defined")),
#  ('HD', NameError("name 'tickers' is not defined")),
#  ('JPM', NameError("name 'tickers' is not defined")),
#  ('MA', NameError("name 'tickers' is not defined")),
#  ('UNH', NameError("name 'tickers' is not defined")),
#  ('VZ', NameError("name 'tickers' is not defined")),
#  ('DIS', NameError("name 'tickers' is not defined")),
#  ('PYPL', NameError("name 'tickers' is not defined")),
#  ('ADBE', NameError("name 'tickers' is not defined")),
#  ('PFE', NameError("name 'tickers' is not defined")),
#  ('MRK', NameError("name 'tickers' is not defined")),
#  ('NFLX', NameError("name 'tickers' is not defined")),
#  ('T', NameError("name 'tickers' is not defined")),
#  ('INTC', NameError("name 'tickers' is not defined")),
#  ('BAC', NameError("name 'tickers' is not defined")),
#  ('CMCSA', NameError("name 'tickers' is not defined")),
#  ('PEP', NameError("name 'tickers' is not defined")),
#  ('CRM', NameError("name 'tickers' is not defined")),
#  ('WMT', NameError("name 'tickers' is not defined")),
#  ('KO', NameError("name 'tickers' is not defined")),
#  ('ABT', NameError("name 'tickers' is not defined")),
#  ('CSCO', NameError("name 'tickers' is not defined")),
#  ('XOM', NameError("name 'tickers' is not defined")),
#  ('ABBV', NameError("name 'tickers' is not defined")),
#  ('TMO', NameError("name 'tickers' is not defined")),
#  ('CVX', NameError("name 'tickers' is not defined")),
#  ('MCD', NameError("name 'tickers' is not defined")),
#  ('COST', NameError("name 'tickers' is not defined")),
#  ('ACN', NameError("name 'tickers' is not defined")),
#  ('BMY', NameError("name 'tickers' is not defined")),
#  ('AMGN', NameError("name 'tickers' is not defined")),
#  ('NKE', NameError("name 'tickers' is not defined")),
#  ('NEE', NameError("name 'tickers' is not defined")),
#  ('MDT', NameError("name 'tickers' is not defined")),
#  ('AVGO', NameError("name 'tickers' is not defined")),
#  ('LIN', NameError("name 'tickers' is not defined")),
#  ('UNP', NameError("name 'tickers' is not defined")),
#  ('QCOM', NameError("name 'tickers' is not defined")),
#  ('TXN', NameError("name 'tickers' is not defined")),
#  ('DHR', NameError("name 'tickers' is not defined")),
#  ('LLY', NameError("name 'tickers' is not defined")),
#  ('LOW', NameError("name 'tickers' is not defined")),
#  ('PM', NameError("name 'tickers' is not defined")),
#  ('ORCL', NameError("name 'tickers' is not defined")),
#  ('UPS', NameError("name 'tickers' is not defined")),
#  ('HON', NameError("name 'tickers' is not defined")),
#  ('IBM', NameError("name 'tickers' is not defined")),
#  ('AMT', NameError("name 'tickers' is not defined")),
#  ('C', NameError("name 'tickers' is not defined")),
#  ('LMT', NameError("name 'tickers' is not defined")),
#  ('AMD', NameError("name 'tickers' is not defined")),
#  ('BA', NameError("name 'tickers' is not defined")),
#  ('MMM', NameError("name 'tickers' is not defined")),
#  ('CHTR', NameError("name 'tickers' is not defined")),
#  ('SBUX', NameError("name 'tickers' is not defined")),
#  ('WFC', NameError("name 'tickers' is not defined")),
#  ('BLK', NameError("name 'tickers' is not defined")),
#  ('RTX', NameError("name 'tickers' is not defined")),
#  ('FIS', NameError("name 'tickers' is not defined")),
#  ('INTU', NameError("name 'tickers' is not defined")),
#  ('SPGI', NameError("name 'tickers' is not defined")),
#  ('NOW', NameError("name 'tickers' is not defined")),
#  ('CVS', NameError("name 'tickers' is not defined")),
#  ('GILD', NameError("name 'tickers' is not defined")),
#  ('MDLZ', NameError("name 'tickers' is not defined")),
#  ('MO', NameError("name 'tickers' is not defined")),
#  ('ISRG', NameError("name 'tickers' is not defined")),
#  ('CAT', NameError("name 'tickers' is not defined")),
#  ('TGT', NameError("name 'tickers' is not defined")),
#  ('BKNG', NameError("name 'tickers' is not defined")),
#  ('PLD', NameError("name 'tickers' is not defined")),
#  ('BDX', NameError("name 'tickers' is not defined")),
#  ('ZTS', NameError("name 'tickers' is not defined")),
#  ('ANTM', NameError("name 'tickers' is not defined")),
#  ('VRTX', NameError("name 'tickers' is not defined")),
#  ('EQIX', NameError("name 'tickers' is not defined")),
#  ('CL', NameError("name 'tickers' is not defined")),
#  ('CCI', NameError("name 'tickers' is not defined")),
#  ('TMUS', NameError("name 'tickers' is not defined")),
#  ('D', NameError("name 'tickers' is not defined")),
#  ('AXP', NameError("name 'tickers' is not defined")),
#  ('CI', NameError("name 'tickers' is not defined")),
#  ('DE', NameError("name 'tickers' is not defined")),
#  ('GS', NameError("name 'tickers' is not defined")),
#  ('ATVI', NameError("name 'tickers' is not defined")),
#  ('TJX', NameError("name 'tickers' is not defined")),
#  ('APD', NameError("name 'tickers' is not defined")),
#  ('MS', NameError("name 'tickers' is not defined")),
#  ('CME', NameError("name 'tickers' is not defined")),
#  ('ADP', NameError("name 'tickers' is not defined")),
#  ('SYK', NameError("name 'tickers' is not defined")),
#  ('DUK', NameError("name 'tickers' is not defined")),
#  ('REGN', NameError("name 'tickers' is not defined")),
#  ('AMAT', NameError("name 'tickers' is not defined")),
#  ('ICE', NameError("name 'tickers' is not defined")),
#  ('GE', NameError("name 'tickers' is not defined")),
#  ('CSX', NameError("name 'tickers' is not defined")),
#  ('MMC', NameError("name 'tickers' is not defined")),
#  ('ITW', NameError("name 'tickers' is not defined")),
#  ('CB', NameError("name 'tickers' is not defined")),
#  ('SO', NameError("name 'tickers' is not defined")),
#  ('BSX', NameError("name 'tickers' is not defined")),
#  ('ADSK', NameError("name 'tickers' is not defined")),
#  ('NSC', NameError("name 'tickers' is not defined")),
#  ('SHW', NameError("name 'tickers' is not defined")),
#  ('FISV', NameError("name 'tickers' is not defined")),
#  ('KMB', NameError("name 'tickers' is not defined")),
#  ('NOC', NameError("name 'tickers' is not defined")),
#  ('PGR', NameError("name 'tickers' is not defined")),
#  ('HUM', NameError("name 'tickers' is not defined")),
#  ('NEM', NameError("name 'tickers' is not defined")),
#  ('TFC', NameError("name 'tickers' is not defined")),
#  ('FDX', NameError("name 'tickers' is not defined")),
#  ('GPN', NameError("name 'tickers' is not defined")),
#  ('ILMN', NameError("name 'tickers' is not defined")),
#  ('LRCX', NameError("name 'tickers' is not defined")),
#  ('USB', NameError("name 'tickers' is not defined")),
#  ('DG', NameError("name 'tickers' is not defined")),
#  ('EW', NameError("name 'tickers' is not defined")),
#  ('ECL', NameError("name 'tickers' is not defined")),
#  ('MU', NameError("name 'tickers' is not defined")),
#  ('EL', NameError("name 'tickers' is not defined")),
#  ('PNC', NameError("name 'tickers' is not defined")),
#  ('MCO', NameError("name 'tickers' is not defined")),
#  ('BIIB', NameError("name 'tickers' is not defined")),
#  ('ROP', NameError("name 'tickers' is not defined")),
#  ('AON', NameError("name 'tickers' is not defined")),
#  ('WM', NameError("name 'tickers' is not defined")),
#  ('ADI', NameError("name 'tickers' is not defined")),
#  ('BAX', NameError("name 'tickers' is not defined")),
#  ('DD', NameError("name 'tickers' is not defined")),
#  ('COP', NameError("name 'tickers' is not defined")),
#  ('EMR', NameError("name 'tickers' is not defined")),
#  ('EA', NameError("name 'tickers' is not defined")),
#  ('ETN', NameError("name 'tickers' is not defined")),
#  ('DLR', NameError("name 'tickers' is not defined")),
#  ('SCHW', NameError("name 'tickers' is not defined")),
#  ('AEP', NameError("name 'tickers' is not defined")),
#  ('LHX', NameError("name 'tickers' is not defined")),
#  ('DXCM', NameError("name 'tickers' is not defined")),
#  ('EBAY', NameError("name 'tickers' is not defined")),
#  ('GIS', NameError("name 'tickers' is not defined")),
#  ('GM', NameError("name 'tickers' is not defined")),
#  ('SRE', NameError("name 'tickers' is not defined")),
#  ('CTSH', NameError("name 'tickers' is not defined")),
#  ('XEL', NameError("name 'tickers' is not defined")),
#  ('EXC', NameError("name 'tickers' is not defined")),
#  ('GD', NameError("name 'tickers' is not defined")),
#  ('HCA', NameError("name 'tickers' is not defined")),
#  ('CNC', NameError("name 'tickers' is not defined")),
#  ('ORLY', NameError("name 'tickers' is not defined")),
#  ('DOW', NameError("name 'tickers' is not defined")),
#  ('SBAC', NameError("name 'tickers' is not defined")),
#  ('INFO', NameError("name 'tickers' is not defined")),
#  ('KLAC', NameError("name 'tickers' is not defined")),
#  ('IDXX', NameError("name 'tickers' is not defined")),
#  ('SNPS', NameError("name 'tickers' is not defined")),
#  ('APH', NameError("name 'tickers' is not defined")),
#  ('TWTR', NameError("name 'tickers' is not defined")),
#  ('ROST', NameError("name 'tickers' is not defined")),
#  ('CMG', NameError("name 'tickers' is not defined")),
#  ('TEL', NameError("name 'tickers' is not defined")),
#  ('MNST', NameError("name 'tickers' is not defined")),
#  ('CMI', NameError("name 'tickers' is not defined")),
#  ('CDNS', NameError("name 'tickers' is not defined")),
#  ('TROW', NameError("name 'tickers' is not defined")),
#  ('MSCI', NameError("name 'tickers' is not defined")),
#  ('PSA', NameError("name 'tickers' is not defined")),
#  ('COF', NameError("name 'tickers' is not defined")),
#  ('JCI', NameError("name 'tickers' is not defined")),
#  ('STZ', NameError("name 'tickers' is not defined")),
#  ('SYY', NameError("name 'tickers' is not defined")),
#  ('A', NameError("name 'tickers' is not defined")),
#  ('VRSK', NameError("name 'tickers' is not defined")),
#  ('MET', NameError("name 'tickers' is not defined")),
#  ('ALL', NameError("name 'tickers' is not defined")),
#  ('PCAR', NameError("name 'tickers' is not defined")),
#  ('BK', NameError("name 'tickers' is not defined")),
#  ('WBA', NameError("name 'tickers' is not defined")),
#  ('TRV', NameError("name 'tickers' is not defined")),
#  ('YUM', NameError("name 'tickers' is not defined")),
#  ('ES', NameError("name 'tickers' is not defined")),
#  ('WEC', NameError("name 'tickers' is not defined")),
#  ('KR', NameError("name 'tickers' is not defined")),
#  ('PPG', NameError("name 'tickers' is not defined")),
#  ('TT', NameError("name 'tickers' is not defined")),
#  ('AZO', NameError("name 'tickers' is not defined")),
#  ('IQV', NameError("name 'tickers' is not defined")),
#  ('ZBH', NameError("name 'tickers' is not defined")),
#  ('CLX', NameError("name 'tickers' is not defined")),
#  ('PSX', NameError("name 'tickers' is not defined")),
#  ('ANSS', NameError("name 'tickers' is not defined")),
#  ('PRU', NameError("name 'tickers' is not defined")),
#  ('KMI', NameError("name 'tickers' is not defined")),
#  ('FAST', NameError("name 'tickers' is not defined")),
#  ('F', NameError("name 'tickers' is not defined")),
#  ('PEG', NameError("name 'tickers' is not defined")),
#  ('SLB', NameError("name 'tickers' is not defined")),
#  ('CTAS', NameError("name 'tickers' is not defined")),
#  ('AFL', NameError("name 'tickers' is not defined")),
#  ('PH', NameError("name 'tickers' is not defined")),
#  ('HPQ', NameError("name 'tickers' is not defined")),
#  ('BBY', NameError("name 'tickers' is not defined")),
#  ('ROK', NameError("name 'tickers' is not defined")),
#  ('MAR', NameError("name 'tickers' is not defined")),
#  ('MCHP', NameError("name 'tickers' is not defined")),
#  ('MSI', NameError("name 'tickers' is not defined")),
#  ('WMB', NameError("name 'tickers' is not defined")),
#  ('AWK', NameError("name 'tickers' is not defined")),
#  ('OTIS', NameError("name 'tickers' is not defined")),
#  ('EOG', NameError("name 'tickers' is not defined")),
#  ('GLW', NameError("name 'tickers' is not defined")),
#  ('AIG', NameError("name 'tickers' is not defined")),
#  ('DHI', NameError("name 'tickers' is not defined")),
#  ('BLL', NameError("name 'tickers' is not defined")),
#  ('RMD', NameError("name 'tickers' is not defined")),
#  ('XLNX', NameError("name 'tickers' is not defined")),
#  ('WLTW', NameError("name 'tickers' is not defined")),
#  ('HLT', NameError("name 'tickers' is not defined")),
#  ('SWK', NameError("name 'tickers' is not defined")),
#  ('MKC', NameError("name 'tickers' is not defined")),
#  ('CARR', NameError("name 'tickers' is not defined")),
#  ('ADM', NameError("name 'tickers' is not defined")),
#  ('ED', NameError("name 'tickers' is not defined")),
#  ('STT', NameError("name 'tickers' is not defined")),
#  ('TDG', NameError("name 'tickers' is not defined")),
#  ('DLTR', NameError("name 'tickers' is not defined")),
#  ('MCK', NameError("name 'tickers' is not defined")),
#  ('WELL', NameError("name 'tickers' is not defined")),
#  ('PAYX', NameError("name 'tickers' is not defined")),
#  ('MPC', NameError("name 'tickers' is not defined")),
#  ('SWKS', NameError("name 'tickers' is not defined")),
#  ('CHD', NameError("name 'tickers' is not defined")),
#  ('MTD', NameError("name 'tickers' is not defined")),
#  ('AME', NameError("name 'tickers' is not defined")),
#  ('ALXN', NameError("name 'tickers' is not defined")),
#  ('DTE', NameError("name 'tickers' is not defined")),
#  ('VLO', NameError("name 'tickers' is not defined")),
#  ('CERN', NameError("name 'tickers' is not defined")),
#  ('LEN', NameError("name 'tickers' is not defined")),
#  ('HSY', NameError("name 'tickers' is not defined")),
#  ('PPL', NameError("name 'tickers' is not defined")),
#  ('APTV', NameError("name 'tickers' is not defined")),
#  ('KHC', NameError("name 'tickers' is not defined")),
#  ('AVB', NameError("name 'tickers' is not defined")),
#  ('ARE', NameError("name 'tickers' is not defined")),
#  ('WY', NameError("name 'tickers' is not defined")),
#  ('VRSN', NameError("name 'tickers' is not defined")),
#  ('O', NameError("name 'tickers' is not defined")),
#  ('CTVA', NameError("name 'tickers' is not defined")),
#  ('FTV', NameError("name 'tickers' is not defined")),
#  ('ALGN', NameError("name 'tickers' is not defined")),
#  ('VFC', NameError("name 'tickers' is not defined")),
#  ('FCX', NameError("name 'tickers' is not defined")),
#  ('SPG', NameError("name 'tickers' is not defined")),
#  ('CPRT', NameError("name 'tickers' is not defined")),
#  ('FLT', NameError("name 'tickers' is not defined")),
#  ('WST', NameError("name 'tickers' is not defined")),
#  ('EIX', NameError("name 'tickers' is not defined")),
#  ('AJG', NameError("name 'tickers' is not defined")),
#  ('AEE', NameError("name 'tickers' is not defined")),
#  ('ETR', NameError("name 'tickers' is not defined")),
#  ('EQR', NameError("name 'tickers' is not defined")),
#  ('LUV', NameError("name 'tickers' is not defined")),
#  ('AMP', NameError("name 'tickers' is not defined")),
#  ('FRC', NameError("name 'tickers' is not defined")),
#  ('TTWO', NameError("name 'tickers' is not defined")),
#  ('RSG', NameError("name 'tickers' is not defined")),
#  ('EFX', NameError("name 'tickers' is not defined")),
#  ('ODFL', NameError("name 'tickers' is not defined")),
#  ('TSN', NameError("name 'tickers' is not defined")),
#  ('MXIM', NameError("name 'tickers' is not defined")),
#  ('CAG', NameError("name 'tickers' is not defined")),
#  ('MKTX', NameError("name 'tickers' is not defined")),
#  ('TSCO', NameError("name 'tickers' is not defined")),
#  ('KEYS', NameError("name 'tickers' is not defined")),
#  ('AKAM', NameError("name 'tickers' is not defined")),
#  ('FTNT', NameError("name 'tickers' is not defined")),
#  ('KMX', NameError("name 'tickers' is not defined")),
#  ('NTRS', NameError("name 'tickers' is not defined")),
#  ('LYB', NameError("name 'tickers' is not defined")),
#  ('KSU', NameError("name 'tickers' is not defined")),
#  ('PXD', NameError("name 'tickers' is not defined")),
#  ('LH', NameError("name 'tickers' is not defined")),
#  ('K', NameError("name 'tickers' is not defined")),
#  ('CMS', NameError("name 'tickers' is not defined")),
#  ('AMCR', NameError("name 'tickers' is not defined")),
#  ('DAL', NameError("name 'tickers' is not defined")),
#  ('TFX', NameError("name 'tickers' is not defined")),
#  ('HOLX', NameError("name 'tickers' is not defined")),
#  ('LVS', NameError("name 'tickers' is not defined")),
#  ('INCY', NameError("name 'tickers' is not defined")),
#  ('VMC', NameError("name 'tickers' is not defined")),
#  ('DFS', NameError("name 'tickers' is not defined")),
#  ('CTXS', NameError("name 'tickers' is not defined")),
#  ('DPZ', NameError("name 'tickers' is not defined")),
#  ('CDW', NameError("name 'tickers' is not defined")),
#  ('DOV', NameError("name 'tickers' is not defined")),
#  ('BR', NameError("name 'tickers' is not defined")),
#  ('CBRE', NameError("name 'tickers' is not defined")),
#  ('VAR', NameError("name 'tickers' is not defined")),
#  ('MAS', NameError("name 'tickers' is not defined")),
#  ('DGX', NameError("name 'tickers' is not defined")),
#  ('VTR', NameError("name 'tickers' is not defined")),
#  ('QRVO', NameError("name 'tickers' is not defined")),
#  ('FE', NameError("name 'tickers' is not defined")),
#  ('GWW', NameError("name 'tickers' is not defined")),
#  ('NDAQ', NameError("name 'tickers' is not defined")),
#  ('PEAK', NameError("name 'tickers' is not defined")),
#  ('NVR', NameError("name 'tickers' is not defined")),
#  ('GRMN', NameError("name 'tickers' is not defined")),
#  ('HIG', NameError("name 'tickers' is not defined")),
#  ('ZBRA', NameError("name 'tickers' is not defined")),
#  ('VIAC', NameError("name 'tickers' is not defined")),
#  ('EXPD', NameError("name 'tickers' is not defined")),
#  ('COO', NameError("name 'tickers' is not defined")),
#  ('ABC', NameError("name 'tickers' is not defined")),
#  ('HRL', NameError("name 'tickers' is not defined")),
#  ('IP', NameError("name 'tickers' is not defined")),
#  ('CAH', NameError("name 'tickers' is not defined")),
#  ('FITB', NameError("name 'tickers' is not defined")),
#  ('XYL', NameError("name 'tickers' is not defined")),
#  ('HAL', NameError("name 'tickers' is not defined")),
#  ('DRE', NameError("name 'tickers' is not defined")),
#  ('FMC', NameError("name 'tickers' is not defined")),
#  ('ESS', NameError("name 'tickers' is not defined")),
#  ('MTB', NameError("name 'tickers' is not defined")),
#  ('PAYC', NameError("name 'tickers' is not defined")),
#  ('NUE', NameError("name 'tickers' is not defined")),
#  ('GPC', NameError("name 'tickers' is not defined")),
#  ('EXR', NameError("name 'tickers' is not defined")),
#  ('ABMD', NameError("name 'tickers' is not defined")),
#  ('SYF', NameError("name 'tickers' is not defined")),
#  ('TIF', NameError("name 'tickers' is not defined")),
#  ('TYL', NameError("name 'tickers' is not defined")),
#  ('IEX', NameError("name 'tickers' is not defined")),
#  ('WAT', NameError("name 'tickers' is not defined")),
#  ('BF-B', NameError("name 'tickers' is not defined")),
#  ('MLM', NameError("name 'tickers' is not defined")),
#  ('EXPE', NameError("name 'tickers' is not defined")),
#  ('LNT', NameError("name 'tickers' is not defined")),
#  ('IFF', NameError("name 'tickers' is not defined")),
#  ('MAA', NameError("name 'tickers' is not defined")),
#  ('CHRW', NameError("name 'tickers' is not defined")),
#  ('STE', NameError("name 'tickers' is not defined")),
#  ('SIVB', NameError("name 'tickers' is not defined")),
#  ('URI', NameError("name 'tickers' is not defined")),
#  ('SJM', NameError("name 'tickers' is not defined")),
#  ('NLOK', NameError("name 'tickers' is not defined")),
#  ('ULTA', NameError("name 'tickers' is not defined")),
#  ('PKI', NameError("name 'tickers' is not defined")),
#  ('JKHY', NameError("name 'tickers' is not defined")),
#  ('BXP', NameError("name 'tickers' is not defined")),
#  ('CE', NameError("name 'tickers' is not defined")),
#  ('HPE', NameError("name 'tickers' is not defined")),
#  ('HES', NameError("name 'tickers' is not defined")),
#  ('ETFC', NameError("name 'tickers' is not defined")),
#  ('IR', NameError("name 'tickers' is not defined")),
#  ('KEY', NameError("name 'tickers' is not defined")),
#  ('ATO', NameError("name 'tickers' is not defined")),
#  ('OXY', NameError("name 'tickers' is not defined")),
#  ('PHM', NameError("name 'tickers' is not defined")),
#  ('JBHT', NameError("name 'tickers' is not defined")),
#  ('LDOS', NameError("name 'tickers' is not defined")),
#  ('CINF', NameError("name 'tickers' is not defined")),
#  ('WAB', NameError("name 'tickers' is not defined")),
#  ('FBHS', NameError("name 'tickers' is not defined")),
#  ('AES', NameError("name 'tickers' is not defined")),
#  ('ANET', NameError("name 'tickers' is not defined")),
#  ('OMC', NameError("name 'tickers' is not defined")),
#  ('IT', NameError("name 'tickers' is not defined")),
#  ('J', NameError("name 'tickers' is not defined")),
#  ('TDY', NameError("name 'tickers' is not defined")),
#  ('EVRG', NameError("name 'tickers' is not defined")),
#  ('PFG', NameError("name 'tickers' is not defined")),
#  ('MGM', NameError("name 'tickers' is not defined")),
#  ('WHR', NameError("name 'tickers' is not defined")),
#  ('OKE', NameError("name 'tickers' is not defined")),
#  ('RF', NameError("name 'tickers' is not defined")),
#  ('CNP', NameError("name 'tickers' is not defined")),
#  ('RCL', NameError("name 'tickers' is not defined")),
#  ('CFG', NameError("name 'tickers' is not defined")),
#  ('BIO', NameError("name 'tickers' is not defined")),
#  ('CTL', NameError("name 'tickers' is not defined")),
#  ('AAP', NameError("name 'tickers' is not defined")),
#  ('DRI', NameError("name 'tickers' is not defined")),
#  ('STX', NameError("name 'tickers' is not defined")),
#  ('BKR', NameError("name 'tickers' is not defined")),
#  ('CBOE', NameError("name 'tickers' is not defined")),
#  ('HAS', NameError("name 'tickers' is not defined")),
#  ('UDR', NameError("name 'tickers' is not defined")),
#  ('WDC', NameError("name 'tickers' is not defined")),
#  ('EMN', NameError("name 'tickers' is not defined")),
#  ('WU', NameError("name 'tickers' is not defined")),
#  ('CXO', NameError("name 'tickers' is not defined")),
#  ('HBAN', NameError("name 'tickers' is not defined")),
#  ('ALB', NameError("name 'tickers' is not defined")),
#  ('LKQ', NameError("name 'tickers' is not defined")),
#  ('NTAP', NameError("name 'tickers' is not defined")),
#  ('XRAY', NameError("name 'tickers' is not defined")),
#  ('HSIC', NameError("name 'tickers' is not defined")),
#  ('AVY', NameError("name 'tickers' is not defined")),
#  ('ALLE', NameError("name 'tickers' is not defined")),
#  ('FOXA', NameError("name 'tickers' is not defined")),
#  ('RJF', NameError("name 'tickers' is not defined")),
#  ('PKG', NameError("name 'tickers' is not defined")),
#  ('LW', NameError("name 'tickers' is not defined")),
#  ('UAL', NameError("name 'tickers' is not defined")),
#  ('TXT', NameError("name 'tickers' is not defined")),
#  ('WRB', NameError("name 'tickers' is not defined")),
#  ('UHS', NameError("name 'tickers' is not defined")),
#  ('L', NameError("name 'tickers' is not defined")),
#  ('CPB', NameError("name 'tickers' is not defined")),
#  ('DISH', NameError("name 'tickers' is not defined")),
#  ('NRG', NameError("name 'tickers' is not defined")),
#  ('RE', NameError("name 'tickers' is not defined")),
#  ('IRM', NameError("name 'tickers' is not defined")),
#  ('NI', NameError("name 'tickers' is not defined")),
#  ('BWA', NameError("name 'tickers' is not defined")),
#  ('GL', NameError("name 'tickers' is not defined")),
#  ('PNW', NameError("name 'tickers' is not defined")),
#  ('MYL', NameError("name 'tickers' is not defined")),
#  ('WYNN', NameError("name 'tickers' is not defined")),
#  ('SNA', NameError("name 'tickers' is not defined")),
#  ('FFIV', NameError("name 'tickers' is not defined")),
#  ('WRK', NameError("name 'tickers' is not defined")),
#  ('JNPR', NameError("name 'tickers' is not defined")),
#  ('COG', NameError("name 'tickers' is not defined")),
#  ('HST', NameError("name 'tickers' is not defined")),
#  ('DVA', NameError("name 'tickers' is not defined")),
#  ('PNR', NameError("name 'tickers' is not defined")),
#  ('ROL', NameError("name 'tickers' is not defined")),
#  ('CCL', NameError("name 'tickers' is not defined")),
#  ('LYV', NameError("name 'tickers' is not defined")),
#  ('AIZ', NameError("name 'tickers' is not defined")),
#  ('CF', NameError("name 'tickers' is not defined")),
#  ('LNC', NameError("name 'tickers' is not defined")),
#  ('PWR', NameError("name 'tickers' is not defined")),
#  ('PRGO', NameError("name 'tickers' is not defined")),
#  ('TAP', NameError("name 'tickers' is not defined")),
#  ('IPG', NameError("name 'tickers' is not defined")),
#  ('AOS', NameError("name 'tickers' is not defined")),
#  ('REG', NameError("name 'tickers' is not defined")),
#  ('HWM', NameError("name 'tickers' is not defined")),
#  ('AAL', NameError("name 'tickers' is not defined")),
#  ('LB', NameError("name 'tickers' is not defined")),
#  ('HII', NameError("name 'tickers' is not defined")),
#  ('RHI', NameError("name 'tickers' is not defined")),
#  ('DISCK', NameError("name 'tickers' is not defined")),
#  ('SEE', NameError("name 'tickers' is not defined")),
#  ('FANG', NameError("name 'tickers' is not defined")),
#  ('MOS', NameError("name 'tickers' is not defined")),
#  ('NWL', NameError("name 'tickers' is not defined")),
#  ('BEN', NameError("name 'tickers' is not defined")),
#  ('VNO', NameError("name 'tickers' is not defined")),
#  ('HBI', NameError("name 'tickers' is not defined")),
#  ('CMA', NameError("name 'tickers' is not defined")),
#  ('FRT', NameError("name 'tickers' is not defined")),
#  ('ZION', NameError("name 'tickers' is not defined")),
#  ('MHK', NameError("name 'tickers' is not defined")),
#  ('NWSA', NameError("name 'tickers' is not defined")),
#  ('NLSN', NameError("name 'tickers' is not defined")),
#  ('APA', NameError("name 'tickers' is not defined")),
#  ('IPGP', NameError("name 'tickers' is not defined")),
#  ('AIV', NameError("name 'tickers' is not defined")),
#  ('LEG', NameError("name 'tickers' is not defined")),
#  ('NBL', NameError("name 'tickers' is not defined")),
#  ('KIM', NameError("name 'tickers' is not defined")),
#  ('DXC', NameError("name 'tickers' is not defined")),
#  ('PBCT', NameError("name 'tickers' is not defined")),
#  ('FLIR', NameError("name 'tickers' is not defined")),
#  ('NOV', NameError("name 'tickers' is not defined")),
#  ('ALK', NameError("name 'tickers' is not defined")),
#  ('MRO', NameError("name 'tickers' is not defined")),
#  ('FOX', NameError("name 'tickers' is not defined")),
#  ('NCLH', NameError("name 'tickers' is not defined")),
#  ('TPR', NameError("name 'tickers' is not defined")),
#  ('DVN', NameError("name 'tickers' is not defined")),
#  ('SLG', NameError("name 'tickers' is not defined")),
#  ('PVH', NameError("name 'tickers' is not defined")),
#  ('IVZ', NameError("name 'tickers' is not defined")),
#  ('UNM', NameError("name 'tickers' is not defined")),
#  ('HFC', NameError("name 'tickers' is not defined")),
#  ('FLS', NameError("name 'tickers' is not defined")),
#  ('DISCA', NameError("name 'tickers' is not defined")),
#  ('XRX', NameError("name 'tickers' is not defined")),
#  ('RL', NameError("name 'tickers' is not defined")),
#  ('GPS', NameError("name 'tickers' is not defined")),
#  ('FTI', NameError("name 'tickers' is not defined")),
#  ('KSS', NameError("name 'tickers' is not defined")),
#  ('HRB', NameError("name 'tickers' is not defined")),
#  ('UAA', NameError("name 'tickers' is not defined")),
#  ('NWS', NameError("name 'tickers' is not defined")),
#  ('UA', NameError("name 'tickers' is not defined")),
#  ('COTY', NameError("name 'tickers' is not defined")),
#  ('OXY-WT', NameError("name 'tickers' is not defined"))]

# %%
info_df = pd.DataFrame({'TICKER': ticker_lst, 'SECTOR': sectors, 'MARKET_CAPS': market_caps})
info_df.to_csv("info_df.csv", index=None)

# %%
dfs = []
unique_sectors = info_df['SECTOR'].unique().tolist()
for sector in unique_sectors:
    sector_df = info_df.loc[info_df['SECTOR'] == sector, :].copy()
    sector_df = sector_df.sort_values(by="MARKET_CAPS")[-1:-6:-1]
    dfs.append(sector_df)

top5_df = pd.concat(dfs)
top5_df.to_csv("top5_df.csv", index=None)

# %%
top5_df.head(10)
# Out:
#    TICKER             SECTOR    MARKET_CAPS
# 0    AAPL         Technology  2127040479232
# 1    MSFT         Technology  1612060819456
# 10   NVDA         Technology   312014110720
# 14   ADBE         Technology   226987065344
# 18   INTC         Technology   209587830784
# 2    AMZN  Consumer Cyclical  1645283377152
# 9      HD  Consumer Cyclical   304619552768
# 30    NKE  Consumer Cyclical   171197939712
# 27    MCD  Consumer Cyclical   157429874688
# 38    LOW  Consumer Cyclical   122260324352

# %%
top5_tickers = top5_df['TICKER'].tolist()

# %%
data = yf.download(tickers = top5_tickers, period = "3mo", interval = "1wk", # '1d'
                   group_by = 'ticker', auto_adjust = True, prepost = False, threads = True, proxy = None)
# Out:
# [*********************100%***********************]  55 of 55 completed
#
# 4 Failed downloads:
# - NFLX: No data found, symbol may be delisted
# - BLK: No data found, symbol may be delisted
# - RTX: No data found, symbol may be delisted
# - PG: No data found, symbol may be delisted

# %%
data.to_pickle("sector_top5_data.pkl")

# %%
data = pd.read_pickle("sector_top5_data.pkl")

# %%
data.head()
# Out:
#                   AEP                                               \
#                  Open       High        Low      Close      Volume
# Date
# 2020-05-18        NaN        NaN        NaN        NaN         NaN
# 2020-05-21        NaN        NaN        NaN        NaN         NaN
# 2020-05-25  78.848135  85.146066  78.659690  84.550987  13697200.0
# 2020-06-01  84.382379  87.238761  82.696313  84.808853  10175400.0
# 2020-06-08  84.729513  87.397459  79.958955  81.129280  12580400.0
#
#                    DLR                                                  ...  \
#                   Open        High         Low       Close      Volume  ...
# Date                                                                    ...
# 2020-05-18  130.737469  134.723856  128.734372  134.674271   3404800.0  ...
# 2020-05-21         NaN         NaN         NaN         NaN         NaN  ...
# 2020-05-25  138.254088  144.987315  133.662802  142.359467   8122200.0  ...
# 2020-06-01  142.746196  143.727922  132.899244  140.098526  11562000.0  ...
# 2020-06-08  140.237359  142.290056  131.699360  134.862686  11592100.0  ...
#
#                   COST                                                  \
#                   Open        High         Low       Close      Volume
# Date
# 2020-05-18         NaN         NaN         NaN         NaN         NaN
# 2020-05-21         NaN         NaN         NaN         NaN         NaN
# 2020-05-25  305.353211  310.332491  298.827239  307.807922  15503500.0
# 2020-06-01  307.239141  314.673163  304.065974  311.370270  15918000.0
# 2020-06-08  309.993220  310.621873  295.614145  298.058899  17096100.0
#
#                     HD
#                   Open        High         Low       Close      Volume
# Date
# 2020-05-18  236.209566  240.901551  234.390427  240.444290   7814500.0
# 2020-05-21         NaN         NaN         NaN         NaN         NaN
# 2020-05-25  246.677053  250.732838  239.350804  247.005096  19802100.0
# 2020-06-01  247.929590  254.331367  244.410594  253.386993  23160600.0
# 2020-06-08  252.490005  259.290009  237.050003  242.449997  22918800.0
#
# [5 rows x 283 columns]
