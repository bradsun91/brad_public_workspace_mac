# %%
from fredapi import Fred

fred = Fred(api_key='60f3c1fa4980377313350511a64d3a86')

tickers1 = ['SP500','GDP','WALCL','UNRATE','FEDFUNDS','INDPRO',
            'A191RL1Q225SBEA', 'M2','DGS10','T10YIE']


for ticker in tickers1:
    data = fred.get_series(ticker)
    print(ticker,data)
# Out:
# SP500 2010-07-05        NaN
# 2010-07-06    1028.06
# 2010-07-07    1060.27
# 2010-07-08    1070.25
# 2010-07-09    1077.96
#                ...
# 2020-06-26    3009.05
# 2020-06-29    3053.24
# 2020-06-30    3100.29
# 2020-07-01    3115.86
# 2020-07-02    3130.01
# Length: 2609, dtype: float64
# GDP 1946-01-01          NaN
# 1946-04-01          NaN
# 1946-07-01          NaN
# 1946-10-01          NaN
# 1947-01-01      243.164
#                 ...
# 2019-01-01    21098.827
# 2019-04-01    21340.267
# 2019-07-01    21542.540
# 2019-10-01    21729.124
# 2020-01-01    21539.689
# Length: 297, dtype: float64
# WALCL 2002-12-18     719542.0
# 2002-12-25     732059.0
# 2003-01-01     730994.0
# 2003-01-08     723762.0
# 2003-01-15     720074.0
#                 ...
# 2020-06-03    7165217.0
# 2020-06-10    7168936.0
# 2020-06-17    7094690.0
# 2020-06-24    7082302.0
# 2020-07-01    7009040.0
# Length: 916, dtype: float64
# UNRATE 1948-01-01     3.4
# 1948-02-01     3.8
# ...
