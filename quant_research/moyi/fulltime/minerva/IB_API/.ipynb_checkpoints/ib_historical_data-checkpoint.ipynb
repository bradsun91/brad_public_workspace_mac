# %%
#import required packages
#使用ib_insync是一个能比较简单的提取数据的包（相比于ib_api自带的功能）
import pandas as pd
from ib_insync import *
util.startLoop()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)

# %%
#establish connection with IB TWS
ib = IB()
ib.connect('127.0.0.1', 7496, clientId=100)
# Out:
# <IB connected to 127.0.0.1:7496 clientId=100>

# %%
#因为我们现在使用的是demo mode，所以这里使用汇率作为取数据演示
contract = Forex('USDJPY')
bars = ib.reqHistoricalData(
    contract, endDateTime='', durationStr='1 Y',
    barSizeSetting='1 day', whatToShow='MIDPOINT', useRTH=True)

# convert to pandas dataframe:
df = util.df(bars)
df.head()
# Out:
#          date      open      high       low     close  volume  average  \
# 0  2019-04-05  111.6300  111.8245  111.5575  111.7275      -1     -1.0
# 1  2019-04-08  111.7175  111.7365  111.2825  111.4815      -1     -1.0
# 2  2019-04-09  111.5130  111.5795  110.9790  111.1420      -1     -1.0
# 3  2019-04-10  111.1520  111.2815  110.8445  111.0135      -1     -1.0
# 4  2019-04-11  110.9620  111.6960  110.9025  111.6635      -1     -1.0
#
#    barCount
# 0        -1
# 1        -1
# 2        -1
# 3        -1
# 4        -1

# %%
contract = Stock('SPY', 'SMART', 'USD')
dt = ''
barsList = []
while True:
    bars = ib.reqHistoricalData(
        contract,
        endDateTime=dt,
        durationStr='10 D',
        barSizeSetting='1 min',
        whatToShow='ADJUSTED_LAST',
        useRTH=True,
#         formatDateb=1
    )
    if not bars:
        break
    barsList.append(bars)
    dt = bars[0].date
    print(dt)
# save to CSV file
allBars = [b for bars in reversed(barsList) for b in bars]
df = util.df(allBars)
# Out:
# Error 321, reqId 302: Error validating request:-'bS' : cause - End date not supported with adjusted last, contract: Stock(symbol='SPY', exchange='SMART', currency='USD')
# 2020-03-23 21:30:00

# %%
df.set_index('date', inplace=True)

# %%
df[['open','high','low','close']].tail(100).plot(figsize = (15,7))
plt.title("SPY Live Minute Data")
# Out:
# Text(0.5, 1.0, 'SPY Live Minute Data')
# Peer closed connection
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect',)>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect',)>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect',)>
# ConnectionError: Socket disconnect

# %%
df
# Out:
#                     date   open   high    low  close  volume  average  \
# 0    2020-03-23 21:30:00  57.37  58.55  57.00  57.50    3329   57.757
# 1    2020-03-23 21:31:00  57.59  58.00  57.30  57.88    1148   57.643
# 2    2020-03-23 21:32:00  57.84  57.85  56.40  56.72    2540   56.979
# 3    2020-03-23 21:33:00  56.72  56.98  55.49  55.68    2850   56.397
# 4    2020-03-23 21:34:00  55.66  55.70  55.12  55.47    2257   55.358
# ...                  ...    ...    ...    ...    ...     ...      ...
# 3663 2020-04-04 00:03:00  47.29  47.30  47.25  47.25     285   47.274
# 3664 2020-04-04 00:04:00  47.25  47.27  47.14  47.23     592   47.208
# 3665 2020-04-04 00:05:00  47.24  47.28  47.22  47.27     289   47.253
# 3666 2020-04-04 00:06:00  47.26  47.34  47.26  47.28     266   47.309
# 3667 2020-04-04 00:07:00  47.28  47.38  47.28  47.32     349   47.334
#
#       barCount
# 0         1480
# 1          724
# 2         1188
# 3         1524
# 4         1318
# ...        ...
# 3663        89
# 3664       187
# 3665       182
# 3666       174
# 3667       174
#
# [3668 rows x 8 columns]

# %%
df.to_csv("TSLA_test_IB.csv", index=False)

# %%
df
# Out:
#                     date   open   high    low  close  volume  average  \
# 0    2020-03-23 21:30:00  57.37  58.55  57.00  57.50    3329   57.757
# 1    2020-03-23 21:31:00  57.59  58.00  57.30  57.88    1148   57.643
# 2    2020-03-23 21:32:00  57.84  57.85  56.40  56.72    2540   56.979
# 3    2020-03-23 21:33:00  56.72  56.98  55.49  55.68    2850   56.397
# 4    2020-03-23 21:34:00  55.66  55.70  55.12  55.47    2257   55.358
# ...                  ...    ...    ...    ...    ...     ...      ...
# 3653 2020-04-03 23:53:00  47.30  47.40  47.29  47.40     421   47.344
# 3654 2020-04-03 23:54:00  47.41  47.48  47.32  47.36     507   47.379
# 3655 2020-04-03 23:55:00  47.37  47.38  47.21  47.23     473   47.272
# 3656 2020-04-03 23:56:00  47.21  47.27  47.18  47.23     255   47.221
# 3657 2020-04-03 23:57:00  47.23  47.27  47.13  47.15     367   47.204
#
#       barCount
# 0         1480
# 1          724
# 2         1188
# 3         1524
# 4         1318
# ...        ...
# 3653       266
# 3654       305
# 3655       201
# 3656       151
# 3657       208
#
# [3658 rows x 8 columns]

# %%
Option?

# %%
option = Option('SPY', '20201215', 490, 'P', 'FTA', multiplier=100)
calc = ib.calculateImpliedVolatility(
    option, optionPrice=6.1, underPrice=525)
print(calc)
calc = ib.calculateOptionPrice(
option, volatility=0.14, underPrice=525)
print(calc)
# Out:
# Error 200, reqId 283: No security definition has been found for the request, contract: Option(symbol='SPY', lastTradeDateOrContractMonth='20201215', strike=490, right='P', multiplier=100, exchange='FTA')
# []
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-dd7bc668d638> in <module>
#       4 print(calc)
#       5 calc = ib.calculateOptionPrice(
# ----> 6 option, volatility=0.14, underPrice=525)
#       7 print(calc)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ib_insync/ib.py in calculateOptionPrice(self, contract, volatility, underPrice, optPrcOptions)
#    1436         return self._run(
#    1437             self.calculateOptionPriceAsync(
# -> 1438                 contract, volatility, underPrice, optPrcOptions))
#    1439
#    1440     def reqSecDefOptParams(
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ib_insync/ib.py in _run(self, *awaitables)
#     290
#     291     def _run(self, *awaitables: Awaitable):
# --> 292         return util.run(*awaitables, timeout=self.RequestTimeout)
#     293
#     294     def waitOnUpdate(self, timeout: float = 0) -> bool:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ib_insync/util.py in run(timeout, *awaitables)
#     309         globalErrorEvent.connect(onError)
#     310         try:
# --> 311             result = loop.run_until_complete(task)
#     312         except asyncio.CancelledError as e:
#     313             raise globalErrorEvent.value() or e
#
# ~/anaconda3/envs/py36/lib/python3.6/asyncio/base_events.py in run_until_complete(self, future)
#     486             raise RuntimeError('Event loop stopped before Future completed.')
#     487
# --> 488         return future.result()
#     489
#     490     def stop(self):
#
# ~/anaconda3/envs/py36/lib/python3.6/asyncio/tasks.py in _step(***failed resolving arguments***)
#     178                 # We use the `send` method directly, because coroutines
#     179                 # don't have `__iter__` and `__next__` methods.
# --> 180                 result = coro.send(None)
#     181             else:
#     182                 result = coro.throw(exc)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ib_insync/ib.py in calculateOptionPriceAsync(self, contract, volatility, underPrice, optPrcOptions)
#    1891         future = self.wrapper.startReq(reqId, contract)
#    1892         self.client.calculateOptionPrice(
# -> 1893             reqId, contract, volatility, underPrice, optPrcOptions)
#    1894         try:
#    1895             await asyncio.wait_for(future, 4)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ib_insync/client.py in calculateOptionPrice(self, reqId, contract, volatility, underPrice, optPrcOptions)
#     806         self.send(
#     807             55, 3, reqId, contract, volatility, underPrice,
# --> 808             len(optPrcOptions), optPrcOptions)
#     809
#     810     def cancelCalculateImpliedVolatility(self, reqId):
#
# TypeError: object of type 'NoneType' has no len()

# %%
bars
# Out:
# []

# %%
#因为demo mode所以现在会出现报错，使用实盘账户的话，应该可以跑通
code = "AAPL"
 
contract = Stock(code, exchange="SMART")
bars = ib.reqHistoricalData(contract, endDateTime='20190314 18:30:00', durationStr='1 D',
        barSizeSetting='30 secs', whatToShow='MIDPOINT', useRTH=True)
 
# convert to pandas dataframe:
df = util.df(bars)
print(df[['date', 'open', 'high', 'low', 'close']])
# Out:
# Error 200, reqId 5: The contract description specified for AAPL is ambiguous;
# you must specify the currency., contract: Stock(symbol='AAPL', exchange='SMART')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-0245e85af5ba> in <module>
#       8 # convert to pandas dataframe:
#       9 df = util.df(bars)
# ---> 10 print(df[['date', 'open', 'high', 'low', 'close']])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
bars
# Out:
# []

# %%
#这是一个使用ib_sync和ib_api 来实现下单的一个例子
contract = Stock('AAPL', 'SMART', 'USD')
ib.qualifyContracts(contract)
 
order = MarketOrder('BUY', 1)
 
trade = ib.placeOrder(contract, order)
 
print(trade)
 
ib.sleep(1)
print(trade.log)
 
limitOrder = LimitOrder('BUY', 1, 0.05)
limitTrade = ib.placeOrder(contract, limitOrder)
 
print(limitTrade)
 
ib.cancelOrder(limitOrder)
# Out:
# Trade(contract=Stock(conId=265598, symbol='AAPL', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='AAPL', tradingClass='NMS'), order=MarketOrder(orderId=110, clientId=100, action='BUY', totalQuantity=1), orderStatus=OrderStatus(orderId=110, status='PendingSubmit', filled=0, remaining=0, avgFillPrice=0.0, permId=0, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0, lastLiquidity=0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 21, 17, 7, 20, 809067, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
# [TradeLogEntry(time=datetime.datetime(2020, 1, 21, 17, 7, 20, 809067, tzinfo=datetime.timezone.utc), status='PendingSubmit', message=''), TradeLogEntry(time=datetime.datetime(2020, 1, 21, 17, 7, 21, 96564, tzinfo=datetime.timezone.utc), status='Submitted', message='')]
# Trade(contract=Stock(conId=265598, symbol='AAPL', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='AAPL', tradingClass='NMS'), order=LimitOrder(orderId=111, clientId=100, action='BUY', totalQuantity=1, lmtPrice=0.05), orderStatus=OrderStatus(orderId=111, status='PendingSubmit', filled=0, remaining=0, avgFillPrice=0.0, permId=0, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0, lastLiquidity=0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 21, 17, 7, 21, 817868, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
# Trade(contract=Stock(conId=265598, symbol='AAPL', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='AAPL', tradingClass='NMS'), order=LimitOrder(orderId=111, clientId=100, action='BUY', totalQuantity=1, lmtPrice=0.05), orderStatus=OrderStatus(orderId=111, status='PendingCancel', filled=0, remaining=0, avgFillPrice=0.0, permId=0, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0, lastLiquidity=0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 21, 17, 7, 21, 817868, tzinfo=datetime.timezone.utc), status='PendingSubmit', message=''), TradeLogEntry(time=datetime.datetime(2020, 1, 21, 17, 7, 21, 818816, tzinfo=datetime.timezone.utc), status='PendingCancel', message='')])

# %%
#尝试调取option数据
spx = Index('SPX')
ib.qualifyContracts(spx)
chains= ib.reqSecDefOptParams(spx.symbol, '', spx.secType, spx.conId)

util.df(chains)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-20-5a2efe7f3c09> in <module>
#       1 #尝试调取option数据
#       2 spx = Index('SPX')
# ----> 3 ib.qualifyContracts(spx)
#       4 chains= ib.reqSecDefOptParams(spx.symbol, '', spx.secType, spx.conId)
#       5
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ib_insync/ib.py in qualifyContracts(self, *contracts)
#     535             contracts: Contracts to qualify.
#     536         """
# --> 537         return self._run(self.qualifyContractsAsync(*contracts))
#     538
#     539     def bracketOrder(
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ib_insync/ib.py in _run(self, *awaitables)
#     290
#     291     def _run(self, *awaitables: Awaitable):
# --> 292         return util.run(*awaitables, timeout=self.RequestTimeout)
#     293
#     294     def waitOnUpdate(self, timeout: float = 0) -> bool:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ib_insync/util.py in run(timeout, *awaitables)
#     309         globalErrorEvent.connect(onError)
#     310         try:
# --> 311             result = loop.run_until_complete(task)
#     312         except asyncio.CancelledError as e:
#     313             raise globalErrorEvent.value() or e
#
# ~/anaconda3/envs/py36/lib/python3.6/asyncio/base_events.py in run_until_complete(self, future)
#     486             raise RuntimeError('Event loop stopped before Future completed.')
#     487
# --> 488         return future.result()
#     489
#     490     def stop(self):
#
# ~/anaconda3/envs/py36/lib/python3.6/asyncio/tasks.py in _step(***failed resolving arguments***)
#     178                 # We use the `send` method directly, because coroutines
#     179                 # don't have `__iter__` and `__next__` methods.
# --> 180                 result = coro.send(None)
#     181             else:
#     182                 result = coro.throw(exc)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ib_insync/ib.py in qualifyContractsAsync(self, *contracts)
#    1628             List[Contract]:
#    1629         detailsLists = await asyncio.gather(
# -> 1630             *(self.reqContractDetailsAsync(c) for c in contracts))
#    1631         result = []
#    1632         for contract, detailsList in zip(contracts, detailsLists):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ib_insync/ib.py in <genexpr>(.0)
#    1628             List[Contract]:
#    1629         detailsLists = await asyncio.gather(
# -> 1630             *(self.reqContractDetailsAsync(c) for c in contracts))
#    1631         result = []
#    1632         for contract, detailsList in zip(contracts, detailsLists):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ib_insync/ib.py in reqContractDetailsAsync(self, contract)
#    1742     def reqContractDetailsAsync(self, contract: Contract) -> \
#    1743             Awaitable[List[ContractDetails]]:
# -> 1744         reqId = self.client.getReqId()
#    1745         future = self.wrapper.startReq(reqId, contract)
#    1746         self.client.reqContractDetails(reqId, contract)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ib_insync/client.py in getReqId(self)
#     155         """Get new request ID."""
#     156         if not self.isReady():
# --> 157             raise ConnectionError('Not connected')
#     158         newId = self._reqIdSeq
#     159         self._reqIdSeq += 1
#
# ConnectionError: Not connected

# %%
#由于是demo mode 所以报错了，TWS setup 文件里最后一个链接中有具体的demo
[ticker] = ib.reqTickers(spx)
ticker
spxValue = ticker.marketPrice()
spxValue

chain = next(c for c in chains if c.tradingClass == 'SPX' and c.exchange == 'SMART')
chain
strikes = [strike for strike in chain.strikes
        if strike % 5 == 0
        and spxValue - 20 < strike < spxValue + 20]
expirations = sorted(exp for exp in chain.expirations)[:3]
rights = ['P', 'C']

contracts = [Option('SPX', expiration, strike, right, 'SMART', tradingClass='SPX')
        for right in rights
        for expiration in expirations
        for strike in strikes]

contracts = ib.qualifyContracts(*contracts)
len(contracts)
# Out:
# Error 10168, reqId 234: Requested market data is not subscribed. Delayed market data is not enabled, contract: Index(conId=416904, symbol='SPX', exchange='CBOE', currency='USD', localSymbol='SPX')
# 0
