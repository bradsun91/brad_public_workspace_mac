# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="darkgrid")

# %%
# 1. backtest.py

#!/usr/bin/python
# -*- coding: utf-8 -*-


from __future__ import print_function

import datetime
import pprint
try:
    import Queue as queue
except ImportError:
    import queue
import time

print("Executing backtest.py")
class Backtest(object):
    """
    Enscapsulates the settings and components for carrying out
    an event-driven backtest.
    """
#     print("*****backtest.py: 01: Class Backtest(object)*****")
    def __init__(
        self, csv_dir, symbol_list, initial_capital,
        heartbeat, start_date, data_handler, 
        execution_handler, portfolio, strategy
    ):
        """
        Initialises the backtest.
        Parameters:
        csv_dir - The hard root to the CSV data directory.
        symbol_list - The list of symbol strings.
        intial_capital - The starting capital for the portfolio.
        heartbeat - Backtest "heartbeat" in seconds
        start_date - The start datetime of the strategy.
        data_handler - (Class) Handles the market data feed.
        execution_handler - (Class) Handles the orders/fills for trades.
        portfolio - (Class) Keeps track of portfolio current and prior positions.
        strategy - (Class) Generates signals based on market data.
        """
#         print("*****backtest.py: 1. Backtest.initializing..*****")
        self.csv_dir = csv_dir
        self.symbol_list = symbol_list
        self.initial_capital = initial_capital
        self.heartbeat = heartbeat
        self.start_date = start_date

        self.data_handler_cls = data_handler
        self.execution_handler_cls = execution_handler
        self.portfolio_cls = portfolio
        self.strategy_cls = strategy

        # Added by Brad on 20191006
        # self.plots_cls = plots

        self.events = queue.Queue()
        
        self.signals = 0
        self.orders = 0
        self.fills = 0
        self.num_strats = 1
       
        self._generate_trading_instances()

    def _generate_trading_instances(self):
        # function1: call0 classes of 1)DataHandler, 2)strategy, 3)portfolion, 4)ExecutionHandler
        """
        Generates the trading instance objects from 
        their class types.
        """
#         print("*****backtest.py: 2. Backtest._generate_trading_instances*****")
#         print(
#             "backtest.py: _generate_trading_instances: Creating DataHandler, Strategy, Portfolio and ExecutionHandler"
#         )
        self.data_handler = self.data_handler_cls(self.events, self.csv_dir, self.symbol_list)
        self.strategy = self.strategy_cls(self.data_handler, self.events)
        self.portfolio = self.portfolio_cls(self.data_handler, self.events, self.start_date, 
                                            self.initial_capital)
        self.execution_handler = self.execution_handler_cls(self.events)
    

    def _run_backtest(self): # 
        # function1: update market bars
        # function2: identify the current event, including 1)market, 2)signal, 3)order, 4)
        """
        Executes the backtest.
        """
#         print("*****backtest.py: 3. Backtest._run_backtest*****")
#         print("Running Backtest...")
        i = 0
        while True:
            i += 1
            # print(i)

            # Update the market bars
            if self.data_handler.continue_backtest == True:
                self.data_handler.update_bars()
            else:
                break

            # Handle the events
            while True:
                try:
                    event = self.events.get(False)
                except queue.Empty:
                    break
                else:
                    if event is not None:
                        if event.type == 'MARKET':
                            self.strategy.calculate_signals(event)
                            self.portfolio.update_timeindex(event)

                        elif event.type == 'SIGNAL':
                            self.signals += 1                            
                            self.portfolio.update_signal(event)

                        elif event.type == 'ORDER':
                            self.orders += 1
                            self.execution_handler.execute_order(event)

                        elif event.type == 'FILL':
                            self.fills += 1
                            self.portfolio.update_fill(event)

            time.sleep(self.heartbeat)

	# OG version
    # def _output_performance(self):
    #     """
    #     Outputs the strategy performance from the backtest.
    #     """
    #     self.portfolio.create_equity_curve_dataframe()
        
    #     print("Creating summary stats...")
    #     stats = self.portfolio.output_summary_stats()
        
    #     print("Creating equity curve...")
    #     print(self.portfolio.equity_curve.tail(10))
    #     pprint.pprint(stats)

    #     print("Signals: %s" % self.signals)
    #     print("Orders: %s" % self.orders)
    #     print("Fills: %s" % self.fills)


    def _output_performance(self):
        """
        Outputs the strategy performance from the backtest.
        """
        self.portfolio.create_equity_curve_dataframe()
#         print("*****backtest.py: 4. Backtest._output_performance*****")
        print("Creating summary stats...")
        stats = self.portfolio.output_summary_stats()
        
        print("Creating equity curve...")
        print(self.portfolio.equity_curve.tail(10))
        pprint.pprint(stats)

        print("Signals: %s" % self.signals)
        print("Orders: %s" % self.orders)
        print("Fills: %s" % self.fills)

    def simulate_trading(self):
        # function 1: call 1)_run _backtest, 2__output_formance
        """
        Simulates the backtest and outputs portfolio performance.
        """
#         print("*****backtest.py: 5. Backtest.simulate_trading*****")
        self._run_backtest()
        self._output_performance()
# Out:
# Executing backtest.py

# %%
# 2. event.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

print("Executing event.py")
class Event(object):
    """
    Event is base class providing an interface for all subsequent 
    (inherited) events, that will trigger further events in the 
    trading infrastructure.   
    """
#     print("*****event.py: 01 Class. Event(object)*****")
    pass


class MarketEvent(Event):
    """
    Handles the event of receiving a new market update with 
    corresponding bars.
    """
#     print("*****event.py: 02 Class. MarketEvent(Event)*****")
    def __init__(self):
        """
        Initialises the MarketEvent.
        """
#         print("*****event.py: 1. initializing..*****")
        self.type = 'MARKET'


class SignalEvent(Event):
    """
    Handles the event of sending a Signal from a Strategy object.
    This is received by a Portfolio object and acted upon.
    """
    print("*****event.py: 03 Class: SignalEvent(Event)*****")
    def __init__(self, strategy_id, symbol, datetime, signal_type, strength):
        """
        Initialises the SignalEvent.
        Parameters:
        strategy_id - The unique ID of the strategy sending the signal.
        symbol - The ticker symbol, e.g. 'GOOG'.
        datetime - The timestamp at which the signal was generated.
        signal_type - 'LONG' or 'SHORT'.
        strength - An adjustment factor "suggestion" used to scale 
            quantity at the portfolio level. Useful for pairs strategies.
        """
#         print("*****event.py: 1. SignalEvent.initializing..*****")
        self.strategy_id = strategy_id
        self.type = 'SIGNAL'
        self.symbol = symbol
        self.datetime = datetime
        self.signal_type = signal_type
        self.strength = strength


class OrderEvent(Event):
    """
    Handles the event of sending an Order to an execution system.
    The order contains a symbol (e.g. GOOG), a type (market or limit),
    quantity and a direction.
    """
    print("*****event.py: 04 Class: OrderEvent(Event)*****")
    def __init__(self, symbol, order_type, quantity, direction):
        """
        Initialises the order type, setting whether it is
        a Market order ('MKT') or Limit order ('LMT'), has
        a quantity (integral) and its direction ('BUY' or
        'SELL').
        TODO: Must handle error checking here to obtain 
        rational orders (i.e. no negative quantities etc).
        Parameters:
        symbol - The instrument to trade.
        order_type - 'MKT' or 'LMT' for Market or Limit.
        quantity - Non-negative integer for quantity.
        direction - 'BUY' or 'SELL' for long or short.
        """
#         print("*****event.py: 1. OrderEvent.initializing..*****")
        self.type = 'ORDER'
        self.symbol = symbol
        self.order_type = order_type
        self.quantity = quantity
        self.direction = direction

    def print_order(self):
        """
        Outputs the values within the Order.
        """
#         print("*****event.py: 2. OrderEvent.print_order*****")
        print(
            "Order: Symbol=%s, Type=%s, Quantity=%s, Direction=%s" % 
            (self.symbol, self.order_type, self.quantity, self.direction)
        )


class FillEvent(Event):
    """
    Encapsulates the notion of a Filled Order, as returned
    from a brokerage. Stores the quantity of an instrument
    actually filled and at what price. In addition, stores
    the commission of the trade from the brokerage.
    
    TODO: Currently does not support filling positions at
    different prices. This will be simulated by averaging
    the cost.
    """
#     print("*****event.py: 05 Class: FillEvent(Event)*****")
    def __init__(self, timeindex, symbol, exchange, quantity, 
                 direction, fill_cost, commission=None):
        """
        Initialises the FillEvent object. Sets the symbol, exchange,
        quantity, direction, cost of fill and an optional 
        commission.
        If commission is not provided, the Fill object will
        calculate it based on the trade size and Interactive
        Brokers fees.
        Parameters:
        timeindex - The bar-resolution when the order was filled.
        symbol - The instrument which was filled.
        exchange - The exchange where the order was filled.
        quantity - The filled quantity.
        direction - The direction of fill ('BUY' or 'SELL')
        fill_cost - The holdings value in dollars.
        commission - An optional commission sent from IB.
        """
#         print("*****event.py: 1. FillEvent.initializing..*****")
        self.type = 'FILL'
        self.timeindex = timeindex
        self.symbol = symbol
        self.exchange = exchange
        self.quantity = quantity
        self.direction = direction
        self.fill_cost = fill_cost

        # Calculate commission
        if commission is None:
            self.commission = self.calculate_ib_commission()
        else:
            self.commission = commission

    def calculate_ib_commission(self):
        """
        Calculates the fees of trading based on an Interactive
        Brokers fee structure for API, in USD.
        This does not include exchange or ECN fees.
        Based on "US API Directed Orders":
        https://www.interactivebrokers.com/en/index.php?f=commission&p=stocks2
        """
#         print("*****event.py: 2. FillEvent.calculate_ib_commission*****")
#         full_cost = 1.3
#         if self.quantity <= 500:
#             full_cost = max(1.3, 0.013 * self.quantity)
#         else: # Greater than 500
#             full_cost = max(1.3, 0.008 * self.quantity)
        full_cost = commissions
        return full_cost
# Out:
# Executing event.py
# *****event.py: 03 Class: SignalEvent(Event)*****
# *****event.py: 04 Class: OrderEvent(Event)*****

# %%
# 3. data.py
#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

from abc import ABCMeta, abstractmethod
import datetime
import os, os.path

import numpy as np
import pandas as pd

# from event import MarketEvent

print("Executing data.py")
class DataHandler(object):
    """
    DataHandler is an abstract base class providing an interface for
    all subsequent (inherited) data handlers (both live and historic).
    The goal of a (derived) DataHandler object is to output a generated
    set of bars (OHLCVI) for each symbol requested. 
    This will replicate how a live strategy would function as current
    market data would be sent "down the pipe". Thus a historic and live
    system will be treated identically by the rest of the backtesting suite.
    """
#     print("*****data.py: 01 Class: Datahandler(object) ran, an abstract base class*****")
    __metaclass__ = ABCMeta

    @abstractmethod
    def get_latest_bar(self, symbol):
#         print("*****data.py: 1. DataHandler.get_latest_bar*****")
        """
        Returns the last bar updated.
        """
        raise NotImplementedError("Should implement get_latest_bar()")

    @abstractmethod
    def get_latest_bars(self, symbol, N=1):
#         print("*****data.py: 2. DataHandler.get_latest_bars*****")
        """
        Returns the last N bars updated.
        """
        raise NotImplementedError("Should implement get_latest_bars()")

    @abstractmethod
    def get_latest_bar_datetime(self, symbol):
#         print("*****data.py: 3. DataHandler.get_latest_bar_datetime*****")
        """
        Returns a Python datetime object for the last bar.
        """
        raise NotImplementedError("Should implement get_latest_bar_datetime()")

    @abstractmethod
    def get_latest_bar_value(self, symbol, val_type):
#         print("*****data.py: 4. DataHandler.get_latest_bar_value*****")
        """
        Returns one of the Open, High, Low, Close, Volume or OI
        from the last bar.
        """
        raise NotImplementedError("Should implement get_latest_bar_value()")

    @abstractmethod
    def get_latest_bars_values(self, symbol, val_type, N=1):
#         print("*****data.py: 5. DataHandler.get_latest_bars_values*****")
        """
        Returns the last N bar values from the 
        latest_symbol list, or N-k if less available.
        """
        raise NotImplementedError("Should implement get_latest_bars_values()")

    @abstractmethod
    def update_bars(self):
#         print("*****data.py: 6. DataHandler.update_bars*****")
        """
        Pushes the latest bars to the bars_queue for each symbol
        in a tuple OHLCVI format: (datetime, open, high, low, 
        close, volume, open interest).
        """
        raise NotImplementedError("Should implement update_bars()")


class HistoricCSVDataHandler(DataHandler):
    """
    HistoricCSVDataHandler is designed to read CSV files for
    each requested symbol from disk and provide an interface
    to obtain the "latest" bar in a manner identical to a live
    trading interface. 
    """
    print("*****data.py: 02 Class: HistoricCSVDataHandler(DataHandler)*****")
    def __init__(self, events, csv_dir, symbol_list):
        
#         print("*****data.py: 1. HistoricCSVDataHandler.initializing..")
        """
        Initialises the historic data handler by requesting
        the location of the CSV files and a list of symbols.
        It will be assumed that all files are of the form
        'symbol.csv', where symbol is a string in the list.
        Parameters:
        events - The Event Queue.
        csv_dir - Absolute directory path to the CSV files.
        symbol_list - A list of symbol strings.
        """
        self.events = events
        self.csv_dir = csv_dir
        self.symbol_list = symbol_list

        self.symbol_data = {}
        self.latest_symbol_data = {}
        self.continue_backtest = True       
        self.bar_index = 0

        self._open_convert_csv_files()

    def _open_convert_csv_files(self):
        """
        Opens the CSV files from the data directory, converting
        them into pandas DataFrames within a symbol dictionary.
        For this handler it will be assumed that the data is
        taken from Yahoo. Thus its format will be respected.
        """
#         print("*****data.py: 2. HistoricCSVDataHandler._open_convert_csv_files")
        comb_index = None
        
        for s in self.symbol_list:
            # Load the CSV file with no header information, indexed on date
            self.symbol_data[s] = pd.io.parsers.read_csv(
                os.path.join(self.csv_dir, '%s.csv' % s),
                header=0, index_col=0, parse_dates=True,
                names=data_cols
            )
            self.symbol_data[s].reset_index(inplace = True)
            self.symbol_data[s].set_index("trade_date", inplace=True)
            # ).sort_values('date')
            # print("symbol_data",self.symbol_data[s])#######################
            # Combine the index to pad forward values
            if comb_index is None:
                comb_index = self.symbol_data[s].index
            else:
                comb_index.union(self.symbol_data[s].index)

            # Set the latest symbol_data to None
            self.latest_symbol_data[s] = []

        # Reindex the dataframes
        for s in self.symbol_list:
            self.symbol_data[s] = self.symbol_data[s].\
                reindex(index=comb_index, method='pad').iterrows()
                


    def _get_new_bar(self, symbol):
        """
        Returns the latest bar from the data feed.
        """
#         print("*****data.py: 3. HistoricCSVDataHandler._get_new_bar")
        for b in self.symbol_data[symbol]:
            yield b

    def get_latest_bar(self, symbol):
        """
        Returns the last bar from the latest_symbol list.
        """
#         print("*****data.py: 4. HistoricCSVDataHandler.get_latest_bar")
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return bars_list[-1]

    def get_latest_bars(self, symbol, N=1):
        """
        Returns the last N bars from the latest_symbol list,
        or N-k if less available.
        """
#         print("*****data.py: 5. HistoricCSVDataHandler.get_latest_bars")
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return bars_list[-N:]

    def get_latest_bar_datetime(self, symbol):
        """
        Returns a Python datetime object for the last bar.
        """
#         print("*****data.py: 6. HistoricCSVDataHandler.get_latest_bar_datetime")
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return bars_list[-1][0]

    def get_latest_bar_value(self, symbol, val_type):
        """
        Returns one of the Open, High, Low, Close, Volume or OI
        values from the pandas Bar series object.
        """
#         print("*****data.py: 7. HistoricCSVDataHandler.get_latest_bar_value")
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return getattr(bars_list[-1][1], val_type)

    def get_latest_bars_values(self, symbol, val_type, N=1):
        """
        Returns the last N bar values from the 
        latest_symbol list, or N-k if less available.
        """
#         print("*****data.py: 8. HistoricCSVDataHandler.get_latest_bars_values")
        try:
            bars_list = self.get_latest_bars(symbol, N)
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return np.array([getattr(b[1], val_type) for b in bars_list])

    def update_bars(self):
        """
        Pushes the latest bar to the latest_symbol_data structure
        for all symbols in the symbol list.
        """
#         print("*****data.py: 9. HistoricCSVDataHandler.update_bars")
        for s in self.symbol_list:
            try:
                bar = next(self._get_new_bar(s))
            except StopIteration:
                self.continue_backtest = False
            else:
                if bar is not None:
                    self.latest_symbol_data[s].append(bar)
        self.events.put(MarketEvent())
# Out:
# Executing data.py
# *****data.py: 02 Class: HistoricCSVDataHandler(DataHandler)*****

# %%
# 4. execution.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

from abc import ABCMeta, abstractmethod
import datetime
try:
    import Queue as queue
except ImportError:
    import queue

# from event import FillEvent, OrderEvent

print("Executing execution.py")
class ExecutionHandler(object):
    """
    The ExecutionHandler abstract class handles the interaction
    between a set of order objects generated by a Portfolio and
    the ultimate set of Fill objects that actually occur in the
    market. 
    The handlers can be used to subclass simulated brokerages
    or live brokerages, with identical interfaces. This allows
    strategies to be backtested in a very similar manner to the
    live trading engine.
    """
#     print ("*****execution.py: 01. Class: ExecutionHandler(object): abstract class*****")
    __metaclass__ = ABCMeta

    @abstractmethod
    def execute_order(self, event):
#         print("*****execution.py: 1. ExecutionHandler.execute_order*****")
        """
        Takes an Order event and executes it, producing
        a Fill event that gets placed onto the Events queue.
        Parameters:
        event - Contains an Event object with order information.
        """
        raise NotImplementedError("Should implement execute_order()")


class SimulatedExecutionHandler(ExecutionHandler):
    
    """
    The simulated execution handler simply converts all order
    objects into their equivalent fill objects automatically
    without latency, slippage or fill-ratio issues.
    This allows a straightforward "first go" test of any strategy,
    before implementation with a more sophisticated execution
    handler.
    """
#     print ("*****execution.py: 02. Class: SimulatedExecutionHandler(ExecutionHandler)*****")
    def __init__(self, events):
        """
        Initialises the handler, setting the event queues
        up internally.
        Parameters:
        events - The Queue of Event objects.
        """
#         print("*****execution.py: 1. SimulatedExecutionHandler.initializing..*****")
        self.events = events

    def execute_order(self, event):
        """
        Simply converts Order objects into Fill objects naively,
        i.e. without any latency, slippage or fill ratio problems.
        Parameters:
        event - Contains an Event object with order information.
        """
#         print("*****execution.py: 2. SimulatedExecutionHandler.execute_order*****")
        if event.type == 'ORDER':
            fill_event = FillEvent(
                datetime.datetime.utcnow(), event.symbol,
                'ARCA', event.quantity, event.direction, None
            )
            self.events.put(fill_event)
# Out:
# Executing execution.py

# %%
# 5. strategy.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

from abc import ABCMeta, abstractmethod
import datetime
try:
    import Queue as queue
except ImportError:
    import queue

import numpy as np
import pandas as pd

# from event import SignalEvent

print("Executing strategy.py")
class Strategy(object):
#     print("*****strategy.py: 01. Class: Strategy(object): abstract class*****")
    """
    Strategy is an abstract base class providing an interface for
    all subsequent (inherited) strategy handling objects.
    The goal of a (derived) Strategy object is to generate Signal
    objects for particular symbols based on the inputs of Bars 
    (OHLCV) generated by a DataHandler object.
    This is designed to work both with historic and live data as
    the Strategy object is agnostic to where the data came from,
    since it obtains the bar tuples from a queue object.
    """

    __metaclass__ = ABCMeta

    @abstractmethod
    def calculate_signals(self):
#         print("*****strategy.py: 1. Strategy(object).calculate_signals*****")
        """
        Provides the mechanisms to calculate the list of signals.
        """
        raise NotImplementedError("Should implement calculate_signals()")
# Out:
# Executing strategy.py

# %%
# 6. portfolio.py

#!/usr/bin/python
# -*- coding: utf-8 -*-


from __future__ import print_function

import datetime
from math import floor
try:
    import Queue as queue
except ImportError:
    import queue

import numpy as np
import pandas as pd

# from event import FillEvent, OrderEvent
# from performance import create_sharpe_ratio, create_drawdowns


print("Executing portfolio.py")
class Portfolio(object):
    
#     print("*****portfolio.py: 01. Portfolio(object)*****")
    """
    The Portfolio class handles the positions and market
    value of all instruments at a resolution of a "bar",
    i.e. secondly, minutely, 5-min, 30-min, 60 min or EOD.
    The positions DataFrame stores a time-index of the 
    quantity of positions held. 
    The holdings DataFrame stores the cash and total market
    holdings value of each symbol for a particular 
    time-index, as well as the percentage change in 
    portfolio total across bars.
    """

    def __init__(self, bars, events, start_date, initial_capital=100000.0):
#         print("*****portfolio.py: 1. Portfolio.initializing...*****")
        """
        Initialises the portfolio with bars and an event queue. 
        Also includes a starting datetime index and initial capital 
        (USD unless otherwise stated).
        Parameters:
        bars - The DataHandler object with current market data.
        events - The Event Queue object.
        start_date - The start date (bar) of the portfolio.
        initial_capital - The starting capital in USD.
        """
        self.bars = bars
        self.events = events
        self.symbol_list = self.bars.symbol_list
        self.start_date = start_date
        self.initial_capital = initial_capital
        
        self.all_positions = self.construct_all_positions()
        self.current_positions = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        self.all_holdings = self.construct_all_holdings()
        self.current_holdings = self.construct_current_holdings()
        
        # Brad's add on 20191117
#         fill.direction = "None"
#         self.fill_cost = self.update_holdings_from_fill(self, fill)
        
        # =============brad's added on 20191117:===============
        self.len_symbol_list = len(symbol_list)
        
        
        print("Number of assets in the portfolio： ",self.len_symbol_list)
        print("Position Value for each asset: ", self.initial_capital/self.len_symbol_list)

        
    def construct_all_positions(self):
#         print("*****portfolio.py: 2. Portfolio.construct_all_positions*****")
        """
        Constructs the positions list using the start_date
        to determine when the time index will begin.
        """
        d = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        d['datetime'] = self.start_date
        return [d]

    def construct_all_holdings(self):
#         print("*****portfolio.py: 3. Portfolio.construct_all_holdings*****")
        """
        Constructs the holdings list using the start_date
        to determine when the time index will begin.
        """
        d = dict( (k,v) for k, v in [(s, 0.0) for s in self.symbol_list] )
        d['datetime'] = self.start_date
        d['cash'] = self.initial_capital
        d['commission'] = 0
        d['total'] = self.initial_capital
        return [d]

    def construct_current_holdings(self):
#         print("*****portfolio.py: 4. Portfolio.construct_current_holdings*****")
        """
        This constructs the dictionary which will hold the instantaneous
        value of the portfolio across all symbols.
        """
        d = dict( (k,v) for k, v in [(s, 0.0) for s in self.symbol_list] )
        d['cash'] = self.initial_capital
        d['commission'] = 0
        d['total'] = self.initial_capital
        return d

    def update_timeindex(self, event):
#         print("*****portfolio.py: 5. Portfolio.update_timeindex*****")
        """
        Adds a new record to the positions matrix for the current 
        market data bar. This reflects the PREVIOUS bar, i.e. all
        current market data at this stage is known (OHLCV).
        Makes use of a MarketEvent from the events queue.
        """
        ##print("symbol_list",self.symbol_list)
        latest_datetime = self.bars.get_latest_bar_datetime(self.symbol_list[0])
        #######################
        
        
        print("latest_datetime:", latest_datetime)
        # Update positions
        # ================
        dp = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        dp['datetime'] = latest_datetime

        for s in self.symbol_list:
            dp[s] = self.current_positions[s]

        # Append the current positions
        self.all_positions.append(dp)

        # Update holdings
        # ===============
        dh = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        dh['datetime'] = latest_datetime
        dh['cash'] = self.current_holdings['cash']
        dh['commission'] = self.current_holdings['commission']
        dh['total'] = self.current_holdings['cash']

        for s in self.symbol_list:
            # Approximation to the real value
            market_value = self.current_positions[s] * \
                self.bars.get_latest_bar_value(s, price_col)
            dh[s] = market_value
            dh['total'] += market_value

        # Append the current holdings
        self.all_holdings.append(dh)

    # ======================
    # FILL/POSITION HANDLING
    # ======================

    def update_positions_from_fill(self, fill):
#         print("*****portfolio.py: 6. Portfolio.update_positions_from_fill*****")
        """
        Takes a Fill object and updates the position matrix to
        reflect the new position.
        Parameters:
        fill - The Fill object to update the positions with.
        """
        # Check whether the fill is a buy or sell
        fill_dir = 0
        if fill.direction == 'BUY':
            fill_dir = 1
        if fill.direction == 'SELL':
            fill_dir = -1

        # Update positions list with new quantities
        self.current_positions[fill.symbol] += fill_dir*fill.quantity

    def update_holdings_from_fill(self, fill):
#         print("*****portfolio.py: 7. Portfolio.update_holdings_from_fill*****")
        """
        Takes a Fill object and updates the holdings matrix to
        reflect the holdings value.
        Parameters:
        fill - The Fill object to update the holdings with.
        """
        # Check whether the fill is a buy or sell
        fill_dir = 0
        if fill.direction == 'BUY':
            fill_dir = 1
        if fill.direction == 'SELL':
            fill_dir = -1

        # Update holdings list with new quantities
        fill_cost = self.bars.get_latest_bar_value(
            fill.symbol, price_col
        )
        cost = fill_dir * fill_cost * fill.quantity
        self.current_holdings[fill.symbol] += cost
        self.current_holdings['commission'] += fill.commission
        self.current_holdings['cash'] -= (cost + fill.commission)
        self.current_holdings['total'] -= (cost + fill.commission)
        # Brad's add on 20191117
        return fill_cost

    def update_fill(self, event):
#         print("*****portfolio.py: 8. Portfolio.update_fill*****")
        """
        Updates the portfolio current positions and holdings 
        from a FillEvent.
        """
        if event.type == 'FILL':
            self.update_positions_from_fill(event)
            self.update_holdings_from_fill(event)

    def generate_naive_order(self, signal):
#         print("*****portfolio.py: 9. Portfolio.generate_naive_order*****")
        """
        Simply files an Order object as a constant quantity
        sizing of the signal object, without risk management or
        position sizing considerations.
        Parameters:
        signal - The tuple containing Signal information.
        """
        order = None

        symbol = signal.symbol
        direction = signal.signal_type
        strength = signal.strength
        # ================ Brad's change on 20191117 =================
        mkt_quantity = qty
        symbol_value = self.bars.get_latest_bar_value(symbol, price_col)
#         mkt_quantity = int(self.initial_capital/self.len_symbol_list/symbol_value)
        print("Asset: ", symbol, "symbol_value: ",symbol_value,  "mkt_quantity: ", mkt_quantity)
        cur_quantity = self.current_positions[symbol]
        order_type = 'MKT'

        if direction == 'LONG' and cur_quantity == 0:
            order = OrderEvent(symbol, order_type, mkt_quantity, 'BUY')
        if direction == 'SHORT' and cur_quantity == 0:
            order = OrderEvent(symbol, order_type, mkt_quantity, 'SELL')   
    
        if direction == 'EXIT' and cur_quantity > 0:
            order = OrderEvent(symbol, order_type, abs(cur_quantity), 'SELL')
        if direction == 'EXIT' and cur_quantity < 0:
            order = OrderEvent(symbol, order_type, abs(cur_quantity), 'BUY')
        return order

    def update_signal(self, event):
#         print("*****portfolio.py: 10. Portfolio.update_signal*****")
        """
        Acts on a SignalEvent to generate new orders 
        based on the portfolio logic.
        """
        if event.type == 'SIGNAL':
            order_event = self.generate_naive_order(event)
            self.events.put(order_event)

    # ========================
    # POST-BACKTEST STATISTICS
    # ========================

    def create_equity_curve_dataframe(self):
#         print("*****portfolio.py: 11. Portfolio.create_equity_curve_dataframe*****")
        """
        Creates a pandas DataFrame from the all_holdings
        list of dictionaries.
        """
        curve = pd.DataFrame(self.all_holdings)
        curve.set_index('datetime', inplace=True)
        curve['returns'] = curve['total'].pct_change()
        curve['equity_curve'] = (1.0+curve['returns']).cumprod()
        self.equity_curve = curve

    def output_summary_stats(self):
#         print("*****portfolio.py: 12. Portfolio.output_summary_stats*****")
        """
        Creates a list of summary statistics for the portfolio.
        """
        total_return = self.equity_curve['equity_curve'][-1]
        returns = self.equity_curve['returns']
        pnl = self.equity_curve['equity_curve']

        sharpe_ratio = create_sharpe_ratio(returns, periods=252*60*6.5)
        drawdown, max_dd, dd_duration = create_drawdowns(pnl)
        self.equity_curve['drawdown'] = drawdown

        stats = [("Total Return", "%0.2f%%" % ((total_return - 1.0) * 100.0)),
                 ("Sharpe Ratio", "%0.2f" % sharpe_ratio),
                 ("Max Drawdown", "%0.2f%%" % (max_dd * 100.0)),
                 ("Drawdown Duration", "%d" % dd_duration)]

        self.equity_curve.to_csv(ticker+"_performance"+".csv")
#         return self.equity_curve
#         print(stats)


class Visualization(Portfolio):
    def output_summary_stats(self):
#         print("*****portfolio.py: 12. Portfolio.output_summary_stats*****")
        """
        Creates a list of summary statistics for the portfolio.
        """
        total_return = self.equity_curve['equity_curve'][-1]
        returns = self.equity_curve['returns']
        pnl = self.equity_curve['equity_curve']

        sharpe_ratio = create_sharpe_ratio(returns, periods=252*60*6.5)
        drawdown, max_dd, dd_duration = create_drawdowns(pnl)
        self.equity_curve['drawdown'] = drawdown
        self.equity_curve['drawdown'].plot()

#         stats = [("Total Return", "%0.2f%%" % ((total_return - 1.0) * 100.0)),
#                  ("Sharpe Ratio", "%0.2f" % sharpe_ratio),
#                  ("Max Drawdown", "%0.2f%%" % (max_dd * 100.0)),
#                  ("Drawdown Duration", "%d" % dd_duration)]

#     def __init__(self, bars, events, start_date, initial_capital=100000.0):
#         self.stats_to_plot = super().output_summary_stats()

#     def plot_cash(self):
#         self.stats_to_plot['cash'].plot()

#     # Added by Brad on 20191007:
#     def draw_summary_plots(self):
#         print("*****portfolio.py: 13. Portfolio.draw_summary_plots*****")
#         self.equity_curve['equity_curve'].plot(figsize = (18,6))
# Out:
# Executing portfolio.py

# %%
class A:
    def fun(self):
        print('A.fun')
        
    def not_fun(self):
        print("A.not_fun")
        
    def series(self):
        return [1, 2, 3, 4, 5]

class B(A):
    def series(self):
        srs =super().series()
#         print('B.fun')
        print(srs)
    
b = B()
b.series()
# Out:
# [1, 2, 3, 4, 5]

# %%
# 7. performance.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

import numpy as np
import pandas as pd

print("Executing performance.py")
def create_sharpe_ratio(returns, periods=252):
    print("*****performance.py: 1. create_sharpe_ratio*****")
    """
    Create the Sharpe ratio for the strategy, based on a 
    benchmark of zero (i.e. no risk-free rate information).
    Parameters:
    returns - A pandas Series representing period percentage returns.
    periods - Daily (252), Hourly (252*6.5), Minutely(252*6.5*60) etc.
    """
    return np.sqrt(periods) * (np.mean(returns)) / np.std(returns)


def create_drawdowns(pnl):
    print("*****performance.py: 2. create_drawdowns*****")
    """
    Calculate the largest peak-to-trough drawdown of the PnL curve
    as well as the duration of the drawdown. Requires that the 
    pnl_returns is a pandas Series.
    Parameters:
    pnl - A pandas Series representing period percentage returns.
    Returns:
    drawdown, duration - Highest peak-to-trough drawdown and duration.
    """

    # Calculate the cumulative returns curve 
    # and set up the High Water Mark
    hwm = [0]

    # Create the drawdown and duration series
    idx = pnl.index
    drawdown = pd.Series(index = idx)
    duration = pd.Series(index = idx)

    # Loop over the index range
    for t in range(1, len(idx)):
        hwm.append(max(hwm[t-1], pnl[t]))
        drawdown[t]= (hwm[t]-pnl[t])
        duration[t]= (0 if drawdown[t] == 0 else duration[t-1]+1)
    return drawdown, drawdown.max(), duration.max()
# Out:
# Executing performance.py

# %%
# mac.py
print("Executing mac.py")
class MovingAverageCrossStrategy(Strategy):
    print("*****mac.py: 01. Class: MovingAverageCrossStrategy(Strategy)*****")
    """
    Carries out a basic Moving Average Crossover strategy with a
    short/long simple weighted moving average. Default short/long
    windows are 12/26 periods respectively.
    """

    def __init__(self, bars, events, short_window=12, long_window=26):
        print("*****mac.py: 1. MovingAverageCrossStrategy.initializing..*****")
        """
        Initialises the buy and hold strategy.

        Parameters:
        bars - The DataHandler object that provides bar information
        events - The Event Queue object.
        short_window - The short moving average lookback.
        long_window - The long moving average lookback.
        """
        self.bars = bars
        self.symbol_list = self.bars.symbol_list
        self.events = events
        self.short_window = short_window
        self.long_window = long_window

        # Set to True if a symbol is in the market
        self.bought = self._calculate_initial_bought()

    def _calculate_initial_bought(self):
        print("*****mac.py: 2. MovingAverageCrossStrategy._calculate_initial_bought*****")
        """
        Adds keys to the bought dictionary for all symbols
        and sets them to 'OUT'.
        """
        bought = {}
        for s in self.symbol_list:
            bought[s] = 'OUT'
        return bought

    def calculate_signals(self, event):
        print("*****mac.py: 3. MovingAverageCrossStrategy.calculate_signals*****")
        """
        Generates a new set of signals based on the MAC
        SMA with the short window crossing the long window
        meaning a long entry and vice versa for a short entry.    

        Parameters
        event - A MarketEvent object. 
        """
        if event.type == 'MARKET':
            for symbol in self.symbol_list:
                bars = self.bars.get_latest_bars_values(symbol, price_col, N=self.long_window)

                if bars is not None and bars != []:
                    short_sma = np.mean(bars[-self.short_window:])
                    long_sma = np.mean(bars[-self.long_window:])

                    dt = self.bars.get_latest_bar_datetime(symbol)
                    sig_dir = ""
                    strength = 1.0
                    strategy_id = 1

                    if short_sma > long_sma and self.bought[symbol] == "OUT":
                        sig_dir = 'LONG'
                        signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
                        self.events.put(signal)
                        self.bought[symbol] = 'LONG'

                    elif short_sma < long_sma and self.bought[symbol] == "LONG":
                        sig_dir = 'EXIT'
                        signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
                        self.events.put(signal)
                        self.bought[symbol] = 'OUT'
# Out:
# Executing mac.py
# *****mac.py: 01. Class: MovingAverageCrossStrategy(Strategy)*****

# %%
class MovingAverageConvergenceDivergence(Strategy):
    
    def __init__(self, bars, events, short_window=12, long_window=26):
        self.bars = bars
        self.symbol_list = self.bars.symbol_list
        self.events = events
        self.short_window = short_window
        self.long_window = long_window

        # Set to True if a symbol is in the market
        self.bought = self._calculate_initial_bought()

    def _calculate_initial_bought(self):
        """
        Adds keys to the bought dictionary for all symbols
        and sets them to 'OUT'.
        """
        bought = {}
        for s in self.symbol_list:
            bought[s] = 'OUT'
        return bought

    def calculate_signals(self, event):
        """
        Generates a new set of signals based on the MAC
        SMA with the short window crossing the long window
        meaning a long entry and vice versa for a short entry.
        Parameters
        event - A MarketEvent object.
        """
        if event.type == 'MARKET':
            for symbol in self.symbol_list:
                bars = self.bars.get_latest_bars_values(symbol, price_col, N=self.long_window)
                if bars is not None and bars != []:
                    exp1 = pd.Series(bars).ewm(span=12, adjust=False).mean()
                    exp2 = pd.Series(bars).ewm(span=26, adjust=False).mean()
                    macd = exp1 - exp2
                    exp3 = macd.ewm(span=9, adjust=False).mean()
                    dt = self.bars.get_latest_bar_datetime(symbol)
                    sig_dir = ""
                    strength = 1.0
                    strategy_id = 1

                    if macd.iloc[-1] > exp3.iloc[-1] and self.bought[symbol] == "OUT":
                        sig_dir = 'LONG'
                        signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
                        self.events.put(signal)
                        self.bought[symbol] = 'LONG'

                    elif macd.iloc[-1] < exp3.iloc[-1] and self.bought[symbol] == "LONG":
                        sig_dir = 'EXIT'
                        signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
                        self.events.put(signal)
                        self.bought[symbol] = 'OUT'

# %%
class Visualization(object):
    def __init__(self, bt_csv_dir, start_date_str):
        self.equity_curve = pd.read_csv(bt_csv_dir+"equity.csv")
        self.equity_curve.drop_duplicates("datetime", inplace = True)
        self.equity_curve =self.equity_curve[self.equity_curve['datetime']>start_date_str]
        self.equity_curve.index = self.equity_curve['datetime']
        self.equity_curve = self.equity_curve[self.equity_curve['total'].map(lambda x: str(x)!="nan")]
        self.equity_curve.drop(['datetime'], axis = 1, inplace=True)
        self.plot_size = [18, 6]
        
    def plot_commissions(self):
        self.equity_curve['commission'].plot(figsize = self.plot_size)
        
    def plot_cash(self):
        self.equity_curve['cash'].plot(figsize = self.plot_size)
        
    def plot_total(self):
        self.equity_curve['total'].plot(figsize = self.plot_size)
        
    def plot_returns(self):
        self.equity_curve['returns'].plot(figsize = self.plot_size)
        
    def plot_equity_curve(self):
        self.equity_curve['equity_curve'].plot(figsize = self.plot_size)
        
    def plot_drawdown(self):
        self.equity_curve['drawdown'].plot(figsize = self.plot_size)
        
    def return_equity_df(self):
        return self.equity_curve

# %%
# Hansen's version
def performance(data):
    data['daily_PL'] = data['total']-data['total'].shift(1)

    trade = False
    profits = []
    total_profit_per_trade = 0

    for i in range(len(data)): 
        if data.iloc[i]['market_value'] == 0.0 and data.iloc[i]['returns'] == 0.0 and trade:
            trade = False
        
            profits.append(total_profit_per_trade)
            total_profit_per_trade = 0

        if trade:
            total_profit_per_trade += data.iloc[i]['daily_PL']

        if data.iloc[i]['market_value'] != 0.0 and not trade:
            trade = True
            total_profit_per_trade += data.iloc[i]['daily_PL']

    win_trade = list(filter(lambda x: x >0, profits))
    loss_trade = list(filter(lambda x: x <0, profits))
    num_win_trade = len(win_trade)
    num_total_trade = len(profits)
    win_rate = num_win_trade/num_total_trade*100
    mean_win_loss_ratio = np.mean(win_trade)/(-np.mean(loss_trade))
    bt_score = (win_rate/100*mean_win_loss_ratio-(1-win_rate/100))
    print('win %:', num_win_trade/num_total_trade*100)
    print('PL Ratio:', np.mean(win_trade)/(-np.mean(loss_trade)))
    print('bt_score:', bt_score)
    return win_rate, mean_win_loss_ratio, bt_score, profits

# %%
# Brad' revised version:

def performance(data):
    commissions = 5 # in USD or RMB
    # Create daily PnL
    data['daily_PL'] = data['total']-data['total'].shift(1)
    trade = False
    profits = []
    total_profit_per_trade = 0
#     trade_count = 0
#     trade_stats = {}
    for i in range(len(data)): 
        
        
        # 1.1 open the position:
        if i > 1 and data.iloc[i-1]['market_value'] == 0 and data.iloc[i]['market_value'] != 0:
            print("-------------------")
            print("Opened the position: ", data.iloc[i]['datetime'])
            total_profit_per_trade += data.iloc[i]['daily_PL']-commissions
            
        # 1.2 open the position (if there's no data before):
        if i == 0 and data.iloc[i]['market_value'] != 0:
            print("No data before, opened the position: ", data.iloc[i]['datetime'])
            total_profit_per_trade += data.iloc[i]['daily_PL']-commissions
            
        # 2. holding the position:
        if i > 1 and data.iloc[i-1]['market_value'] != 0 and data.iloc[i]['market_value'] != 0:
            print("Holding the position: ", data.iloc[i]['datetime'])
            total_profit_per_trade += data.iloc[i]['daily_PL']
            
            
        # 3. close the position:
        if i > 1 and data.iloc[i-1]['market_value'] !=0 and data.iloc[i]['market_value'] == 0:
            print("Closed the posotion: ", data.iloc[i]['datetime'])
            profits.append(total_profit_per_trade)
            # The most recent trade is over, reset total_profit_per_trade
            print("This trade's pnl:", total_profit_per_trade)
            total_profit_per_trade = 0
            print("-------------------")
        
            
        # 4. if the position is empty 
        if data.iloc[i]['market_value'] == 0:
            print("Position is empty: ", data.iloc[i]['datetime'])
            

    win_trade = list(filter(lambda x: x >0, profits))
    loss_trade = list(filter(lambda x: x <0, profits))
    num_win_trade = len(win_trade)
    num_total_trade = len(profits)
    win_rate = num_win_trade/num_total_trade*100
    mean_win_loss_ratio = np.mean(win_trade)/(-np.mean(loss_trade))
    bt_score = (win_rate/100*mean_win_loss_ratio-(1-win_rate/100))
    print('win %:', num_win_trade/num_total_trade*100)
    print('PL Ratio:', np.mean(win_trade)/(-np.mean(loss_trade)))
    print('bt_score:', bt_score)
    return win_rate, mean_win_loss_ratio, bt_score, profits

# %%
symbol_list = [
        "000069.SZ",#华侨城A
#         "002524.SZ",#光正集团
#         "600712.SH",#南宁百货
    
]
ticker_performances = {}

if __name__ == "__main__":
    for ticker in symbol_list:
    # csv_dir = REPLACE_WITH_YOUR_CSV_DIR_HERE
        equity_folder = "./"
        csv_dir = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/CH_database/"
    #     symbol_list = [

    # # ==============ETF================
    # #         "518880", # 黄金ETF
    # #         "513050",# 中概互联网
    # #         "513100",# 纳指ETF
    # #         "159920",# 恒生ETF
    # #         "510900",# 【H股ETF：弃，MACD不赚钱】
    # #         "512010",#医药ETF，
    # # ==============股票================
    # #         "002559.SZ",
    # #         "002638.SZ",
    # #         "601899.SH",#紫金矿业
    # #         "600208.SH",#新湖中宝、所属板块：参股券商
    # #         "000069.SZ",#华侨城A
    # #         "002524.SZ",#光正集团
    # #         "600712.SH",#南宁百货
    # #         "002610.SZ",#爱康科技
    # #         "601777.SH",#【力帆股份：基本面弱，暂弃】
    #         "002094.SZ",#青岛金王
    # #         "600467.SH"#【好当家：股价涨太高，暂时弃】

    #     ]
    #     data_cols = ['trade_date', 'open', 'high','low', 'close', 'volume','ts_code'] #for ETFs
        data_cols = ['ts_code','trade_date','open','high','low','close','pre_close','change','pct_chg','vol','amount'] #for stocks
        commissions = 5
    #     symbol_list = ['TSLA','AMZN','AAPL']
    #     symbol_list = ['SPY']
    #     symbol_list = ["VTI","TLT","IEF","GLD","DBC"]
    #     symbol_list = ['jd000d']
        initial_capital = 1000000.0
        start_date = datetime.datetime(1991,12,1,0,0,0)
        start_date_str = str(start_date)
        heartbeat = 0.0
        price_col = "close"
        qty = 2000
        backtest = Backtest(csv_dir, 
                            [ticker], 
                            initial_capital, 
                            heartbeat,
                            start_date,
                            HistoricCSVDataHandler, 
                            SimulatedExecutionHandler, 
                            Portfolio, 
    #                         MovingAverageCrossStrategy,
                           MovingAverageConvergenceDivergence)

        backtest.simulate_trading()
# Out:
# Number of assets in the portfolio：  1
# Position Value for each asset:  1000000.0
# latest_datetime: 2010-01-04
# latest_datetime: 2010-01-05
# latest_datetime: 2010-01-06
# latest_datetime: 2010-01-07
# latest_datetime: 2010-01-08
# latest_datetime: 2010-01-11
# latest_datetime: 2010-01-12
# latest_datetime: 2010-01-13
# latest_datetime: 2010-01-14
# latest_datetime: 2010-01-15
# latest_datetime: 2010-01-18
# latest_datetime: 2010-01-19
# latest_datetime: 2010-01-20
# latest_datetime: 2010-01-22
# latest_datetime: 2010-01-25
# latest_datetime: 2010-01-26
# latest_datetime: 2010-01-27
# latest_datetime: 2010-01-28
# latest_datetime: 2010-01-29
# Asset:  000069.SZ symbol_value:  5.5385 mkt_quantity:  2000
# latest_datetime: 2010-02-01
# latest_datetime: 2010-02-02
# latest_datetime: 2010-02-03
# latest_datetime: 2010-02-04
# latest_datetime: 2010-02-05
# latest_datetime: 2010-02-08
# latest_datetime: 2010-02-09
# Asset:  000069.SZ symbol_value:  5.3177 mkt_quantity:  2000
# latest_datetime: 2010-02-10
# latest_datetime: 2010-02-11
# latest_datetime: 2010-02-12
# latest_datetime: 2010-02-22
# latest_datetime: 2010-02-23
# latest_datetime: 2010-02-24
# latest_datetime: 2010-02-25
# latest_datetime: 2010-02-26
# Asset:  000069.SZ symbol_value:  5.5566 mkt_quantity:  2000
# latest_datetime: 2010-03-01
# latest_datetime: 2010-03-02
# latest_datetime: 2010-03-03
# latest_datetime: 2010-03-04
# Asset:  000069.SZ symbol_value:  5.3394 mkt_quantity:  2000
# latest_datetime: 2010-03-05
# latest_datetime: 2010-03-08
# latest_datetime: 2010-03-09
# latest_datetime: 2010-03-10
# latest_datetime: 2010-03-11
# Asset:  000069.SZ symbol_value:  5.4661 mkt_quantity:  2000
# latest_datetime: 2010-03-12
# Asset:  000069.SZ symbol_value:  5.3973 mkt_quantity:  2000
# latest_datetime: 2010-03-15
# latest_datetime: 2010-03-16
# latest_datetime: 2010-03-17
# Asset:  000069.SZ symbol_value:  5.5638 mkt_quantity:  2000
# latest_datetime: 2010-03-18
# latest_datetime: 2010-03-19
# latest_datetime: 2010-03-22
# latest_datetime: 2010-03-23
# latest_datetime: 2010-03-24
# latest_datetime: 2010-03-25
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:34: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:34: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
# latest_datetime: 2010-03-26
# latest_datetime: 2010-03-29
# latest_datetime: 2010-03-30
# latest_datetime: 2010-03-31
# latest_datetime: 2010-04-01
# latest_datetime: 2010-04-02
# latest_datetime: 2010-04-06
# latest_datetime: 2010-04-07
# latest_datetime: 2010-04-08
# Asset:  000069.SZ symbol_value:  5.4806 mkt_quantity:  2000
# latest_datetime: 2010-04-09
# latest_datetime: 2010-04-12
# latest_datetime: 2010-04-13
# latest_datetime: 2010-04-14
# latest_datetime: 2010-04-15
# latest_datetime: 2010-04-16
# latest_datetime: 2010-04-19
# latest_datetime: 2010-04-20
# latest_datetime: 2010-04-21
# latest_datetime: 2010-04-22
# latest_datetime: 2010-04-23
# latest_datetime: 2010-04-26
# latest_datetime: 2010-04-27
# latest_datetime: 2010-04-28
# latest_datetime: 2010-04-29
# latest_datetime: 2010-04-30
# latest_datetime: 2010-05-04
# latest_datetime: 2010-05-05
# latest_datetime: 2010-05-06
# latest_datetime: 2010-05-07
# latest_datetime: 2010-05-10
# Asset:  000069.SZ symbol_value:  4.2607 mkt_quantity:  2000
# latest_datetime: 2010-05-11
# latest_datetime: 2010-05-12
# latest_datetime: 2010-05-13
# latest_datetime: 2010-05-17
# latest_datetime: 2010-05-18
# latest_datetime: 2010-05-19
# latest_datetime: 2010-05-20
# latest_datetime: 2010-05-21
# latest_datetime: 2010-05-24
# latest_datetime: 2010-05-25
# latest_datetime: 2010-05-26
# latest_datetime: 2010-05-27
# latest_datetime: 2010-05-28
# latest_datetime: 2010-05-31
# latest_datetime: 2010-06-01
# latest_datetime: 2010-06-02
# latest_datetime: 2010-06-03
# latest_datetime: 2010-06-04
# latest_datetime: 2010-06-07
# latest_datetime: 2010-06-08
# latest_datetime: 2010-06-09
# latest_datetime: 2010-06-10
# latest_datetime: 2010-06-11
# latest_datetime: 2010-06-17
# latest_datetime: 2010-06-18
# latest_datetime: 2010-06-21
# latest_datetime: 2010-06-22
# latest_datetime: 2010-06-23
# latest_datetime: 2010-06-24
# latest_datetime: 2010-06-25
# latest_datetime: 2010-06-28
# latest_datetime: 2010-06-29
# Asset:  000069.SZ symbol_value:  4.4510000000000005 mkt_quantity:  2000
# latest_datetime: 2010-06-30
# latest_datetime: 2010-07-01
# latest_datetime: 2010-07-02
# latest_datetime: 2010-07-05
# latest_datetime: 2010-07-06
# latest_datetime: 2010-07-07
# latest_datetime: 2010-07-08
# latest_datetime: 2010-07-09
# latest_datetime: 2010-07-12
# latest_datetime: 2010-07-13
# Asset:  000069.SZ symbol_value:  4.4692 mkt_quantity:  2000
# latest_datetime: 2010-07-14
# latest_datetime: 2010-07-15
# latest_datetime: 2010-07-16
# latest_datetime: 2010-07-19
# latest_datetime: 2010-07-20
# latest_datetime: 2010-07-21
# latest_datetime: 2010-07-22
# latest_datetime: 2010-07-23
# latest_datetime: 2010-07-26
# latest_datetime: 2010-07-27
# latest_datetime: 2010-07-28
# latest_datetime: 2010-07-29
# latest_datetime: 2010-07-30
# latest_datetime: 2010-08-02
# latest_datetime: 2010-08-03
# latest_datetime: 2010-08-04
# Asset:  000069.SZ symbol_value:  4.8706 mkt_quantity:  2000
# latest_datetime: 2010-08-05
# latest_datetime: 2010-08-06
# latest_datetime: 2010-08-09
# latest_datetime: 2010-08-10
# latest_datetime: 2010-08-11
# latest_datetime: 2010-08-12
# latest_datetime: 2010-08-13
# latest_datetime: 2010-08-16
# latest_datetime: 2010-08-17
# latest_datetime: 2010-08-18
# Asset:  000069.SZ symbol_value:  5.0311 mkt_quantity:  2000
# latest_datetime: 2010-08-19
# latest_datetime: 2010-08-20
# Asset:  000069.SZ symbol_value:  4.9326 mkt_quantity:  2000
# latest_datetime: 2010-08-23
# latest_datetime: 2010-08-24
# latest_datetime: 2010-08-25
# latest_datetime: 2010-08-26
# latest_datetime: 2010-08-27
# latest_datetime: 2010-08-30
# latest_datetime: 2010-08-31
# latest_datetime: 2010-09-01
# latest_datetime: 2010-09-02
# latest_datetime: 2010-09-03
# latest_datetime: 2010-09-06
# latest_datetime: 2010-09-07
# latest_datetime: 2010-09-08
# latest_datetime: 2010-09-09
# latest_datetime: 2010-09-10
# latest_datetime: 2010-09-13
# latest_datetime: 2010-09-14
# latest_datetime: 2010-09-15
# latest_datetime: 2010-09-16
# latest_datetime: 2010-09-17
# latest_datetime: 2010-09-20
# latest_datetime: 2010-09-21
# latest_datetime: 2010-09-27
# latest_datetime: 2010-09-28
# latest_datetime: 2010-09-29
# latest_datetime: 2010-09-30
# Asset:  000069.SZ symbol_value:  4.6298 mkt_quantity:  2000
# latest_datetime: 2010-10-08
# latest_datetime: 2010-10-11
# latest_datetime: 2010-10-12
# latest_datetime: 2010-10-13
# latest_datetime: 2010-10-14
# latest_datetime: 2010-10-15
# latest_datetime: 2010-10-18
# latest_datetime: 2010-10-19
# latest_datetime: 2010-10-20
# latest_datetime: 2010-10-21
# latest_datetime: 2010-10-22
# Asset:  000069.SZ symbol_value:  4.6991 mkt_quantity:  2000
# latest_datetime: 2010-10-25
# latest_datetime: 2010-10-26
# latest_datetime: 2010-10-27
# latest_datetime: 2010-10-28
# latest_datetime: 2010-10-29
# latest_datetime: 2010-11-01
# latest_datetime: 2010-11-02
# latest_datetime: 2010-11-03
# latest_datetime: 2010-11-04
# latest_datetime: 2010-11-05
# latest_datetime: 2010-11-08
# Asset:  000069.SZ symbol_value:  5.0639 mkt_quantity:  2000
# latest_datetime: 2010-11-09
# latest_datetime: 2010-11-10
# Asset:  000069.SZ symbol_value:  4.7356 mkt_quantity:  2000
# latest_datetime: 2010-11-11
# latest_datetime: 2010-11-12
# latest_datetime: 2010-11-15
# latest_datetime: 2010-11-16
# latest_datetime: 2010-11-17
# latest_datetime: 2010-11-18
# latest_datetime: 2010-11-19
# latest_datetime: 2010-11-22
# latest_datetime: 2010-11-23
# latest_datetime: 2010-11-24
# latest_datetime: 2010-11-25
# latest_datetime: 2010-11-26
# latest_datetime: 2010-11-29
# latest_datetime: 2010-11-30
# latest_datetime: 2010-12-01
# latest_datetime: 2010-12-02
# latest_datetime: 2010-12-03
# Asset:  000069.SZ symbol_value:  4.3707 mkt_quantity:  2000
# latest_datetime: 2010-12-06
# latest_datetime: 2010-12-07
# latest_datetime: 2010-12-08
# latest_datetime: 2010-12-09
# latest_datetime: 2010-12-10
# latest_datetime: 2010-12-14
# latest_datetime: 2010-12-15
# latest_datetime: 2010-12-16
# latest_datetime: 2010-12-17
# latest_datetime: 2010-12-20
# latest_datetime: 2010-12-21
# latest_datetime: 2010-12-22
# latest_datetime: 2010-12-23
# latest_datetime: 2010-12-24
# latest_datetime: 2010-12-27
# latest_datetime: 2010-12-28
# latest_datetime: 2010-12-29
# latest_datetime: 2010-12-30
# Asset:  000069.SZ symbol_value:  4.3999 mkt_quantity:  2000
# latest_datetime: 2010-12-31
# latest_datetime: 2011-01-04
# latest_datetime: 2011-01-05
# latest_datetime: 2011-01-06
# latest_datetime: 2011-01-07
# Asset:  000069.SZ symbol_value:  4.7064 mkt_quantity:  2000
# latest_datetime: 2011-01-10
# latest_datetime: 2011-01-11
# latest_datetime: 2011-01-12
# latest_datetime: 2011-01-13
# latest_datetime: 2011-01-14
# latest_datetime: 2011-01-17
# Asset:  000069.SZ symbol_value:  4.4802 mkt_quantity:  2000
# latest_datetime: 2011-01-18
# latest_datetime: 2011-01-19
# latest_datetime: 2011-01-20
# latest_datetime: 2011-01-21
# latest_datetime: 2011-01-24
# latest_datetime: 2011-01-25
# latest_datetime: 2011-01-26
# Asset:  000069.SZ symbol_value:  4.6517 mkt_quantity:  2000
# latest_datetime: 2011-01-27
# Asset:  000069.SZ symbol_value:  4.4656 mkt_quantity:  2000
# latest_datetime: 2011-01-28
# latest_datetime: 2011-01-31
# latest_datetime: 2011-02-01
# latest_datetime: 2011-02-09
# latest_datetime: 2011-02-10
# latest_datetime: 2011-02-11
# latest_datetime: 2011-02-14
# Asset:  000069.SZ symbol_value:  4.7502 mkt_quantity:  2000
# latest_datetime: 2011-02-15
# latest_datetime: 2011-02-16
# latest_datetime: 2011-02-17
# latest_datetime: 2011-02-18
# latest_datetime: 2011-02-21
# latest_datetime: 2011-02-22
# latest_datetime: 2011-02-23
# latest_datetime: 2011-02-24
# latest_datetime: 2011-02-25
# Asset:  000069.SZ symbol_value:  4.4948 mkt_quantity:  2000
# latest_datetime: 2011-02-28
# latest_datetime: 2011-03-01
# Asset:  000069.SZ symbol_value:  5.1259 mkt_quantity:  2000
# latest_datetime: 2011-03-02
# latest_datetime: 2011-03-03
# latest_datetime: 2011-03-04
# latest_datetime: 2011-03-07
# latest_datetime: 2011-03-08
# latest_datetime: 2011-03-09
# latest_datetime: 2011-03-10
# latest_datetime: 2011-03-11
# latest_datetime: 2011-03-14
# latest_datetime: 2011-03-15
# latest_datetime: 2011-03-16
# latest_datetime: 2011-03-17
# latest_datetime: 2011-03-18
# latest_datetime: 2011-03-21
# latest_datetime: 2011-03-22
# latest_datetime: 2011-03-23
# latest_datetime: 2011-03-24
# latest_datetime: 2011-03-28
# latest_datetime: 2011-03-29
# latest_datetime: 2011-03-30
# Asset:  000069.SZ symbol_value:  5.4689 mkt_quantity:  2000
# latest_datetime: 2011-03-31
# latest_datetime: 2011-04-01
# latest_datetime: 2011-04-06
# latest_datetime: 2011-04-07
# latest_datetime: 2011-04-08
# latest_datetime: 2011-04-11
# latest_datetime: 2011-04-12
# latest_datetime: 2011-04-13
# latest_datetime: 2011-04-14
# latest_datetime: 2011-04-15
# latest_datetime: 2011-04-18
# Asset:  000069.SZ symbol_value:  5.9274 mkt_quantity:  2000
# latest_datetime: 2011-04-19
# latest_datetime: 2011-04-20
# latest_datetime: 2011-04-21
# latest_datetime: 2011-04-22
# latest_datetime: 2011-04-25
# latest_datetime: 2011-04-26
# Asset:  000069.SZ symbol_value:  5.4395 mkt_quantity:  2000
# latest_datetime: 2011-04-27
# latest_datetime: 2011-04-28
# latest_datetime: 2011-04-29
# latest_datetime: 2011-05-03
# latest_datetime: 2011-05-04
# latest_datetime: 2011-05-05
# latest_datetime: 2011-05-06
# latest_datetime: 2011-05-09
# latest_datetime: 2011-05-10
# latest_datetime: 2011-05-11
# latest_datetime: 2011-05-12
# latest_datetime: 2011-05-13
# latest_datetime: 2011-05-16
# latest_datetime: 2011-05-17
# Asset:  000069.SZ symbol_value:  5.3802 mkt_quantity:  2000
# latest_datetime: 2011-05-18
# latest_datetime: 2011-05-19
# latest_datetime: 2011-05-20
# latest_datetime: 2011-05-23
# Asset:  000069.SZ symbol_value:  5.0109 mkt_quantity:  2000
# latest_datetime: 2011-05-24
# Asset:  000069.SZ symbol_value:  5.0175 mkt_quantity:  2000
# latest_datetime: 2011-05-25
# Asset:  000069.SZ symbol_value:  4.8329 mkt_quantity:  2000
# latest_datetime: 2011-05-26
# latest_datetime: 2011-05-27
# latest_datetime: 2011-05-30
# latest_datetime: 2011-05-31
# latest_datetime: 2011-06-01
# latest_datetime: 2011-06-02
# latest_datetime: 2011-06-03
# latest_datetime: 2011-06-07
# latest_datetime: 2011-06-08
# Asset:  000069.SZ symbol_value:  5.0373 mkt_quantity:  2000
# latest_datetime: 2011-06-09
# latest_datetime: 2011-06-10
# latest_datetime: 2011-06-13
# latest_datetime: 2011-06-14
# latest_datetime: 2011-06-15
# latest_datetime: 2011-06-16
# latest_datetime: 2011-06-17
# latest_datetime: 2011-06-20
# latest_datetime: 2011-06-21
# latest_datetime: 2011-06-22
# latest_datetime: 2011-06-23
# latest_datetime: 2011-06-24
# latest_datetime: 2011-06-27
# latest_datetime: 2011-06-28
# latest_datetime: 2011-06-29
# latest_datetime: 2011-06-30
# latest_datetime: 2011-07-01
# latest_datetime: 2011-07-04
# latest_datetime: 2011-07-05
# latest_datetime: 2011-07-06
# latest_datetime: 2011-07-07
# latest_datetime: 2011-07-08
# latest_datetime: 2011-07-11
# latest_datetime: 2011-07-12
# latest_datetime: 2011-07-13
# latest_datetime: 2011-07-14
# latest_datetime: 2011-07-15
# Asset:  000069.SZ symbol_value:  5.2549 mkt_quantity:  2000
# latest_datetime: 2011-07-18
# latest_datetime: 2011-07-19
# latest_datetime: 2011-07-20
# latest_datetime: 2011-07-21
# latest_datetime: 2011-07-22
# latest_datetime: 2011-07-25
# latest_datetime: 2011-07-26
# latest_datetime: 2011-07-27
# latest_datetime: 2011-07-28
# latest_datetime: 2011-07-29
# latest_datetime: 2011-08-01
# latest_datetime: 2011-08-02
# latest_datetime: 2011-08-03
# latest_datetime: 2011-08-04
# latest_datetime: 2011-08-05
# latest_datetime: 2011-08-08
# latest_datetime: 2011-08-09
# latest_datetime: 2011-08-10
# latest_datetime: 2011-08-11
# Asset:  000069.SZ symbol_value:  5.2285 mkt_quantity:  2000
# latest_datetime: 2011-08-12
# latest_datetime: 2011-08-15
# latest_datetime: 2011-08-16
# latest_datetime: 2011-08-17
# latest_datetime: 2011-08-18
# latest_datetime: 2011-08-19
# Asset:  000069.SZ symbol_value:  4.8923 mkt_quantity:  2000
# latest_datetime: 2011-08-22
# latest_datetime: 2011-08-23
# latest_datetime: 2011-08-24
# latest_datetime: 2011-08-25
# latest_datetime: 2011-08-26
# latest_datetime: 2011-08-29
# latest_datetime: 2011-08-30
# latest_datetime: 2011-08-31
# latest_datetime: 2011-09-01
# latest_datetime: 2011-09-02
# latest_datetime: 2011-09-05
# latest_datetime: 2011-09-06
# latest_datetime: 2011-09-07
# latest_datetime: 2011-09-08
# latest_datetime: 2011-09-13
# latest_datetime: 2011-09-14
# latest_datetime: 2011-09-15
# latest_datetime: 2011-09-16
# Asset:  000069.SZ symbol_value:  4.8593 mkt_quantity:  2000
# latest_datetime: 2011-09-19
# latest_datetime: 2011-09-20
# latest_datetime: 2011-09-21
# latest_datetime: 2011-09-22
# Asset:  000069.SZ symbol_value:  4.6813 mkt_quantity:  2000
# latest_datetime: 2011-09-23
# latest_datetime: 2011-09-26
# latest_datetime: 2011-09-27
# latest_datetime: 2011-09-28
# latest_datetime: 2011-09-29
# latest_datetime: 2011-09-30
# latest_datetime: 2011-10-10
# latest_datetime: 2011-10-11
# latest_datetime: 2011-10-12
# latest_datetime: 2011-10-13
# latest_datetime: 2011-10-14
# latest_datetime: 2011-10-17
# latest_datetime: 2011-10-18
# latest_datetime: 2011-10-19
# latest_datetime: 2011-10-20
# latest_datetime: 2011-10-21
# latest_datetime: 2011-10-24
# latest_datetime: 2011-10-25
# Asset:  000069.SZ symbol_value:  4.2857 mkt_quantity:  2000
# latest_datetime: 2011-10-26
# latest_datetime: 2011-10-27
# latest_datetime: 2011-10-28
# latest_datetime: 2011-10-31
# latest_datetime: 2011-11-01
# latest_datetime: 2011-11-02
# latest_datetime: 2011-11-03
# latest_datetime: 2011-11-04
# latest_datetime: 2011-11-07
# latest_datetime: 2011-11-08
# latest_datetime: 2011-11-09
# latest_datetime: 2011-11-10
# latest_datetime: 2011-11-11
# Asset:  000069.SZ symbol_value:  4.4835 mkt_quantity:  2000
# latest_datetime: 2011-11-14
# latest_datetime: 2011-11-15
# latest_datetime: 2011-11-16
# latest_datetime: 2011-11-17
# latest_datetime: 2011-11-18
# latest_datetime: 2011-11-21
# latest_datetime: 2011-11-22
# latest_datetime: 2011-11-23
# latest_datetime: 2011-11-24
# latest_datetime: 2011-11-25
# latest_datetime: 2011-11-28
# latest_datetime: 2011-11-29
# latest_datetime: 2011-11-30
# latest_datetime: 2011-12-01
# Asset:  000069.SZ symbol_value:  4.6219 mkt_quantity:  2000
# latest_datetime: 2011-12-02
# latest_datetime: 2011-12-05
# latest_datetime: 2011-12-06
# latest_datetime: 2011-12-07
# latest_datetime: 2011-12-08
# latest_datetime: 2011-12-09
# latest_datetime: 2011-12-12
# latest_datetime: 2011-12-13
# latest_datetime: 2011-12-14
# latest_datetime: 2011-12-15
# latest_datetime: 2011-12-16
# latest_datetime: 2011-12-19
# latest_datetime: 2011-12-20
# latest_datetime: 2011-12-21
# Asset:  000069.SZ symbol_value:  4.5626 mkt_quantity:  2000
# latest_datetime: 2011-12-22
# latest_datetime: 2011-12-23
# latest_datetime: 2011-12-26
# latest_datetime: 2011-12-27
# latest_datetime: 2011-12-28
# latest_datetime: 2011-12-29
# latest_datetime: 2011-12-30
# latest_datetime: 2012-01-04
# latest_datetime: 2012-01-05
# latest_datetime: 2012-01-06
# latest_datetime: 2012-01-09
# latest_datetime: 2012-01-10
# latest_datetime: 2012-01-11
# latest_datetime: 2012-01-12
# Asset:  000069.SZ symbol_value:  4.6483 mkt_quantity:  2000
# latest_datetime: 2012-01-13
# latest_datetime: 2012-01-16
# Asset:  000069.SZ symbol_value:  4.4505 mkt_quantity:  2000
# latest_datetime: 2012-01-17
# Asset:  000069.SZ symbol_value:  4.6417 mkt_quantity:  2000
# latest_datetime: 2012-01-18
# latest_datetime: 2012-01-19
# latest_datetime: 2012-01-20
# latest_datetime: 2012-01-30
# latest_datetime: 2012-01-31
# latest_datetime: 2012-02-01
# latest_datetime: 2012-02-02
# latest_datetime: 2012-02-03
# latest_datetime: 2012-02-06
# latest_datetime: 2012-02-07
# latest_datetime: 2012-02-08
# latest_datetime: 2012-02-09
# latest_datetime: 2012-02-10
# Asset:  000069.SZ symbol_value:  4.7604 mkt_quantity:  2000
# latest_datetime: 2012-02-13
# latest_datetime: 2012-02-14
# latest_datetime: 2012-02-15
# latest_datetime: 2012-02-16
# latest_datetime: 2012-02-17
# latest_datetime: 2012-02-20
# latest_datetime: 2012-02-21
# latest_datetime: 2012-02-22
# latest_datetime: 2012-02-23
# Asset:  000069.SZ symbol_value:  4.8857 mkt_quantity:  2000
# latest_datetime: 2012-02-24
# latest_datetime: 2012-02-27
# latest_datetime: 2012-02-28
# latest_datetime: 2012-02-29
# latest_datetime: 2012-03-01
# latest_datetime: 2012-03-02
# latest_datetime: 2012-03-05
# latest_datetime: 2012-03-06
# latest_datetime: 2012-03-07
# latest_datetime: 2012-03-08
# latest_datetime: 2012-03-09
# latest_datetime: 2012-03-12
# latest_datetime: 2012-03-13
# Asset:  000069.SZ symbol_value:  5.0044 mkt_quantity:  2000
# latest_datetime: 2012-03-14
# latest_datetime: 2012-03-15
# latest_datetime: 2012-03-16
# latest_datetime: 2012-03-19
# latest_datetime: 2012-03-20
# latest_datetime: 2012-03-21
# latest_datetime: 2012-03-22
# latest_datetime: 2012-03-23
# latest_datetime: 2012-03-26
# latest_datetime: 2012-03-27
# latest_datetime: 2012-03-28
# latest_datetime: 2012-03-29
# latest_datetime: 2012-03-30
# latest_datetime: 2012-04-05
# latest_datetime: 2012-04-06
# Asset:  000069.SZ symbol_value:  4.7802 mkt_quantity:  2000
# latest_datetime: 2012-04-09
# latest_datetime: 2012-04-10
# latest_datetime: 2012-04-11
# latest_datetime: 2012-04-12
# latest_datetime: 2012-04-13
# latest_datetime: 2012-04-16
# latest_datetime: 2012-04-17
# latest_datetime: 2012-04-18
# latest_datetime: 2012-04-19
# latest_datetime: 2012-04-20
# latest_datetime: 2012-04-23
# latest_datetime: 2012-04-24
# latest_datetime: 2012-04-25
# latest_datetime: 2012-04-27
# latest_datetime: 2012-05-02
# latest_datetime: 2012-05-03
# latest_datetime: 2012-05-04
# latest_datetime: 2012-05-07
# latest_datetime: 2012-05-08
# latest_datetime: 2012-05-09
# latest_datetime: 2012-05-10
# Asset:  000069.SZ symbol_value:  4.9252 mkt_quantity:  2000
# latest_datetime: 2012-05-11
# latest_datetime: 2012-05-14
# latest_datetime: 2012-05-15
# latest_datetime: 2012-05-16
# latest_datetime: 2012-05-17
# latest_datetime: 2012-05-18
# latest_datetime: 2012-05-21
# latest_datetime: 2012-05-22
# latest_datetime: 2012-05-23
# latest_datetime: 2012-05-24
# latest_datetime: 2012-05-25
# latest_datetime: 2012-05-28
# latest_datetime: 2012-05-29
# Asset:  000069.SZ symbol_value:  5.0881 mkt_quantity:  2000
# latest_datetime: 2012-05-30
# latest_datetime: 2012-05-31
# latest_datetime: 2012-06-01
# latest_datetime: 2012-06-04
# latest_datetime: 2012-06-05
# latest_datetime: 2012-06-06
# latest_datetime: 2012-06-07
# latest_datetime: 2012-06-08
# latest_datetime: 2012-06-11
# latest_datetime: 2012-06-12
# latest_datetime: 2012-06-13
# latest_datetime: 2012-06-14
# latest_datetime: 2012-06-15
# latest_datetime: 2012-06-18
# latest_datetime: 2012-06-19
# latest_datetime: 2012-06-20
# latest_datetime: 2012-06-21
# latest_datetime: 2012-06-25
# Asset:  000069.SZ symbol_value:  5.4336 mkt_quantity:  2000
# latest_datetime: 2012-06-26
# latest_datetime: 2012-06-27
# latest_datetime: 2012-06-28
# latest_datetime: 2012-06-29
# latest_datetime: 2012-07-02
# latest_datetime: 2012-07-03
# latest_datetime: 2012-07-04
# Asset:  000069.SZ symbol_value:  5.8482 mkt_quantity:  2000
# latest_datetime: 2012-07-05
# latest_datetime: 2012-07-06
# latest_datetime: 2012-07-09
# latest_datetime: 2012-07-10
# latest_datetime: 2012-07-11
# latest_datetime: 2012-07-12
# latest_datetime: 2012-07-13
# latest_datetime: 2012-07-16
# latest_datetime: 2012-07-17
# latest_datetime: 2012-07-18
# Asset:  000069.SZ symbol_value:  5.6323 mkt_quantity:  2000
# latest_datetime: 2012-07-19
# latest_datetime: 2012-07-20
# latest_datetime: 2012-07-23
# latest_datetime: 2012-07-24
# latest_datetime: 2012-07-25
# latest_datetime: 2012-07-26
# latest_datetime: 2012-07-27
# latest_datetime: 2012-07-30
# latest_datetime: 2012-07-31
# latest_datetime: 2012-08-01
# latest_datetime: 2012-08-02
# latest_datetime: 2012-08-03
# latest_datetime: 2012-08-06
# latest_datetime: 2012-08-07
# latest_datetime: 2012-08-08
# latest_datetime: 2012-08-09
# latest_datetime: 2012-08-10
# Asset:  000069.SZ symbol_value:  5.1572 mkt_quantity:  2000
# latest_datetime: 2012-08-13
# latest_datetime: 2012-08-14
# latest_datetime: 2012-08-15
# latest_datetime: 2012-08-16
# latest_datetime: 2012-08-17
# latest_datetime: 2012-08-20
# Asset:  000069.SZ symbol_value:  4.8462 mkt_quantity:  2000
# latest_datetime: 2012-08-21
# latest_datetime: 2012-08-22
# latest_datetime: 2012-08-23
# latest_datetime: 2012-08-24
# latest_datetime: 2012-08-27
# latest_datetime: 2012-08-28
# latest_datetime: 2012-08-29
# latest_datetime: 2012-08-30
# latest_datetime: 2012-08-31
# latest_datetime: 2012-09-03
# Asset:  000069.SZ symbol_value:  4.9153 mkt_quantity:  2000
# latest_datetime: 2012-09-04
# latest_datetime: 2012-09-05
# latest_datetime: 2012-09-06
# latest_datetime: 2012-09-07
# latest_datetime: 2012-09-10
# latest_datetime: 2012-09-11
# latest_datetime: 2012-09-12
# latest_datetime: 2012-09-13
# latest_datetime: 2012-09-14
# latest_datetime: 2012-09-17
# latest_datetime: 2012-09-18
# Asset:  000069.SZ symbol_value:  4.7512 mkt_quantity:  2000
# latest_datetime: 2012-09-19
# latest_datetime: 2012-09-20
# latest_datetime: 2012-09-21
# latest_datetime: 2012-09-24
# latest_datetime: 2012-09-25
# latest_datetime: 2012-09-26
# latest_datetime: 2012-09-27
# latest_datetime: 2012-09-28
# latest_datetime: 2012-10-08
# latest_datetime: 2012-10-09
# latest_datetime: 2012-10-10
# Asset:  000069.SZ symbol_value:  4.8548 mkt_quantity:  2000
# latest_datetime: 2012-10-11
# latest_datetime: 2012-10-12
# latest_datetime: 2012-10-15
# latest_datetime: 2012-10-16
# latest_datetime: 2012-10-17
# latest_datetime: 2012-10-18
# latest_datetime: 2012-10-19
# latest_datetime: 2012-10-22
# latest_datetime: 2012-10-23
# latest_datetime: 2012-10-24
# latest_datetime: 2012-10-25
# latest_datetime: 2012-10-26
# latest_datetime: 2012-10-29
# latest_datetime: 2012-10-30
# latest_datetime: 2012-10-31
# latest_datetime: 2012-11-01
# latest_datetime: 2012-11-02
# latest_datetime: 2012-11-05
# latest_datetime: 2012-11-06
# latest_datetime: 2012-11-07
# latest_datetime: 2012-11-08
# Asset:  000069.SZ symbol_value:  5.1485 mkt_quantity:  2000
# latest_datetime: 2012-11-09
# latest_datetime: 2012-11-12
# latest_datetime: 2012-11-13
# latest_datetime: 2012-11-14
# latest_datetime: 2012-11-15
# latest_datetime: 2012-11-16
# latest_datetime: 2012-11-19
# latest_datetime: 2012-11-20
# latest_datetime: 2012-11-21
# latest_datetime: 2012-11-22
# latest_datetime: 2012-11-23
# Asset:  000069.SZ symbol_value:  5.1572 mkt_quantity:  2000
# latest_datetime: 2012-11-26
# latest_datetime: 2012-11-27
# latest_datetime: 2012-11-28
# latest_datetime: 2012-11-29
# Asset:  000069.SZ symbol_value:  4.8548 mkt_quantity:  2000
# latest_datetime: 2012-11-30
# latest_datetime: 2012-12-03
# latest_datetime: 2012-12-04
# latest_datetime: 2012-12-05
# Asset:  000069.SZ symbol_value:  5.2608 mkt_quantity:  2000
# latest_datetime: 2012-12-06
# latest_datetime: 2012-12-07
# latest_datetime: 2012-12-10
# latest_datetime: 2012-12-11
# latest_datetime: 2012-12-12
# latest_datetime: 2012-12-13
# latest_datetime: 2012-12-14
# latest_datetime: 2012-12-17
# latest_datetime: 2012-12-18
# latest_datetime: 2012-12-19
# latest_datetime: 2012-12-20
# latest_datetime: 2012-12-21
# latest_datetime: 2012-12-24
# latest_datetime: 2012-12-25
# latest_datetime: 2012-12-26
# latest_datetime: 2012-12-27
# latest_datetime: 2012-12-28
# latest_datetime: 2012-12-31
# latest_datetime: 2013-01-04
# latest_datetime: 2013-01-07
# latest_datetime: 2013-01-08
# latest_datetime: 2013-01-09
# latest_datetime: 2013-01-10
# latest_datetime: 2013-01-11
# latest_datetime: 2013-01-14
# latest_datetime: 2013-01-15
# latest_datetime: 2013-01-16
# Asset:  000069.SZ symbol_value:  6.1506 mkt_quantity:  2000
# latest_datetime: 2013-01-17
# latest_datetime: 2013-01-18
# latest_datetime: 2013-01-21
# latest_datetime: 2013-01-22
# latest_datetime: 2013-01-23
# latest_datetime: 2013-01-24
# latest_datetime: 2013-01-25
# latest_datetime: 2013-01-28
# latest_datetime: 2013-01-29
# latest_datetime: 2013-01-30
# latest_datetime: 2013-01-31
# latest_datetime: 2013-02-01
# latest_datetime: 2013-02-04
# latest_datetime: 2013-02-05
# latest_datetime: 2013-02-06
# latest_datetime: 2013-02-07
# Asset:  000069.SZ symbol_value:  5.9519 mkt_quantity:  2000
# latest_datetime: 2013-02-08
# latest_datetime: 2013-02-18
# latest_datetime: 2013-02-19
# Asset:  000069.SZ symbol_value:  5.7273 mkt_quantity:  2000
# latest_datetime: 2013-02-20
# latest_datetime: 2013-02-21
# latest_datetime: 2013-02-22
# latest_datetime: 2013-02-25
# latest_datetime: 2013-02-26
# latest_datetime: 2013-02-27
# latest_datetime: 2013-02-28
# latest_datetime: 2013-03-01
# latest_datetime: 2013-03-04
# latest_datetime: 2013-03-05
# latest_datetime: 2013-03-06
# latest_datetime: 2013-03-07
# latest_datetime: 2013-03-08
# latest_datetime: 2013-03-11
# latest_datetime: 2013-03-12
# latest_datetime: 2013-03-13
# latest_datetime: 2013-03-14
# latest_datetime: 2013-03-15
# latest_datetime: 2013-03-18
# latest_datetime: 2013-03-19
# Asset:  000069.SZ symbol_value:  5.1658 mkt_quantity:  2000
# latest_datetime: 2013-03-20
# latest_datetime: 2013-03-21
# latest_datetime: 2013-03-22
# latest_datetime: 2013-03-25
# latest_datetime: 2013-03-26
# latest_datetime: 2013-03-27
# latest_datetime: 2013-03-28
# latest_datetime: 2013-03-29
# latest_datetime: 2013-04-01
# latest_datetime: 2013-04-02
# latest_datetime: 2013-04-03
# latest_datetime: 2013-04-08
# latest_datetime: 2013-04-09
# latest_datetime: 2013-04-10
# Asset:  000069.SZ symbol_value:  4.9671 mkt_quantity:  2000
# latest_datetime: 2013-04-11
# latest_datetime: 2013-04-12
# latest_datetime: 2013-04-15
# latest_datetime: 2013-04-16
# Asset:  000069.SZ symbol_value:  5.2004 mkt_quantity:  2000
# latest_datetime: 2013-04-17
# latest_datetime: 2013-04-18
# latest_datetime: 2013-04-19
# latest_datetime: 2013-04-22
# latest_datetime: 2013-04-23
# latest_datetime: 2013-04-24
# Asset:  000069.SZ symbol_value:  5.0362 mkt_quantity:  2000
# latest_datetime: 2013-04-25
# latest_datetime: 2013-04-26
# latest_datetime: 2013-05-02
# latest_datetime: 2013-05-03
# Asset:  000069.SZ symbol_value:  5.0967 mkt_quantity:  2000
# latest_datetime: 2013-05-06
# latest_datetime: 2013-05-07
# latest_datetime: 2013-05-08
# latest_datetime: 2013-05-09
# Asset:  000069.SZ symbol_value:  5.0449 mkt_quantity:  2000
# latest_datetime: 2013-05-10
# latest_datetime: 2013-05-13
# latest_datetime: 2013-05-14
# latest_datetime: 2013-05-15
# Asset:  000069.SZ symbol_value:  5.3472 mkt_quantity:  2000
# latest_datetime: 2013-05-16
# latest_datetime: 2013-05-17
# latest_datetime: 2013-05-20
# latest_datetime: 2013-05-21
# latest_datetime: 2013-05-22
# latest_datetime: 2013-05-23
# latest_datetime: 2013-05-24
# latest_datetime: 2013-05-27
# latest_datetime: 2013-05-28
# latest_datetime: 2013-05-29
# latest_datetime: 2013-05-30
# latest_datetime: 2013-05-31
# latest_datetime: 2013-06-03
# latest_datetime: 2013-06-04
# Asset:  000069.SZ symbol_value:  5.5113 mkt_quantity:  2000
# latest_datetime: 2013-06-05
# latest_datetime: 2013-06-06
# latest_datetime: 2013-06-07
# latest_datetime: 2013-06-13
# latest_datetime: 2013-06-14
# latest_datetime: 2013-06-17
# latest_datetime: 2013-06-18
# latest_datetime: 2013-06-19
# latest_datetime: 2013-06-20
# latest_datetime: 2013-06-21
# latest_datetime: 2013-06-24
# latest_datetime: 2013-06-25
# latest_datetime: 2013-06-26
# latest_datetime: 2013-06-27
# latest_datetime: 2013-06-28
# latest_datetime: 2013-07-01
# latest_datetime: 2013-07-02
# latest_datetime: 2013-07-03
# latest_datetime: 2013-07-04
# latest_datetime: 2013-07-05
# latest_datetime: 2013-07-08
# Asset:  000069.SZ symbol_value:  4.4855 mkt_quantity:  2000
# latest_datetime: 2013-07-09
# latest_datetime: 2013-07-10
# latest_datetime: 2013-07-11
# latest_datetime: 2013-07-12
# latest_datetime: 2013-07-15
# latest_datetime: 2013-07-16
# latest_datetime: 2013-07-17
# latest_datetime: 2013-07-18
# latest_datetime: 2013-07-19
# latest_datetime: 2013-07-22
# latest_datetime: 2013-07-23
# latest_datetime: 2013-07-24
# latest_datetime: 2013-07-25
# latest_datetime: 2013-07-26
# latest_datetime: 2013-07-29
# latest_datetime: 2013-07-30
# latest_datetime: 2013-07-31
# latest_datetime: 2013-08-01
# latest_datetime: 2013-08-02
# latest_datetime: 2013-08-05
# latest_datetime: 2013-08-06
# latest_datetime: 2013-08-07
# latest_datetime: 2013-08-08
# latest_datetime: 2013-08-09
# latest_datetime: 2013-08-12
# latest_datetime: 2013-08-13
# latest_datetime: 2013-08-14
# latest_datetime: 2013-08-15
# latest_datetime: 2013-08-16
# latest_datetime: 2013-08-19
# latest_datetime: 2013-08-20
# latest_datetime: 2013-08-21
# Asset:  000069.SZ symbol_value:  5.274 mkt_quantity:  2000
# latest_datetime: 2013-08-22
# latest_datetime: 2013-08-23
# latest_datetime: 2013-08-26
# latest_datetime: 2013-08-27
# latest_datetime: 2013-08-28
# latest_datetime: 2013-08-29
# latest_datetime: 2013-08-30
# latest_datetime: 2013-09-02
# latest_datetime: 2013-09-03
# latest_datetime: 2013-09-04
# latest_datetime: 2013-09-05
# latest_datetime: 2013-09-06
# latest_datetime: 2013-09-09
# Asset:  000069.SZ symbol_value:  5.3178 mkt_quantity:  2000
# latest_datetime: 2013-09-10
# latest_datetime: 2013-09-11
# latest_datetime: 2013-09-12
# latest_datetime: 2013-09-13
# latest_datetime: 2013-09-16
# latest_datetime: 2013-09-17
# latest_datetime: 2013-09-18
# latest_datetime: 2013-09-23
# latest_datetime: 2013-09-24
# Asset:  000069.SZ symbol_value:  5.1601 mkt_quantity:  2000
# latest_datetime: 2013-09-25
# latest_datetime: 2013-09-26
# latest_datetime: 2013-09-27
# latest_datetime: 2013-09-30
# latest_datetime: 2013-10-08
# latest_datetime: 2013-10-09
# latest_datetime: 2013-10-10
# Asset:  000069.SZ symbol_value:  5.5018 mkt_quantity:  2000
# latest_datetime: 2013-10-11
# latest_datetime: 2013-10-14
# latest_datetime: 2013-10-15
# latest_datetime: 2013-10-16
# latest_datetime: 2013-10-17
# latest_datetime: 2013-10-18
# latest_datetime: 2013-10-21
# latest_datetime: 2013-10-22
# Asset:  000069.SZ symbol_value:  5.3529 mkt_quantity:  2000
# latest_datetime: 2013-10-23
# Asset:  000069.SZ symbol_value:  5.3616 mkt_quantity:  2000
# latest_datetime: 2013-10-24
# latest_datetime: 2013-10-25
# latest_datetime: 2013-10-28
# Asset:  000069.SZ symbol_value:  5.1163 mkt_quantity:  2000
# latest_datetime: 2013-10-29
# latest_datetime: 2013-10-30
# latest_datetime: 2013-10-31
# latest_datetime: 2013-11-01
# latest_datetime: 2013-11-04
# latest_datetime: 2013-11-05
# latest_datetime: 2013-11-06
# latest_datetime: 2013-11-07
# latest_datetime: 2013-11-08
# latest_datetime: 2013-11-11
# latest_datetime: 2013-11-12
# latest_datetime: 2013-11-13
# latest_datetime: 2013-11-14
# latest_datetime: 2013-11-15
# latest_datetime: 2013-11-18
# latest_datetime: 2013-11-19
# Asset:  000069.SZ symbol_value:  5.0813 mkt_quantity:  2000
# latest_datetime: 2013-11-20
# latest_datetime: 2013-11-21
# Asset:  000069.SZ symbol_value:  4.8798 mkt_quantity:  2000
# latest_datetime: 2013-11-22
# latest_datetime: 2013-11-25
# latest_datetime: 2013-11-26
# latest_datetime: 2013-11-27
# latest_datetime: 2013-11-28
# latest_datetime: 2013-11-29
# latest_datetime: 2013-12-02
# latest_datetime: 2013-12-03
# latest_datetime: 2013-12-04
# latest_datetime: 2013-12-05
# Asset:  000069.SZ symbol_value:  4.8009 mkt_quantity:  2000
# latest_datetime: 2013-12-06
# latest_datetime: 2013-12-09
# latest_datetime: 2013-12-10
# latest_datetime: 2013-12-11
# latest_datetime: 2013-12-12
# latest_datetime: 2013-12-13
# latest_datetime: 2013-12-16
# Asset:  000069.SZ symbol_value:  4.7484 mkt_quantity:  2000
# latest_datetime: 2013-12-17
# latest_datetime: 2013-12-18
# latest_datetime: 2013-12-19
# latest_datetime: 2013-12-20
# latest_datetime: 2013-12-23
# latest_datetime: 2013-12-24
# latest_datetime: 2013-12-25
# latest_datetime: 2013-12-26
# latest_datetime: 2013-12-27
# latest_datetime: 2013-12-30
# latest_datetime: 2013-12-31
# latest_datetime: 2014-01-02
# latest_datetime: 2014-01-03
# latest_datetime: 2014-01-06
# latest_datetime: 2014-01-07
# latest_datetime: 2014-01-08
# latest_datetime: 2014-01-09
# latest_datetime: 2014-01-10
# latest_datetime: 2014-01-13
# latest_datetime: 2014-01-14
# latest_datetime: 2014-01-15
# latest_datetime: 2014-01-16
# latest_datetime: 2014-01-17
# latest_datetime: 2014-01-20
# latest_datetime: 2014-01-21
# latest_datetime: 2014-01-22
# Asset:  000069.SZ symbol_value:  4.4067 mkt_quantity:  2000
# latest_datetime: 2014-01-23
# latest_datetime: 2014-01-24
# latest_datetime: 2014-01-27
# latest_datetime: 2014-01-28
# latest_datetime: 2014-01-29
# latest_datetime: 2014-01-30
# latest_datetime: 2014-02-07
# latest_datetime: 2014-02-10
# latest_datetime: 2014-02-11
# latest_datetime: 2014-02-12
# latest_datetime: 2014-02-13
# latest_datetime: 2014-02-14
# latest_datetime: 2014-02-17
# latest_datetime: 2014-02-18
# latest_datetime: 2014-02-19
# latest_datetime: 2014-02-20
# latest_datetime: 2014-02-21
# Asset:  000069.SZ symbol_value:  4.2928 mkt_quantity:  2000
# latest_datetime: 2014-02-24
# latest_datetime: 2014-02-25
# latest_datetime: 2014-02-26
# latest_datetime: 2014-02-27
# latest_datetime: 2014-02-28
# latest_datetime: 2014-03-03
# latest_datetime: 2014-03-04
# latest_datetime: 2014-03-05
# latest_datetime: 2014-03-06
# latest_datetime: 2014-03-07
# latest_datetime: 2014-03-10
# latest_datetime: 2014-03-11
# latest_datetime: 2014-03-12
# latest_datetime: 2014-03-13
# latest_datetime: 2014-03-14
# latest_datetime: 2014-03-17
# Asset:  000069.SZ symbol_value:  3.8898 mkt_quantity:  2000
# latest_datetime: 2014-03-18
# latest_datetime: 2014-03-19
# latest_datetime: 2014-03-20
# latest_datetime: 2014-03-21
# latest_datetime: 2014-03-24
# latest_datetime: 2014-03-25
# latest_datetime: 2014-03-26
# latest_datetime: 2014-03-27
# latest_datetime: 2014-03-28
# latest_datetime: 2014-03-31
# latest_datetime: 2014-04-01
# latest_datetime: 2014-04-02
# latest_datetime: 2014-04-03
# latest_datetime: 2014-04-04
# latest_datetime: 2014-04-08
# latest_datetime: 2014-04-09
# latest_datetime: 2014-04-10
# latest_datetime: 2014-04-11
# latest_datetime: 2014-04-14
# Asset:  000069.SZ symbol_value:  4.1263 mkt_quantity:  2000
# latest_datetime: 2014-04-15
# latest_datetime: 2014-04-16
# latest_datetime: 2014-04-17
# latest_datetime: 2014-04-18
# latest_datetime: 2014-04-21
# latest_datetime: 2014-04-22
# latest_datetime: 2014-04-23
# latest_datetime: 2014-04-24
# latest_datetime: 2014-04-25
# latest_datetime: 2014-04-28
# Asset:  000069.SZ symbol_value:  4.3892 mkt_quantity:  2000
# latest_datetime: 2014-04-29
# latest_datetime: 2014-04-30
# latest_datetime: 2014-05-05
# latest_datetime: 2014-05-06
# latest_datetime: 2014-05-07
# Asset:  000069.SZ symbol_value:  4.0913 mkt_quantity:  2000
# latest_datetime: 2014-05-08
# latest_datetime: 2014-05-09
# latest_datetime: 2014-05-12
# latest_datetime: 2014-05-13
# latest_datetime: 2014-05-14
# latest_datetime: 2014-05-15
# latest_datetime: 2014-05-16
# latest_datetime: 2014-05-19
# latest_datetime: 2014-05-20
# latest_datetime: 2014-05-21
# latest_datetime: 2014-05-22
# latest_datetime: 2014-05-23
# Asset:  000069.SZ symbol_value:  4.1439 mkt_quantity:  2000
# latest_datetime: 2014-05-26
# latest_datetime: 2014-05-27
# latest_datetime: 2014-05-28
# latest_datetime: 2014-05-29
# latest_datetime: 2014-05-30
# latest_datetime: 2014-06-03
# latest_datetime: 2014-06-04
# latest_datetime: 2014-06-05
# latest_datetime: 2014-06-06
# latest_datetime: 2014-06-09
# latest_datetime: 2014-06-10
# latest_datetime: 2014-06-11
# latest_datetime: 2014-06-12
# latest_datetime: 2014-06-13
# latest_datetime: 2014-06-16
# Asset:  000069.SZ symbol_value:  4.2575 mkt_quantity:  2000
# latest_datetime: 2014-06-17
# latest_datetime: 2014-06-18
# latest_datetime: 2014-06-19
# latest_datetime: 2014-06-20
# latest_datetime: 2014-06-23
# latest_datetime: 2014-06-24
# latest_datetime: 2014-06-25
# latest_datetime: 2014-06-26
# latest_datetime: 2014-06-27
# latest_datetime: 2014-06-30
# latest_datetime: 2014-07-01
# latest_datetime: 2014-07-02
# latest_datetime: 2014-07-03
# latest_datetime: 2014-07-04
# Asset:  000069.SZ symbol_value:  4.2486 mkt_quantity:  2000
# latest_datetime: 2014-07-07
# latest_datetime: 2014-07-08
# latest_datetime: 2014-07-09
# latest_datetime: 2014-07-10
# latest_datetime: 2014-07-11
# latest_datetime: 2014-07-14
# latest_datetime: 2014-07-15
# latest_datetime: 2014-07-16
# latest_datetime: 2014-07-17
# latest_datetime: 2014-07-18
# latest_datetime: 2014-07-21
# latest_datetime: 2014-07-22
# latest_datetime: 2014-07-23
# latest_datetime: 2014-07-24
# latest_datetime: 2014-07-25
# latest_datetime: 2014-07-28
# latest_datetime: 2014-07-29
# latest_datetime: 2014-07-30
# latest_datetime: 2014-07-31
# latest_datetime: 2014-08-01
# latest_datetime: 2014-08-04
# latest_datetime: 2014-08-05
# latest_datetime: 2014-08-06
# latest_datetime: 2014-08-07
# latest_datetime: 2014-08-08
# latest_datetime: 2014-08-11
# latest_datetime: 2014-08-12
# latest_datetime: 2014-08-13
# Asset:  000069.SZ symbol_value:  4.8619 mkt_quantity:  2000
# latest_datetime: 2014-08-14
# latest_datetime: 2014-08-15
# latest_datetime: 2014-08-18
# latest_datetime: 2014-08-19
# latest_datetime: 2014-08-20
# latest_datetime: 2014-08-21
# latest_datetime: 2014-08-22
# latest_datetime: 2014-08-25
# latest_datetime: 2014-08-26
# latest_datetime: 2014-08-27
# latest_datetime: 2014-08-28
# latest_datetime: 2014-08-29
# latest_datetime: 2014-09-01
# latest_datetime: 2014-09-02
# latest_datetime: 2014-09-03
# Asset:  000069.SZ symbol_value:  4.8886 mkt_quantity:  2000
# latest_datetime: 2014-09-04
# latest_datetime: 2014-09-05
# latest_datetime: 2014-09-09
# latest_datetime: 2014-09-10
# latest_datetime: 2014-09-11
# latest_datetime: 2014-09-12
# latest_datetime: 2014-09-15
# Asset:  000069.SZ symbol_value:  4.7642 mkt_quantity:  2000
# latest_datetime: 2014-09-16
# latest_datetime: 2014-09-17
# latest_datetime: 2014-09-18
# latest_datetime: 2014-09-19
# latest_datetime: 2014-09-22
# latest_datetime: 2014-09-23
# latest_datetime: 2014-09-24
# latest_datetime: 2014-09-25
# latest_datetime: 2014-09-26
# latest_datetime: 2014-09-29
# latest_datetime: 2014-09-30
# latest_datetime: 2014-10-08
# Asset:  000069.SZ symbol_value:  4.933 mkt_quantity:  2000
# latest_datetime: 2014-10-09
# latest_datetime: 2014-10-10
# latest_datetime: 2014-10-13
# latest_datetime: 2014-10-14
# latest_datetime: 2014-10-15
# latest_datetime: 2014-10-16
# latest_datetime: 2014-10-17
# latest_datetime: 2014-10-20
# Asset:  000069.SZ symbol_value:  4.7997 mkt_quantity:  2000
# latest_datetime: 2014-10-21
# latest_datetime: 2014-10-22
# latest_datetime: 2014-10-23
# latest_datetime: 2014-10-24
# latest_datetime: 2014-10-27
# latest_datetime: 2014-10-28
# latest_datetime: 2014-10-29
# latest_datetime: 2014-10-30
# latest_datetime: 2014-10-31
# Asset:  000069.SZ symbol_value:  4.8975 mkt_quantity:  2000
# latest_datetime: 2014-11-03
# latest_datetime: 2014-11-04
# latest_datetime: 2014-11-05
# latest_datetime: 2014-11-06
# latest_datetime: 2014-11-07
# latest_datetime: 2014-11-10
# latest_datetime: 2014-11-11
# latest_datetime: 2014-11-12
# latest_datetime: 2014-11-13
# latest_datetime: 2014-11-14
# latest_datetime: 2014-11-17
# latest_datetime: 2014-11-18
# latest_datetime: 2014-11-19
# latest_datetime: 2014-11-20
# latest_datetime: 2014-11-21
# latest_datetime: 2014-11-24
# latest_datetime: 2014-11-25
# latest_datetime: 2014-11-26
# latest_datetime: 2014-11-27
# latest_datetime: 2014-11-28
# latest_datetime: 2014-12-01
# latest_datetime: 2014-12-02
# latest_datetime: 2014-12-03
# latest_datetime: 2014-12-04
# latest_datetime: 2014-12-05
# latest_datetime: 2014-12-08
# latest_datetime: 2014-12-09
# latest_datetime: 2014-12-10
# latest_datetime: 2014-12-11
# latest_datetime: 2014-12-12
# latest_datetime: 2014-12-15
# latest_datetime: 2014-12-16
# latest_datetime: 2014-12-17
# latest_datetime: 2014-12-18
# latest_datetime: 2014-12-19
# latest_datetime: 2014-12-22
# Asset:  000069.SZ symbol_value:  6.0974 mkt_quantity:  2000
# latest_datetime: 2014-12-23
# latest_datetime: 2014-12-24
# latest_datetime: 2014-12-25
# latest_datetime: 2014-12-26
# latest_datetime: 2014-12-29
# Asset:  000069.SZ symbol_value:  6.7729 mkt_quantity:  2000
# latest_datetime: 2014-12-30
# latest_datetime: 2014-12-31
# latest_datetime: 2015-01-05
# latest_datetime: 2015-01-06
# latest_datetime: 2015-01-07
# latest_datetime: 2015-01-08
# latest_datetime: 2015-01-09
# latest_datetime: 2015-01-12
# latest_datetime: 2015-01-13
# Asset:  000069.SZ symbol_value:  6.7374 mkt_quantity:  2000
# latest_datetime: 2015-01-14
# latest_datetime: 2015-01-15
# latest_datetime: 2015-01-16
# latest_datetime: 2015-01-19
# latest_datetime: 2015-01-20
# latest_datetime: 2015-01-21
# latest_datetime: 2015-03-23
# Asset:  000069.SZ symbol_value:  7.7062 mkt_quantity:  2000
# latest_datetime: 2015-03-24
# latest_datetime: 2015-03-25
# latest_datetime: 2015-03-26
# latest_datetime: 2015-03-27
# latest_datetime: 2015-03-30
# latest_datetime: 2015-03-31
# latest_datetime: 2015-04-01
# latest_datetime: 2015-04-02
# latest_datetime: 2015-04-03
# latest_datetime: 2015-04-07
# latest_datetime: 2015-04-08
# latest_datetime: 2015-04-09
# latest_datetime: 2015-04-10
# latest_datetime: 2015-04-13
# latest_datetime: 2015-04-14
# latest_datetime: 2015-04-15
# latest_datetime: 2015-04-16
# latest_datetime: 2015-04-17
# latest_datetime: 2015-04-20
# Asset:  000069.SZ symbol_value:  9.0306 mkt_quantity:  2000
# latest_datetime: 2015-04-21
# latest_datetime: 2015-04-22
# latest_datetime: 2015-04-23
# latest_datetime: 2015-04-24
# latest_datetime: 2015-04-27
# latest_datetime: 2015-04-28
# latest_datetime: 2015-04-29
# latest_datetime: 2015-04-30
# latest_datetime: 2015-05-04
# latest_datetime: 2015-05-05
# latest_datetime: 2015-05-06
# latest_datetime: 2015-05-07
# latest_datetime: 2015-05-08
# latest_datetime: 2015-05-11
# latest_datetime: 2015-05-12
# latest_datetime: 2015-05-13
# latest_datetime: 2015-05-14
# latest_datetime: 2015-05-15
# latest_datetime: 2015-05-18
# latest_datetime: 2015-05-19
# latest_datetime: 2015-05-20
# latest_datetime: 2015-05-21
# latest_datetime: 2015-05-22
# Asset:  000069.SZ symbol_value:  9.1283 mkt_quantity:  2000
# latest_datetime: 2015-05-25
# latest_datetime: 2015-05-26
# latest_datetime: 2015-05-27
# latest_datetime: 2015-05-28
# latest_datetime: 2015-05-29
# latest_datetime: 2015-06-01
# latest_datetime: 2015-06-02
# latest_datetime: 2015-06-03
# latest_datetime: 2015-06-04
# latest_datetime: 2015-06-05
# latest_datetime: 2015-06-08
# latest_datetime: 2015-06-09
# latest_datetime: 2015-06-10
# latest_datetime: 2015-06-11
# latest_datetime: 2015-06-12
# latest_datetime: 2015-06-15
# latest_datetime: 2015-06-16
# latest_datetime: 2015-06-17
# latest_datetime: 2015-06-18
# latest_datetime: 2015-06-19
# latest_datetime: 2015-06-23
# Asset:  000069.SZ symbol_value:  11.4037 mkt_quantity:  2000
# latest_datetime: 2015-06-24
# Asset:  000069.SZ symbol_value:  11.9459 mkt_quantity:  2000
# latest_datetime: 2015-06-25
# latest_datetime: 2015-06-26
# Asset:  000069.SZ symbol_value:  11.0838 mkt_quantity:  2000
# latest_datetime: 2015-06-29
# latest_datetime: 2015-06-30
# latest_datetime: 2015-07-01
# latest_datetime: 2015-07-02
# latest_datetime: 2015-07-03
# latest_datetime: 2015-07-06
# latest_datetime: 2015-07-07
# latest_datetime: 2015-07-17
# latest_datetime: 2015-07-20
# latest_datetime: 2015-07-21
# latest_datetime: 2015-07-22
# latest_datetime: 2015-07-23
# latest_datetime: 2015-07-24
# latest_datetime: 2015-07-27
# latest_datetime: 2015-07-28
# latest_datetime: 2015-07-29
# latest_datetime: 2015-07-30
# latest_datetime: 2015-07-31
# latest_datetime: 2015-08-03
# Asset:  000069.SZ symbol_value:  8.957 mkt_quantity:  2000
# latest_datetime: 2015-08-04
# latest_datetime: 2015-08-05
# latest_datetime: 2015-08-06
# latest_datetime: 2015-08-07
# latest_datetime: 2015-08-10
# latest_datetime: 2015-08-11
# latest_datetime: 2015-08-12
# latest_datetime: 2015-08-13
# latest_datetime: 2015-08-14
# latest_datetime: 2015-08-17
# latest_datetime: 2015-08-18
# latest_datetime: 2015-08-19
# latest_datetime: 2015-08-20
# Asset:  000069.SZ symbol_value:  8.3659 mkt_quantity:  2000
# latest_datetime: 2015-08-21
# latest_datetime: 2015-08-24
# latest_datetime: 2015-08-25
# latest_datetime: 2015-08-26
# latest_datetime: 2015-08-27
# latest_datetime: 2015-08-28
# latest_datetime: 2015-08-31
# latest_datetime: 2015-09-01
# latest_datetime: 2015-09-02
# latest_datetime: 2015-09-07
# latest_datetime: 2015-09-08
# latest_datetime: 2015-09-09
# latest_datetime: 2015-09-10
# Asset:  000069.SZ symbol_value:  7.0134 mkt_quantity:  2000
# latest_datetime: 2015-09-11
# latest_datetime: 2015-09-14
# Asset:  000069.SZ symbol_value:  6.5924 mkt_quantity:  2000
# latest_datetime: 2015-09-15
# latest_datetime: 2015-09-16
# latest_datetime: 2015-09-17
# Asset:  000069.SZ symbol_value:  6.5118 mkt_quantity:  2000
# latest_datetime: 2015-09-18
# latest_datetime: 2015-09-21
# latest_datetime: 2015-09-22
# latest_datetime: 2015-09-23
# latest_datetime: 2015-09-24
# latest_datetime: 2015-09-25
# latest_datetime: 2015-09-28
# latest_datetime: 2015-09-29
# Asset:  000069.SZ symbol_value:  6.2699 mkt_quantity:  2000
# latest_datetime: 2015-09-30
# latest_datetime: 2015-10-08
# latest_datetime: 2015-10-09
# latest_datetime: 2015-10-12
# Asset:  000069.SZ symbol_value:  6.9417 mkt_quantity:  2000
# latest_datetime: 2015-10-13
# latest_datetime: 2015-10-14
# latest_datetime: 2015-10-15
# latest_datetime: 2015-10-16
# latest_datetime: 2015-10-19
# latest_datetime: 2015-10-20
# latest_datetime: 2015-10-21
# latest_datetime: 2015-10-22
# latest_datetime: 2015-10-23
# latest_datetime: 2015-10-26
# latest_datetime: 2015-10-27
# latest_datetime: 2015-10-28
# latest_datetime: 2015-10-29
# latest_datetime: 2015-10-30
# latest_datetime: 2015-11-02
# Asset:  000069.SZ symbol_value:  7.1925 mkt_quantity:  2000
# latest_datetime: 2015-11-03
# latest_datetime: 2015-11-04
# latest_datetime: 2015-11-05
# latest_datetime: 2015-11-06
# Asset:  000069.SZ symbol_value:  7.8643 mkt_quantity:  2000
# latest_datetime: 2015-11-09
# latest_datetime: 2015-11-10
# latest_datetime: 2015-11-11
# latest_datetime: 2015-11-12
# latest_datetime: 2015-11-13
# latest_datetime: 2015-11-16
# Asset:  000069.SZ symbol_value:  7.5956 mkt_quantity:  2000
# latest_datetime: 2015-11-17
# latest_datetime: 2015-11-18
# latest_datetime: 2015-11-19
# latest_datetime: 2015-11-20
# Asset:  000069.SZ symbol_value:  7.8105 mkt_quantity:  2000
# latest_datetime: 2015-11-23
# Asset:  000069.SZ symbol_value:  7.6583 mkt_quantity:  2000
# latest_datetime: 2015-11-24
# latest_datetime: 2015-11-25
# latest_datetime: 2015-11-26
# latest_datetime: 2015-11-27
# latest_datetime: 2015-11-30
# latest_datetime: 2015-12-01
# latest_datetime: 2015-12-02
# latest_datetime: 2015-12-03
# Asset:  000069.SZ symbol_value:  7.9897 mkt_quantity:  2000
# latest_datetime: 2015-12-04
# latest_datetime: 2015-12-07
# Asset:  000069.SZ symbol_value:  7.6672 mkt_quantity:  2000
# latest_datetime: 2015-12-08
# latest_datetime: 2015-12-09
# latest_datetime: 2015-12-10
# latest_datetime: 2015-12-11
# latest_datetime: 2015-12-14
# latest_datetime: 2015-12-15
# latest_datetime: 2015-12-16
# Asset:  000069.SZ symbol_value:  7.5597 mkt_quantity:  2000
# latest_datetime: 2015-12-17
# latest_datetime: 2015-12-18
# latest_datetime: 2015-12-21
# latest_datetime: 2015-12-22
# latest_datetime: 2015-12-23
# latest_datetime: 2015-12-24
# latest_datetime: 2015-12-25
# latest_datetime: 2015-12-28
# latest_datetime: 2015-12-29
# latest_datetime: 2015-12-30
# Asset:  000069.SZ symbol_value:  7.9449 mkt_quantity:  2000
# latest_datetime: 2015-12-31
# latest_datetime: 2016-01-04
# latest_datetime: 2016-01-05
# latest_datetime: 2016-01-06
# latest_datetime: 2016-01-07
# latest_datetime: 2016-01-08
# latest_datetime: 2016-01-11
# latest_datetime: 2016-01-12
# latest_datetime: 2016-01-13
# latest_datetime: 2016-01-14
# latest_datetime: 2016-01-15
# latest_datetime: 2016-01-18
# latest_datetime: 2016-01-19
# latest_datetime: 2016-01-20
# latest_datetime: 2016-01-21
# ...
# latest_datetime: 2018-07-12
# latest_datetime: 2018-07-13
# latest_datetime: 2018-07-16
# latest_datetime: 2018-07-17
# latest_datetime: 2018-07-18
# Asset:  000069.SZ symbol_value:  6.0356 mkt_quantity:  2000
# latest_datetime: 2018-07-19
# latest_datetime: 2018-07-20
# latest_datetime: 2018-07-23
# latest_datetime: 2018-07-24
# latest_datetime: 2018-07-25
# latest_datetime: 2018-07-26
# latest_datetime: 2018-07-27
# latest_datetime: 2018-07-30
# latest_datetime: 2018-07-31
# latest_datetime: 2018-08-01
# latest_datetime: 2018-08-02
# latest_datetime: 2018-08-03
# Asset:  000069.SZ symbol_value:  6.0356 mkt_quantity:  2000
# latest_datetime: 2018-08-06
# latest_datetime: 2018-08-07
# latest_datetime: 2018-08-08
# latest_datetime: 2018-08-09
# latest_datetime: 2018-08-10
# latest_datetime: 2018-08-13
# Asset:  000069.SZ symbol_value:  6.2751 mkt_quantity:  2000
# latest_datetime: 2018-08-14
# Asset:  000069.SZ symbol_value:  6.1697 mkt_quantity:  2000
# latest_datetime: 2018-08-15
# latest_datetime: 2018-08-16
# latest_datetime: 2018-08-17
# latest_datetime: 2018-08-20
# latest_datetime: 2018-08-21
# latest_datetime: 2018-08-22
# latest_datetime: 2018-08-23
# latest_datetime: 2018-08-24
# latest_datetime: 2018-08-27
# latest_datetime: 2018-08-28
# Asset:  000069.SZ symbol_value:  6.2081 mkt_quantity:  2000
# latest_datetime: 2018-08-29
# latest_datetime: 2018-08-30
# latest_datetime: 2018-08-31
# latest_datetime: 2018-09-03
# Asset:  000069.SZ symbol_value:  5.9302 mkt_quantity:  2000
# latest_datetime: 2018-09-04
# latest_datetime: 2018-09-05
# latest_datetime: 2018-09-06
# latest_datetime: 2018-09-07
# latest_datetime: 2018-09-10
# latest_datetime: 2018-09-11
# latest_datetime: 2018-09-12
# latest_datetime: 2018-09-13
# latest_datetime: 2018-09-14
# latest_datetime: 2018-09-17
# latest_datetime: 2018-09-18
# latest_datetime: 2018-09-19
# Asset:  000069.SZ symbol_value:  6.1123 mkt_quantity:  2000
# latest_datetime: 2018-09-20
# latest_datetime: 2018-09-21
# latest_datetime: 2018-09-25
# latest_datetime: 2018-09-26
# latest_datetime: 2018-09-27
# latest_datetime: 2018-09-28
# latest_datetime: 2018-10-08
# latest_datetime: 2018-10-09
# latest_datetime: 2018-10-10
# Asset:  000069.SZ symbol_value:  5.7003 mkt_quantity:  2000
# latest_datetime: 2018-10-11
# latest_datetime: 2018-10-12
# latest_datetime: 2018-10-15
# latest_datetime: 2018-10-16
# latest_datetime: 2018-10-17
# latest_datetime: 2018-10-18
# latest_datetime: 2018-10-19
# latest_datetime: 2018-10-22
# latest_datetime: 2018-10-23
# latest_datetime: 2018-10-24
# latest_datetime: 2018-10-25
# Asset:  000069.SZ symbol_value:  5.4895 mkt_quantity:  2000
# latest_datetime: 2018-10-26
# latest_datetime: 2018-10-29
# latest_datetime: 2018-10-30
# latest_datetime: 2018-10-31
# latest_datetime: 2018-11-01
# latest_datetime: 2018-11-02
# latest_datetime: 2018-11-05
# latest_datetime: 2018-11-06
# latest_datetime: 2018-11-07
# latest_datetime: 2018-11-08
# latest_datetime: 2018-11-09
# latest_datetime: 2018-11-12
# latest_datetime: 2018-11-13
# latest_datetime: 2018-11-14
# latest_datetime: 2018-11-15
# latest_datetime: 2018-11-16
# latest_datetime: 2018-11-19
# latest_datetime: 2018-11-20
# latest_datetime: 2018-11-21
# latest_datetime: 2018-11-22
# latest_datetime: 2018-11-23
# latest_datetime: 2018-11-26
# latest_datetime: 2018-11-27
# Asset:  000069.SZ symbol_value:  5.7769 mkt_quantity:  2000
# latest_datetime: 2018-11-28
# latest_datetime: 2018-11-29
# latest_datetime: 2018-11-30
# latest_datetime: 2018-12-03
# latest_datetime: 2018-12-04
# latest_datetime: 2018-12-05
# latest_datetime: 2018-12-06
# latest_datetime: 2018-12-07
# latest_datetime: 2018-12-10
# latest_datetime: 2018-12-11
# latest_datetime: 2018-12-12
# latest_datetime: 2018-12-13
# latest_datetime: 2018-12-14
# latest_datetime: 2018-12-17
# Asset:  000069.SZ symbol_value:  5.8823 mkt_quantity:  2000
# latest_datetime: 2018-12-18
# latest_datetime: 2018-12-19
# latest_datetime: 2018-12-20
# latest_datetime: 2018-12-21
# Asset:  000069.SZ symbol_value:  5.6716 mkt_quantity:  2000
# latest_datetime: 2018-12-24
# latest_datetime: 2018-12-25
# latest_datetime: 2018-12-26
# Asset:  000069.SZ symbol_value:  5.8344 mkt_quantity:  2000
# latest_datetime: 2018-12-27
# latest_datetime: 2018-12-28
# latest_datetime: 2019-01-02
# latest_datetime: 2019-01-03
# latest_datetime: 2019-01-04
# latest_datetime: 2019-01-07
# latest_datetime: 2019-01-08
# latest_datetime: 2019-01-09
# latest_datetime: 2019-01-10
# latest_datetime: 2019-01-11
# latest_datetime: 2019-01-14
# latest_datetime: 2019-01-15
# latest_datetime: 2019-01-16
# latest_datetime: 2019-01-17
# Asset:  000069.SZ symbol_value:  5.8439999999999985 mkt_quantity:  2000
# latest_datetime: 2019-01-18
# Asset:  000069.SZ symbol_value:  5.9398 mkt_quantity:  2000
# latest_datetime: 2019-01-21
# latest_datetime: 2019-01-22
# Asset:  000069.SZ symbol_value:  5.8632 mkt_quantity:  2000
# latest_datetime: 2019-01-23
# latest_datetime: 2019-01-24
# latest_datetime: 2019-01-25
# Asset:  000069.SZ symbol_value:  6.0356 mkt_quantity:  2000
# latest_datetime: 2019-01-28
# latest_datetime: 2019-01-29
# latest_datetime: 2019-01-30
# latest_datetime: 2019-01-31
# latest_datetime: 2019-02-01
# latest_datetime: 2019-02-11
# latest_datetime: 2019-02-12
# latest_datetime: 2019-02-13
# latest_datetime: 2019-02-14
# latest_datetime: 2019-02-15
# latest_datetime: 2019-02-18
# latest_datetime: 2019-02-19
# latest_datetime: 2019-02-20
# latest_datetime: 2019-02-21
# latest_datetime: 2019-02-22
# latest_datetime: 2019-02-25
# latest_datetime: 2019-02-26
# latest_datetime: 2019-02-27
# latest_datetime: 2019-02-28
# latest_datetime: 2019-03-01
# latest_datetime: 2019-03-04
# latest_datetime: 2019-03-05
# latest_datetime: 2019-03-06
# latest_datetime: 2019-03-07
# latest_datetime: 2019-03-08
# latest_datetime: 2019-03-11
# Asset:  000069.SZ symbol_value:  6.6104 mkt_quantity:  2000
# latest_datetime: 2019-03-12
# latest_datetime: 2019-03-13
# latest_datetime: 2019-03-14
# latest_datetime: 2019-03-15
# latest_datetime: 2019-03-18
# latest_datetime: 2019-03-19
# latest_datetime: 2019-03-20
# Asset:  000069.SZ symbol_value:  6.9266 mkt_quantity:  2000
# latest_datetime: 2019-03-21
# latest_datetime: 2019-03-22
# latest_datetime: 2019-03-25
# latest_datetime: 2019-03-26
# latest_datetime: 2019-03-27
# latest_datetime: 2019-03-28
# latest_datetime: 2019-03-29
# latest_datetime: 2019-04-01
# latest_datetime: 2019-04-02
# latest_datetime: 2019-04-03
# latest_datetime: 2019-04-04
# latest_datetime: 2019-04-08
# latest_datetime: 2019-04-09
# latest_datetime: 2019-04-10
# latest_datetime: 2019-04-11
# latest_datetime: 2019-04-12
# latest_datetime: 2019-04-15
# latest_datetime: 2019-04-16
# latest_datetime: 2019-04-17
# latest_datetime: 2019-04-18
# Asset:  000069.SZ symbol_value:  8.0858 mkt_quantity:  2000
# latest_datetime: 2019-04-19
# latest_datetime: 2019-04-22
# latest_datetime: 2019-04-23
# latest_datetime: 2019-04-24
# latest_datetime: 2019-04-25
# latest_datetime: 2019-04-26
# latest_datetime: 2019-04-29
# latest_datetime: 2019-04-30
# latest_datetime: 2019-05-06
# latest_datetime: 2019-05-07
# latest_datetime: 2019-05-08
# latest_datetime: 2019-05-09
# latest_datetime: 2019-05-10
# latest_datetime: 2019-05-13
# latest_datetime: 2019-05-14
# latest_datetime: 2019-05-15
# latest_datetime: 2019-05-16
# latest_datetime: 2019-05-17
# latest_datetime: 2019-05-20
# latest_datetime: 2019-05-21
# latest_datetime: 2019-05-22
# Asset:  000069.SZ symbol_value:  6.92 mkt_quantity:  2000
# latest_datetime: 2019-05-23
# Asset:  000069.SZ symbol_value:  6.86 mkt_quantity:  2000
# latest_datetime: 2019-05-24
# Asset:  000069.SZ symbol_value:  6.82 mkt_quantity:  2000
# latest_datetime: 2019-05-27
# latest_datetime: 2019-05-28
# latest_datetime: 2019-05-29
# latest_datetime: 2019-05-30
# latest_datetime: 2019-05-31
# latest_datetime: 2019-06-03
# latest_datetime: 2019-06-04
# latest_datetime: 2019-06-05
# latest_datetime: 2019-06-06
# latest_datetime: 2019-06-10
# latest_datetime: 2019-06-11
# latest_datetime: 2019-06-12
# latest_datetime: 2019-06-13
# latest_datetime: 2019-06-14
# latest_datetime: 2019-06-17
# latest_datetime: 2019-06-18
# latest_datetime: 2019-06-19
# latest_datetime: 2019-06-20
# latest_datetime: 2019-06-21
# latest_datetime: 2019-06-24
# latest_datetime: 2019-06-25
# latest_datetime: 2019-06-26
# Asset:  000069.SZ symbol_value:  6.92 mkt_quantity:  2000
# latest_datetime: 2019-06-27
# latest_datetime: 2019-06-28
# latest_datetime: 2019-07-01
# latest_datetime: 2019-07-02
# Asset:  000069.SZ symbol_value:  7.19 mkt_quantity:  2000
# latest_datetime: 2019-07-03
# latest_datetime: 2019-07-04
# latest_datetime: 2019-07-05
# latest_datetime: 2019-07-08
# latest_datetime: 2019-07-09
# latest_datetime: 2019-07-10
# latest_datetime: 2019-07-11
# latest_datetime: 2019-07-12
# latest_datetime: 2019-07-15
# latest_datetime: 2019-07-16
# latest_datetime: 2019-07-17
# latest_datetime: 2019-07-18
# latest_datetime: 2019-07-19
# latest_datetime: 2019-07-22
# latest_datetime: 2019-07-23
# latest_datetime: 2019-07-24
# latest_datetime: 2019-07-25
# latest_datetime: 2019-07-26
# latest_datetime: 2019-07-29
# Asset:  000069.SZ symbol_value:  7.37 mkt_quantity:  2000
# latest_datetime: 2019-07-30
# latest_datetime: 2019-07-31
# latest_datetime: 2019-08-01
# latest_datetime: 2019-08-02
# latest_datetime: 2019-08-05
# latest_datetime: 2019-08-06
# latest_datetime: 2019-08-07
# latest_datetime: 2019-08-08
# latest_datetime: 2019-08-09
# latest_datetime: 2019-08-12
# latest_datetime: 2019-08-13
# latest_datetime: 2019-08-14
# latest_datetime: 2019-08-15
# latest_datetime: 2019-08-16
# latest_datetime: 2019-08-19
# latest_datetime: 2019-08-20
# Asset:  000069.SZ symbol_value:  7.02 mkt_quantity:  2000
# latest_datetime: 2019-08-21
# latest_datetime: 2019-08-22
# latest_datetime: 2019-08-23
# latest_datetime: 2019-08-26
# latest_datetime: 2019-08-27
# latest_datetime: 2019-08-28
# latest_datetime: 2019-08-29
# latest_datetime: 2019-08-30
# latest_datetime: 2019-09-02
# latest_datetime: 2019-09-03
# latest_datetime: 2019-09-04
# latest_datetime: 2019-09-05
# latest_datetime: 2019-09-06
# latest_datetime: 2019-09-09
# latest_datetime: 2019-09-10
# latest_datetime: 2019-09-11
# latest_datetime: 2019-09-12
# latest_datetime: 2019-09-16
# latest_datetime: 2019-09-17
# Asset:  000069.SZ symbol_value:  7.03 mkt_quantity:  2000
# latest_datetime: 2019-09-18
# latest_datetime: 2019-09-19
# latest_datetime: 2019-09-20
# latest_datetime: 2019-09-23
# latest_datetime: 2019-09-24
# latest_datetime: 2019-09-25
# latest_datetime: 2019-09-26
# latest_datetime: 2019-09-27
# latest_datetime: 2019-09-30
# latest_datetime: 2019-10-08
# latest_datetime: 2019-10-09
# Asset:  000069.SZ symbol_value:  7.33 mkt_quantity:  2000
# latest_datetime: 2019-10-10
# latest_datetime: 2019-10-11
# latest_datetime: 2019-10-14
# latest_datetime: 2019-10-15
# latest_datetime: 2019-10-16
# latest_datetime: 2019-10-17
# latest_datetime: 2019-10-18
# latest_datetime: 2019-10-21
# latest_datetime: 2019-10-22
# Asset:  000069.SZ symbol_value:  7.22 mkt_quantity:  2000
# latest_datetime: 2019-10-23
# latest_datetime: 2019-10-24
# latest_datetime: 2019-10-25
# latest_datetime: 2019-10-28
# latest_datetime: 2019-10-29
# latest_datetime: 2019-10-30
# latest_datetime: 2019-10-31
# latest_datetime: 2019-11-01
# latest_datetime: 2019-11-04
# latest_datetime: 2019-11-05
# latest_datetime: 2019-11-06
# Asset:  000069.SZ symbol_value:  7.24 mkt_quantity:  2000
# latest_datetime: 2019-11-07
# latest_datetime: 2019-11-08
# latest_datetime: 2019-11-11
# Asset:  000069.SZ symbol_value:  6.98 mkt_quantity:  2000
# latest_datetime: 2019-11-12
# latest_datetime: 2019-11-13
# latest_datetime: 2019-11-14
# latest_datetime: 2019-11-15
# latest_datetime: 2019-11-18
# latest_datetime: 2019-11-19
# latest_datetime: 2019-11-20
# latest_datetime: 2019-11-21
# latest_datetime: 2019-11-22
# latest_datetime: 2019-11-25
# latest_datetime: 2019-11-26
# Asset:  000069.SZ symbol_value:  7.08 mkt_quantity:  2000
# latest_datetime: 2019-11-27
# latest_datetime: 2019-11-28
# latest_datetime: 2019-11-29
# latest_datetime: 2019-12-02
# latest_datetime: 2019-12-03
# latest_datetime: 2019-12-04
# latest_datetime: 2019-12-05
# latest_datetime: 2019-12-06
# latest_datetime: 2019-12-09
# latest_datetime: 2019-12-10
# latest_datetime: 2019-12-11
# latest_datetime: 2019-12-12
# latest_datetime: 2019-12-13
# latest_datetime: 2019-12-16
# latest_datetime: 2019-12-17
# latest_datetime: 2019-12-18
# latest_datetime: 2019-12-19
# latest_datetime: 2019-12-20
# latest_datetime: 2019-12-23
# latest_datetime: 2019-12-24
# latest_datetime: 2019-12-25
# latest_datetime: 2019-12-26
# latest_datetime: 2019-12-27
# latest_datetime: 2019-12-30
# latest_datetime: 2019-12-31
# latest_datetime: 2020-01-02
# latest_datetime: 2020-01-03
# latest_datetime: 2020-01-06
# latest_datetime: 2020-01-07
# latest_datetime: 2020-01-08
# latest_datetime: 2020-01-09
# latest_datetime: 2020-01-10
# Asset:  000069.SZ symbol_value:  7.66 mkt_quantity:  2000
# latest_datetime: 2020-01-13
# latest_datetime: 2020-01-14
# latest_datetime: 2020-01-15
# latest_datetime: 2020-01-16
# latest_datetime: 2020-01-17
# latest_datetime: 2020-01-20
# latest_datetime: 2020-01-21
# latest_datetime: 2020-01-22
# latest_datetime: 2020-01-23
# latest_datetime: 2020-02-03
# latest_datetime: 2020-02-04
# latest_datetime: 2020-02-05
# latest_datetime: 2020-02-06
# latest_datetime: 2020-02-07
# latest_datetime: 2020-02-10
# latest_datetime: 2020-02-11
# latest_datetime: 2020-02-12
# latest_datetime: 2020-02-13
# latest_datetime: 2020-02-14
# latest_datetime: 2020-02-17
# Asset:  000069.SZ symbol_value:  6.78 mkt_quantity:  2000
# latest_datetime: 2020-02-18
# latest_datetime: 2020-02-19
# latest_datetime: 2020-02-20
# latest_datetime: 2020-02-21
# latest_datetime: 2020-02-24
# latest_datetime: 2020-02-25
# latest_datetime: 2020-02-26
# latest_datetime: 2020-02-27
# latest_datetime: 2020-02-28
# latest_datetime: 2020-03-02
# latest_datetime: 2020-03-03
# latest_datetime: 2020-03-04
# latest_datetime: 2020-03-05
# latest_datetime: 2020-03-06
# latest_datetime: 2020-03-09
# latest_datetime: 2020-03-10
# Asset:  000069.SZ symbol_value:  6.71 mkt_quantity:  2000
# latest_datetime: 2020-03-11
# latest_datetime: 2020-03-12
# latest_datetime: 2020-03-13
# latest_datetime: 2020-03-16
# latest_datetime: 2020-03-17
# latest_datetime: 2020-03-18
# latest_datetime: 2020-03-19
# latest_datetime: 2020-03-20
# latest_datetime: 2020-03-23
# latest_datetime: 2020-03-24
# latest_datetime: 2020-03-25
# latest_datetime: 2020-03-26
# Asset:  000069.SZ symbol_value:  6.48 mkt_quantity:  2000
# latest_datetime: 2020-03-27
# latest_datetime: 2020-03-30
# latest_datetime: 2020-03-31
# latest_datetime: 2020-04-01
# latest_datetime: 2020-04-02
# latest_datetime: 2020-04-03
# latest_datetime: 2020-04-03
# Creating summary stats...
# *****performance.py: 1. create_sharpe_ratio*****
# *****performance.py: 2. create_drawdowns*****
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:42: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:43: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# Creating equity curve...
#             000069.SZ       cash  commission      total   returns  \
# datetime
# 2020-03-24        0.0  1007227.2        1080  1007227.2  0.000000
# 2020-03-25        0.0  1007227.2        1080  1007227.2  0.000000
# 2020-03-26        0.0  1007227.2        1080  1007227.2  0.000000
# 2020-03-27    13060.0   994262.2        1085  1007322.2  0.000094
# 2020-03-30    12960.0   994262.2        1085  1007222.2 -0.000099
# 2020-03-31    12780.0   994262.2        1085  1007042.2 -0.000179
# 2020-04-01    12760.0   994262.2        1085  1007022.2 -0.000020
# 2020-04-02    12760.0   994262.2        1085  1007022.2  0.000000
# 2020-04-03    12800.0   994262.2        1085  1007062.2  0.000040
# 2020-04-03    12800.0   994262.2        1085  1007062.2  0.000000
#
#             equity_curve  drawdown
# datetime
# 2020-03-24      1.007227  0.000665
# 2020-03-25      1.007227  0.000665
# 2020-03-26      1.007227  0.000665
# 2020-03-27      1.007322  0.000570
# 2020-03-30      1.007222  0.000670
# 2020-03-31      1.007042  0.000850
# 2020-04-01      1.007022  0.000870
# 2020-04-02      1.007022  0.000870
# 2020-04-03      1.007062  0.000830
# 2020-04-03      1.007062  0.000830
# None
# Signals: 217
# Orders: 217
# Fills: 217

# %%
df_equity = pd.read_csv(ticker+"_performance"+".csv")
df_equity.drop_duplicates("datetime", inplace = True)
df_equity =df_equity[df_equity['datetime']>start_date_str]
df_equity.index = df_equity['datetime']
df_equity = df_equity[df_equity['total'].map(lambda x: str(x)!="nan")]
df_equity.columns = ['datetime', 'market_value', 'cash', 'commission', 'total', 'returns',
'equity_curve', 'drawdown']
df_equity_copy = df_equity.copy()
data = df_equity_copy
win_rate, mean_win_loss_ratio, bt_score, profits = performance(data)
print("TICKER: ", ticker)
print("BT_SCORE: ", bt_score)
ticker_performances[ticker] = bt_score
# Out:
# win %: 38.38383838383838
# PL Ratio: 2.0265864399522613
# bt_score: 0.16172004765844372
# TICKER:  000069.SZ
# BT_SCORE:  0.16172004765844372

# %%
df_equity.to_csv("df_equity_data_20200405.csv", index=False)

# %%
# Brad's version
len(profits)
# Out:
# 108

# %%
profits
# Out:
# [-451.5999999999767,
#  -444.4000000000233,
#  -147.59999999997672,
#  -176.40000000002328,
#  370.5999999999767,
#  792.8000000000466,
#  -207.0,
#  128.59999999997672,
#  -666.5999999999767,
#  48.40000000002328,
#  -462.4000000000233,
#  -382.20000000018626,
#  -520.8000000000466,
#  676.0,
#  -985.8000000002794,
#  -748.5999999996275,
#  -379.20000000006985,
#  425.20000000018626,
#  -682.4000000000233,
#  -366.0,
#  385.5999999998603,
#  -128.60000000032596,
#  -405.59999999962747,
#  227.39999999990687,
#  227.40000000002328,
#  280.0,
#  681.0,
#  -441.79999999993015,
#  -632.0,
#  -338.20000000006985,
#  577.4000000000233,
#  -614.8000000000466,
#  1769.6000000000931,
#  -459.2000000003027,
#  -407.4000000000233,
#  -338.4000000000233,
#  -113.59999999997672,
#  318.19999999995343,
#  1567.0,
#  -325.4000000000233,
#  -307.79999999993015,
#  -500.5999999999767,
#  -413.0,
#  -115.0,
#  -237.80000000004657,
#  463.0,
#  -605.8000000000466,
#  217.20000000006985,
#  1216.5999999999767,
#  -258.80000000004657,
#  -276.5999999999767,
#  2389.8000000002794,
#  -81.0,
#  2638.7999999996973,
#  4540.800000000396,
#  -1734.2000000003027,
#  -1192.2000000000698,
#  -852.0,
#  -493.7999999996973,
#  491.5999999999767,
#  -547.3999999999069,
#  -314.40000000037253,
#  -655.0,
#  760.4000000003725,
#  -242.8000000003958,
#  -224.79999999969732,
#  -744.5999999999767,
#  8.0,
#  -440.0,
#  660.2000000000698,
#  -336.0,
#  -408.40000000037253,
#  -118.59999999962747,
#  -154.8000000003958,
#  -10.0,
#  696.4000000000233,
#  62.40000000002328,
#  895.5999999999767,
#  -263.5999999999767,
#  1058.5999999999767,
#  2768.5999999999767,
#  -1199.800000000163,
#  484.4000000002561,
#  -119.80000000016298,
#  -797.199999999837,
#  3578.0,
#  -467.80000000004657,
#  -687.1999999999534,
#  -101.40000000002328,
#  -907.0,
#  -10.0,
#  -220.80000000004657,
#  -565.7999999999302,
#  -834.0,
#  564.7999999999302,
#  -431.4000000000233,
#  9.20000000006985,
#  -163.20000000006985,
#  1139.600000000326,
#  2308.4000000000233,
#  -130.0,
#  190.0,
#  350.0,
#  10.0,
#  -230.0,
#  -530.0,
#  1150.0,
#  -150.0]

# %%
# hansen's version
len(profits)
# Out:
# 99

# %%
profits
# Out:
# [-451.5999999999767,
#  -444.4000000000233,
#  -147.59999999997672,
#  -176.40000000002328,
#  370.5999999999767,
#  792.8000000000466,
#  -207.0,
#  128.59999999997672,
#  -666.5999999999767,
#  48.40000000002328,
#  -462.4000000000233,
#  -382.20000000018626,
#  -520.8000000000466,
#  676.0,
#  -985.8000000002794,
#  -1127.7999999996973,
#  425.20000000018626,
#  -682.4000000000233,
#  -366.0,
#  385.5999999998603,
#  -128.60000000032596,
#  -178.1999999997206,
#  227.40000000002328,
#  280.0,
#  681.0,
#  -441.79999999993015,
#  -632.0,
#  -338.20000000006985,
#  577.4000000000233,
#  -614.8000000000466,
#  1769.6000000000931,
#  -459.2000000003027,
#  -407.4000000000233,
#  -338.4000000000233,
#  -113.59999999997672,
#  318.19999999995343,
#  1567.0,
#  -325.4000000000233,
#  -808.3999999999069,
#  -413.0,
#  -115.0,
#  -237.80000000004657,
#  463.0,
#  -605.8000000000466,
#  217.20000000006985,
#  1216.5999999999767,
#  -258.80000000004657,
#  -276.5999999999767,
#  2389.8000000002794,
#  -81.0,
#  2638.7999999996973,
#  2806.600000000093,
#  -1192.2000000000698,
#  -852.0,
#  -493.7999999996973,
#  491.5999999999767,
#  -547.3999999999069,
#  -314.40000000037253,
#  -655.0,
#  760.4000000003725,
#  -242.8000000003958,
#  -224.79999999969732,
#  -744.5999999999767,
#  8.0,
#  -440.0,
#  660.2000000000698,
#  -744.4000000003725,
#  -273.4000000000233,
#  -10.0,
#  696.4000000000233,
#  62.40000000002328,
#  632.0,
#  1058.5999999999767,
#  2768.5999999999767,
#  -1199.800000000163,
#  484.4000000002561,
#  -119.80000000016298,
#  -797.199999999837,
#  3578.0,
#  -467.80000000004657,
#  -687.1999999999534,
#  -101.40000000002328,
#  -907.0,
#  -10.0,
#  -220.80000000004657,
#  -565.7999999999302,
#  -834.0,
#  564.7999999999302,
#  -431.4000000000233,
#  -154.0,
#  1139.600000000326,
#  2308.4000000000233,
#  60.0,
#  350.0,
#  10.0,
#  -230.0,
#  -530.0,
#  1150.0,
#  -150.0]

# %%
df_equity_copy.head(30)
# Out:
#               datetime  market_value       cash  commission      total  \
# datetime
# 2010-01-04  2010-01-04           0.0  1000000.0           0  1000000.0
# 2010-01-05  2010-01-05           0.0  1000000.0           0  1000000.0
# 2010-01-06  2010-01-06           0.0  1000000.0           0  1000000.0
# 2010-01-07  2010-01-07           0.0  1000000.0           0  1000000.0
# 2010-01-08  2010-01-08           0.0  1000000.0           0  1000000.0
# 2010-01-11  2010-01-11           0.0  1000000.0           0  1000000.0
# 2010-01-12  2010-01-12           0.0  1000000.0           0  1000000.0
# 2010-01-13  2010-01-13           0.0  1000000.0           0  1000000.0
# 2010-01-14  2010-01-14           0.0  1000000.0           0  1000000.0
# 2010-01-15  2010-01-15           0.0  1000000.0           0  1000000.0
# 2010-01-18  2010-01-18           0.0  1000000.0           0  1000000.0
# 2010-01-19  2010-01-19           0.0  1000000.0           0  1000000.0
# 2010-01-20  2010-01-20           0.0  1000000.0           0  1000000.0
# 2010-01-22  2010-01-22           0.0  1000000.0           0  1000000.0
# 2010-01-25  2010-01-25           0.0  1000000.0           0  1000000.0
# 2010-01-26  2010-01-26           0.0  1000000.0           0  1000000.0
# 2010-01-27  2010-01-27           0.0  1000000.0           0  1000000.0
# 2010-01-28  2010-01-28           0.0  1000000.0           0  1000000.0
# 2010-01-29  2010-01-29           0.0  1000000.0           0  1000000.0
# 2010-02-01  2010-02-01       11431.8   988918.0           5  1000349.8
# 2010-02-02  2010-02-02       11236.2   988918.0           5  1000154.2
# 2010-02-03  2010-02-03       11649.0   988918.0           5  1000567.0
# 2010-02-04  2010-02-04       11583.8   988918.0           5  1000501.8
# 2010-02-05  2010-02-05       11113.2   988918.0           5  1000031.2
# 2010-02-08  2010-02-08       10809.2   988918.0           5   999727.2
# 2010-02-09  2010-02-09       10635.4   988918.0           5   999553.4
# 2010-02-10  2010-02-10           0.0   999548.4          10   999548.4
# 2010-02-11  2010-02-11           0.0   999548.4          10   999548.4
# 2010-02-12  2010-02-12           0.0   999548.4          10   999548.4
# 2010-02-22  2010-02-22           0.0   999548.4          10   999548.4
#
#              returns  equity_curve  drawdown  daily_PL
# datetime
# 2010-01-04  0.000000      1.000000  0.000000       NaN
# 2010-01-05  0.000000      1.000000  0.000000       0.0
# 2010-01-06  0.000000      1.000000  0.000000       0.0
# 2010-01-07  0.000000      1.000000  0.000000       0.0
# 2010-01-08  0.000000      1.000000  0.000000       0.0
# 2010-01-11  0.000000      1.000000  0.000000       0.0
# 2010-01-12  0.000000      1.000000  0.000000       0.0
# 2010-01-13  0.000000      1.000000  0.000000       0.0
# 2010-01-14  0.000000      1.000000  0.000000       0.0
# 2010-01-15  0.000000      1.000000  0.000000       0.0
# 2010-01-18  0.000000      1.000000  0.000000       0.0
# 2010-01-19  0.000000      1.000000  0.000000       0.0
# 2010-01-20  0.000000      1.000000  0.000000       0.0
# 2010-01-22  0.000000      1.000000  0.000000       0.0
# 2010-01-25  0.000000      1.000000  0.000000       0.0
# 2010-01-26  0.000000      1.000000  0.000000       0.0
# 2010-01-27  0.000000      1.000000  0.000000       0.0
# 2010-01-28  0.000000      1.000000  0.000000       0.0
# 2010-01-29  0.000000      1.000000  0.000000       0.0
# 2010-02-01  0.000350      1.000350  0.000000     349.8
# 2010-02-02 -0.000196      1.000154  0.000196    -195.6
# 2010-02-03  0.000413      1.000567  0.000000     412.8
# 2010-02-04 -0.000065      1.000502  0.000065     -65.2
# 2010-02-05 -0.000470      1.000031  0.000536    -470.6
# 2010-02-08 -0.000304      0.999727  0.000840    -304.0
# 2010-02-09 -0.000174      0.999553  0.001014    -173.8
# 2010-02-10 -0.000005      0.999548  0.001019      -5.0
# 2010-02-11  0.000000      0.999548  0.001019       0.0
# 2010-02-12  0.000000      0.999548  0.001019       0.0
# 2010-02-22  0.000000      0.999548  0.001019       0.0

# %%
df_equity_copy['equity_curve'].plot(figsize = (16,5))

# %%
len(profits)
# Out:
# 108

# %%
96013.4560+3991.544000000009
# Out:
# 100005.00000000001

# %%
win_rate, mean_win_loss_ratio, bt_score, profits = performance(df_equity_copy)
# 问题：有commissions的反而分数高
# Out:
# Position is empty:  2010-01-04
# Position is empty:  2010-01-05
# Position is empty:  2010-01-06
# Position is empty:  2010-01-07
# Position is empty:  2010-01-08
# Position is empty:  2010-01-11
# Position is empty:  2010-01-12
# Position is empty:  2010-01-13
# Position is empty:  2010-01-14
# Position is empty:  2010-01-15
# Position is empty:  2010-01-18
# Position is empty:  2010-01-19
# Position is empty:  2010-01-20
# Position is empty:  2010-01-22
# Position is empty:  2010-01-25
# Position is empty:  2010-01-26
# Position is empty:  2010-01-27
# Position is empty:  2010-01-28
# Position is empty:  2010-01-29
# -------------------
# Opened the position:  2010-02-01
# Holding the position:  2010-02-02
# Holding the position:  2010-02-03
# Holding the position:  2010-02-04
# Holding the position:  2010-02-05
# Holding the position:  2010-02-08
# Holding the position:  2010-02-09
# Closed the posotion:  2010-02-10
# This trade's pnl: -3991.544000000009
# -------------------
# Position is empty:  2010-02-10
# Position is empty:  2010-02-11
# Position is empty:  2010-02-12
# Position is empty:  2010-02-22
# Position is empty:  2010-02-23
# Position is empty:  2010-02-24
# Position is empty:  2010-02-25
# Position is empty:  2010-02-26
# -------------------
# Opened the position:  2010-03-01
# Holding the position:  2010-03-02
# Holding the position:  2010-03-03
# Holding the position:  2010-03-04
# Closed the posotion:  2010-03-05
# This trade's pnl: -3913.7311999999947
# -------------------
# Position is empty:  2010-03-05
# Position is empty:  2010-03-08
# Position is empty:  2010-03-09
# Position is empty:  2010-03-10
# Position is empty:  2010-03-11
# -------------------
# Opened the position:  2010-03-12
# Closed the posotion:  2010-03-15
# This trade's pnl: -1263.6271999999735
# -------------------
# Position is empty:  2010-03-15
# Position is empty:  2010-03-16
# Position is empty:  2010-03-17
# -------------------
# Opened the position:  2010-03-18
# Holding the position:  2010-03-19
# Holding the position:  2010-03-22
# Holding the position:  2010-03-23
# Holding the position:  2010-03-24
# Holding the position:  2010-03-25
# Holding the position:  2010-03-26
# Holding the position:  2010-03-29
# Holding the position:  2010-03-30
# Holding the position:  2010-03-31
# Holding the position:  2010-04-01
# Holding the position:  2010-04-02
# Holding the position:  2010-04-06
# Holding the position:  2010-04-07
# Holding the position:  2010-04-08
# Closed the posotion:  2010-04-09
# This trade's pnl: -1500.3536000000022
# -------------------
# Position is empty:  2010-04-09
# Position is empty:  2010-04-12
# Position is empty:  2010-04-13
# Position is empty:  2010-04-14
# Position is empty:  2010-04-15
# Position is empty:  2010-04-16
# Position is empty:  2010-04-19
# Position is empty:  2010-04-20
# Position is empty:  2010-04-21
# Position is empty:  2010-04-22
# Position is empty:  2010-04-23
# Position is empty:  2010-04-26
# Position is empty:  2010-04-27
# Position is empty:  2010-04-28
# Position is empty:  2010-04-29
# Position is empty:  2010-04-30
# Position is empty:  2010-05-04
# Position is empty:  2010-05-05
# Position is empty:  2010-05-06
# Position is empty:  2010-05-07
# Position is empty:  2010-05-10
# -------------------
# Opened the position:  2010-05-11
# Holding the position:  2010-05-12
# Holding the position:  2010-05-13
# Holding the position:  2010-05-17
# Holding the position:  2010-05-18
# Holding the position:  2010-05-19
# Holding the position:  2010-05-20
# Holding the position:  2010-05-21
# Holding the position:  2010-05-24
# Holding the position:  2010-05-25
# Holding the position:  2010-05-26
# Holding the position:  2010-05-27
# Holding the position:  2010-05-28
# Holding the position:  2010-05-31
# Holding the position:  2010-06-01
# Holding the position:  2010-06-02
# Holding the position:  2010-06-03
# Holding the position:  2010-06-04
# Holding the position:  2010-06-07
# Holding the position:  2010-06-08
# Holding the position:  2010-06-09
# Holding the position:  2010-06-10
# Holding the position:  2010-06-11
# Holding the position:  2010-06-17
# Holding the position:  2010-06-18
# Holding the position:  2010-06-21
# Holding the position:  2010-06-22
# Holding the position:  2010-06-23
# Holding the position:  2010-06-24
# Holding the position:  2010-06-25
# Holding the position:  2010-06-28
# Holding the position:  2010-06-29
# Closed the posotion:  2010-06-30
# This trade's pnl: 4461.341000000015
# -------------------
# Position is empty:  2010-06-30
# Position is empty:  2010-07-01
# Position is empty:  2010-07-02
# Position is empty:  2010-07-05
# Position is empty:  2010-07-06
# Position is empty:  2010-07-07
# Position is empty:  2010-07-08
# Position is empty:  2010-07-09
# Position is empty:  2010-07-12
# Position is empty:  2010-07-13
# -------------------
# Opened the position:  2010-07-14
# Holding the position:  2010-07-15
# Holding the position:  2010-07-16
# Holding the position:  2010-07-19
# Holding the position:  2010-07-20
# Holding the position:  2010-07-21
# Holding the position:  2010-07-22
# Holding the position:  2010-07-23
# Holding the position:  2010-07-26
# Holding the position:  2010-07-27
# Holding the position:  2010-07-28
# Holding the position:  2010-07-29
# Holding the position:  2010-07-30
# Holding the position:  2010-08-02
# Holding the position:  2010-08-03
# Holding the position:  2010-08-04
# Closed the posotion:  2010-08-05
# This trade's pnl: 8976.324999999997
# -------------------
# Position is empty:  2010-08-05
# Position is empty:  2010-08-06
# Position is empty:  2010-08-09
# Position is empty:  2010-08-10
# Position is empty:  2010-08-11
# Position is empty:  2010-08-12
# Position is empty:  2010-08-13
# Position is empty:  2010-08-16
# Position is empty:  2010-08-17
# Position is empty:  2010-08-18
# -------------------
# Opened the position:  2010-08-19
# Holding the position:  2010-08-20
# Closed the posotion:  2010-08-23
# This trade's pnl: -1962.7859999999928
# -------------------
# Position is empty:  2010-08-23
# Position is empty:  2010-08-24
# Position is empty:  2010-08-25
# Position is empty:  2010-08-26
# Position is empty:  2010-08-27
# Position is empty:  2010-08-30
# Position is empty:  2010-08-31
# Position is empty:  2010-09-01
# Position is empty:  2010-09-02
# Position is empty:  2010-09-03
# Position is empty:  2010-09-06
# Position is empty:  2010-09-07
# Position is empty:  2010-09-08
# Position is empty:  2010-09-09
# Position is empty:  2010-09-10
# Position is empty:  2010-09-13
# Position is empty:  2010-09-14
# Position is empty:  2010-09-15
# Position is empty:  2010-09-16
# Position is empty:  2010-09-17
# Position is empty:  2010-09-20
# Position is empty:  2010-09-21
# Position is empty:  2010-09-27
# Position is empty:  2010-09-28
# Position is empty:  2010-09-29
# Position is empty:  2010-09-30
# -------------------
# Opened the position:  2010-10-08
# Holding the position:  2010-10-11
# Holding the position:  2010-10-12
# Holding the position:  2010-10-13
# Holding the position:  2010-10-14
# Holding the position:  2010-10-15
# Holding the position:  2010-10-18
# Holding the position:  2010-10-19
# Holding the position:  2010-10-20
# Holding the position:  2010-10-21
# Holding the position:  2010-10-22
# Closed the posotion:  2010-10-25
# This trade's pnl: 1491.8106999999582
# -------------------
# Position is empty:  2010-10-25
# Position is empty:  2010-10-26
# Position is empty:  2010-10-27
# Position is empty:  2010-10-28
# Position is empty:  2010-10-29
# Position is empty:  2010-11-01
# Position is empty:  2010-11-02
# Position is empty:  2010-11-03
# Position is empty:  2010-11-04
# Position is empty:  2010-11-05
# Position is empty:  2010-11-08
# -------------------
# Opened the position:  2010-11-09
# Holding the position:  2010-11-10
# Closed the posotion:  2010-11-11
# This trade's pnl: -6487.940100000022
# -------------------
# Position is empty:  2010-11-11
# Position is empty:  2010-11-12
# Position is empty:  2010-11-15
# Position is empty:  2010-11-16
# Position is empty:  2010-11-17
# Position is empty:  2010-11-18
# Position is empty:  2010-11-19
# Position is empty:  2010-11-22
# Position is empty:  2010-11-23
# Position is empty:  2010-11-24
# Position is empty:  2010-11-25
# Position is empty:  2010-11-26
# Position is empty:  2010-11-29
# Position is empty:  2010-11-30
# Position is empty:  2010-12-01
# Position is empty:  2010-12-02
# Position is empty:  2010-12-03
# -------------------
# Opened the position:  2010-12-06
# Holding the position:  2010-12-07
# Holding the position:  2010-12-08
# Holding the position:  2010-12-09
# Holding the position:  2010-12-10
# Holding the position:  2010-12-14
# Holding the position:  2010-12-15
# Holding the position:  2010-12-16
# Holding the position:  2010-12-17
# Holding the position:  2010-12-20
# Holding the position:  2010-12-21
# Holding the position:  2010-12-22
# Holding the position:  2010-12-23
# Holding the position:  2010-12-24
# Holding the position:  2010-12-27
# Holding the position:  2010-12-28
# Holding the position:  2010-12-29
# Holding the position:  2010-12-30
# Closed the posotion:  2010-12-31
# This trade's pnl: 663.066799999986
# -------------------
# Position is empty:  2010-12-31
# Position is empty:  2011-01-04
# Position is empty:  2011-01-05
# Position is empty:  2011-01-06
# Position is empty:  2011-01-07
# -------------------
# Opened the position:  2011-01-10
# Holding the position:  2011-01-11
# Holding the position:  2011-01-12
# Holding the position:  2011-01-13
# Holding the position:  2011-01-14
# Holding the position:  2011-01-17
# Closed the posotion:  2011-01-18
# This trade's pnl: -4811.071400000001
# -------------------
# Position is empty:  2011-01-18
# Position is empty:  2011-01-19
# Position is empty:  2011-01-20
# Position is empty:  2011-01-21
# Position is empty:  2011-01-24
# Position is empty:  2011-01-25
# Position is empty:  2011-01-26
# -------------------
# Opened the position:  2011-01-27
# Closed the posotion:  2011-01-28
# This trade's pnl: -4005.5917000000045
# -------------------
# Position is empty:  2011-01-28
# Position is empty:  2011-01-31
# Position is empty:  2011-02-01
# Position is empty:  2011-02-09
# Position is empty:  2011-02-10
# Position is empty:  2011-02-11
# Position is empty:  2011-02-14
# -------------------
# Opened the position:  2011-02-15
# Holding the position:  2011-02-16
# Holding the position:  2011-02-17
# Holding the position:  2011-02-18
# Holding the position:  2011-02-21
# Holding the position:  2011-02-22
# Holding the position:  2011-02-23
# Holding the position:  2011-02-24
# Holding the position:  2011-02-25
# Closed the posotion:  2011-02-28
# This trade's pnl: -5381.425400000022
# -------------------
# Position is empty:  2011-02-28
# Position is empty:  2011-03-01
# -------------------
# Opened the position:  2011-03-02
# Holding the position:  2011-03-03
# Holding the position:  2011-03-04
# Holding the position:  2011-03-07
# Holding the position:  2011-03-08
# Holding the position:  2011-03-09
# Holding the position:  2011-03-10
# Holding the position:  2011-03-11
# Holding the position:  2011-03-14
# Holding the position:  2011-03-15
# Holding the position:  2011-03-16
# Holding the position:  2011-03-17
# Holding the position:  2011-03-18
# Holding the position:  2011-03-21
# Holding the position:  2011-03-22
# Holding the position:  2011-03-23
# Holding the position:  2011-03-24
# Holding the position:  2011-03-28
# Holding the position:  2011-03-29
# Holding the position:  2011-03-30
# Closed the posotion:  2011-03-31
# This trade's pnl: 6686.2439999999915
# -------------------
# Position is empty:  2011-03-31
# Position is empty:  2011-04-01
# Position is empty:  2011-04-06
# Position is empty:  2011-04-07
# Position is empty:  2011-04-08
# Position is empty:  2011-04-11
# Position is empty:  2011-04-12
# Position is empty:  2011-04-13
# Position is empty:  2011-04-14
# Position is empty:  2011-04-15
# Position is empty:  2011-04-18
# -------------------
# Opened the position:  2011-04-19
# Holding the position:  2011-04-20
# Holding the position:  2011-04-21
# Holding the position:  2011-04-22
# Holding the position:  2011-04-25
# Holding the position:  2011-04-26
# Closed the posotion:  2011-04-27
# This trade's pnl: -8235.873000000007
# -------------------
# Position is empty:  2011-04-27
# Position is empty:  2011-04-28
# Position is empty:  2011-04-29
# Position is empty:  2011-05-03
# Position is empty:  2011-05-04
# Position is empty:  2011-05-05
# Position is empty:  2011-05-06
# Position is empty:  2011-05-09
# Position is empty:  2011-05-10
# Position is empty:  2011-05-11
# Position is empty:  2011-05-12
# Position is empty:  2011-05-13
# Position is empty:  2011-05-16
# Position is empty:  2011-05-17
# -------------------
# Opened the position:  2011-05-18
# Holding the position:  2011-05-19
# Holding the position:  2011-05-20
# Holding the position:  2011-05-23
# Closed the posotion:  2011-05-24
# This trade's pnl: -6868.809800000003
# -------------------
# Position is empty:  2011-05-24
# -------------------
# Opened the position:  2011-05-25
# Closed the posotion:  2011-05-26
# This trade's pnl: -3684.0779999999795
# -------------------
# Position is empty:  2011-05-26
# Position is empty:  2011-05-27
# Position is empty:  2011-05-30
# Position is empty:  2011-05-31
# Position is empty:  2011-06-01
# Position is empty:  2011-06-02
# Position is empty:  2011-06-03
# Position is empty:  2011-06-07
# Position is empty:  2011-06-08
# -------------------
# Opened the position:  2011-06-09
# Holding the position:  2011-06-10
# Holding the position:  2011-06-13
# Holding the position:  2011-06-14
# Holding the position:  2011-06-15
# Holding the position:  2011-06-16
# Holding the position:  2011-06-17
# Holding the position:  2011-06-20
# Holding the position:  2011-06-21
# Holding the position:  2011-06-22
# Holding the position:  2011-06-23
# Holding the position:  2011-06-24
# Holding the position:  2011-06-27
# Holding the position:  2011-06-28
# Holding the position:  2011-06-29
# Holding the position:  2011-06-30
# Holding the position:  2011-07-01
# Holding the position:  2011-07-04
# Holding the position:  2011-07-05
# Holding the position:  2011-07-06
# Holding the position:  2011-07-07
# Holding the position:  2011-07-08
# Holding the position:  2011-07-11
# Holding the position:  2011-07-12
# Holding the position:  2011-07-13
# Holding the position:  2011-07-14
# Holding the position:  2011-07-15
# Closed the posotion:  2011-07-18
# This trade's pnl: 4314.577600000004
# -------------------
# Position is empty:  2011-07-18
# Position is empty:  2011-07-19
# Position is empty:  2011-07-20
# Position is empty:  2011-07-21
# Position is empty:  2011-07-22
# Position is empty:  2011-07-25
# Position is empty:  2011-07-26
# Position is empty:  2011-07-27
# Position is empty:  2011-07-28
# Position is empty:  2011-07-29
# Position is empty:  2011-08-01
# Position is empty:  2011-08-02
# Position is empty:  2011-08-03
# Position is empty:  2011-08-04
# Position is empty:  2011-08-05
# Position is empty:  2011-08-08
# Position is empty:  2011-08-09
# Position is empty:  2011-08-10
# Position is empty:  2011-08-11
# -------------------
# Opened the position:  2011-08-12
# Holding the position:  2011-08-15
# Holding the position:  2011-08-16
# Holding the position:  2011-08-17
# Holding the position:  2011-08-18
# Holding the position:  2011-08-19
# Closed the posotion:  2011-08-22
# This trade's pnl: -6434.825000000026
# -------------------
# Position is empty:  2011-08-22
# Position is empty:  2011-08-23
# Position is empty:  2011-08-24
# Position is empty:  2011-08-25
# Position is empty:  2011-08-26
# Position is empty:  2011-08-29
# Position is empty:  2011-08-30
# Position is empty:  2011-08-31
# Position is empty:  2011-09-01
# Position is empty:  2011-09-02
# Position is empty:  2011-09-05
# Position is empty:  2011-09-06
# Position is empty:  2011-09-07
# Position is empty:  2011-09-08
# Position is empty:  2011-09-13
# Position is empty:  2011-09-14
# Position is empty:  2011-09-15
# Position is empty:  2011-09-16
# -------------------
# Opened the position:  2011-09-19
# Holding the position:  2011-09-20
# Holding the position:  2011-09-21
# Holding the position:  2011-09-22
# Closed the posotion:  2011-09-23
# This trade's pnl: -3668.0619999999835
# -------------------
# Position is empty:  2011-09-23
# Position is empty:  2011-09-26
# Position is empty:  2011-09-27
# Position is empty:  2011-09-28
# Position is empty:  2011-09-29
# Position is empty:  2011-09-30
# Position is empty:  2011-10-10
# Position is empty:  2011-10-11
# Position is empty:  2011-10-12
# Position is empty:  2011-10-13
# Position is empty:  2011-10-14
# Position is empty:  2011-10-17
# Position is empty:  2011-10-18
# Position is empty:  2011-10-19
# Position is empty:  2011-10-20
# Position is empty:  2011-10-21
# Position is empty:  2011-10-24
# Position is empty:  2011-10-25
# -------------------
# Opened the position:  2011-10-26
# Holding the position:  2011-10-27
# Holding the position:  2011-10-28
# Holding the position:  2011-10-31
# Holding the position:  2011-11-01
# Holding the position:  2011-11-02
# Holding the position:  2011-11-03
# Holding the position:  2011-11-04
# Holding the position:  2011-11-07
# Holding the position:  2011-11-08
# Holding the position:  2011-11-09
# Holding the position:  2011-11-10
# Holding the position:  2011-11-11
# Closed the posotion:  2011-11-14
# This trade's pnl: 4610.26739999999
# -------------------
# Position is empty:  2011-11-14
# Position is empty:  2011-11-15
# Position is empty:  2011-11-16
# Position is empty:  2011-11-17
# Position is empty:  2011-11-18
# Position is empty:  2011-11-21
# Position is empty:  2011-11-22
# Position is empty:  2011-11-23
# Position is empty:  2011-11-24
# Position is empty:  2011-11-25
# Position is empty:  2011-11-28
# Position is empty:  2011-11-29
# Position is empty:  2011-11-30
# Position is empty:  2011-12-01
# -------------------
# Opened the position:  2011-12-02
# Holding the position:  2011-12-05
# Holding the position:  2011-12-06
# Holding the position:  2011-12-07
# Holding the position:  2011-12-08
# Holding the position:  2011-12-09
# Holding the position:  2011-12-12
# Holding the position:  2011-12-13
# Holding the position:  2011-12-14
# Holding the position:  2011-12-15
# Holding the position:  2011-12-16
# Holding the position:  2011-12-19
# Holding the position:  2011-12-20
# Holding the position:  2011-12-21
# Closed the posotion:  2011-12-22
# This trade's pnl: -1288.0148000000045
# -------------------
# Position is empty:  2011-12-22
# Position is empty:  2011-12-23
# Position is empty:  2011-12-26
# Position is empty:  2011-12-27
# Position is empty:  2011-12-28
# Position is empty:  2011-12-29
# Position is empty:  2011-12-30
# Position is empty:  2012-01-04
# Position is empty:  2012-01-05
# Position is empty:  2012-01-06
# Position is empty:  2012-01-09
# Position is empty:  2012-01-10
# Position is empty:  2012-01-11
# Position is empty:  2012-01-12
# -------------------
# Opened the position:  2012-01-13
# Holding the position:  2012-01-16
# Closed the posotion:  2012-01-17
# This trade's pnl: -4260.271399999998
# -------------------
# Position is empty:  2012-01-17
# -------------------
# Opened the position:  2012-01-18
# Holding the position:  2012-01-19
# Holding the position:  2012-01-20
# Holding the position:  2012-01-30
# Holding the position:  2012-01-31
# Holding the position:  2012-02-01
# Holding the position:  2012-02-02
# Holding the position:  2012-02-03
# Holding the position:  2012-02-06
# Holding the position:  2012-02-07
# Holding the position:  2012-02-08
# Holding the position:  2012-02-09
# Holding the position:  2012-02-10
# Closed the posotion:  2012-02-13
# This trade's pnl: 2552.1540999999997
# -------------------
# Position is empty:  2012-02-13
# Position is empty:  2012-02-14
# Position is empty:  2012-02-15
# Position is empty:  2012-02-16
# Position is empty:  2012-02-17
# Position is empty:  2012-02-20
# Position is empty:  2012-02-21
# Position is empty:  2012-02-22
# Position is empty:  2012-02-23
# -------------------
# Opened the position:  2012-02-24
# Holding the position:  2012-02-27
# Holding the position:  2012-02-28
# Holding the position:  2012-02-29
# Holding the position:  2012-03-01
# Holding the position:  2012-03-02
# Holding the position:  2012-03-05
# Holding the position:  2012-03-06
# Holding the position:  2012-03-07
# Holding the position:  2012-03-08
# Holding the position:  2012-03-09
# Holding the position:  2012-03-12
# Holding the position:  2012-03-13
# Closed the posotion:  2012-03-14
# This trade's pnl: 2424.4329
# -------------------
# Position is empty:  2012-03-14
# Position is empty:  2012-03-15
# Position is empty:  2012-03-16
# Position is empty:  2012-03-19
# Position is empty:  2012-03-20
# Position is empty:  2012-03-21
# Position is empty:  2012-03-22
# Position is empty:  2012-03-23
# Position is empty:  2012-03-26
# Position is empty:  2012-03-27
# Position is empty:  2012-03-28
# Position is empty:  2012-03-29
# Position is empty:  2012-03-30
# Position is empty:  2012-04-05
# Position is empty:  2012-04-06
# -------------------
# Opened the position:  2012-04-09
# Holding the position:  2012-04-10
# Holding the position:  2012-04-11
# Holding the position:  2012-04-12
# Holding the position:  2012-04-13
# Holding the position:  2012-04-16
# Holding the position:  2012-04-17
# Holding the position:  2012-04-18
# Holding the position:  2012-04-19
# Holding the position:  2012-04-20
# Holding the position:  2012-04-23
# Holding the position:  2012-04-24
# Holding the position:  2012-04-25
# Holding the position:  2012-04-27
# Holding the position:  2012-05-02
# Holding the position:  2012-05-03
# Holding the position:  2012-05-04
# Holding the position:  2012-05-07
# Holding the position:  2012-05-08
# Holding the position:  2012-05-09
# Holding the position:  2012-05-10
# Closed the posotion:  2012-05-11
# This trade's pnl: 3028.2550000000338
# -------------------
# Position is empty:  2012-05-11
# Position is empty:  2012-05-14
# Position is empty:  2012-05-15
# Position is empty:  2012-05-16
# Position is empty:  2012-05-17
# Position is empty:  2012-05-18
# Position is empty:  2012-05-21
# Position is empty:  2012-05-22
# Position is empty:  2012-05-23
# Position is empty:  2012-05-24
# Position is empty:  2012-05-25
# Position is empty:  2012-05-28
# Position is empty:  2012-05-29
# -------------------
# Opened the position:  2012-05-30
# Holding the position:  2012-05-31
# Holding the position:  2012-06-01
# Holding the position:  2012-06-04
# Holding the position:  2012-06-05
# Holding the position:  2012-06-06
# Holding the position:  2012-06-07
# Holding the position:  2012-06-08
# Holding the position:  2012-06-11
# Holding the position:  2012-06-12
# Holding the position:  2012-06-13
# Holding the position:  2012-06-14
# Holding the position:  2012-06-15
# Holding the position:  2012-06-18
# Holding the position:  2012-06-19
# Holding the position:  2012-06-20
# Holding the position:  2012-06-21
# Holding the position:  2012-06-25
# Closed the posotion:  2012-06-26
# This trade's pnl: 6785.111499999999
# -------------------
# Position is empty:  2012-06-26
# Position is empty:  2012-06-27
# Position is empty:  2012-06-28
# Position is empty:  2012-06-29
# Position is empty:  2012-07-02
# Position is empty:  2012-07-03
# Position is empty:  2012-07-04
# -------------------
# Opened the position:  2012-07-05
# Holding the position:  2012-07-06
# Holding the position:  2012-07-09
# Holding the position:  2012-07-10
# Holding the position:  2012-07-11
# Holding the position:  2012-07-12
# Holding the position:  2012-07-13
# Holding the position:  2012-07-16
# Holding the position:  2012-07-17
# Holding the position:  2012-07-18
# Closed the posotion:  2012-07-19
# This trade's pnl: -3696.674100000004
# -------------------
# Position is empty:  2012-07-19
# Position is empty:  2012-07-20
# Position is empty:  2012-07-23
# Position is empty:  2012-07-24
# Position is empty:  2012-07-25
# Position is empty:  2012-07-26
# Position is empty:  2012-07-27
# Position is empty:  2012-07-30
# Position is empty:  2012-07-31
# Position is empty:  2012-08-01
# Position is empty:  2012-08-02
# Position is empty:  2012-08-03
# Position is empty:  2012-08-06
# Position is empty:  2012-08-07
# Position is empty:  2012-08-08
# Position is empty:  2012-08-09
# Position is empty:  2012-08-10
# -------------------
# Opened the position:  2012-08-13
# Holding the position:  2012-08-14
# Holding the position:  2012-08-15
# Holding the position:  2012-08-16
# Holding the position:  2012-08-17
# Holding the position:  2012-08-20
# Closed the posotion:  2012-08-21
# This trade's pnl: -6035.289999999994
# -------------------
# Position is empty:  2012-08-21
# Position is empty:  2012-08-22
# Position is empty:  2012-08-23
# Position is empty:  2012-08-24
# Position is empty:  2012-08-27
# Position is empty:  2012-08-28
# Position is empty:  2012-08-29
# Position is empty:  2012-08-30
# Position is empty:  2012-08-31
# Position is empty:  2012-09-03
# -------------------
# Opened the position:  2012-09-04
# Holding the position:  2012-09-05
# Holding the position:  2012-09-06
# Holding the position:  2012-09-07
# Holding the position:  2012-09-10
# Holding the position:  2012-09-11
# Holding the position:  2012-09-12
# Holding the position:  2012-09-13
# Holding the position:  2012-09-14
# Holding the position:  2012-09-17
# Holding the position:  2012-09-18
# Closed the posotion:  2012-09-19
# This trade's pnl: -3343.450400000016
# -------------------
# Position is empty:  2012-09-19
# Position is empty:  2012-09-20
# Position is empty:  2012-09-21
# Position is empty:  2012-09-24
# Position is empty:  2012-09-25
# Position is empty:  2012-09-26
# Position is empty:  2012-09-27
# Position is empty:  2012-09-28
# Position is empty:  2012-10-08
# Position is empty:  2012-10-09
# Position is empty:  2012-10-10
# -------------------
# Opened the position:  2012-10-11
# Holding the position:  2012-10-12
# Holding the position:  2012-10-15
# Holding the position:  2012-10-16
# Holding the position:  2012-10-17
# Holding the position:  2012-10-18
# Holding the position:  2012-10-19
# Holding the position:  2012-10-22
# Holding the position:  2012-10-23
# Holding the position:  2012-10-24
# Holding the position:  2012-10-25
# Holding the position:  2012-10-26
# Holding the position:  2012-10-29
# Holding the position:  2012-10-30
# Holding the position:  2012-10-31
# Holding the position:  2012-11-01
# Holding the position:  2012-11-02
# Holding the position:  2012-11-05
# Holding the position:  2012-11-06
# Holding the position:  2012-11-07
# Holding the position:  2012-11-08
# Closed the posotion:  2012-11-09
# This trade's pnl: 6044.632599999997
# -------------------
# Position is empty:  2012-11-09
# Position is empty:  2012-11-12
# Position is empty:  2012-11-13
# Position is empty:  2012-11-14
# Position is empty:  2012-11-15
# Position is empty:  2012-11-16
# Position is empty:  2012-11-19
# Position is empty:  2012-11-20
# Position is empty:  2012-11-21
# Position is empty:  2012-11-22
# Position is empty:  2012-11-23
# -------------------
# Opened the position:  2012-11-26
# Holding the position:  2012-11-27
# Holding the position:  2012-11-28
# Holding the position:  2012-11-29
# Closed the posotion:  2012-11-30
# This trade's pnl: -5868.535999999993
# -------------------
# Position is empty:  2012-11-30
# Position is empty:  2012-12-03
# Position is empty:  2012-12-04
# Position is empty:  2012-12-05
# -------------------
# Opened the position:  2012-12-06
# Holding the position:  2012-12-07
# Holding the position:  2012-12-10
# Holding the position:  2012-12-11
# Holding the position:  2012-12-12
# Holding the position:  2012-12-13
# Holding the position:  2012-12-14
# Holding the position:  2012-12-17
# Holding the position:  2012-12-18
# Holding the position:  2012-12-19
# Holding the position:  2012-12-20
# Holding the position:  2012-12-21
# Holding the position:  2012-12-24
# Holding the position:  2012-12-25
# Holding the position:  2012-12-26
# Holding the position:  2012-12-27
# Holding the position:  2012-12-28
# Holding the position:  2012-12-31
# Holding the position:  2013-01-04
# Holding the position:  2013-01-07
# Holding the position:  2013-01-08
# Holding the position:  2013-01-09
# Holding the position:  2013-01-10
# Holding the position:  2013-01-11
# Holding the position:  2013-01-14
# Holding the position:  2013-01-15
# Holding the position:  2013-01-16
# Closed the posotion:  2013-01-17
# This trade's pnl: 16908.318400000004
# -------------------
# Position is empty:  2013-01-17
# Position is empty:  2013-01-18
# Position is empty:  2013-01-21
# Position is empty:  2013-01-22
# Position is empty:  2013-01-23
# Position is empty:  2013-01-24
# Position is empty:  2013-01-25
# Position is empty:  2013-01-28
# Position is empty:  2013-01-29
# Position is empty:  2013-01-30
# Position is empty:  2013-01-31
# Position is empty:  2013-02-01
# Position is empty:  2013-02-04
# Position is empty:  2013-02-05
# Position is empty:  2013-02-06
# Position is empty:  2013-02-07
# -------------------
# Opened the position:  2013-02-08
# Holding the position:  2013-02-18
# Holding the position:  2013-02-19
# Closed the posotion:  2013-02-20
# This trade's pnl: -3778.5046
# -------------------
# Position is empty:  2013-02-20
# Position is empty:  2013-02-21
# Position is empty:  2013-02-22
# Position is empty:  2013-02-25
# Position is empty:  2013-02-26
# Position is empty:  2013-02-27
# Position is empty:  2013-02-28
# Position is empty:  2013-03-01
# Position is empty:  2013-03-04
# Position is empty:  2013-03-05
# Position is empty:  2013-03-06
# Position is empty:  2013-03-07
# Position is empty:  2013-03-08
# Position is empty:  2013-03-11
# Position is empty:  2013-03-12
# Position is empty:  2013-03-13
# Position is empty:  2013-03-14
# Position is empty:  2013-03-15
# Position is empty:  2013-03-18
# Position is empty:  2013-03-19
# -------------------
# Opened the position:  2013-03-20
# Holding the position:  2013-03-21
# Holding the position:  2013-03-22
# Holding the position:  2013-03-25
# Holding the position:  2013-03-26
# Holding the position:  2013-03-27
# Holding the position:  2013-03-28
# Holding the position:  2013-03-29
# Holding the position:  2013-04-01
# Holding the position:  2013-04-02
# Holding the position:  2013-04-03
# Holding the position:  2013-04-08
# Holding the position:  2013-04-09
# Holding the position:  2013-04-10
# Closed the posotion:  2013-04-11
# This trade's pnl: -3851.434599999993
# -------------------
# Position is empty:  2013-04-11
# Position is empty:  2013-04-12
# Position is empty:  2013-04-15
# Position is empty:  2013-04-16
# -------------------
# Opened the position:  2013-04-17
# Holding the position:  2013-04-18
# Holding the position:  2013-04-19
# Holding the position:  2013-04-22
# Holding the position:  2013-04-23
# Holding the position:  2013-04-24
# Closed the posotion:  2013-04-25
# This trade's pnl: -3162.401800000007
# -------------------
# Position is empty:  2013-04-25
# Position is empty:  2013-04-26
# Position is empty:  2013-05-02
# Position is empty:  2013-05-03
# -------------------
# Opened the position:  2013-05-06
# Holding the position:  2013-05-07
# Holding the position:  2013-05-08
# Holding the position:  2013-05-09
# Closed the posotion:  2013-05-10
# This trade's pnl: -1021.3159999999916
# -------------------
# Position is empty:  2013-05-10
# Position is empty:  2013-05-13
# Position is empty:  2013-05-14
# Position is empty:  2013-05-15
# -------------------
# Opened the position:  2013-05-16
# Holding the position:  2013-05-17
# Holding the position:  2013-05-20
# Holding the position:  2013-05-21
# Holding the position:  2013-05-22
# Holding the position:  2013-05-23
# Holding the position:  2013-05-24
# Holding the position:  2013-05-27
# Holding the position:  2013-05-28
# Holding the position:  2013-05-29
# Holding the position:  2013-05-30
# Holding the position:  2013-05-31
# Holding the position:  2013-06-03
# Holding the position:  2013-06-04
# Closed the posotion:  2013-06-05
# This trade's pnl: 3063.8341000000073
# -------------------
# Position is empty:  2013-06-05
# Position is empty:  2013-06-06
# Position is empty:  2013-06-07
# Position is empty:  2013-06-13
# Position is empty:  2013-06-14
# Position is empty:  2013-06-17
# Position is empty:  2013-06-18
# Position is empty:  2013-06-19
# Position is empty:  2013-06-20
# Position is empty:  2013-06-21
# Position is empty:  2013-06-24
# Position is empty:  2013-06-25
# Position is empty:  2013-06-26
# Position is empty:  2013-06-27
# Position is empty:  2013-06-28
# Position is empty:  2013-07-01
# Position is empty:  2013-07-02
# Position is empty:  2013-07-03
# Position is empty:  2013-07-04
# Position is empty:  2013-07-05
# Position is empty:  2013-07-08
# -------------------
# Opened the position:  2013-07-09
# Holding the position:  2013-07-10
# Holding the position:  2013-07-11
# Holding the position:  2013-07-12
# Holding the position:  2013-07-15
# Holding the position:  2013-07-16
# Holding the position:  2013-07-17
# Holding the position:  2013-07-18
# Holding the position:  2013-07-19
# Holding the position:  2013-07-22
# Holding the position:  2013-07-23
# Holding the position:  2013-07-24
# Holding the position:  2013-07-25
# Holding the position:  2013-07-26
# Holding the position:  2013-07-29
# Holding the position:  2013-07-30
# Holding the position:  2013-07-31
# Holding the position:  2013-08-01
# Holding the position:  2013-08-02
# Holding the position:  2013-08-05
# Holding the position:  2013-08-06
# Holding the position:  2013-08-07
# Holding the position:  2013-08-08
# Holding the position:  2013-08-09
# Holding the position:  2013-08-12
# Holding the position:  2013-08-13
# Holding the position:  2013-08-14
# Holding the position:  2013-08-15
# Holding the position:  2013-08-16
# Holding the position:  2013-08-19
# Holding the position:  2013-08-20
# Holding the position:  2013-08-21
# Closed the posotion:  2013-08-22
# This trade's pnl: 17573.819000000003
# -------------------
# Position is empty:  2013-08-22
# Position is empty:  2013-08-23
# Position is empty:  2013-08-26
# Position is empty:  2013-08-27
# Position is empty:  2013-08-28
# Position is empty:  2013-08-29
# Position is empty:  2013-08-30
# Position is empty:  2013-09-02
# Position is empty:  2013-09-03
# Position is empty:  2013-09-04
# Position is empty:  2013-09-05
# Position is empty:  2013-09-06
# Position is empty:  2013-09-09
# -------------------
# Opened the position:  2013-09-10
# Holding the position:  2013-09-11
# Holding the position:  2013-09-12
# Holding the position:  2013-09-13
# Holding the position:  2013-09-16
# Holding the position:  2013-09-17
# Holding the position:  2013-09-18
# Holding the position:  2013-09-23
# Holding the position:  2013-09-24
# Closed the posotion:  2013-09-25
# This trade's pnl: -2970.3908000000083
# -------------------
# Position is empty:  2013-09-25
# Position is empty:  2013-09-26
# Position is empty:  2013-09-27
# Position is empty:  2013-09-30
# Position is empty:  2013-10-08
# Position is empty:  2013-10-09
# Position is empty:  2013-10-10
# -------------------
# Opened the position:  2013-10-11
# Holding the position:  2013-10-14
# Holding the position:  2013-10-15
# Holding the position:  2013-10-16
# Holding the position:  2013-10-17
# Holding the position:  2013-10-18
# Holding the position:  2013-10-21
# Holding the position:  2013-10-22
# Closed the posotion:  2013-10-23
# This trade's pnl: -2711.257500000007
# -------------------
# Position is empty:  2013-10-23
# -------------------
# Opened the position:  2013-10-24
# Holding the position:  2013-10-25
# Holding the position:  2013-10-28
# Closed the posotion:  2013-10-29
# This trade's pnl: -4580.090299999996
# -------------------
# Position is empty:  2013-10-29
# Position is empty:  2013-10-30
# Position is empty:  2013-10-31
# Position is empty:  2013-11-01
# Position is empty:  2013-11-04
# Position is empty:  2013-11-05
# Position is empty:  2013-11-06
# Position is empty:  2013-11-07
# Position is empty:  2013-11-08
# Position is empty:  2013-11-11
# Position is empty:  2013-11-12
# Position is empty:  2013-11-13
# Position is empty:  2013-11-14
# Position is empty:  2013-11-15
# Position is empty:  2013-11-18
# Position is empty:  2013-11-19
# -------------------
# Opened the position:  2013-11-20
# Holding the position:  2013-11-21
# Closed the posotion:  2013-11-22
# This trade's pnl: -3970.5199999999895
# -------------------
# Position is empty:  2013-11-22
# Position is empty:  2013-11-25
# Position is empty:  2013-11-26
# Position is empty:  2013-11-27
# Position is empty:  2013-11-28
# Position is empty:  2013-11-29
# Position is empty:  2013-12-02
# Position is empty:  2013-12-03
# Position is empty:  2013-12-04
# Position is empty:  2013-12-05
# -------------------
# Opened the position:  2013-12-06
# Holding the position:  2013-12-09
# Holding the position:  2013-12-10
# Holding the position:  2013-12-11
# Holding the position:  2013-12-12
# Holding the position:  2013-12-13
# Holding the position:  2013-12-16
# Closed the posotion:  2013-12-17
# This trade's pnl: -1098.5224999999919
# -------------------
# Position is empty:  2013-12-17
# Position is empty:  2013-12-18
# Position is empty:  2013-12-19
# Position is empty:  2013-12-20
# Position is empty:  2013-12-23
# Position is empty:  2013-12-24
# Position is empty:  2013-12-25
# Position is empty:  2013-12-26
# Position is empty:  2013-12-27
# Position is empty:  2013-12-30
# Position is empty:  2013-12-31
# Position is empty:  2014-01-02
# Position is empty:  2014-01-03
# Position is empty:  2014-01-06
# Position is empty:  2014-01-07
# Position is empty:  2014-01-08
# Position is empty:  2014-01-09
# Position is empty:  2014-01-10
# Position is empty:  2014-01-13
# Position is empty:  2014-01-14
# Position is empty:  2014-01-15
# Position is empty:  2014-01-16
# Position is empty:  2014-01-17
# Position is empty:  2014-01-20
# Position is empty:  2014-01-21
# Position is empty:  2014-01-22
# -------------------
# Opened the position:  2014-01-23
# Holding the position:  2014-01-24
# Holding the position:  2014-01-27
# Holding the position:  2014-01-28
# Holding the position:  2014-01-29
# Holding the position:  2014-01-30
# Holding the position:  2014-02-07
# Holding the position:  2014-02-10
# Holding the position:  2014-02-11
# Holding the position:  2014-02-12
# Holding the position:  2014-02-13
# Holding the position:  2014-02-14
# Holding the position:  2014-02-17
# Holding the position:  2014-02-18
# Holding the position:  2014-02-19
# Holding the position:  2014-02-20
# Holding the position:  2014-02-21
# Closed the posotion:  2014-02-24
# This trade's pnl: -2589.618800000011
# -------------------
# Position is empty:  2014-02-24
# Position is empty:  2014-02-25
# Position is empty:  2014-02-26
# Position is empty:  2014-02-27
# Position is empty:  2014-02-28
# Position is empty:  2014-03-03
# Position is empty:  2014-03-04
# Position is empty:  2014-03-05
# Position is empty:  2014-03-06
# Position is empty:  2014-03-07
# Position is empty:  2014-03-10
# Position is empty:  2014-03-11
# Position is empty:  2014-03-12
# Position is empty:  2014-03-13
# Position is empty:  2014-03-14
# Position is empty:  2014-03-17
# -------------------
# Opened the position:  2014-03-18
# Holding the position:  2014-03-19
# Holding the position:  2014-03-20
# Holding the position:  2014-03-21
# Holding the position:  2014-03-24
# Holding the position:  2014-03-25
# Holding the position:  2014-03-26
# Holding the position:  2014-03-27
# Holding the position:  2014-03-28
# Holding the position:  2014-03-31
# Holding the position:  2014-04-01
# Holding the position:  2014-04-02
# Holding the position:  2014-04-03
# Holding the position:  2014-04-04
# Holding the position:  2014-04-08
# Holding the position:  2014-04-09
# Holding the position:  2014-04-10
# Holding the position:  2014-04-11
# Holding the position:  2014-04-14
# Closed the posotion:  2014-04-15
# This trade's pnl: 6074.941999999981
# -------------------
# Position is empty:  2014-04-15
# Position is empty:  2014-04-16
# Position is empty:  2014-04-17
# Position is empty:  2014-04-18
# Position is empty:  2014-04-21
# Position is empty:  2014-04-22
# Position is empty:  2014-04-23
# Position is empty:  2014-04-24
# Position is empty:  2014-04-25
# Position is empty:  2014-04-28
# -------------------
# Opened the position:  2014-04-29
# Holding the position:  2014-04-30
# Holding the position:  2014-05-05
# Holding the position:  2014-05-06
# Holding the position:  2014-05-07
# Closed the posotion:  2014-05-08
# This trade's pnl: -6792.055699999983
# -------------------
# Position is empty:  2014-05-08
# Position is empty:  2014-05-09
# Position is empty:  2014-05-12
# Position is empty:  2014-05-13
# Position is empty:  2014-05-14
# Position is empty:  2014-05-15
# Position is empty:  2014-05-16
# Position is empty:  2014-05-19
# Position is empty:  2014-05-20
# Position is empty:  2014-05-21
# Position is empty:  2014-05-22
# Position is empty:  2014-05-23
# -------------------
# Opened the position:  2014-05-26
# Holding the position:  2014-05-27
# Holding the position:  2014-05-28
# Holding the position:  2014-05-29
# Holding the position:  2014-05-30
# Holding the position:  2014-06-03
# Holding the position:  2014-06-04
# Holding the position:  2014-06-05
# Holding the position:  2014-06-06
# Holding the position:  2014-06-09
# Holding the position:  2014-06-10
# Holding the position:  2014-06-11
# Holding the position:  2014-06-12
# Holding the position:  2014-06-13
# Holding the position:  2014-06-16
# Closed the posotion:  2014-06-17
# This trade's pnl: 2736.281600000002
# -------------------
# Position is empty:  2014-06-17
# Position is empty:  2014-06-18
# Position is empty:  2014-06-19
# Position is empty:  2014-06-20
# Position is empty:  2014-06-23
# Position is empty:  2014-06-24
# Position is empty:  2014-06-25
# Position is empty:  2014-06-26
# Position is empty:  2014-06-27
# Position is empty:  2014-06-30
# Position is empty:  2014-07-01
# Position is empty:  2014-07-02
# Position is empty:  2014-07-03
# Position is empty:  2014-07-04
# -------------------
# Opened the position:  2014-07-07
# Holding the position:  2014-07-08
# Holding the position:  2014-07-09
# Holding the position:  2014-07-10
# Holding the position:  2014-07-11
# Holding the position:  2014-07-14
# Holding the position:  2014-07-15
# Holding the position:  2014-07-16
# Holding the position:  2014-07-17
# Holding the position:  2014-07-18
# Holding the position:  2014-07-21
# Holding the position:  2014-07-22
# Holding the position:  2014-07-23
# Holding the position:  2014-07-24
# Holding the position:  2014-07-25
# Holding the position:  2014-07-28
# Holding the position:  2014-07-29
# Holding the position:  2014-07-30
# Holding the position:  2014-07-31
# Holding the position:  2014-08-01
# Holding the position:  2014-08-04
# Holding the position:  2014-08-05
# Holding the position:  2014-08-06
# Holding the position:  2014-08-07
# Holding the position:  2014-08-08
# Holding the position:  2014-08-11
# Holding the position:  2014-08-12
# Holding the position:  2014-08-13
# Closed the posotion:  2014-08-14
# This trade's pnl: 14430.242100000018
# -------------------
# Position is empty:  2014-08-14
# Position is empty:  2014-08-15
# Position is empty:  2014-08-18
# Position is empty:  2014-08-19
# Position is empty:  2014-08-20
# Position is empty:  2014-08-21
# Position is empty:  2014-08-22
# Position is empty:  2014-08-25
# Position is empty:  2014-08-26
# Position is empty:  2014-08-27
# Position is empty:  2014-08-28
# Position is empty:  2014-08-29
# Position is empty:  2014-09-01
# Position is empty:  2014-09-02
# Position is empty:  2014-09-03
# -------------------
# Opened the position:  2014-09-04
# Holding the position:  2014-09-05
# Holding the position:  2014-09-09
# Holding the position:  2014-09-10
# Holding the position:  2014-09-11
# Holding the position:  2014-09-12
# Holding the position:  2014-09-15
# Closed the posotion:  2014-09-16
# This trade's pnl: -2549.6020000000135
# -------------------
# Position is empty:  2014-09-16
# Position is empty:  2014-09-17
# Position is empty:  2014-09-18
# Position is empty:  2014-09-19
# Position is empty:  2014-09-22
# Position is empty:  2014-09-23
# Position is empty:  2014-09-24
# Position is empty:  2014-09-25
# Position is empty:  2014-09-26
# Position is empty:  2014-09-29
# Position is empty:  2014-09-30
# Position is empty:  2014-10-08
# -------------------
# Opened the position:  2014-10-09
# Holding the position:  2014-10-10
# Holding the position:  2014-10-13
# Holding the position:  2014-10-14
# Holding the position:  2014-10-15
# Holding the position:  2014-10-16
# Holding the position:  2014-10-17
# Holding the position:  2014-10-20
# Closed the posotion:  2014-10-21
# This trade's pnl: -2707.124299999996
# -------------------
# Position is empty:  2014-10-21
# Position is empty:  2014-10-22
# Position is empty:  2014-10-23
# Position is empty:  2014-10-24
# Position is empty:  2014-10-27
# Position is empty:  2014-10-28
# Position is empty:  2014-10-29
# Position is empty:  2014-10-30
# Position is empty:  2014-10-31
# -------------------
# Opened the position:  2014-11-03
# Holding the position:  2014-11-04
# Holding the position:  2014-11-05
# Holding the position:  2014-11-06
# Holding the position:  2014-11-07
# Holding the position:  2014-11-10
# Holding the position:  2014-11-11
# Holding the position:  2014-11-12
# Holding the position:  2014-11-13
# Holding the position:  2014-11-14
# Holding the position:  2014-11-17
# Holding the position:  2014-11-18
# Holding the position:  2014-11-19
# Holding the position:  2014-11-20
# Holding the position:  2014-11-21
# Holding the position:  2014-11-24
# Holding the position:  2014-11-25
# Holding the position:  2014-11-26
# Holding the position:  2014-11-27
# Holding the position:  2014-11-28
# Holding the position:  2014-12-01
# Holding the position:  2014-12-02
# Holding the position:  2014-12-03
# Holding the position:  2014-12-04
# Holding the position:  2014-12-05
# Holding the position:  2014-12-08
# Holding the position:  2014-12-09
# Holding the position:  2014-12-10
# Holding the position:  2014-12-11
# Holding the position:  2014-12-12
# Holding the position:  2014-12-15
# Holding the position:  2014-12-16
# Holding the position:  2014-12-17
# Holding the position:  2014-12-18
# Holding the position:  2014-12-19
# Holding the position:  2014-12-22
# Closed the posotion:  2014-12-23
# This trade's pnl: 24494.558200000014
# -------------------
# Position is empty:  2014-12-23
# Position is empty:  2014-12-24
# Position is empty:  2014-12-25
# Position is empty:  2014-12-26
# Position is empty:  2014-12-29
# -------------------
# Opened the position:  2014-12-30
# Holding the position:  2014-12-31
# Holding the position:  2015-01-05
# Holding the position:  2015-01-06
# Holding the position:  2015-01-07
# Holding the position:  2015-01-08
# Holding the position:  2015-01-09
# Holding the position:  2015-01-12
# Holding the position:  2015-01-13
# Closed the posotion:  2015-01-14
# This trade's pnl: -529.122000000003
# -------------------
# Position is empty:  2015-01-14
# Position is empty:  2015-01-15
# Position is empty:  2015-01-16
# Position is empty:  2015-01-19
# Position is empty:  2015-01-20
# Position is empty:  2015-01-21
# Position is empty:  2015-03-23
# -------------------
# Opened the position:  2015-03-24
# Holding the position:  2015-03-25
# Holding the position:  2015-03-26
# Holding the position:  2015-03-27
# Holding the position:  2015-03-30
# Holding the position:  2015-03-31
# Holding the position:  2015-04-01
# Holding the position:  2015-04-02
# Holding the position:  2015-04-03
# Holding the position:  2015-04-07
# Holding the position:  2015-04-08
# Holding the position:  2015-04-09
# Holding the position:  2015-04-10
# Holding the position:  2015-04-13
# Holding the position:  2015-04-14
# Holding the position:  2015-04-15
# Holding the position:  2015-04-16
# Holding the position:  2015-04-17
# Holding the position:  2015-04-20
# Closed the posotion:  2015-04-21
# This trade's pnl: 17180.414400000023
# -------------------
# Position is empty:  2015-04-21
# Position is empty:  2015-04-22
# Position is empty:  2015-04-23
# Position is empty:  2015-04-24
# Position is empty:  2015-04-27
# Position is empty:  2015-04-28
# Position is empty:  2015-04-29
# Position is empty:  2015-04-30
# Position is empty:  2015-05-04
# Position is empty:  2015-05-05
# Position is empty:  2015-05-06
# Position is empty:  2015-05-07
# Position is empty:  2015-05-08
# Position is empty:  2015-05-11
# Position is empty:  2015-05-12
# Position is empty:  2015-05-13
# Position is empty:  2015-05-14
# Position is empty:  2015-05-15
# Position is empty:  2015-05-18
# Position is empty:  2015-05-19
# Position is empty:  2015-05-20
# Position is empty:  2015-05-21
# Position is empty:  2015-05-22
# -------------------
# Opened the position:  2015-05-25
# Holding the position:  2015-05-26
# Holding the position:  2015-05-27
# Holding the position:  2015-05-28
# Holding the position:  2015-05-29
# Holding the position:  2015-06-01
# Holding the position:  2015-06-02
# Holding the position:  2015-06-03
# Holding the position:  2015-06-04
# Holding the position:  2015-06-05
# Holding the position:  2015-06-08
# Holding the position:  2015-06-09
# Holding the position:  2015-06-10
# Holding the position:  2015-06-11
# Holding the position:  2015-06-12
# Holding the position:  2015-06-15
# Holding the position:  2015-06-16
# Holding the position:  2015-06-17
# Holding the position:  2015-06-18
# Holding the position:  2015-06-19
# Holding the position:  2015-06-23
# Closed the posotion:  2015-06-24
# This trade's pnl: 24919.731600000014
# -------------------
# Position is empty:  2015-06-24
# -------------------
# Opened the position:  2015-06-25
# Holding the position:  2015-06-26
# Closed the posotion:  2015-06-29
# This trade's pnl: -7221.6391
# -------------------
# Position is empty:  2015-06-29
# Position is empty:  2015-06-30
# Position is empty:  2015-07-01
# ...
# Position is empty:  2018-07-04
# Position is empty:  2018-07-05
# Position is empty:  2018-07-06
# Position is empty:  2018-07-09
# Position is empty:  2018-07-10
# Position is empty:  2018-07-11
# Position is empty:  2018-07-12
# Position is empty:  2018-07-13
# Position is empty:  2018-07-16
# Position is empty:  2018-07-17
# Position is empty:  2018-07-18
# -------------------
# Opened the position:  2018-07-19
# Holding the position:  2018-07-20
# Holding the position:  2018-07-23
# Holding the position:  2018-07-24
# Holding the position:  2018-07-25
# Holding the position:  2018-07-26
# Holding the position:  2018-07-27
# Holding the position:  2018-07-30
# Holding the position:  2018-07-31
# Holding the position:  2018-08-01
# Holding the position:  2018-08-02
# Holding the position:  2018-08-03
# Closed the posotion:  2018-08-06
# This trade's pnl: -5.0
# -------------------
# Position is empty:  2018-08-06
# Position is empty:  2018-08-07
# Position is empty:  2018-08-08
# Position is empty:  2018-08-09
# Position is empty:  2018-08-10
# Position is empty:  2018-08-13
# -------------------
# Opened the position:  2018-08-14
# Closed the posotion:  2018-08-15
# This trade's pnl: -1684.6543999999994
# -------------------
# Position is empty:  2018-08-15
# Position is empty:  2018-08-16
# Position is empty:  2018-08-17
# Position is empty:  2018-08-20
# Position is empty:  2018-08-21
# Position is empty:  2018-08-22
# Position is empty:  2018-08-23
# Position is empty:  2018-08-24
# Position is empty:  2018-08-27
# Position is empty:  2018-08-28
# -------------------
# Opened the position:  2018-08-29
# Holding the position:  2018-08-30
# Holding the position:  2018-08-31
# Holding the position:  2018-09-03
# Closed the posotion:  2018-09-04
# This trade's pnl: -4481.1352999999945
# -------------------
# Position is empty:  2018-09-04
# Position is empty:  2018-09-05
# Position is empty:  2018-09-06
# Position is empty:  2018-09-07
# Position is empty:  2018-09-10
# Position is empty:  2018-09-11
# Position is empty:  2018-09-12
# Position is empty:  2018-09-13
# Position is empty:  2018-09-14
# Position is empty:  2018-09-17
# Position is empty:  2018-09-18
# Position is empty:  2018-09-19
# -------------------
# Opened the position:  2018-09-20
# Holding the position:  2018-09-21
# Holding the position:  2018-09-25
# Holding the position:  2018-09-26
# Holding the position:  2018-09-27
# Holding the position:  2018-09-28
# Holding the position:  2018-10-08
# Holding the position:  2018-10-09
# Holding the position:  2018-10-10
# Closed the posotion:  2018-10-11
# This trade's pnl: -6745.320000000007
# -------------------
# Position is empty:  2018-10-11
# Position is empty:  2018-10-12
# Position is empty:  2018-10-15
# Position is empty:  2018-10-16
# Position is empty:  2018-10-17
# Position is empty:  2018-10-18
# Position is empty:  2018-10-19
# Position is empty:  2018-10-22
# Position is empty:  2018-10-23
# Position is empty:  2018-10-24
# Position is empty:  2018-10-25
# -------------------
# Opened the position:  2018-10-26
# Holding the position:  2018-10-29
# Holding the position:  2018-10-30
# Holding the position:  2018-10-31
# Holding the position:  2018-11-01
# Holding the position:  2018-11-02
# Holding the position:  2018-11-05
# Holding the position:  2018-11-06
# Holding the position:  2018-11-07
# Holding the position:  2018-11-08
# Holding the position:  2018-11-09
# Holding the position:  2018-11-12
# Holding the position:  2018-11-13
# Holding the position:  2018-11-14
# Holding the position:  2018-11-15
# Holding the position:  2018-11-16
# Holding the position:  2018-11-19
# Holding the position:  2018-11-20
# Holding the position:  2018-11-21
# Holding the position:  2018-11-22
# Holding the position:  2018-11-23
# Holding the position:  2018-11-26
# Holding the position:  2018-11-27
# Closed the posotion:  2018-11-28
# This trade's pnl: 5230.27840000001
# -------------------
# Position is empty:  2018-11-28
# Position is empty:  2018-11-29
# Position is empty:  2018-11-30
# Position is empty:  2018-12-03
# Position is empty:  2018-12-04
# Position is empty:  2018-12-05
# Position is empty:  2018-12-06
# Position is empty:  2018-12-07
# Position is empty:  2018-12-10
# Position is empty:  2018-12-11
# Position is empty:  2018-12-12
# Position is empty:  2018-12-13
# Position is empty:  2018-12-14
# Position is empty:  2018-12-17
# -------------------
# Opened the position:  2018-12-18
# Holding the position:  2018-12-19
# Holding the position:  2018-12-20
# Holding the position:  2018-12-21
# Closed the posotion:  2018-12-24
# This trade's pnl: -3586.899999999965
# -------------------
# Position is empty:  2018-12-24
# Position is empty:  2018-12-25
# Position is empty:  2018-12-26
# -------------------
# Opened the position:  2018-12-27
# Holding the position:  2018-12-28
# Holding the position:  2019-01-02
# Holding the position:  2019-01-03
# Holding the position:  2019-01-04
# Holding the position:  2019-01-07
# Holding the position:  2019-01-08
# Holding the position:  2019-01-09
# Holding the position:  2019-01-10
# Holding the position:  2019-01-11
# Holding the position:  2019-01-14
# Holding the position:  2019-01-15
# Holding the position:  2019-01-16
# Holding the position:  2019-01-17
# Closed the posotion:  2019-01-18
# This trade's pnl: 159.5343999999459
# -------------------
# Position is empty:  2019-01-18
# -------------------
# Opened the position:  2019-01-21
# Holding the position:  2019-01-22
# Closed the posotion:  2019-01-23
# This trade's pnl: -1294.560999999987
# -------------------
# Position is empty:  2019-01-23
# Position is empty:  2019-01-24
# Position is empty:  2019-01-25
# -------------------
# Opened the position:  2019-01-28
# Holding the position:  2019-01-29
# Holding the position:  2019-01-30
# Holding the position:  2019-01-31
# Holding the position:  2019-02-01
# Holding the position:  2019-02-11
# Holding the position:  2019-02-12
# Holding the position:  2019-02-13
# Holding the position:  2019-02-14
# Holding the position:  2019-02-15
# Holding the position:  2019-02-18
# Holding the position:  2019-02-19
# Holding the position:  2019-02-20
# Holding the position:  2019-02-21
# Holding the position:  2019-02-22
# Holding the position:  2019-02-25
# Holding the position:  2019-02-26
# Holding the position:  2019-02-27
# Holding the position:  2019-02-28
# Holding the position:  2019-03-01
# Holding the position:  2019-03-04
# Holding the position:  2019-03-05
# Holding the position:  2019-03-06
# Holding the position:  2019-03-07
# Holding the position:  2019-03-08
# Holding the position:  2019-03-11
# Closed the posotion:  2019-03-12
# This trade's pnl: 9518.28640000004
# -------------------
# Position is empty:  2019-03-12
# Position is empty:  2019-03-13
# Position is empty:  2019-03-14
# Position is empty:  2019-03-15
# Position is empty:  2019-03-18
# Position is empty:  2019-03-19
# Position is empty:  2019-03-20
# -------------------
# Opened the position:  2019-03-21
# Holding the position:  2019-03-22
# Holding the position:  2019-03-25
# Holding the position:  2019-03-26
# Holding the position:  2019-03-27
# Holding the position:  2019-03-28
# Holding the position:  2019-03-29
# Holding the position:  2019-04-01
# Holding the position:  2019-04-02
# Holding the position:  2019-04-03
# Holding the position:  2019-04-04
# Holding the position:  2019-04-08
# Holding the position:  2019-04-09
# Holding the position:  2019-04-10
# Holding the position:  2019-04-11
# Holding the position:  2019-04-12
# Holding the position:  2019-04-15
# Holding the position:  2019-04-16
# Holding the position:  2019-04-17
# Holding the position:  2019-04-18
# Closed the posotion:  2019-04-19
# This trade's pnl: 16730.370400000014
# -------------------
# Position is empty:  2019-04-19
# Position is empty:  2019-04-22
# Position is empty:  2019-04-23
# Position is empty:  2019-04-24
# Position is empty:  2019-04-25
# Position is empty:  2019-04-26
# Position is empty:  2019-04-29
# Position is empty:  2019-04-30
# Position is empty:  2019-05-06
# Position is empty:  2019-05-07
# Position is empty:  2019-05-08
# Position is empty:  2019-05-09
# Position is empty:  2019-05-10
# Position is empty:  2019-05-13
# Position is empty:  2019-05-14
# Position is empty:  2019-05-15
# Position is empty:  2019-05-16
# Position is empty:  2019-05-17
# Position is empty:  2019-05-20
# Position is empty:  2019-05-21
# Position is empty:  2019-05-22
# -------------------
# Opened the position:  2019-05-23
# Closed the posotion:  2019-05-24
# This trade's pnl: -872.0
# -------------------
# Position is empty:  2019-05-24
# -------------------
# Opened the position:  2019-05-27
# Holding the position:  2019-05-28
# Holding the position:  2019-05-29
# Holding the position:  2019-05-30
# Holding the position:  2019-05-31
# Holding the position:  2019-06-03
# Holding the position:  2019-06-04
# Holding the position:  2019-06-05
# Holding the position:  2019-06-06
# Holding the position:  2019-06-10
# Holding the position:  2019-06-11
# Holding the position:  2019-06-12
# Holding the position:  2019-06-13
# Holding the position:  2019-06-14
# Holding the position:  2019-06-17
# Holding the position:  2019-06-18
# Holding the position:  2019-06-19
# Holding the position:  2019-06-20
# Holding the position:  2019-06-21
# Holding the position:  2019-06-24
# Holding the position:  2019-06-25
# Holding the position:  2019-06-26
# Closed the posotion:  2019-06-27
# This trade's pnl: 1461.1999999999825
# -------------------
# Position is empty:  2019-06-27
# Position is empty:  2019-06-28
# Position is empty:  2019-07-01
# Position is empty:  2019-07-02
# -------------------
# Opened the position:  2019-07-03
# Holding the position:  2019-07-04
# Holding the position:  2019-07-05
# Holding the position:  2019-07-08
# Holding the position:  2019-07-09
# Holding the position:  2019-07-10
# Holding the position:  2019-07-11
# Holding the position:  2019-07-12
# Holding the position:  2019-07-15
# Holding the position:  2019-07-16
# Holding the position:  2019-07-17
# Holding the position:  2019-07-18
# Holding the position:  2019-07-19
# Holding the position:  2019-07-22
# Holding the position:  2019-07-23
# Holding the position:  2019-07-24
# Holding the position:  2019-07-25
# Holding the position:  2019-07-26
# Holding the position:  2019-07-29
# Closed the posotion:  2019-07-30
# This trade's pnl: 2498.4400000000023
# -------------------
# Position is empty:  2019-07-30
# Position is empty:  2019-07-31
# Position is empty:  2019-08-01
# Position is empty:  2019-08-02
# Position is empty:  2019-08-05
# Position is empty:  2019-08-06
# Position is empty:  2019-08-07
# Position is empty:  2019-08-08
# Position is empty:  2019-08-09
# Position is empty:  2019-08-12
# Position is empty:  2019-08-13
# Position is empty:  2019-08-14
# Position is empty:  2019-08-15
# Position is empty:  2019-08-16
# Position is empty:  2019-08-19
# Position is empty:  2019-08-20
# -------------------
# Opened the position:  2019-08-21
# Holding the position:  2019-08-22
# Holding the position:  2019-08-23
# Holding the position:  2019-08-26
# Holding the position:  2019-08-27
# Holding the position:  2019-08-28
# Holding the position:  2019-08-29
# Holding the position:  2019-08-30
# Holding the position:  2019-09-02
# Holding the position:  2019-09-03
# Holding the position:  2019-09-04
# Holding the position:  2019-09-05
# Holding the position:  2019-09-06
# Holding the position:  2019-09-09
# Holding the position:  2019-09-10
# Holding the position:  2019-09-11
# Holding the position:  2019-09-12
# Holding the position:  2019-09-16
# Holding the position:  2019-09-17
# Closed the posotion:  2019-09-18
# This trade's pnl: 137.45000000001164
# -------------------
# Position is empty:  2019-09-18
# Position is empty:  2019-09-19
# Position is empty:  2019-09-20
# Position is empty:  2019-09-23
# Position is empty:  2019-09-24
# Position is empty:  2019-09-25
# Position is empty:  2019-09-26
# Position is empty:  2019-09-27
# Position is empty:  2019-09-30
# Position is empty:  2019-10-08
# Position is empty:  2019-10-09
# -------------------
# Opened the position:  2019-10-10
# Holding the position:  2019-10-11
# Holding the position:  2019-10-14
# Holding the position:  2019-10-15
# Holding the position:  2019-10-16
# Holding the position:  2019-10-17
# Holding the position:  2019-10-18
# Holding the position:  2019-10-21
# Holding the position:  2019-10-22
# Closed the posotion:  2019-10-23
# This trade's pnl: -1505.6199999999953
# -------------------
# Position is empty:  2019-10-23
# Position is empty:  2019-10-24
# Position is empty:  2019-10-25
# Position is empty:  2019-10-28
# Position is empty:  2019-10-29
# Position is empty:  2019-10-30
# Position is empty:  2019-10-31
# Position is empty:  2019-11-01
# Position is empty:  2019-11-04
# Position is empty:  2019-11-05
# Position is empty:  2019-11-06
# -------------------
# Opened the position:  2019-11-07
# Holding the position:  2019-11-08
# Holding the position:  2019-11-11
# Closed the posotion:  2019-11-12
# This trade's pnl: -3596.1200000000244
# -------------------
# Position is empty:  2019-11-12
# Position is empty:  2019-11-13
# Position is empty:  2019-11-14
# Position is empty:  2019-11-15
# Position is empty:  2019-11-18
# Position is empty:  2019-11-19
# Position is empty:  2019-11-20
# Position is empty:  2019-11-21
# Position is empty:  2019-11-22
# Position is empty:  2019-11-25
# Position is empty:  2019-11-26
# -------------------
# Opened the position:  2019-11-27
# Holding the position:  2019-11-28
# Holding the position:  2019-11-29
# Holding the position:  2019-12-02
# Holding the position:  2019-12-03
# Holding the position:  2019-12-04
# Holding the position:  2019-12-05
# Holding the position:  2019-12-06
# Holding the position:  2019-12-09
# Holding the position:  2019-12-10
# Holding the position:  2019-12-11
# Holding the position:  2019-12-12
# Holding the position:  2019-12-13
# Holding the position:  2019-12-16
# Holding the position:  2019-12-17
# Holding the position:  2019-12-18
# Holding the position:  2019-12-19
# Holding the position:  2019-12-20
# Holding the position:  2019-12-23
# Holding the position:  2019-12-24
# Holding the position:  2019-12-25
# Holding the position:  2019-12-26
# Holding the position:  2019-12-27
# Holding the position:  2019-12-30
# Holding the position:  2019-12-31
# Holding the position:  2020-01-02
# Holding the position:  2020-01-03
# Holding the position:  2020-01-06
# Holding the position:  2020-01-07
# Holding the position:  2020-01-08
# Holding the position:  2020-01-09
# Holding the position:  2020-01-10
# Closed the posotion:  2020-01-13
# This trade's pnl: 8186.920000000013
# -------------------
# Position is empty:  2020-01-13
# Position is empty:  2020-01-14
# Position is empty:  2020-01-15
# Position is empty:  2020-01-16
# Position is empty:  2020-01-17
# Position is empty:  2020-01-20
# Position is empty:  2020-01-21
# Position is empty:  2020-01-22
# Position is empty:  2020-01-23
# Position is empty:  2020-02-03
# Position is empty:  2020-02-04
# Position is empty:  2020-02-05
# Position is empty:  2020-02-06
# Position is empty:  2020-02-07
# Position is empty:  2020-02-10
# Position is empty:  2020-02-11
# Position is empty:  2020-02-12
# Position is empty:  2020-02-13
# Position is empty:  2020-02-14
# Position is empty:  2020-02-17
# -------------------
# Opened the position:  2020-02-18
# Holding the position:  2020-02-19
# Holding the position:  2020-02-20
# Holding the position:  2020-02-21
# Holding the position:  2020-02-24
# Holding the position:  2020-02-25
# Holding the position:  2020-02-26
# Holding the position:  2020-02-27
# Holding the position:  2020-02-28
# Holding the position:  2020-03-02
# Holding the position:  2020-03-03
# Holding the position:  2020-03-04
# Holding the position:  2020-03-05
# Holding the position:  2020-03-06
# Holding the position:  2020-03-09
# Holding the position:  2020-03-10
# Closed the posotion:  2020-03-11
# This trade's pnl: -1037.429999999993
# -------------------
# Position is empty:  2020-03-11
# Position is empty:  2020-03-12
# Position is empty:  2020-03-13
# Position is empty:  2020-03-16
# Position is empty:  2020-03-17
# Position is empty:  2020-03-18
# Position is empty:  2020-03-19
# Position is empty:  2020-03-20
# Position is empty:  2020-03-23
# Position is empty:  2020-03-24
# Position is empty:  2020-03-25
# Position is empty:  2020-03-26
# -------------------
# Opened the position:  2020-03-27
# Holding the position:  2020-03-30
# Holding the position:  2020-03-31
# Holding the position:  2020-04-01
# Holding the position:  2020-04-02
# Holding the position:  2020-04-03
# win %: 37.03703703703704
# PL Ratio: 2.1903254705930593
# bt_score: 0.18160202614557763

# %%
list(filter(lambda x: x >0, profits))
# Out:
# [3197.956999999995,
#  906.2310999999754,
#  941.0362000000023,
#  4610.26739999999,
#  708.987999999983,
#  3908.290399999998,
#  4238.08269999997,
#  143.7612999999983,
#  528.488199999978,
#  323.8384000000078,
#  2026.2409000000043,
#  2002.4245999999985,
#  325.7387999999919,
#  334.4259999999922,
#  1934.2936999999947,
#  2302.2507999999943,
#  791.0649999999878,
#  2609.870200000005,
#  178.29520000000775,
#  1449.350499999986,
#  175.41190000002098,
#  10029.34080000002,
#  2235.0929999999935,
#  3046.229500000045,
#  1195.1300000000047,
#  250.21820000000298,
#  957.8211999999912,
#  1931.4944999999861,
#  9947.747199999954,
#  9966.122599999988,
#  3095.25089999997,
#  3439.838499999998,
#  1742.026400000017,
#  1593.4804000000004,
#  138.7436000000016,
#  571.7746000000043,
#  2391.4260000000068,
#  3488.3678000000073,
#  677.0,
#  655.9899999999616,
#  1186.4214999999967,
#  368.6699999999837,
#  1042.420000000042,
#  1145.026899999997,
#  409.34189999999944,
#  1167.9599999999919,
#  1385.8000000000175]

# %%
len(profits)
# Out:
# 108

# %%
df_equity_copy.head(30)
# Out:
#               datetime  market_value         cash  commission        total  \
# datetime
# 2010-01-04  2010-01-04        0.0000  100000.0000           0  100000.0000
# 2010-01-05  2010-01-05        0.0000  100000.0000           0  100000.0000
# 2010-01-06  2010-01-06        0.0000  100000.0000           0  100000.0000
# 2010-01-07  2010-01-07        0.0000  100000.0000           0  100000.0000
# 2010-01-08  2010-01-08        0.0000  100000.0000           0  100000.0000
# 2010-01-11  2010-01-11        0.0000  100000.0000           0  100000.0000
# 2010-01-12  2010-01-12        0.0000  100000.0000           0  100000.0000
# 2010-01-13  2010-01-13        0.0000  100000.0000           0  100000.0000
# 2010-01-14  2010-01-14        0.0000  100000.0000           0  100000.0000
# 2010-01-15  2010-01-15        0.0000  100000.0000           0  100000.0000
# 2010-01-18  2010-01-18        0.0000  100000.0000           0  100000.0000
# 2010-01-19  2010-01-19        0.0000  100000.0000           0  100000.0000
# 2010-01-20  2010-01-20        0.0000  100000.0000           0  100000.0000
# 2010-01-22  2010-01-22        0.0000  100000.0000           0  100000.0000
# 2010-01-25  2010-01-25        0.0000  100000.0000           0  100000.0000
# 2010-01-26  2010-01-26        0.0000  100000.0000           0  100000.0000
# 2010-01-27  2010-01-27        0.0000  100000.0000           0  100000.0000
# 2010-01-28  2010-01-28        0.0000  100000.0000           0  100000.0000
# 2010-01-29  2010-01-29        0.0000  100000.0000           0  100000.0000
# 2010-02-01  2010-02-01   103200.5745      -2.6175           5  103197.9570
# 2010-02-02  2010-02-02   101434.7955      -2.6175           5  101432.1780
# 2010-02-03  2010-02-03   105161.3475      -2.6175           5  105158.7300
# 2010-02-04  2010-02-04   104572.7545      -2.6175           5  104570.1370
# 2010-02-05  2010-02-05   100324.4130      -2.6175           5  100321.7955
# 2010-02-08  2010-02-08    97580.0530      -2.6175           5   97577.4355
# 2010-02-09  2010-02-09    96011.0735      -2.6175           5   96008.4560
# 2010-02-10  2010-02-10        0.0000   96003.4560          10   96003.4560
# 2010-02-11  2010-02-11        0.0000   96003.4560          10   96003.4560
# 2010-02-12  2010-02-12        0.0000   96003.4560          10   96003.4560
# 2010-02-22  2010-02-22        0.0000   96003.4560          10   96003.4560
#
#              returns  equity_curve  drawdown   daily_PL
# datetime
# 2010-01-04  0.000000      1.000000  0.000000        NaN
# 2010-01-05  0.000000      1.000000  0.000000     0.0000
# 2010-01-06  0.000000      1.000000  0.000000     0.0000
# 2010-01-07  0.000000      1.000000  0.000000     0.0000
# 2010-01-08  0.000000      1.000000  0.000000     0.0000
# 2010-01-11  0.000000      1.000000  0.000000     0.0000
# 2010-01-12  0.000000      1.000000  0.000000     0.0000
# 2010-01-13  0.000000      1.000000  0.000000     0.0000
# 2010-01-14  0.000000      1.000000  0.000000     0.0000
# 2010-01-15  0.000000      1.000000  0.000000     0.0000
# 2010-01-18  0.000000      1.000000  0.000000     0.0000
# 2010-01-19  0.000000      1.000000  0.000000     0.0000
# 2010-01-20  0.000000      1.000000  0.000000     0.0000
# 2010-01-22  0.000000      1.000000  0.000000     0.0000
# 2010-01-25  0.000000      1.000000  0.000000     0.0000
# 2010-01-26  0.000000      1.000000  0.000000     0.0000
# 2010-01-27  0.000000      1.000000  0.000000     0.0000
# 2010-01-28  0.000000      1.000000  0.000000     0.0000
# 2010-01-29  0.000000      1.000000  0.000000     0.0000
# 2010-02-01  0.031980      1.031980  0.000000  3197.9570
# 2010-02-02 -0.017111      1.014322  0.017658 -1765.7790
# 2010-02-03  0.036739      1.051587  0.000000  3726.5520
# 2010-02-04 -0.005597      1.045701  0.005886  -588.5930
# 2010-02-05 -0.040627      1.003218  0.048369 -4248.3415
# 2010-02-08 -0.027356      0.975774  0.075813 -2744.3600
# 2010-02-09 -0.016079      0.960085  0.091503 -1568.9795
# 2010-02-10 -0.000052      0.960035  0.091553    -5.0000
# 2010-02-11  0.000000      0.960035  0.091553     0.0000
# 2010-02-12  0.000000      0.960035  0.091553     0.0000
# 2010-02-22  0.000000      0.960035  0.091553     0.0000

# %%
103200.5745

# %%
# df_equity.to_csv("df_equity_data.csv", index = False)

# %% [markdown]
# # Loop backtest for each ticker and find the best backtest performances

# %%
df_equity.columns = ['datetime', 'market_value', 'cash', 'commission', 'total', 'returns',
       'equity_curve', 'drawdown']

# %%
df_equity_copy = df_equity.copy()
data = df_equity_copy



# performance(data)
# print(data.head())
