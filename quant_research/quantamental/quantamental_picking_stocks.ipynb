# %%
import pandas as pd
import numpy as np

# %%
#-*- coding : utf-8-*-
# coding:unicode_escape

fin_data = pd.read_csv("fin_data_20201113.csv", encoding='gbk')

# %%
mkt_data_location = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/CH_database/"

# %%
fin_data
# Out:
#             代码    名称    涨幅%     现价     涨跌     买价     卖价         总量       现量  \
# 0       000001  平安银行  -2.72  17.18  -0.48  17.17  17.18  1289189.0  11541.0
# 1       000002  万 科Ａ  -2.39  29.05  -0.71  29.04  29.05   660135.0   5732.0
# 2       000004  国农科技    0.1  30.62   0.03  30.62  30.65    71323.0    896.0
# 3       000005  世纪星源   2.29   2.68   0.06   2.67   2.68   136360.0    679.0
# 4       000006  深振业Ａ  -1.22   5.67  -0.07   5.67   5.68    96442.0   1311.0
# ...        ...   ...    ...    ...    ...    ...    ...        ...      ...
# 4094    600007  中国国贸  -0.47  12.78  -0.06  12.77  12.78    13812.0    102.0
# 4095    600006  东风汽车   0.63   6.36   0.04   6.36   6.37   523954.0   3177.0
# 4096    600004  白云机场   1.48  14.38   0.21  14.38  14.39   275339.0   2727.0
# 4097    600000  浦发银行  -0.74   9.36  -0.07   9.36   9.37   449101.0   5274.0
# 4098  数据来源:通达信   NaN    NaN    NaN    NaN    NaN    NaN        NaN      NaN
#
#         涨速%  ...      净益率%   毛利率%  营业利润率%   净利润率% 研发费用(亿)      员工人数      交易代码  \
# 0      0.12  ...     6.24㈢   --     24.81   19.22    0.00   34980.0       1.0
# 1     -0.09  ...     9.80㈢  29.94   17.46    8.23    3.94  133455.0       2.0
# 2     -0.19  ...     3.96㈢  82.38   41.18   39.08    0.17     251.0       4.0
# 3     -0.36  ...    -1.70㈢     16  -12.83  -12.64    0.17     680.0       5.0
# 4     -0.34  ...     7.28㈢  44.68    39.5   31.83    0.00     385.0       6.0
# ...     ...  ...       ...    ...     ...     ...     ...       ...       ...
# 4094      0  ...     7.85㈢  53.64   36.03   27.41    0.00    2197.0  600007.0
# 4095      0  ...     6.31㈢  13.08    4.91    4.85    3.02    6982.0  600006.0
# 4096   -0.2  ...    -1.87㈢  -2.56   -6.02   -7.96    0.12   12888.0  600004.0
# 4097   -0.1  ...     7.81㈢   --     34.76   30.08    0.00   58553.0  600000.0
# 4098    NaN  ...       NaN    NaN     NaN     NaN     NaN       NaN       NaN
#
#        自选日   自选价 自选收益%
# 0     --    --    --
# 1     --    --    --
# 2     --    --    --
# 3     --    --    --
# 4     --    --    --
# ...    ...   ...   ...
# 4094  --    --    --
# 4095  --    --    --
# 4096  --    --    --
# 4097  --    --    --
# 4098   NaN   NaN   NaN
#
# [4099 rows x 114 columns]

# %%
fin_data['财务更新']
# Out:
# 0       20201022.0
# 1       20201030.0
# 2       20201030.0
# 3       20201029.0
# 4       20201029.0
#            ...
# 4093    20201031.0
# 4094    20201031.0
# 4095    20201030.0
# 4096    20201106.0
# 4097    20201109.0
# Name: 财务更新, Length: 4098, dtype: float64

# %%
# Delete the last row: "数据来源:通达信"

fin_data.drop([len(fin_data)-1], inplace = True)

# %%
# Present all the columns:
for col in fin_data.columns:
    print(col)
# Out:
# 代码
# 名称
# 涨幅%
# 现价
# 涨跌
# 买价
# 卖价
# 总量
# 现量
# 涨速%
# 换手%
# 今开
# 最高
# 最低
# 昨收
# 市盈(动)
# 总金额
# 量比
# 细分行业
# 地区
# 振幅%
# 均价
# 内盘
# 外盘
# 内外比
# 买量
# 卖量
# 未匹配量
# 开盘金额
# 开盘换手Z
# 封成比
# 封单额
# 流通股(亿)
# 流通市值
# AB股总市值
# 强弱度%
# 活跃度
# 笔均量
# 笔换手
# 连涨天
# 3日涨幅%
# 20日涨幅%
# 60日涨幅%
# 年初至今%
# 换手Z
# 流通市值Z
# 市盈(TTM)
# 市盈(静)
# 贝塔系数
# 近日指标提示
# 短期形态
# 中期形态
# 长期形态
# 开盘%
# 最高%
# 最低%
# 均涨幅%
# 实体涨幅%
# 回头波%
# 攻击波%
# 现均差%
# 财务更新
# 上市日期
# 总股本(亿)
# B/A股(亿)
# H股(亿)
# 总资产(亿)
# 净资产(亿)
# 少数股权(亿)
# 资产负债率%
# 流动资产(亿)
# 固定资产(亿)
# 无形资产(亿)
# 流动负债(亿)
# 存货(亿)
# 应收帐款(亿)
# 资本公积金(亿)
# 营业收入(亿)
# 营业成本(亿)
# 营业利润(亿)
# 投资收益(亿)
# 利润总额(亿)
# 税后利润(亿)
# 净利润(亿)
# 扣非净利润(亿)
# 未分利润(亿)
# 经营现金流(亿)
# 总现金流(亿)
# 股东人数
# 人均持股
# 人均市值
# 利润同比%
# 收入同比%
# 市净率
# 市现率
# 市销率
# 股息率%
# 每股收益
# 每股净资
# 调整后净资
# 每股公积
# 每股未分配
# 每股现金流
# 权益比%
# 净益率%
# 毛利率%
# 营业利润率%
# 净利润率%
# 研发费用(亿)
# 员工人数
# 交易代码
# 自选日
# 自选价
# 自选收益%

# %% [markdown]
# - 1. 市盈(TTM)：Price Earnings Ratio；股票价格／每股收益；越小越好
#
# - 2. 市净率：Price-to-Book Ratio:，每股股价／每股净资产；越低，投资价值越高
#
# - 3. 市现率：股票价格/每股现金流量；越低，说明每股现金增加额越多，经营压力越小
#
# - 4. 市销率：Price-to-Sales Ratio，每股股价／每股销售额；越低，说明该公司股票的投资价值越大
#
# - 5. 股息率%：Dividend Yield Ratio，股息／股票价格；是一年的总派息额与当时市价的比例。该指标是投资收益率的简化形式；越大越好
#
# - 6. 每股收益：越大越好
#
# - 7. 每股净资：越大越好
#
# - 8. 每股现金流：越大越好
#
# - 9. 净益率（净资产收益率）%：ROE；该指标体现了自有资本活得净收益的能力；指标越高，说明投资带来的收益越高。
#
# - 10. 营业利润率%：Operating Profit Ratio；营业利润／全部业务收入*100%；越大越好
#
# - 11. 净利润率%：净利润/营业收入×100%；越大越好

# %%
# All industries
fin_data['细分行业'].unique()
# Out:
# array(['银行', '全国地产', '互联网', '环境保护', '区域地产', '酒店餐饮', '运输设备', '综合类', '建筑工程',
#        '玻璃', '家用电器', '文教休闲', '其他商业', '元器件', 'IT设备', '其他建材', '汽车服务',
#        '火力发电', '医药商业', '汽车配件', '广告包装', '轻工机械', '新型电力', '多元金融', '饲料',
#        '电气设备', '房产服务', '石油加工', '铅锌', '农业综合', '批发业', '通信设备', '旅游景点', '港口',
#        '机场', '石油贸易', '空运', '医疗保健', '商贸代理', '化学制药', '影视音像', '工程机械', '软件服务',
#        '证券', '化纤', '水泥', '生物制药', '专用机械', '供气供热', '农药化肥', '机床制造', '百货',
#        '中成药', '路桥', '造纸', '食品', '黄金', '化工原料', '矿物制品', '水运', '日用化工',
#        '机械基件', '汽车整车', '煤炭开采', '铁路', '染料涂料', '白酒', '林业', '水务', '水力发电',
#        '旅游服务', '纺织', '铝', '保险', '园区开发', '小金属', '铜', '普钢', '航空', '特种钢',
#        '种植业', '出版业', '焦炭加工', '啤酒', '公路', '超市连锁', '钢加工', '渔业', '农用机械',
#        '软饮料', '化工机械', '塑料', '红黄酒', '橡胶', '家居用品', '摩托车', '电器仪表', '服饰',
#        '仓储物流', '纺织机械', '电器连锁', '装修装饰', '半导体', '电信运营', '石油开采', '乳制品',
#        '商品城', '公共交通', '陶瓷', '船舶', nan], dtype=object)

# %%
print("行业数量", len(fin_data['细分行业'].unique()))
# Out:
# 行业数量 111

# %%
def ensure_float(x):
    if isinstance(x,np.float):
        return x
    else :
        return np.NaN

# %% [markdown]
# # 0. 先按照流通市值，得出每个行业中的市值排名

# %%
fin_name0 = "流通市值"
rank_col_name0 = fin_name0+"排名"
score_col_name0 = fin_name0+"排名分数"

fin_data[fin_name0] = fin_data[fin_name0].apply(lambda x: str(x))
fin_data[fin_name0] = fin_data[fin_name0].apply(lambda x: x.replace(" ",""))
fin_data[fin_name0] = fin_data[fin_name0].apply(lambda x: x.replace("亿","00000000"))
fin_data[fin_name0] = fin_data[fin_name0].apply(lambda x: x.replace(".",""))
fin_data[fin_name0] = fin_data[fin_name0].apply(lambda x: x.replace("--",""))
fin_data[fin_name0] = fin_data[fin_name0].apply(lambda x: x.strip("\n"))
fin_data[fin_name0] = fin_data[fin_name0].apply(lambda x: x.strip("\t"))
fin_data[fin_name0] = fin_data[fin_name0].apply(lambda x: x.strip("\""))

fin_data = fin_data.replace(r'', np.NaN)
for i, item in enumerate(fin_data[fin_name0]):
    try:
        fin_data[fin_name0][i] = float(fin_data[fin_name0][i])
    except:
        # to see if there's any value/row that cannot be converted to float
        print(fin_data[fin_name0][i], i)
        
        
fin_data[fin_name0] = fin_data[fin_name0].apply(ensure_float)
fin_data[rank_col_name0] = fin_data.groupby(['细分行业'])[fin_name0].rank(ascending = False)
fin_data[fin_data['细分行业']=="全国地产"][['代码','名称','细分行业',fin_name0,rank_col_name0]].sort_values(rank_col_name0)
# Out:
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# # 1. 市盈(TTM)：
#
# Price Earnings Ratio；股票价格／每股收益；越小越好

# %%
fin_data['市盈(TTM)'][0]
# Out:
# '12.71'

# %%
fin_name1 = "市盈(TTM)"
rank_col_name1 = fin_name1+"排名"
score_col_name1 = fin_name1+"排名分数"

fin_data[fin_name1] = fin_data[fin_name1].apply(lambda x: str(x))
fin_data[fin_name1] = fin_data[fin_name1].apply(lambda x: x.replace(" ",""))
fin_data[fin_name1] = fin_data[fin_name1].apply(lambda x: x.replace("--",""))
fin_data[fin_name1] = fin_data[fin_name1].apply(lambda x: x.strip("\n"))
fin_data[fin_name1] = fin_data[fin_name1].apply(lambda x: x.strip("\t"))
fin_data[fin_name1] = fin_data[fin_name1].apply(lambda x: x.strip("\""))

# %%
fin_data = fin_data.replace(r'', np.NaN)
for i, item in enumerate(fin_data[fin_name1]):
    try:
        fin_data[fin_name1][i] = float(fin_data[fin_name1][i])
    except:
        # to see if there's any value/row that cannot be converted to float
        print(fin_data[fin_name1][i], i)
# Out:
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
fin_data[fin_name1] = fin_data[fin_name1].apply(ensure_float)
fin_data[rank_col_name1] = fin_data.groupby(['细分行业'])[fin_name1].rank(ascending = True)
fin_data[fin_data['细分行业']=="全国地产"][['代码','名称','细分行业',fin_name1,rank_col_name1]].sort_values(rank_col_name1)
# Out:
#           代码     名称  细分行业  市盈(TTM)  市盈(TTM)排名
# 597   002146   荣盛发展  全国地产     3.59        1.0
# 3563  600657   信达地产  全国地产     4.39        2.0
# 3606  600606   绿地控股  全国地产     5.15        3.0
# 4041  600077   宋都股份  全国地产     5.71        4.0
# 3645  600565   迪马股份  全国地产     6.52        5.0
# 3778  600383   金地集团  全国地产     6.69        6.0
# 4066  600048   保利地产  全国地产     6.87        7.0
# 73    000402  金 融 街  全国地产     7.03        8.0
# 274   000736   中交地产  全国地产     7.69        9.0
# 28    000036   华联控股  全国地产     8.29       10.0
# 1     000002   万 科Ａ  全国地产     8.54       11.0
# 454   001979   招商蛇口  全国地产     8.82       12.0
# 3956  600173   卧龙地产  全国地产     9.19       13.0
# 3691  600510    黑牡丹  全国地产     9.60       14.0
# 3556  600665    天地源  全国地产     9.90       15.0
# 4049  600067   冠城大通  全国地产    10.38       16.0
# 3927  600208   新湖中宝  全国地产    11.32       17.0
# 3415  600823   世茂股份  全国地产    11.43       18.0
# 3482  600748   上实发展  全国地产    12.05       19.0
# 585   002133   广宇集团  全国地产    14.86       20.0
# 3542  600684   珠江实业  全国地产    17.09       21.0
# 24    000031    大悦城  全国地产    25.88       22.0
# 11    000014   沙河股份  全国地产    40.57       23.0
# 3966  600162   香江控股  全国地产    45.45       24.0
# 308   000797   中国武夷  全国地产    58.49       25.0
# 188   000616   海航投资  全国地产  1944.22       26.0
# 33    000042   中洲控股  全国地产      NaN        NaN
# 187   000615   京汉股份  全国地产      NaN        NaN
# 191   000620    新华联  全国地产      NaN        NaN
# 220   000667   美好置业  全国地产      NaN        NaN
# 389   000918    嘉凯城  全国地产      NaN        NaN
# 3444  600791   京能置业  全国地产      NaN        NaN
# 3520  600708   光明地产  全国地产      NaN        NaN
# 3687  600515   海航基础  全国地产      NaN        NaN
# 3769  600393   粤泰股份  全国地产      NaN        NaN

# %% [markdown]
# # 2. 市净率：
#
# Price-to-Book Ratio:，每股股价／每股净资产；越低，投资价值越高

# %%
fin_data['市净率'][0]
# Out:
# '1.15'

# %%
fin_name2 = "市净率"
rank_col_name2 = fin_name2+"排名"
score_col_name2 = fin_name2+"排名分数"

fin_data[fin_name2] = fin_data[fin_name2].apply(lambda x: str(x))
fin_data[fin_name2] = fin_data[fin_name2].apply(lambda x: x.replace(" ",""))
fin_data[fin_name2] = fin_data[fin_name2].apply(lambda x: x.replace("--",""))
fin_data[fin_name2] = fin_data[fin_name2].apply(lambda x: x.strip("\n"))
fin_data[fin_name2] = fin_data[fin_name2].apply(lambda x: x.strip("\t"))
fin_data[fin_name2] = fin_data[fin_name2].apply(lambda x: x.strip("\""))

# %%
fin_data = fin_data.replace(r'', np.NaN)
for i, item in enumerate(fin_data[fin_name2]):
    try:
        fin_data[fin_name2][i] = float(fin_data[fin_name2][i])
    except:
        # to see if there's any value/row that cannot be converted to float
        print(fin_data[fin_name2][i], i)
# Out:
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
fin_data[fin_name2] = fin_data[fin_name2].apply(ensure_float)
fin_data[rank_col_name2] = fin_data.groupby(['细分行业'])[fin_name2].rank(ascending = True)
fin_data[fin_data['细分行业']=="全国地产"][['代码','名称','细分行业',fin_name2,rank_col_name2]].sort_values(rank_col_name2)
# Out:
#           代码     名称  细分行业   市净率  市净率排名
# 3563  600657   信达地产  全国地产  0.54    1.5
# 3520  600708   光明地产  全国地产  0.54    1.5
# 73    000402  金 融 街  全国地产  0.59    3.0
# 4049  600067   冠城大通  全国地产  0.70    4.5
# 585   002133   广宇集团  全国地产  0.70    4.5
# 597   002146   荣盛发展  全国地产  0.72    6.0
# 3927  600208   新湖中宝  全国地产  0.73    7.0
# 33    000042   中洲控股  全国地产  0.78    8.5
# 191   000620    新华联  全国地产  0.78    8.5
# 3645  600565   迪马股份  全国地产  0.82   10.5
# 3556  600665    天地源  全国地产  0.82   10.5
# 188   000616   海航投资  全国地产  0.84   12.0
# 3415  600823   世茂股份  全国地产  0.87   13.0
# 3482  600748   上实发展  全国地产  0.88   14.0
# 3691  600510    黑牡丹  全国地产  0.92   15.0
# 3606  600606   绿地控股  全国地产  0.94   16.0
# 308   000797   中国武夷  全国地产  1.02   17.0
# 4041  600077   宋都股份  全国地产  1.03   18.0
# 3542  600684   珠江实业  全国地产  1.04   19.0
# 24    000031    大悦城  全国地产  1.05   20.0
# 3769  600393   粤泰股份  全国地产  1.16   21.0
# 3778  600383   金地集团  全国地产  1.19   22.0
# 3687  600515   海航基础  全国地产  1.20   23.0
# 3956  600173   卧龙地产  全国地产  1.24   24.0
# 28    000036   华联控股  全国地产  1.25   25.0
# 220   000667   美好置业  全国地产  1.27   26.0
# 3444  600791   京能置业  全国地产  1.30   27.5
# 4066  600048   保利地产  全国地产  1.30   27.5
# 3966  600162   香江控股  全国地产  1.37   29.0
# 454   001979   招商蛇口  全国地产  1.61   30.0
# 274   000736   中交地产  全国地产  1.67   31.5
# 1     000002   万 科Ａ  全国地产  1.67   31.5
# 187   000615   京汉股份  全国地产  1.98   33.0
# 11    000014   沙河股份  全国地产  2.09   34.0
# 389   000918    嘉凯城  全国地产  3.16   35.0

# %% [markdown]
# # 3. 市现率：
#
# 股票价格/每股现金流量；越低，说明每股现金增加额越多，经营压力越小

# %%
fin_data['市现率'][0]
# Out:
# 10.86

# %%
fin_name3 = '市现率'
rank_col_name3 = fin_name3+"排名"
score_col_name3 = fin_name3+"排名分数"

fin_data[fin_name3] = fin_data[fin_name3].apply(lambda x: str(x))
fin_data[fin_name3] = fin_data[fin_name3].apply(lambda x: x.replace(" ",""))
fin_data[fin_name3] = fin_data[fin_name3].apply(lambda x: x.replace("--",""))
fin_data[fin_name3] = fin_data[fin_name3].apply(lambda x: x.strip("\n"))
fin_data[fin_name3] = fin_data[fin_name3].apply(lambda x: x.strip("\t"))
fin_data[fin_name3] = fin_data[fin_name3].apply(lambda x: x.strip("\""))

# %%
fin_data = fin_data.replace(r'', np.NaN)
for i, item in enumerate(fin_data[fin_name3]):
    try:
        fin_data[fin_name3][i] = float(fin_data[fin_name3][i])
    except:
        # to see if there's any value/row that cannot be converted to float
        print(fin_data[fin_name3][i], i)
# Out:
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for i, item in enumerate(fin_data[fin_name3]):
    if type(eval(str(fin_data[fin_name3][i]))) == float:
        pass
    else:
        print(i, fin_data[fin_name3][i])

# %%
fin_data[fin_name3] = fin_data[fin_name3].apply(ensure_float)


# 需要处理负数问题


fin_data[rank_col_name3] = fin_data.groupby(['细分行业'])[fin_name3].rank(ascending = True)
fin_data[fin_data['细分行业']=="全国地产"][['代码','名称','细分行业',fin_name3,rank_col_name3]].sort_values(rank_col_name3)
# Out:
#           代码     名称  细分行业     市现率  市现率排名
# 4049  600067   冠城大通  全国地产 -191.01    1.0
# 3927  600208   新湖中宝  全国地产  -42.45    2.0
# 389   000918    嘉凯城  全国地产  -41.39    3.0
# 3691  600510    黑牡丹  全国地产  -21.20    4.0
# 188   000616   海航投资  全国地产  -19.16    5.0
# 3687  600515   海航基础  全国地产  -12.73    6.0
# 187   000615   京汉股份  全国地产  -11.11    7.0
# 4066  600048   保利地产  全国地产  -10.40    8.0
# 28    000036   华联控股  全国地产   -7.57    9.0
# 3645  600565   迪马股份  全国地产   -4.60   10.0
# 597   002146   荣盛发展  全国地产   -4.02   11.0
# 3542  600684   珠江实业  全国地产   -3.26   12.0
# 3444  600791   京能置业  全国地产   -2.08   13.0
# 4041  600077   宋都股份  全国地产   -1.69   14.0
# 274   000736   中交地产  全国地产   -0.35   15.0
# 191   000620    新华联  全国地产    2.08   16.0
# 3563  600657   信达地产  全国地产    2.14   17.0
# 3556  600665    天地源  全国地产    2.55   18.0
# 24    000031    大悦城  全国地产    3.19   19.0
# 3520  600708   光明地产  全国地产    3.37   20.0
# 585   002133   广宇集团  全国地产    3.50   21.0
# 308   000797   中国武夷  全国地产    4.07   22.0
# 1     000002   万 科Ａ  全国地产   10.11   23.0
# 454   001979   招商蛇口  全国地产   11.16   24.0
# 3415  600823   世茂股份  全国地产   11.86   25.0
# 3606  600606   绿地控股  全国地产   15.10   26.0
# 11    000014   沙河股份  全国地产   15.91   27.0
# 3966  600162   香江控股  全国地产   17.65   28.0
# 3482  600748   上实发展  全国地产   19.30   29.0
# 3956  600173   卧龙地产  全国地产   19.81   30.0
# 33    000042   中洲控股  全国地产   51.48   31.0
# 3778  600383   金地集团  全国地产   56.39   32.0
# 220   000667   美好置业  全国地产  133.68   33.0
# 73    000402  金 融 街  全国地产  139.15   34.0
# 3769  600393   粤泰股份  全国地产  358.63   35.0

# %% [markdown]
# # 4. 市销率：
#
# Price-to-Sales Ratio，每股股价／每股销售额；越低，说明该公司股票的投资价值越大

# %%
fin_data['市销率'][0]
# Out:
# 2.86

# %%
fin_name4 = '市销率'
rank_col_name4 = fin_name4+"排名"
score_col_name4 = fin_name4+"排名分数"

fin_data[fin_name4] = fin_data[fin_name4].apply(lambda x: str(x))
fin_data[fin_name4] = fin_data[fin_name4].apply(lambda x: x.replace(" ",""))
fin_data[fin_name4] = fin_data[fin_name4].apply(lambda x: x.replace("--",""))
fin_data[fin_name4] = fin_data[fin_name4].apply(lambda x: x.strip("\n"))
fin_data[fin_name4] = fin_data[fin_name4].apply(lambda x: x.strip("\t"))
fin_data[fin_name4] = fin_data[fin_name4].apply(lambda x: x.strip("\""))

# %%
fin_data = fin_data.replace(r'', np.NaN)
for i, item in enumerate(fin_data[fin_name4]):
    try:
        fin_data[fin_name4][i] = float(fin_data[fin_name4][i])
    except:
        # to see if there's any value/row that cannot be converted to float
        print(fin_data[fin_name4][i], i)
# Out:
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
fin_data[fin_name4] = fin_data[fin_name4].apply(ensure_float)
fin_data[rank_col_name4] = fin_data.groupby(['细分行业'])[fin_name4].rank(ascending = True)
fin_data[fin_data['细分行业']=="全国地产"][['代码','名称','细分行业',fin_name4,rank_col_name4]].sort_values(rank_col_name4)
# Out:
#           代码     名称  细分行业    市销率  市销率排名
# 3606  600606   绿地控股  全国地产   0.24    1.0
# 274   000736   中交地产  全国地产   0.62    2.0
# 585   002133   广宇集团  全国地产   0.63    3.0
# 597   002146   荣盛发展  全国地产   0.70    4.0
# 3563  600657   信达地产  全国地产   0.99    5.0
# 4049  600067   冠城大通  全国地产   1.02    6.0
# 33    000042   中洲控股  全国地产   1.06    7.0
# 24    000031    大悦城  全国地产   1.14    8.0
# 3520  600708   光明地产  全国地产   1.19    9.0
# 3645  600565   迪马股份  全国地产   1.20   10.0
# 3691  600510    黑牡丹  全国地产   1.21   11.0
# 4041  600077   宋都股份  全国地产   1.34   12.0
# 3542  600684   珠江实业  全国地产   1.38   13.0
# 1     000002   万 科Ａ  全国地产   1.40   14.0
# 3778  600383   金地集团  全国地产   1.56   15.0
# 191   000620    新华联  全国地产   1.58   16.0
# 4066  600048   保利地产  全国地产   1.61   17.0
# 3482  600748   上实发展  全国地产   1.79   18.0
# 3415  600823   世茂股份  全国地产   1.86   19.0
# 73    000402  金 融 街  全国地产   1.96   20.0
# 3556  600665    天地源  全国地产   1.97   21.0
# 454   001979   招商蛇口  全国地产   2.28   22.0
# 187   000615   京汉股份  全国地产   2.36   23.0
# 3769  600393   粤泰股份  全国地产   2.41   24.0
# 28    000036   华联控股  全国地产   2.42   25.0
# 308   000797   中国武夷  全国地产   2.81   26.0
# 3927  600208   新湖中宝  全国地产   3.39   27.0
# 3956  600173   卧龙地产  全国地产   3.74   28.0
# 220   000667   美好置业  全国地产   4.04   29.0
# 3966  600162   香江控股  全国地产   4.25   30.0
# 3687  600515   海航基础  全国地产   7.88   31.0
# 11    000014   沙河股份  全国地产   8.20   32.0
# 389   000918    嘉凯城  全国地产  12.55   33.0
# 3444  600791   京能置业  全国地产  14.16   34.0
# 188   000616   海航投资  全国地产  88.30   35.0

# %% [markdown]
# # 5. 股息率%：
#
# Dividend Yield Ratio，股息／股票价格；是一年的总派息额与当时市价的比例。该指标是投资收益率的简化形式；越大越好

# %%
fin_data['股息率%'][0]
# Out:
# 1.23

# %%
fin_name5 = '股息率%'
rank_col_name5 = fin_name5+"排名"
score_col_name5 = fin_name5+"排名分数"

fin_data[fin_name5] = fin_data[fin_name5].apply(lambda x: str(x))
fin_data[fin_name5] = fin_data[fin_name5].apply(lambda x: x.replace(" ",""))
fin_data[fin_name5] = fin_data[fin_name5].apply(lambda x: x.replace("--",""))
fin_data[fin_name5] = fin_data[fin_name5].apply(lambda x: x.strip("\n"))
fin_data[fin_name5] = fin_data[fin_name5].apply(lambda x: x.strip("\t"))
fin_data[fin_name5] = fin_data[fin_name5].apply(lambda x: x.strip("\""))

# %%
fin_data = fin_data.replace(r'', np.NaN)
for i, item in enumerate(fin_data[fin_name5]):
    try:
        fin_data[fin_name5][i] = float(fin_data[fin_name5][i])
    except:
        # to see if there's any value/row that cannot be converted to float
        print(fin_data[fin_name5][i], i)
# Out:
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
fin_data[fin_name5] = fin_data[fin_name5].apply(ensure_float)
fin_data[rank_col_name5] = fin_data.groupby(['细分行业'])[fin_name5].rank(ascending = False)
fin_data[fin_data['细分行业']=="全国地产"][['代码','名称','细分行业',fin_name5,rank_col_name5]].sort_values(rank_col_name5)
# Out:
#           代码     名称  细分行业  股息率%  股息率%排名
# 28    000036   华联控股  全国地产  9.66     1.0
# 597   002146   荣盛发展  全国地产  6.72     2.0
# 3606  600606   绿地控股  全国地产  6.31     3.0
# 454   001979   招商蛇口  全国地产  5.55     4.0
# 4066  600048   保利地产  全国地产  5.03     5.0
# 3778  600383   金地集团  全国地产  4.69     6.0
# 3415  600823   世茂股份  全国地产  4.34     7.0
# 73    000402  金 融 街  全国地产  4.29     8.0
# 3556  600665    天地源  全国地产  4.20     9.0
# 3520  600708   光明地产  全国地产  3.73    10.0
# 24    000031    大悦城  全国地产  3.57    11.0
# 1     000002   万 科Ａ  全国地产  3.42    12.0
# 3966  600162   香江控股  全国地产  3.27    13.0
# 3956  600173   卧龙地产  全国地产  2.95    14.0
# 3691  600510    黑牡丹  全国地产  2.86    15.0
# 585   002133   广宇集团  全国地产  2.52    16.0
# 3563  600657   信达地产  全国地产  2.31    17.0
# 3482  600748   上实发展  全国地产  1.92    18.0
# 3645  600565   迪马股份  全国地产  1.88    19.0
# 308   000797   中国武夷  全国地产  1.49    20.0
# 33    000042   中洲控股  全国地产  1.32    21.0
# 274   000736   中交地产  全国地产  1.15    22.0
# 4041  600077   宋都股份  全国地产  1.13    23.0
# 3542  600684   珠江实业  全国地产  0.94    24.0
# 3927  600208   新湖中宝  全国地产  0.31    25.0
# 3444  600791   京能置业  全国地产  0.26    26.0
# 11    000014   沙河股份  全国地产  0.12    27.0
# 187   000615   京汉股份  全国地产  0.00    31.5
# 3769  600393   粤泰股份  全国地产  0.00    31.5
# 188   000616   海航投资  全国地产  0.00    31.5
# 4049  600067   冠城大通  全国地产  0.00    31.5
# 191   000620    新华联  全国地产  0.00    31.5
# 220   000667   美好置业  全国地产  0.00    31.5
# 3687  600515   海航基础  全国地产  0.00    31.5
# 389   000918    嘉凯城  全国地产  0.00    31.5

# %% [markdown]
# # 6. 每股收益：
#
# 越大越好

# %%
fin_data[fin_name6][0]
# Out:
# '1.110㈢'

# %%
fin_name6 = '每股收益'
rank_col_name6 = fin_name6+"排名"
score_col_name6 = fin_name6+"排名分数"

fin_data[fin_name6] = fin_data[fin_name6].apply(lambda x: str(x))
fin_data[fin_name6] = fin_data[fin_name6].apply(lambda x: x.replace(" ",""))
fin_data[fin_name6] = fin_data[fin_name6].apply(lambda x: x.replace("㈢",""))
fin_data[fin_name6] = fin_data[fin_name6].apply(lambda x: x.replace("㈣",""))
fin_data[fin_name6] = fin_data[fin_name6].apply(lambda x: x.replace("㈡",""))
fin_data[fin_name6] = fin_data[fin_name6].apply(lambda x: x.replace("--",""))
fin_data[fin_name6] = fin_data[fin_name6].apply(lambda x: x.strip("\n"))
fin_data[fin_name6] = fin_data[fin_name6].apply(lambda x: x.strip("\t"))
fin_data[fin_name6] = fin_data[fin_name6].apply(lambda x: x.strip("\""))


fin_data = fin_data.replace(r'', np.NaN)
for i, item in enumerate(fin_data[fin_name6]):
    try:
        fin_data[fin_name6][i] = float(fin_data[fin_name6][i])
    except:
        # to see if there's any value/row that cannot be converted to float
        print(fin_data[fin_name6][i], i)


fin_data[fin_name6] = fin_data[fin_name6].apply(ensure_float)
fin_data[rank_col_name6] = fin_data.groupby(['细分行业'])[fin_name6].rank(ascending = False)
fin_data[fin_data['细分行业']=="全国地产"][['代码','名称','细分行业',fin_name6,rank_col_name6]].sort_values(rank_col_name6)
# Out:
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           代码     名称  细分行业   每股收益  每股收益排名
# 1     000002   万 科Ａ  全国地产  1.740     1.0
# 3778  600383   金地集团  全国地产  1.110     2.5
# 4066  600048   保利地产  全国地产  1.110     2.5
# 597   002146   荣盛发展  全国地产  1.010     4.0
# 3606  600606   绿地控股  全国地产  0.990     5.0
# 3691  600510    黑牡丹  全国地产  0.700     6.0
# 274   000736   中交地产  全国地产  0.410     7.0
# 3563  600657   信达地产  全国地产  0.390     8.0
# 28    000036   华联控股  全国地产  0.360     9.0
# 3927  600208   新湖中宝  全国地产  0.320    10.0
# 73    000402  金 融 街  全国地产  0.300    11.0
# 3956  600173   卧龙地产  全国地产  0.292    12.0
# 3415  600823   世茂股份  全国地产  0.290    13.0
# 4049  600067   冠城大通  全国地产  0.280    14.0
# 3482  600748   上实发展  全国地产  0.220    15.0
# 3687  600515   海航基础  全国地产  0.208    16.0
# 454   001979   招商蛇口  全国地产  0.190    17.0
# 24    000031    大悦城  全国地产  0.180    18.5
# 585   002133   广宇集团  全国地产  0.180    18.5
# 3556  600665    天地源  全国地产  0.153    20.0
# 33    000042   中洲控股  全国地产  0.148    21.0
# 3645  600565   迪马股份  全国地产  0.140    22.0
# 4041  600077   宋都股份  全国地产  0.130    23.0
# 3769  600393   粤泰股份  全国地产  0.080    24.0
# 11    000014   沙河股份  全国地产  0.069    25.0
# 3966  600162   香江控股  全国地产 -0.003    26.0
# 3542  600684   珠江实业  全国地产 -0.020    27.0
# 188   000616   海航投资  全国地产 -0.023    28.0
# 308   000797   中国武夷  全国地产 -0.056    29.0
# 220   000667   美好置业  全国地产 -0.058    30.0
# 3520  600708   光明地产  全国地产 -0.100    31.0
# 187   000615   京汉股份  全国地产 -0.123    32.0
# 3444  600791   京能置业  全国地产 -0.150    33.0
# 191   000620    新华联  全国地产 -0.360    34.0
# 389   000918    嘉凯城  全国地产 -0.560    35.0

# %% [markdown]
# # 7. 每股净资：
#
# 越大越好

# %%
fin_data['每股净资'][0]
# Out:
# '14.88'

# %%
fin_name7 = '每股净资'
rank_col_name7 = fin_name7+"排名"
score_col_name7 = fin_name7+"排名分数"

fin_data[fin_name7] = fin_data[fin_name7].apply(lambda x: str(x))
fin_data[fin_name7] = fin_data[fin_name7].apply(lambda x: x.replace(" ",""))
fin_data[fin_name7] = fin_data[fin_name7].apply(lambda x: x.replace("--",""))
fin_data[fin_name7] = fin_data[fin_name7].apply(lambda x: x.strip("\n"))
fin_data[fin_name7] = fin_data[fin_name7].apply(lambda x: x.strip("\t"))
fin_data[fin_name7] = fin_data[fin_name7].apply(lambda x: x.strip("\""))



fin_data = fin_data.replace(r'', np.NaN)
for i, item in enumerate(fin_data[fin_name7]):
    try:
        fin_data[fin_name7][i] = float(fin_data[fin_name7][i])
    except:
        # to see if there's any value/row that cannot be converted to float
        print(fin_data[fin_name7][i], i)
        
        
fin_data[fin_name7] = fin_data[fin_name7].apply(ensure_float)
fin_data[rank_col_name7] = fin_data.groupby(['细分行业'])[fin_name7].rank(ascending = False)
fin_data[fin_data['细分行业']=="全国地产"][['代码','名称','细分行业',fin_name7,rank_col_name7]].sort_values(rank_col_name7)
# Out:
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
#           代码     名称  细分行业   每股净资  每股净资排名
# 1     000002   万 科Ａ  全国地产  17.45     1.0
# 4066  600048   保利地产  全国地产  12.15     2.0
# 33    000042   中洲控股  全国地产  11.65     3.0
# 73    000402  金 融 街  全国地产  11.64     4.0
# 3778  600383   金地集团  全国地产  11.63     5.0
# 597   002146   荣盛发展  全国地产   9.86     6.0
# 454   001979   招商蛇口  全国地产   8.99     7.0
# 3691  600510    黑牡丹  全国地产   8.45     8.0
# 3563  600657   信达地产  全国地产   7.96     9.0
# 3415  600823   世茂股份  全国地产   6.84    10.0
# 3606  600606   绿地控股  全国地产   6.64    11.0
# 3687  600515   海航基础  全国地产   6.17    12.0
# 3482  600748   上实发展  全国地产   5.85    13.0
# 4049  600067   冠城大通  全国地产   5.46    14.0
# 3520  600708   光明地产  全国地产   4.91    15.0
# 585   002133   广宇集团  全国地产   4.51    16.0
# 24    000031    大悦城  全国地产   4.50    17.0
# 11    000014   沙河股份  全国地产   4.48    18.0
# 3927  600208   新湖中宝  全国地产   4.32    19.0
# 274   000736   中交地产  全国地产   4.30    20.5
# 3556  600665    天地源  全国地产   4.30    20.5
# 3956  600173   卧龙地产  全国地产   4.09    22.0
# 191   000620    新华联  全国地产   3.81    23.0
# 3645  600565   迪马股份  全国地产   3.66    24.0
# 3444  600791   京能置业  全国地产   3.53    25.0
# 4041  600077   宋都股份  全国地产   3.42    26.0
# 28    000036   华联控股  全国地产   3.29    27.0
# 308   000797   中国武夷  全国地产   3.20    28.0
# 188   000616   海航投资  全国地产   3.07    29.0
# 3542  600684   珠江实业  全国地产   3.06    30.0
# 220   000667   美好置业  全国地产   2.81    31.0
# 3769  600393   粤泰股份  全国地产   2.46    32.0
# 187   000615   京汉股份  全国地产   2.23    33.0
# 3966  600162   香江控股  全国地产   1.50    34.0
# 389   000918    嘉凯城  全国地产   1.42    35.0

# %% [markdown]
# # 8. 每股现金流：
#
# 越大越好

# %%
fin_data['每股现金流'][0]
# Out:
# '1.58'

# %%
fin_name8 = '每股现金流'
rank_col_name8 = fin_name8+"排名"
score_col_name8 = fin_name8+"排名分数"

fin_data[fin_name8] = fin_data[fin_name8].apply(lambda x: str(x))
fin_data[fin_name8] = fin_data[fin_name8].apply(lambda x: x.replace(" ",""))
fin_data[fin_name8] = fin_data[fin_name8].apply(lambda x: x.replace("--",""))
fin_data[fin_name8] = fin_data[fin_name8].apply(lambda x: x.strip("\n"))
fin_data[fin_name8] = fin_data[fin_name8].apply(lambda x: x.strip("\t"))
fin_data[fin_name8] = fin_data[fin_name8].apply(lambda x: x.strip("\""))



fin_data = fin_data.replace(r'', np.NaN)
for i, item in enumerate(fin_data[fin_name8]):
    try:
        fin_data[fin_name8][i] = float(fin_data[fin_name8][i])
    except:
        # to see if there's any value/row that cannot be converted to float
        print(fin_data[fin_name8][i], i)
        
        
fin_data[fin_name8] = fin_data[fin_name8].apply(ensure_float)
fin_data[rank_col_name8] = fin_data.groupby(['细分行业'])[fin_name8].rank(ascending = False)
fin_data[fin_data['细分行业']=="全国地产"][['代码','名称','细分行业',fin_name8,rank_col_name8]].sort_values(rank_col_name8)
# Out:
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
#           代码     名称  细分行业  每股现金流  每股现金流排名
# 1     000002   万 科Ａ  全国地产   2.87      1.0
# 3563  600657   信达地产  全国地产   2.00      2.0
# 24    000031    大悦城  全国地产   1.49      3.0
# 191   000620    新华联  全国地产   1.42      4.0
# 3556  600665    天地源  全国地产   1.37      5.0
# 454   001979   招商蛇口  全国地产   1.29      6.0
# 585   002133   广宇集团  全国地产   0.90      7.0
# 308   000797   中国武夷  全国地产   0.80      8.0
# 3520  600708   光明地产  全国地产   0.79      9.0
# 11    000014   沙河股份  全国地产   0.59     10.0
# 3415  600823   世茂股份  全国地产   0.50     11.0
# 3606  600606   绿地控股  全国地产   0.41     12.0
# 3482  600748   上实发展  全国地产   0.27     13.0
# 3956  600173   卧龙地产  全国地产   0.26     14.0
# 3778  600383   金地集团  全国地产   0.25     15.0
# 33    000042   中洲控股  全国地产   0.18     16.0
# 3966  600162   香江控股  全国地产   0.12     17.0
# 73    000402  金 融 街  全国地产   0.05     18.0
# 220   000667   美好置业  全国地产   0.03     19.0
# 3769  600393   粤泰股份  全国地产   0.01     20.0
# 4049  600067   冠城大通  全国地产  -0.02     21.0
# 3927  600208   新湖中宝  全国地产  -0.07     22.0
# 389   000918    嘉凯城  全国地产  -0.11     23.0
# 188   000616   海航投资  全国地产  -0.14     24.0
# 3691  600510    黑牡丹  全国地产  -0.37     25.0
# 187   000615   京汉股份  全国地产  -0.40     26.0
# 28    000036   华联控股  全国地产  -0.54     27.0
# 3687  600515   海航基础  全国地产  -0.58     28.0
# 3645  600565   迪马股份  全国地产  -0.65     29.0
# 3542  600684   珠江实业  全国地产  -0.98     30.0
# 4066  600048   保利地产  全国地产  -1.52     31.0
# 597   002146   荣盛发展  全国地产  -1.75     32.0
# 4041  600077   宋都股份  全国地产  -2.08     33.0
# 3444  600791   京能置业  全国地产  -2.22     34.0
# 274   000736   中交地产  全国地产 -20.42     35.0

# %% [markdown]
# # 9. 净益率（净资产收益率）%：
#
# ROE；该指标体现了自有资本活得净收益的能力；指标越高，说明投资带来的收益越高。

# %%
fin_data['净益率%'][0]
# Out:
# '   6.24㈢'

# %%
fin_name9 = '净益率%'
rank_col_name9 = fin_name9+"排名"
score_col_name9 = fin_name9+"排名分数"

fin_data[fin_name9] = fin_data[fin_name9].apply(lambda x: str(x))
fin_data[fin_name9] = fin_data[fin_name9].apply(lambda x: x.replace(" ",""))
fin_data[fin_name9] = fin_data[fin_name9].apply(lambda x: x.replace("㈢",""))
fin_data[fin_name9] = fin_data[fin_name9].apply(lambda x: x.replace("㈣",""))
fin_data[fin_name9] = fin_data[fin_name9].apply(lambda x: x.replace("㈡",""))
fin_data[fin_name9] = fin_data[fin_name9].apply(lambda x: x.replace("--",""))
fin_data[fin_name9] = fin_data[fin_name9].apply(lambda x: x.strip("\n"))
fin_data[fin_name9] = fin_data[fin_name9].apply(lambda x: x.strip("\t"))
fin_data[fin_name9] = fin_data[fin_name9].apply(lambda x: x.strip("\""))


fin_data = fin_data.replace(r'', np.NaN)
for i, item in enumerate(fin_data[fin_name9]):
    try:
        fin_data[fin_name9][i] = float(fin_data[fin_name9][i])
    except:
        # to see if there's any value/row that cannot be converted to float
        print(fin_data[fin_name9][i], i)


fin_data[fin_name9] = fin_data[fin_name9].apply(ensure_float)
fin_data[rank_col_name9] = fin_data.groupby(['细分行业'])[fin_name9].rank(ascending = False)
fin_data[fin_data['细分行业']=="全国地产"][['代码','名称','细分行业',fin_name9,rank_col_name9]].sort_values(rank_col_name9)
# Out:
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           代码     名称  细分行业   净益率%  净益率%排名
# 3606  600606   绿地控股  全国地产  14.91     1.0
# 28    000036   华联控股  全国地产  10.89     2.0
# 597   002146   荣盛发展  全国地产  10.27     3.0
# 1     000002   万 科Ａ  全国地产   9.80     4.0
# 274   000736   中交地产  全国地产   9.57     5.0
# 3778  600383   金地集团  全国地产   9.49     6.0
# 3691  600510    黑牡丹  全国地产   8.05     7.0
# 4066  600048   保利地产  全国地产   7.97     8.0
# 3927  600208   新湖中宝  全国地产   7.36     9.0
# 3956  600173   卧龙地产  全国地产   7.15    10.0
# 3563  600657   信达地产  全国地产   4.86    11.0
# 4049  600067   冠城大通  全国地产   4.75    12.0
# 3415  600823   世茂股份  全国地产   4.21    13.0
# 585   002133   广宇集团  全国地产   4.10    14.0
# 24    000031    大悦城  全国地产   3.94    15.0
# 3482  600748   上实发展  全国地产   3.79    16.0
# 4041  600077   宋都股份  全国地产   3.63    17.0
# 3556  600665    天地源  全国地产   3.56    18.0
# 3645  600565   迪马股份  全国地产   3.49    19.0
# 3687  600515   海航基础  全国地产   3.38    20.0
# 3769  600393   粤泰股份  全国地产   3.22    21.0
# 73    000402  金 融 街  全国地产   2.62    22.0
# 454   001979   招商蛇口  全国地产   2.51    23.0
# 11    000014   沙河股份  全国地产   1.53    24.0
# 33    000042   中洲控股  全国地产   1.27    25.0
# 3966  600162   香江控股  全国地产  -0.17    26.0
# 3542  600684   珠江实业  全国地产  -0.50    27.0
# 3520  600708   光明地产  全国地产  -0.56    28.0
# 188   000616   海航投资  全国地产  -0.76    29.0
# 308   000797   中国武夷  全国地产  -1.66    30.0
# 220   000667   美好置业  全国地产  -2.07    31.0
# 3444  600791   京能置业  全国地产  -3.00    32.0
# 187   000615   京汉股份  全国地产  -5.53    33.0
# 191   000620    新华联  全国地产  -9.41    34.0
# 389   000918    嘉凯城  全国地产 -39.07    35.0

# %% [markdown]
# # 10. 营业利润率%：
#
# Operating Profit Ratio；营业利润／全部业务收入*100%；越大越好

# %%
fin_data['营业利润率%'][0]
# Out:
# '24.81'

# %%
fin_name10 = '营业利润率%'
rank_col_name10 = fin_name10+"排名"
score_col_name10 = fin_name10+"排名分数"

fin_data[fin_name10] = fin_data[fin_name10].apply(lambda x: str(x))
fin_data[fin_name10] = fin_data[fin_name10].apply(lambda x: x.replace(" ",""))
fin_data[fin_name10] = fin_data[fin_name10].apply(lambda x: x.replace("--",""))
fin_data[fin_name10] = fin_data[fin_name10].apply(lambda x: x.strip("\n"))
fin_data[fin_name10] = fin_data[fin_name10].apply(lambda x: x.strip("\t"))
fin_data[fin_name10] = fin_data[fin_name10].apply(lambda x: x.strip("\""))


fin_data = fin_data.replace(r'', np.NaN)
for i, item in enumerate(fin_data[fin_name10]):
    try:
        fin_data[fin_name10][i] = float(fin_data[fin_name10][i])
    except:
        # to see if there's any value/row that cannot be converted to float
        print(fin_data[fin_name10][i], i)


fin_data[fin_name10] = fin_data[fin_name10].apply(ensure_float)
fin_data[rank_col_name10] = fin_data.groupby(['细分行业'])[fin_name10].rank(ascending = False)
fin_data[fin_data['细分行业']=="全国地产"][['代码','名称','细分行业',fin_name10,rank_col_name10]].sort_values(rank_col_name10)
# Out:
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#           代码     名称  细分行业  营业利润率%  营业利润率%排名
# 28    000036   华联控股  全国地产   40.02       1.0
# 3687  600515   海航基础  全国地产   29.69       2.0
# 3778  600383   金地集团  全国地产   29.30       3.0
# 3956  600173   卧龙地产  全国地产   28.86       4.0
# 3927  600208   新湖中宝  全国地产   26.89       5.0
# 3691  600510    黑牡丹  全国地产   22.86       6.0
# 3415  600823   世茂股份  全国地产   22.21       7.0
# 4066  600048   保利地产  全国地产   20.65       8.0
# 3563  600657   信达地产  全国地产   17.64       9.0
# 1     000002   万 科Ａ  全国地产   17.46      10.0
# 24    000031    大悦城  全国地产   15.33      11.0
# 73    000402  金 融 街  全国地产   15.31      12.0
# 597   002146   荣盛发展  全国地产   15.04      13.0
# 274   000736   中交地产  全国地产   14.27      14.0
# 3482  600748   上实发展  全国地产   13.63      15.0
# 4049  600067   冠城大通  全国地产   11.92      16.0
# 454   001979   招商蛇口  全国地产   10.52      17.0
# 3556  600665    天地源  全国地产   10.45      18.0
# 187   000615   京汉股份  全国地产    8.08      19.0
# 4041  600077   宋都股份  全国地产    7.65      20.0
# 3769  600393   粤泰股份  全国地产    7.28      21.0
# 3606  600606   绿地控股  全国地产    7.25      22.0
# 11    000014   沙河股份  全国地产    6.50      23.0
# 585   002133   广宇集团  全国地产    5.18      24.0
# 3645  600565   迪马股份  全国地产    3.45      25.0
# 3542  600684   珠江实业  全国地产    3.26      26.0
# 33    000042   中洲控股  全国地产    3.16      27.0
# 3520  600708   光明地产  全国地产    0.81      28.0
# 3966  600162   香江控股  全国地产   -2.32      29.0
# 308   000797   中国武夷  全国地产   -7.18      30.0
# 220   000667   美好置业  全国地产  -10.42      31.0
# 191   000620    新华联  全国地产  -17.40      32.0
# 3444  600791   京能置业  全国地产  -45.50      33.0
# 188   000616   海航投资  全国地产  -87.28      34.0
# 389   000918    嘉凯城  全国地产 -124.02      35.0

# %% [markdown]
# # 11. 净利润率%：
#
# 净利润/营业收入×100%；越大越好

# %%
fin_data['净利润率%'][0]
# Out:
# '19.22'

# %%
fin_name11 = '净利润率%'
rank_col_name11 = fin_name11+"排名"
score_col_name11 = fin_name11+"排名分数"

fin_data[fin_name11] = fin_data[fin_name11].apply(lambda x: str(x))
fin_data[fin_name11] = fin_data[fin_name11].apply(lambda x: x.replace(" ",""))
fin_data[fin_name11] = fin_data[fin_name11].apply(lambda x: x.replace("--",""))
fin_data[fin_name11] = fin_data[fin_name11].apply(lambda x: x.strip("\n"))
fin_data[fin_name11] = fin_data[fin_name11].apply(lambda x: x.strip("\t"))
fin_data[fin_name11] = fin_data[fin_name11].apply(lambda x: x.strip("\""))


fin_data = fin_data.replace(r'', np.NaN)
for i, item in enumerate(fin_data[fin_name11]):
    try:
        fin_data[fin_name11][i] = float(fin_data[fin_name11][i])
    except:
        # to see if there's any value/row that cannot be converted to float
        print(fin_data[fin_name11][i], i)


fin_data[fin_name11] = fin_data[fin_name11].apply(ensure_float)
fin_data[rank_col_name11] = fin_data.groupby(['细分行业'])[fin_name11].rank(ascending = False)
fin_data[fin_data['细分行业']=="全国地产"][['代码','名称','细分行业',fin_name11,rank_col_name11]].sort_values(rank_col_name11)
# Out:
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#           代码     名称  细分行业   净利润率%  净利润率%排名
# 3927  600208   新湖中宝  全国地产   34.07      1.0
# 3687  600515   海航基础  全国地产   22.14      2.0
# 3956  600173   卧龙地产  全国地产   21.62      3.0
# 28    000036   华联控股  全国地产   21.08      4.0
# 3778  600383   金地集团  全国地产   12.42      5.0
# 4066  600048   保利地产  全国地产   11.25      6.0
# 3691  600510    黑牡丹  全国地产   10.58      7.0
# 597   002146   荣盛发展  全国地产   10.09      8.0
# 3563  600657   信达地产  全国地产    9.01      9.0
# 3415  600823   世茂股份  全国地产    9.00     10.0
# 73    000402  金 融 街  全国地产    8.65     11.0
# 3556  600665    天地源  全国地产    8.58     12.0
# 3482  600748   上实发展  全国地产    8.44     13.0
# 1     000002   万 科Ａ  全国地产    8.23     14.0
# 4049  600067   冠城大通  全国地产    6.90     15.0
# 3769  600393   粤泰股份  全国地产    6.72     16.0
# 11    000014   沙河股份  全国地产    6.01     17.0
# 3645  600565   迪马股份  全国地产    5.13     18.0
# 4041  600077   宋都股份  全国地产    4.73     19.0
# 454   001979   招商蛇口  全国地产    4.37     20.0
# 24    000031    大悦城  全国地产    4.27     21.0
# 3606  600606   绿地控股  全国地产    3.75     22.0
# 585   002133   广宇集团  全国地产    3.69     23.0
# 274   000736   中交地产  全国地产    3.56     24.0
# 33    000042   中洲控股  全国地产    1.72     25.0
# 3966  600162   香江控股  全国地产   -0.54     26.0
# 3542  600684   珠江实业  全国地产   -0.66     27.0
# 3520  600708   光明地产  全国地产   -1.57     28.0
# 308   000797   中国武夷  全国地产   -4.84     29.0
# 220   000667   美好置业  全国地产   -6.55     30.0
# 187   000615   京汉股份  全国地产   -6.58     31.0
# 191   000620    新华联  全国地产  -19.13     32.0
# 3444  600791   京能置业  全国地产  -45.30     33.0
# 188   000616   海航投资  全国地产  -79.82     34.0
# 389   000918    嘉凯城  全国地产 -155.17     35.0

# %% [markdown]
# # Check ALL

# %% [markdown]
# array(['银行', '全国地产', '互联网', '环境保护', '区域地产', '酒店餐饮', '运输设备', '综合类', '建筑工程',
#        '玻璃', '家用电器', '文教休闲', '其他商业', '元器件', 'IT设备', '其他建材', '汽车服务',
#        '火力发电', '医药商业', '汽车配件', '广告包装', '轻工机械', '新型电力', '多元金融', '饲料',
#        '电气设备', '房产服务', '石油加工', '铅锌', '农业综合', '批发业', '通信设备', '旅游景点', '港口',
#        '机场', '石油贸易', '空运', '医疗保健', '商贸代理', '化学制药', '影视音像', '工程机械', '软件服务',
#        '证券', '化纤', '水泥', '生物制药', '专用机械', '供气供热', '农药化肥', '机床制造', '百货',
#        '中成药', '路桥', '造纸', '食品', '黄金', '化工原料', '矿物制品', '水运', '日用化工',
#        '机械基件', '汽车整车', '煤炭开采', '铁路', '染料涂料', '白酒', '林业', '水务', '水力发电',
#        '旅游服务', '纺织', '铝', '保险', '园区开发', '小金属', '铜', '普钢', '航空', '特种钢',
#        '种植业', '出版业', '焦炭加工', '啤酒', '公路', '超市连锁', '钢加工', '渔业', '农用机械',
#        '软饮料', '化工机械', '塑料', '红黄酒', '橡胶', '家居用品', '摩托车', '电器仪表', '服饰',
#        '仓储物流', '纺织机械', '电器连锁', '装修装饰', '半导体', '电信运营', '石油开采', '乳制品',
#        '商品城', '公共交通', '陶瓷', '船舶', nan], dtype=object)

# %% [markdown]
# - 1. 市盈(TTM)：Price Earnings Ratio；股票价格／每股收益；越小越好
#
# - 2. 市净率：Price-to-Book Ratio:，每股股价／每股净资产；越低，投资价值越高
#
# - 3. 市现率：股票价格/每股现金流量；越低，说明每股现金增加额越多，经营压力越小
#
# - 4. 市销率：Price-to-Sales Ratio，每股股价／每股销售额；越低，说明该公司股票的投资价值越大
#
# - 5. 股息率%：Dividend Yield Ratio，股息／股票价格；是一年的总派息额与当时市价的比例。该指标是投资收益率的简化形式；越大越好
#
# - 6. 每股收益：越大越好
#
# - 7. 每股净资：越大越好
#
# - 8. 每股现金流：越大越好
#
# - 9. 净益率（净资产收益率）%：ROE；该指标体现了自有资本活得净收益的能力；指标越高，说明投资带来的收益越高。
#
# - 10. 营业利润率%：Operating Profit Ratio；营业利润／全部业务收入*100%；越大越好
#
# - 11. 净利润率%：净利润/营业收入×100%；越大越好

# %%
fin_data[fin_data['细分行业']=="食品"][['代码','名称','细分行业','财务更新',
                                    rank_col_name0,
                                    rank_col_name1,
                                    rank_col_name2,
#                                     rank_col_name3,
                                    rank_col_name4,
                                    rank_col_name5,
                                    rank_col_name6,
                                    rank_col_name7,
                                    rank_col_name8,
                                    rank_col_name9,
                                    rank_col_name10,
                                    rank_col_name11,
                                   ]].sort_values(rank_col_name11)
# Out:
#           代码    名称 细分行业        财务更新  流通市值排名  市盈(TTM)排名  市净率排名  市销率排名  股息率%排名  \
# 1025  002582   好想你   食品  20201031.0    32.0        1.0    2.0   18.0    27.5
# 2154  300741  华宝股份   食品  20201028.0    31.0       16.0   34.0   63.0     3.0
# 2487  688089   嘉必优   食品  20201029.0    66.0       31.0   35.0   64.0    19.0
# 1824  300401  花园生物   食品  20201029.0    28.0       19.0   22.0   57.0    62.5
# 3941  600191  华资实业   食品  20201031.0    53.0        NaN    3.0   66.0    45.5
# ...      ...   ...  ...         ...     ...        ...    ...    ...     ...
# 1603  300175  朗源股份   食品  20201028.0    55.0       61.0   23.0   40.0    53.0
# 257   000716   黑芝麻   食品  20201029.0    61.0        NaN    1.0    6.0    29.0
# 2705  603777   来伊份   食品  20201102.0    36.0        NaN   20.0   12.0    25.0
# 940   002495  佳隆股份   食品  20201031.0    64.0        NaN    8.0   58.0    62.5
# 429   000972  ST中基   食品  20201030.0    63.0        NaN   38.0   69.0    62.5
#
#       每股收益排名  每股净资排名  每股现金流排名  净益率%排名  营业利润率%排名  净利润率%排名
# 1025     1.0     7.0     68.0     1.0       1.0      1.0
# 2154     7.0     4.0     15.0    27.0       2.0      2.0
# 2487    18.0     8.0     24.0    41.0       4.0      3.0
# 1824    34.0    31.0     35.0    46.0       3.0      4.0
# 3941    61.0    42.0     63.0    64.0       9.0      5.0
# ...      ...     ...      ...     ...       ...      ...
# 1603    64.0    62.0     59.0    65.0      68.0     65.0
# 257     67.0    46.0     40.0    67.0      66.0     66.0
# 2705    69.0    34.0     52.0    68.0      65.0     67.0
# 940     66.0    65.0     62.0    66.0      67.0     68.0
# 429     68.0    66.0     61.0    69.0      69.0     69.0
#
# [69 rows x 15 columns]

# %%
fin_data
# Out:
#           代码    名称    涨幅%     现价     涨跌     买价     卖价         总量       现量  \
# 0     000001  平安银行  -2.72  17.18  -0.48  17.17  17.18  1289189.0  11541.0
# 1     000002  万 科Ａ  -2.39  29.05  -0.71  29.04  29.05   660135.0   5732.0
# 2     000004  国农科技    0.1  30.62   0.03  30.62  30.65    71323.0    896.0
# 3     000005  世纪星源   2.29   2.68   0.06   2.67   2.68   136360.0    679.0
# 4     000006  深振业Ａ  -1.22   5.67  -0.07   5.67   5.68    96442.0   1311.0
# ...      ...   ...    ...    ...    ...    ...    ...        ...      ...
# 4093  600008  首创股份   0.99   3.06   0.03   3.06   3.07   662676.0  15518.0
# 4094  600007  中国国贸  -0.47  12.78  -0.06  12.77  12.78    13812.0    102.0
# 4095  600006  东风汽车   0.63   6.36   0.04   6.36   6.37   523954.0   3177.0
# 4096  600004  白云机场   1.48  14.38   0.21  14.38  14.39   275339.0   2727.0
# 4097  600000  浦发银行  -0.74   9.36  -0.07   9.36   9.37   449101.0   5274.0
#
#         涨速%  ... 市净率排名 市现率排名 市销率排名 股息率%排名 每股净资排名 每股现金流排名  净益率%排名 营业利润率%排名  \
# 0      0.12  ...  33.0  34.0  21.0   36.0    5.0    20.0    35.0     36.0
# 1     -0.09  ...  31.5  23.0  14.0   12.0    1.0     1.0     4.0     10.0
# 2     -0.19  ...  40.0  17.0  79.0   61.5   10.0    73.0    45.0     10.0
# 3     -0.36  ...  27.0  82.0  77.0   77.5   81.5    55.0    80.0     84.0
# 4     -0.34  ...  29.5   1.0  38.5   17.5   21.0    38.0    14.0      7.0
# ...     ...  ...   ...   ...   ...    ...    ...     ...     ...      ...
# 4093      0  ...  17.0  37.0  13.0    9.0   77.5    27.0    57.0     49.5
# 4094      0  ...  11.0  14.0   9.0    3.0    4.0     5.0     7.0      8.0
# 4095      0  ...  12.0   2.0  10.0    5.0   17.0    13.0     6.0      9.0
# 4096   -0.2  ...   3.0   4.0   3.0    4.0    3.0     3.0     3.0      3.0
# 4097   -0.1  ...   6.0  19.0   6.0    4.0    3.0     5.0    21.0     23.0
#
#      净利润率%排名 每股收益排名
# 0       37.0    8.0
# 1       14.0    1.0
# 2        8.0   24.0
# 3       85.0   80.0
# 4        6.0   12.0
# ...      ...    ...
# 4093    61.0   56.0
# 4094     7.0    5.0
# 4095     6.0   11.0
# 4096     3.0    3.0
# 4097    23.0    4.0
#
# [4098 rows x 126 columns]

# %% [markdown]
# # 计算总分

# %%
fin_data[score_col_name0] = 1/fin_data[rank_col_name0]
fin_data[score_col_name1] = 1/fin_data[rank_col_name1]
fin_data[score_col_name2] = 1/fin_data[rank_col_name2]
# fin_data[score_col_name3] = 1/fin_data[rank_col_name3] # 需要处理负数问题，先不考虑这个财务因子
fin_data[score_col_name4] = 1/fin_data[rank_col_name4]
fin_data[score_col_name5] = 1/fin_data[rank_col_name5]
fin_data[score_col_name6] = 1/fin_data[rank_col_name6]
fin_data[score_col_name7] = 1/fin_data[rank_col_name7]
fin_data[score_col_name8] = 1/fin_data[rank_col_name8]
fin_data[score_col_name9] = 1/fin_data[rank_col_name9]
fin_data[score_col_name10] = 1/fin_data[rank_col_name10]
fin_data[score_col_name11] = 1/fin_data[rank_col_name11]

weight_0 = 1
weight_1 = 1
weight_2 = 1
# weight_3 = 1
weight_4 = 1
weight_5 = 1
weight_6 = 1
weight_7 = 1
weight_8 = 1
weight_9 = 1
weight_10 = 1
weight_11 = 1

fin_data['总分数'] = fin_data[score_col_name0]*weight_0+\
                    fin_data[score_col_name1]*weight_1+\
                    fin_data[score_col_name2]*weight_2+\
                    fin_data[score_col_name4]*weight_4+\
                    fin_data[score_col_name5]*weight_5+\
                    fin_data[score_col_name6]*weight_6+\
                    fin_data[score_col_name7]*weight_7+\
                    fin_data[score_col_name8]*weight_8+\
                    fin_data[score_col_name9]*weight_9+\
                    fin_data[score_col_name10]*weight_10

# %%
fin_data
# Out:
#           代码    名称    涨幅%     现价     涨跌     买价     卖价         总量       现量  \
# 0     000001  平安银行  -2.72  17.18  -0.48  17.17  17.18  1289189.0  11541.0
# 1     000002  万 科Ａ  -2.39  29.05  -0.71  29.04  29.05   660135.0   5732.0
# 2     000004  国农科技    0.1  30.62   0.03  30.62  30.65    71323.0    896.0
# 3     000005  世纪星源   2.29   2.68   0.06   2.67   2.68   136360.0    679.0
# 4     000006  深振业Ａ  -1.22   5.67  -0.07   5.67   5.68    96442.0   1311.0
# ...      ...   ...    ...    ...    ...    ...    ...        ...      ...
# 4093  600008  首创股份   0.99   3.06   0.03   3.06   3.07   662676.0  15518.0
# 4094  600007  中国国贸  -0.47  12.78  -0.06  12.77  12.78    13812.0    102.0
# 4095  600006  东风汽车   0.63   6.36   0.04   6.36   6.37   523954.0   3177.0
# 4096  600004  白云机场   1.48  14.38   0.21  14.38  14.39   275339.0   2727.0
# 4097  600000  浦发银行  -0.74   9.36  -0.07   9.36   9.37   449101.0   5274.0
#
#         涨速%  ...   市净率排名分数   市销率排名分数  股息率%排名分数  每股收益排名分数  每股净资排名分数 每股现金流排名分数  \
# 0      0.12  ...  0.030303  0.047619  0.027778  0.125000  0.200000  0.050000
# 1     -0.09  ...  0.031746  0.071429  0.083333  1.000000  1.000000  1.000000
# 2     -0.19  ...  0.025000  0.012658  0.016260  0.041667  0.100000  0.013699
# 3     -0.36  ...  0.037037  0.012987  0.012903  0.012500  0.012270  0.018182
# 4     -0.34  ...  0.033898  0.025974  0.057143  0.083333  0.047619  0.026316
# ...     ...  ...       ...       ...       ...       ...       ...       ...
# 4093      0  ...  0.058824  0.076923  0.111111  0.017857  0.012903  0.037037
# 4094      0  ...  0.090909  0.111111  0.333333  0.200000  0.250000  0.200000
# 4095      0  ...  0.083333  0.100000  0.200000  0.090909  0.058824  0.076923
# 4096   -0.2  ...  0.333333  0.333333  0.250000  0.333333  0.333333  0.333333
# 4097   -0.1  ...  0.166667  0.166667  0.250000  0.250000  0.333333  0.200000
#
#       净益率%排名分数 营业利润率%排名分数 净利润率%排名分数       总分数
# 0     0.028571   0.027778  0.027027  0.732287
# 1     0.250000   0.100000  0.071429  4.627417
# 2     0.022222   0.100000  0.125000  0.376471
# 3     0.012500   0.011905  0.011765  0.176542
# 4     0.071429   0.142857  0.166667  0.621902
# ...        ...        ...       ...       ...
# 4093  0.017544   0.020202  0.016393  0.952401
# 4094  0.142857   0.125000  0.142857  1.819877
# 4095  0.166667   0.111111  0.166667  1.228676
# 4096  0.333333   0.333333  0.333333  3.333333
# 4097  0.047619   0.043478  0.043478  1.767288
#
# [4098 rows x 138 columns]

# %% [markdown]
# # 挑选自己感兴趣的行业，查看排名：

# %%
fin_data[fin_data['细分行业']=="食品"][['代码','名称','细分行业','财务更新',
#                                   # 财务指标
#                                     fin_name0,
#                                     fin_name1,
#                                     fin_name2,
# #                                     fin_name3,
#                                     fin_name4,
#                                     fin_name5,
#                                     fin_name6,
#                                     fin_name7,
#                                     fin_name8,
#                                     fin_name9,
#                                     fin_name10,
#                                     fin_name11,
                                  
#                                   # 排名
                                    rank_col_name0,
                                    rank_col_name1,
                                    rank_col_name2,
#                                     rank_col_name3,
                                    rank_col_name4,
                                    rank_col_name5,
                                    rank_col_name6,
                                    rank_col_name7,
                                    rank_col_name8,
                                    rank_col_name9,
                                    rank_col_name10,
                                    rank_col_name11,
                                  
                                   # 分数
                                    score_col_name0,
                                    score_col_name1,
                                    score_col_name2,
#                                     score_col_name3,                                  
                                    score_col_name4,
                                    score_col_name5,
                                    score_col_name6,
                                    score_col_name7,
                                    score_col_name8,
                                    score_col_name9,
                                    score_col_name10,
                                    score_col_name11,
                                   '总分数'
                                   ]].sort_values("总分数", ascending = False)
# Out:
#           代码    名称 细分行业        财务更新  流通市值排名  市盈(TTM)排名  市净率排名  市销率排名  股息率%排名  \
# 1025  002582   好想你   食品  20201031.0    32.0        1.0    2.0   18.0    27.5
# 2648  603886  元祖股份   食品  20201028.0    34.0        5.0   24.0   17.0     1.0
# 2930  603288  海天味业   食品  20201102.0     1.0       57.0   68.0   67.0    33.0
# 2154  300741  华宝股份   食品  20201028.0    31.0       16.0   34.0   63.0     3.0
# 2306  300999   金龙鱼   食品  20201031.0    11.0       37.0   32.0   19.0    62.5
# ...      ...   ...  ...         ...     ...        ...    ...    ...     ...
# 429   000972  ST中基   食品  20201030.0    63.0        NaN   38.0   69.0    62.5
# 940   002495  佳隆股份   食品  20201031.0    64.0        NaN    8.0   58.0    62.5
# 2324  300908  仲景食品   食品  20201030.0     NaN        NaN    NaN    1.0    62.5
# 2705  603777   来伊份   食品  20201102.0    36.0        NaN   20.0   12.0    25.0
# 3941  600191  华资实业   食品  20201031.0    53.0        NaN    3.0   66.0    45.5
#
#       每股收益排名  ...   市净率排名分数   市销率排名分数  股息率%排名分数  每股收益排名分数  每股净资排名分数  \
# 1025     1.0  ...  0.500000  0.055556  0.036364  1.000000  0.142857
# 2648    10.0  ...  0.041667  0.058824  1.000000  0.100000  0.043478
# 2930     6.0  ...  0.014706  0.014925  0.030303  0.166667  0.037037
# 2154     7.0  ...  0.029412  0.015873  0.333333  0.142857  0.250000
# 2306    14.5  ...  0.031250  0.052632  0.016000  0.068966  1.000000
# ...      ...  ...       ...       ...       ...       ...       ...
# 429     68.0  ...  0.026316  0.014493  0.016000  0.014706  0.015152
# 940     66.0  ...  0.125000  0.017241  0.016000  0.015152  0.015385
# 2324    65.0  ...       NaN  1.000000  0.016000  0.015385       NaN
# 2705    69.0  ...  0.050000  0.083333  0.040000  0.014493  0.029412
# 3941    61.0  ...  0.333333  0.015152  0.021978  0.016393  0.023810
#
#       每股现金流排名分数  净益率%排名分数  营业利润率%排名分数  净利润率%排名分数       总分数
# 1025   0.014706  1.000000    1.000000   1.000000  4.780732
# 2648   0.500000  0.100000    0.040000   0.043478  2.113380
# 2930   0.043478  0.333333    0.090909   0.090909  1.748903
# 2154   0.066667  0.037037    0.500000   0.500000  1.469937
# 2306   0.111111  0.020833    0.018182   0.018182  1.436909
# ...         ...       ...         ...        ...       ...
# 429    0.016393  0.014493    0.014493   0.014493       NaN
# 940    0.016129  0.015152    0.014925   0.014706       NaN
# 2324        NaN  0.166667    0.058824   0.062500       NaN
# 2705   0.019231  0.014706    0.015385   0.014925       NaN
# 3941   0.015873  0.015625    0.111111   0.200000       NaN
#
# [69 rows x 27 columns]

# %% [markdown]
# # 技术分析 - 月线向上+周线向上+日线向上

# %%
# 确定想看哪只股票，然后调用数据

# %%
ticker = "002582"
df = pd.read_csv(mkt_data_location+ticker+)

# %% [markdown]
# ## 建立技术指标筛选器 - functions of EMA, Double EMA and MACD

# %%
def
