# %%
import os
import csv
import pandas as pd

# %% [markdown]
# # 结论：pd.io.parsers.read_csv 和 pd.read_csv是一个东西

# %%
csv_dir = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/test/"

# %%
folder_files = csv_dir+"*.csv"

# %%
for s in symbol_list:
    df = pd.io.parsers.read_csv(
                    os.path.join(csv_dir, '%s.csv' % s),
                    header=0, index_col=0, parse_dates=True,
                    usecols=[0,5], names=[date_col,s]
                )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-30c506980cdc> in <module>
#       1 csv_dir = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/test/"
# ----> 2 for s in self.symbol_list:
#       3     df = pd.io.parsers.read_csv(
#       4                     os.path.join(csv_dir, '%s.csv' % s),
#       5                     header=0, index_col=0, parse_dates=True,
#
# NameError: name 'self' is not defined

# %%
pd.io.parsers.read_csv(csv_dir+"000001.SZ.csv", header=0, index_col=0, parse_dates=True, usecols=[0,1], names = ['1','2'])
# Out:
#                     2
# 1
# 000001.SZ  2010-01-04
# 000001.SZ  2010-01-05
# 000001.SZ  2010-01-06
# 000001.SZ  2010-01-07
# 000001.SZ  2010-01-08
# ...               ...
# 000001.SZ  2020-05-18
# 000001.SZ  2020-05-19
# 000001.SZ  2020-05-20
# 000001.SZ  2020-05-21
# 000001.SZ  2020-05-22
#
# [2453 rows x 1 columns]

# %%
pd.io.parsers.read_csv(csv_dir+"000001.SZ.csv", header=0, index_col=1, parse_dates=False).index
# Out:
# Index(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07', '2010-01-08',
#        '2010-01-11', '2010-01-12', '2010-01-13', '2010-01-14', '2010-01-15',
#        ...
#        '2020-05-11', '2020-05-12', '2020-05-13', '2020-05-14', '2020-05-15',
#        '2020-05-18', '2020-05-19', '2020-05-20', '2020-05-21', '2020-05-22'],
#       dtype='object', name='trade_date', length=2453)

# %%
pd.read_csv(csv_dir+"000001.SZ.csv")
# Out:
#         ts_code  trade_date     open     high      low    close  pre_close  \
# 0     000001.SZ  2010-01-04   8.0647   8.0844   7.7884   7.7983     8.0154
# 1     000001.SZ  2010-01-05   7.8114   7.8608   7.4825   7.6634     7.7983
# 2     000001.SZ  2010-01-06   7.6470   7.6470   7.4727   7.5319     7.6634
# 3     000001.SZ  2010-01-07   7.5319   7.5812   7.3674   7.4497     7.5319
# 4     000001.SZ  2010-01-08   7.4003   7.4825   7.3510   7.4332     7.4497
# ...         ...         ...      ...      ...      ...      ...        ...
# 2448  000001.SZ  2020-05-18  13.2000  13.3400  13.1200  13.2000    13.2300
# 2449  000001.SZ  2020-05-19  13.4100  13.4500  13.2700  13.3600    13.2000
# 2450  000001.SZ  2020-05-20  13.3800  13.6200  13.2700  13.5100    13.3600
# 2451  000001.SZ  2020-05-21  13.5200  13.5700  13.3600  13.4000    13.5100
# 2452  000001.SZ  2020-05-22  13.3300  13.3400  12.9200  12.9200    13.4000
#
#       change  pct_chg        vol        amount
# ...

# %% [markdown]
# # Plotly

# %%
go.Surface(z=z_data.values)
# Out:
# Surface({
#     'z': array([[ 0.000000e+00,  2.780985e+01,  4.961936e+01, ...,  3.312340e+00,
#                   1.156517e+00, -1.476620e-01],
#                 [ 1.000000e+00,  2.771966e+01,  4.855022e+01, ...,  2.996142e+00,
#                   2.967954e+00,  1.999594e+00],
#                 [ 2.000000e+00,  3.042670e+01,  3.347752e+01, ...,  7.306965e+00,
#                   5.736840e+00,  3.625628e+00],
#                 ...,
#                 [ 2.200000e+01,  0.000000e+00,  0.000000e+00, ...,  3.896037e+00,
#                   1.077756e+00,  0.000000e+00],
#                 [ 2.300000e+01,  1.229679e-03,  3.008948e+00, ...,  1.236256e-01,
#                   3.985531e+00, -1.835741e-01],
#                 [ 2.400000e+01,  0.000000e+00,  5.626141e+00, ...,  5.868994e+00,
#                   5.833817e+00,  3.568177e+00]])
# })

# %%
z_data.values
# Out:
# array([[ 0.000000e+00,  2.780985e+01,  4.961936e+01,  8.308067e+01,
#          1.166632e+02,  1.304140e+02,  1.507206e+02,  2.201871e+02,
#          1.561536e+02,  1.486416e+02,  2.037845e+02,  2.060386e+02,
#          1.071618e+02,  6.836975e+01,  4.533590e+01,  4.996142e+01,
#          2.189279e+01,  1.702552e+01,  1.174317e+01,  1.475226e+01,
#          1.366710e+01,  5.677561e+00,  3.312340e+00,  1.156517e+00,
#         -1.476620e-01],
#        [ 1.000000e+00,  2.771966e+01,  4.855022e+01,  6.521374e+01,
#          9.527666e+01,  1.169964e+02,  1.339056e+02,  1.523412e+02,
#          1.519340e+02,  1.601139e+02,  1.795327e+02,  1.476184e+02,
#          1.703943e+02,  1.218194e+02,  5.258537e+01,  3.308871e+01,
#          3.840972e+01,  4.424843e+01,  6.957860e+01,  4.019351e+00,
#          3.050024e+00,  3.039719e+00,  2.996142e+00,  2.967954e+00,
#          1.999594e+00],
#        [ 2.000000e+00,  3.042670e+01,  3.347752e+01,  4.480953e+01,
# ...

# %%
z_data
# Out:
#    Unnamed: 0          0         1          2          3          4
# 0           0  27.809850  49.61936  83.080670  116.66320  130.41400
# 1           1  27.719660  48.55022  65.213740   95.27666  116.99640
# 2           2  30.426700  33.47752  44.809530   62.47495   77.43523
# 3           3  16.665490  30.10860  39.969520   44.12225   59.57512
# 4           4   8.815617  18.35160   8.658275   27.58590   48.62691
# 5           5   6.628881  10.41339  24.819390   26.08952   30.16050

# %%
import plotly.graph_objects as go

import pandas as pd

# Read data from a csv
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')
z_data = z_data.iloc[:6,:6]
fig = go.Figure(data=[go.Surface(z=z_data.values)])

fig.update_layout(title='Mt Bruno Elevation', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))

fig.show()
# Out:
# <div>
#
#
#             <div id="8d5aefb4-67ef-4368-8403-ff957ebf3c3a" class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8d5aefb4-67ef-4368-8403-ff957ebf3c3a")) {
#                     Plotly.newPlot(
#                         '8d5aefb4-67ef-4368-8403-ff957ebf3c3a',
#                         [{"type": "surface", "z": [[0.0, 27.80985, 49.61936, 83.08067, 116.6632, 130.414], [1.0, 27.719659999999998, 48.55022, 65.21374, 95.27665999999999, 116.9964], [2.0, 30.4267, 33.47752, 44.80953, 62.47495, 77.43523], [3.0, 16.66549, 30.1086, 39.96952, 44.12225, 59.57512], [4.0, 8.815617, 18.3516, 8.658275, 27.5859, 48.626909999999995], [5.0, 6.628881, 10.41339, 24.81939, 26.08952, 30.1605]]}],
# ...
