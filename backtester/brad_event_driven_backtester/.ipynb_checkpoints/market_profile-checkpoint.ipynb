# %%
import pandas as pd, numpy as np
import os
import matplotlib.pyplot as plt
from market_profile import MarketProfile
from matplotlib import style
style.use("ggplot")
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-4c25fdbc37ae> in <module>()
#       2 import os
#       3 import matplotlib.pyplot as plt
# ----> 4 from market_profile import MarketProfile
#       5 from matplotlib import style
#       6 style.use("ggplot")
#
# ImportError: No module named 'market_profile'

# %%
df = pd.read_

# %%
df = pd.read_csv('GOOGL.csv')

# %%
df.head(3)
# Out:
#     datetime        open        high         low       close   volume  \
# 0  2015-3-30  560.250000  562.159973  556.789978  561.140015  1239400
# 1  2015-3-31  557.940002  562.450012  554.669983  554.700012  1746600
# 2   2015-4-1  554.830017  558.500000  546.030029  549.489990  1932300
#
#     adj_close
# 0  561.140015
# 1  554.700012
# 2  549.489990

# %%
mp = MarketProfile(df, tick_size=1)

# %%
# Out:
#        datetime         open         high          low        close   volume  \
# 0     2015-3-30   560.250000   562.159973   556.789978   561.140015  1239400
# 1     2015-3-31   557.940002   562.450012   554.669983   554.700012  1746600
# 2      2015-4-1   554.830017   558.500000   546.030029   549.489990  1932300
# 3      2015-4-2   547.409973   548.000000   540.440002   541.309998  2388000
# 4      2015-4-6   538.840027   545.539978   535.700012   543.950012  1685900
# 5      2015-4-7   544.989990   550.159973   543.590027   544.859985  1365900
# 6      2015-4-8   546.000000   551.500000   546.000000   548.840027  1419300
# 7      2015-4-9   549.210022   549.369995   541.950012   548.020020  1618300
# 8     2015-4-10   549.570007   549.849976   544.979980   548.539978  1305200
# 9     2015-4-13   547.049988   553.270020   546.299988   548.640015  1466300
# 10    2015-4-14   546.570007   546.570007   535.739990   539.780029  2354300
# 11    2015-4-15   537.960022   543.190002   532.369995   541.039978  2348100
# 12    2015-4-16   538.349976   545.229980   538.099976   543.520020  1586100
# 13    2015-4-17   537.309998   539.799988   529.000000   532.739990  2461700
# 14    2015-4-20   533.750000   545.799988   533.349976   544.530029  1925400
# 15    2015-4-21   546.309998   547.770020   542.210022   542.919983  1456400
# 16    2015-4-22   543.059998   551.000000   541.320007   549.179993  1590300
# 17    2015-4-23   550.409973   561.169983   550.080017   557.460022  3909200
# 18    2015-4-24   580.049988   584.700012   568.349976   573.659973  4608400
# 19    2015-4-27   572.770020   575.520020   562.299988   566.119995  2403100
# 20    2015-4-28   564.320007   567.830017   560.960022   564.369995  1858900
# 21    2015-4-29   560.510010   565.840027   559.000000   561.390015  1681100
# 22    2015-4-30   558.559998   561.109985   546.719971   548.770020  2362000
# 23     2015-5-1   550.510010   551.219971   543.849976   551.159973  1828600
# 24     2015-5-4   550.989990   556.690002   547.390015   552.840027  1763000
# 25     2015-5-5   550.159973   552.609985   542.369995   543.039978  1426400
# 26     2015-5-6   542.640015   543.929993   532.239990   535.080017  1951700
# 27     2015-5-7   535.900024   545.200012   533.450012   542.039978  1592200
# 28     2015-5-8   548.869995   552.799988   548.030029   548.950012  1411300
# 29    2015-5-11   548.489990   553.369995   545.599976   545.780029  1092900
# ...         ...          ...          ...          ...          ...      ...
# 977   2019-2-14  1125.000000  1136.130005  1117.089966  1129.199951  1055300
# 978   2019-2-15  1139.300049  1139.300049  1116.719971  1119.630005  1391300
# 979   2019-2-19  1116.640015  1129.640015  1116.640015  1126.510010  1099000
# 980   2019-2-20  1128.880005  1130.930054  1111.750000  1120.589966  1204500
# 981   2019-2-21  1118.780029  1119.150024  1097.979980  1104.209961  1663600
# 982   2019-2-22  1109.699951  1117.250000  1100.500000  1116.560059  1471800
# 983   2019-2-25  1121.930054  1125.400024  1114.109985  1117.329956  1310400
# 984   2019-2-26  1114.369995  1126.439941  1106.699951  1122.010010  1751300
# 985   2019-2-27  1114.010010  1125.729980  1108.560059  1122.890015  1104600
# 986   2019-2-28  1119.000000  1133.989990  1118.410034  1126.550049  1371100
# 987    2019-3-1  1131.000000  1150.000000  1131.000000  1148.520020  1704300
# 988    2019-3-4  1154.560059  1165.520020  1138.250000  1153.420044  1774500
# 989    2019-3-5  1156.000000  1176.489990  1153.020020  1169.189941  2004700
# 990    2019-3-6  1171.760010  1174.739990  1163.050049  1164.939941  1180100
# 991    2019-3-7  1160.500000  1163.579956  1141.709961  1150.849976  1504300
# 992    2019-3-8  1133.900024  1153.449951  1130.199951  1149.969971  1184700
# 993   2019-3-11  1152.000000  1179.910034  1151.569946  1179.260010  1501600
# 994   2019-3-12  1182.300049  1205.709961  1182.300049  1197.250000  2111000
# 995   2019-3-13  1205.930054  1207.119995  1197.910034  1199.060059  1294400
# 996   2019-3-14  1199.020020  1204.699951  1191.229980  1192.530029  1365100
# 997   2019-3-15  1198.000000  1201.719971  1187.010010  1190.300049  2594300
# 998   2019-3-18  1189.689941  1194.949951  1181.479980  1188.550049  1222100
# 999   2019-3-19  1191.719971  1203.410034  1189.459961  1202.459961  1489400
# 1000  2019-3-20  1201.400024  1229.989990  1199.589966  1226.430054  2075400
# 1001  2019-3-21  1220.000000  1236.439941  1216.579956  1236.130005  1407500
# 1002  2019-3-22  1228.849976  1233.630005  1206.000000  1207.650024  1721100
# 1003  2019-3-25  1199.560059  1209.439941  1190.000000  1197.380005  1378800
# 1004  2019-3-26  1205.189941  1207.650024  1181.760010  1189.839966  1537600
# 1005  2019-3-27  1191.920044  1191.920044  1164.229980  1178.010010  1471400
# 1006  2019-3-28  1175.500000  1177.250000  1163.430054  1172.270020  1113900
#
#         adj_close
# 0      561.140015
# 1      554.700012
# 2      549.489990
# 3      541.309998
# 4      543.950012
# 5      544.859985
# 6      548.840027
# 7      548.020020
# 8      548.539978
# 9      548.640015
# 10     539.780029
# 11     541.039978
# 12     543.520020
# 13     532.739990
# 14     544.530029
# 15     542.919983
# 16     549.179993
# 17     557.460022
# 18     573.659973
# 19     566.119995
# 20     564.369995
# 21     561.390015
# 22     548.770020
# 23     551.159973
# 24     552.840027
# 25     543.039978
# 26     535.080017
# 27     542.039978
# 28     548.950012
# 29     545.780029
# ...           ...
# 977   1129.199951
# 978   1119.630005
# 979   1126.510010
# 980   1120.589966
# 981   1104.209961
# 982   1116.560059
# 983   1117.329956
# 984   1122.010010
# 985   1122.890015
# 986   1126.550049
# 987   1148.520020
# 988   1153.420044
# 989   1169.189941
# 990   1164.939941
# 991   1150.849976
# 992   1149.969971
# 993   1179.260010
# 994   1197.250000
# 995   1199.060059
# 996   1192.530029
# 997   1190.300049
# 998   1188.550049
# 999   1202.459961
# 1000  1226.430054
# 1001  1236.130005
# 1002  1207.650024
# 1003  1197.380005
# 1004  1189.839966
# 1005  1178.010010
# 1006  1172.270020
#
# [1007 rows x 7 columns]

# %%
df.index.max()
# Out:
# 1006

# %%
mp_slice = mp[df.index.max():df.index.max()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Close'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-b4495aba9f33> in <module>()
# ----> 1 mp_slice = mp[df.index.max():df.index.max()]
#
# ~\Anaconda3\lib\site-packages\market_profile\__init__.py in __getitem__(self, index)
#      20     def __getitem__(self, index):
#      21         if isinstance(index, slice):
# ---> 22             return MarketProfileSlice(self, slice(index.start, index.stop))
#      23         else:
#      24             raise TypeError("index must be int or slice")
#
# ~\Anaconda3\lib\site-packages\market_profile\__init__.py in __init__(self, market_profile, _slice)
#      36         self.mp = market_profile
#      37         self.ds = self.mp.df[_slice]
# ---> 38         self.build_profile()
#      39
#      40     def open_range(self):
#
# ~\Anaconda3\lib\site-packages\market_profile\__init__.py in build_profile(self)
#      90     # http://eminimind.com/the-ultimate-guide-to-market-profile/
#      91     def build_profile(self):
# ---> 92         rounded_set = self.ds['Close'].apply(lambda x: self.mp.round_to_row(x))
#      93
#      94         if self.mp.mode == 'tpo':
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Close'
