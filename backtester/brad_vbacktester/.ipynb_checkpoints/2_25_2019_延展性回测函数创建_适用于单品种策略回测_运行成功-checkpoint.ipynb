# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

style.use("ggplot")
# %matplotlib inline

lib_path = r'C:/Users/workspace/brad_public_workspace_on_win/brad_public_workspace_on_win/backtester/brad_vbacktester/'
file_path = 'C:/Users/workspace/brad_public_workspace_on_win/brad_public_workspace_on_win/backtester/brad_vbacktester/'
trx_file = "trx_1000000_daily.csv"
eos_file = "eos_daily_1000000_multiplied.csv"

from sys import path
path.append(lib_path) #将存放module的路径添加进来

from metrics import expected_returns, win_loss_rate
from performance import sngl_performance
from data import process_sngl_data
from plot import plot_cum_returns
from strategies import Strat_SMA

# %% [markdown]
# # 使用brad_vbacktester回测

# %%
trx = process_sngl_data(file_path, trx_file)
signal_df = Strat_SMA(trx, 'close', 10)
sngl_performance = sngl_performance(signal_df, 'close')
win_loss_rate(sngl_performance)
expected_returns(sngl_performance, 'close')
# Out:
# C:\Users\workspace\brad_public_workspace_on_win\brad_public_workspace_on_win\backtester\brad_vbacktester\strategies.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[SMA_col] = df[price_col].rolling(window = window).mean()
# C:\Users\workspace\brad_public_workspace_on_win\brad_public_workspace_on_win\backtester\brad_vbacktester\strategies.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['diff'] = df[SMA_col] - df[price_col]
# C:\Users\workspace\brad_public_workspace_on_win\brad_public_workspace_on_win\backtester\brad_vbacktester\strategies.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['signal'] = df['diff'].apply(lambda x: 1 if x>0 else -1 if x<0 else 0)
# ======================================================
# Correct rate:  0.43005181347150256
# ======================================================
# Expected returns: -0.3071%

# %%
plot_cum_returns(sngl_performance, figsize=(18, 6))

# %%
lib_path = r'C:/Users/workspace/brad_public_workspace_on_win/brad_public_workspace_on_win/backtester/brad_vbacktester/'
file_path = 'C:/Users/workspace/brad_public_workspace_on_win/brad_public_workspace_on_win/backtester/brad_vbacktester/'
trx_file = "trx_1000000_daily.csv"
eos_file = "eos_daily_1000000_multiplied.csv"

from sys import path
path.append(lib_path) #将存放module的路径添加进来

from metrics import expected_returns, win_loss_rate
from performance import sngl_performance
from data import process_sngl_data
from plot import plot_cum_returns
from strategies import Strat_SMA

# %%
eos = process_sngl_data(file_path, eos_file)
signal_df = Strat_SMA(eos, 'close', 10)
sngl_performance = sngl_performance(signal_df, 'close')
win_loss_rate(sngl_performance)
expected_returns(sngl_performance, 'close')
# Out:
# ======================================================
# Correct rate:  0.4551422319474836
# ======================================================
# Expected returns: -0.2643%
# C:\Users\workspace\brad_public_workspace_on_win\brad_public_workspace_on_win\backtester\brad_vbacktester\strategies.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[SMA_col] = df[price_col].rolling(window = window).mean()
# C:\Users\workspace\brad_public_workspace_on_win\brad_public_workspace_on_win\backtester\brad_vbacktester\strategies.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['diff'] = df[SMA_col] - df[price_col]
# C:\Users\workspace\brad_public_workspace_on_win\brad_public_workspace_on_win\backtester\brad_vbacktester\strategies.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['signal'] = df['diff'].apply(lambda x: 1 if x>0 else -1 if x<0 else 0)

# %%
plot_cum_returns(sngl_performance, figsize=(18, 6))

# %% [markdown]
# # 计算QR值

# %%
from indicators import QR, QRSUM

# %%
eos_trx_qr= QR(eos, trx, 'close')
# Out:
# C:\Users\workspace\brad_public_workspace_on_win\brad_public_workspace_on_win\backtester\brad_vbacktester\indicators.py:12: FutureWarning: 'date' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   df_merged = df1.merge(df2, on = 'date', how = 'inner')

# %%
eos_trx_qr['p1_pct'].corr(eos_trx_qr['p2_pct'])
# Out:
# 0.381690928262231

# %%
def MACD(df, price_col, n_fast, n_slow, n_emadiff): # n_fast = 12, n_slow = 26, n_emadiff = 9
    EMAfast = df[price_col].ewm(span = n_fast).mean()
    EMAslow = df[price_col].ewm(span = n_slow).mean()
    diff = pd.Series(EMAfast - EMAslow, name = 'diff' + str(n_fast) + '_' + str(n_slow))
    EMAdiff = diff.ewm(span = n_emadiff).mean().rename('EMAdiff' + '_' + str(n_emadiff))
    MACD = pd.Series(diff - EMAdiff, name = 'MACD' + str(n_fast) + '_' + str(n_slow) + '_' + str(n_emadiff))
    df['EMAfast'] = EMAfast
    df['EMAslow'] = EMAslow
    df['diff'] = diff
    df['EMAdiff'] = EMAdiff
    df['QMACD'] = MACD
    return df

# %%
eos_trx_qr_.head(2)
# Out:
#                                 date  close_x  close_y    p1_pct    p2_pct  \
# date
# 2018-01-30 23:45:00  2018-1-30 23:45  1191.00     5.15       NaN       NaN
# 2018-01-31 23:45:00  2018-1-31 23:45  1133.72     5.17 -0.048094  0.003883
#
#                            qr
# date
# 2018-01-30 23:45:00       NaN
# 2018-01-31 23:45:00 -0.051978

# %%
eos_trx_qr_ = eos_trx_qr[:340].copy()
QMACD = MACD(eos_trx_qr_, "qr", 12, 26, 9)

# %%
def three_graphs_twinx(series1, series2, series3):
    
    fig = plt.figure(figsize = (30, 15))
    
    ax1 = fig.add_subplot(1, 1, 1)
    ax2 = ax1.twinx()
    ax3 = ax1.twinx()
    
    series1.plot(ax = ax1, color = 'blue', lw = 0.5)
    series2.plot(ax = ax2, color = 'red', lw =0.5)
    series3.plot(ax = ax3, color = 'green', lw = 2)
#     ax1.legend(["Asset1", '11'])
#     ax2.legend("Asset2")
#     ax3.legend("QR")
    # ax1.axhline(-1.0, color='g', linestyle='--', lw=1)
#     ax2.axhline(0, color = 'red', linestyle='--', lw=1)
    ax3.axhline(0, color = 'black', linestyle='--', lw=1)
    plt.legend(fontsize = 20)

# %%
series1 = eos_trx_qr_['close_x']
series2 = eos_trx_qr_['close_y']
series3 = eos_trx_qr_['QMACD']
three_graphs_twinx(series1, series2, series3)

# %%
eos_trx_qr['qr'].plot(figsize=(20, 8))
plt.title("QR: EOS and TRX");

# %%
eos_trx_qrsum = QRSUM(eos, trx, 'close')
# Out:
# C:\Users\workspace\brad_public_workspace_on_win\brad_public_workspace_on_win\backtester\brad_vbacktester\indicators.py:27: FutureWarning: 'date' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   df_merged = df1.merge(df2, on = 'date', how = 'inner')

# %%
eos_trx_qrsum.plot(figsize=(20, 8))
plt.title("QRSUM: EOS and TRX");

# %%
eos_trx_qrsum_df = pd.DataFrame(eos_trx_qrsum)

# %%
eos_trx_qrsum_df
# Out:
#                                 date  close_x  close_y    p1_pct    p2_pct  \
# date
# 2018-01-30 23:45:00  2018-1-30 23:45  1191.00   5.1500       NaN       NaN
# 2018-01-31 23:45:00  2018-1-31 23:45  1133.72   5.1700 -0.048094  0.003883
# 2018-02-01 23:45:00   2018-2-1 23:45  1106.31   5.0600 -0.024177 -0.021277
# 2018-02-02 23:45:00   2018-2-2 23:45  1200.77   4.9300  0.085383 -0.025692
# 2018-02-22 23:45:00  0.028601 -0.185332
# 2018-02-23 23:45:00  0.003641 -0.181691
# 2018-02-24 23:45:00 -0.007413 -0.189105
# 2018-02-25 23:45:00 -0.006794 -0.195899
# 2018-02-26 23:45:00  0.023475 -0.172424
# 2018-02-27 23:45:00  0.035048 -0.137376
# 2018-02-28 23:45:00 -0.018653 -0.156029
# ...                       ...       ...
# 2019-01-20 23:45:00 -0.014458 -0.953432
# 2019-01-21 23:45:00 -0.070514 -1.023946
# 2019-01-22 23:45:00 -0.022893 -1.046839
# 2019-01-23 23:45:00 -0.000461 -1.047300
# 2019-01-24 23:45:00 -0.001465 -1.048765
# 2019-01-25 23:45:00  0.008211 -1.040554
# 2019-01-26 23:45:00 -0.046757 -1.087311
# 2019-01-27 23:45:00 -0.074452 -1.161764
# 2019-01-28 23:45:00  0.043948 -1.117816
# 2019-01-29 23:45:00 -0.023848 -1.141664
# 2019-01-30 23:45:00  0.022747 -1.118916
# 2019-01-31 23:45:00  0.052728 -1.066188
# 2019-02-01 23:45:00 -0.002959 -1.069148
# 2019-02-02 23:45:00  0.012058 -1.057090
# 2019-02-03 23:45:00  0.026496 -1.030593
# 2019-02-04 23:45:00 -0.042770 -1.073363
# 2019-02-05 23:45:00  0.008555 -1.064808
# 2019-02-06 23:45:00  0.014428 -1.050380
# 2019-02-07 23:45:00  0.007419 -1.042961
# 2019-02-08 23:45:00  0.092902 -0.950059
# 2019-02-09 23:45:00  0.038653 -0.911407
# 2019-02-10 23:45:00  0.006337 -0.905070
# 2019-02-11 23:45:00  0.081586 -0.823484
# 2019-02-12 23:45:00  0.022494 -0.800990
# 2019-02-13 23:45:00  0.015653 -0.785337
# 2019-02-14 23:45:00  0.002739 -0.782597
# 2019-02-15 23:45:00 -0.008792 -0.791389
# 2019-02-16 23:45:00  0.016731 -0.774658
# 2019-02-17 23:45:00 -0.003455 -0.778113
# 2019-02-18 23:45:00  0.097558 -0.680555
#
# [385 rows x 7 columns]

# %%
eos_trx_qrsum_df[['qr','qrsum']].plot(figsize=(20, 10))

# %%
def MACD(df, price_col, n_fast, n_slow, n_emadiff): # n_fast = 12, n_slow = 26, n_emadiff = 9
    EMAfast = df[price_col].ewm(span = n_fast).mean()
    EMAslow = df[price_col].ewm(span = n_slow).mean()
    diff = pd.Series(EMAfast - EMAslow, name = 'diff' + str(n_fast) + '_' + str(n_slow))
    EMAdiff = diff.ewm(span = n_emadiff).mean().rename('EMAdiff' + '_' + str(n_emadiff))
    MACD = pd.Series(diff - EMAdiff, name = 'MACD' + str(n_fast) + '_' + str(n_slow) + '_' + str(n_emadiff))
    df['EMAfast'] = EMAfast
    df['EMAslow'] = EMAslow
    df['diff'] = diff
    df['EMAdiff'] = EMAdiff
    df['MACD'] = MACD
    return df

# %%
eos_trx_qrsum_df
# Out:
#                                 date  close_x  close_y    p1_pct    p2_pct  \
# date
# 2018-01-30 23:45:00  2018-1-30 23:45  1191.00   5.1500       NaN       NaN
# 2018-01-31 23:45:00  2018-1-31 23:45  1133.72   5.1700 -0.048094  0.003883
# 2018-02-01 23:45:00   2018-2-1 23:45  1106.31   5.0600 -0.024177 -0.021277
# 2019-01-31 23:45:00 -0.100351  0.006679
# 2019-02-01 23:45:00 -0.097672  0.010717
# 2019-02-02 23:45:00 -0.094085  0.014346
# 2019-02-03 23:45:00 -0.089481  0.018417
# 2019-02-04 23:45:00 -0.084959  0.018089
# 2019-02-05 23:45:00 -0.080395  0.018256
# 2019-02-06 23:45:00 -0.075630  0.019058
# 2019-02-07 23:45:00 -0.070699  0.019724
# 2019-02-08 23:45:00 -0.064279  0.025681
# 2019-02-09 23:45:00 -0.056499  0.031121
# 2019-02-10 23:45:00 -0.048044  0.033819
# 2019-02-11 23:45:00 -0.038198  0.039382
# 2019-02-12 23:45:00 -0.027551  0.042588
# 2019-02-13 23:45:00 -0.016648  0.043615
# 2019-02-14 23:45:00 -0.006073  0.042299
# 2019-02-15 23:45:00  0.003615  0.038751
# 2019-02-16 23:45:00  0.012497  0.035530
# 2019-02-17 23:45:00  0.020326  0.031315
# 2019-02-18 23:45:00  0.028594  0.033072
#
# [385 rows x 12 columns]

# %%
Q_MACD = MACD(eos_trx_qrsum_df, 'qrsum', 12, 26, 9)

# %%
Q_MACD.head()
# Out:
#                                 date  close_x  close_y    p1_pct    p2_pct  \
# date
# 2018-01-30 23:45:00  2018-1-30 23:45  1191.00     5.15       NaN       NaN
# 2018-01-31 23:45:00  2018-1-31 23:45  1133.72     5.17 -0.048094  0.003883
# 2018-02-01 23:45:00   2018-2-1 23:45  1106.31     5.06 -0.024177 -0.021277
# 2018-02-02 23:45:00   2018-2-2 23:45  1200.77     4.93  0.085383 -0.025692
# 2018-02-03 23:45:00   2018-2-3 23:45  1163.80     4.88 -0.030789 -0.010142
#
#                            qr     qrsum   EMAfast   EMAslow      diff  \
# date
# 2018-01-30 23:45:00       NaN       NaN       NaN       NaN       NaN
# 2018-01-31 23:45:00 -0.051978 -0.051978 -0.051978 -0.051978  0.000000
# 2018-02-01 23:45:00 -0.002900 -0.054878 -0.053549 -0.053484 -0.000065
# 2018-02-02 23:45:00  0.111075  0.056197 -0.010715 -0.014077  0.003362
# 2018-02-03 23:45:00 -0.020647  0.035550  0.003889 -0.000203  0.004092
#
#                       EMAdiff      MACD
# date
# 2018-01-30 23:45:00       NaN       NaN
# 2018-01-31 23:45:00  0.000000  0.000000
# 2018-02-01 23:45:00 -0.000036 -0.000029
# 2018-02-02 23:45:00  0.001356  0.002005
# 2018-02-03 23:45:00  0.002283  0.001809

# %%
Q_MACD[['qrsum']].plot(figsize=(20, 8))

# %%
Q_MACD[['qrsum', 'EMAfast', 'EMAslow']].plot(figsize=(20, 8));

# %%
Q_MACD[['diff', 'EMAdiff', 'MACD']].plot(figsize=(20, 8))
plt.legend(['diff', 'EMAdiff', 'Q-MACD']);

# %%
Q_MACD_QR = MACD(eos_trx_qrsum_df, 'qr', 12, 26, 9)

# %%
Q_MACD[['qr', 'EMAfast', 'EMAslow']].plot(figsize=(20, 8));

# %%
Q_MACD_QR[['diff', 'EMAdiff', 'MACD']].plot(figsize=(20, 8))
plt.legend(['diff', 'EMAdiff', 'Q-MACD']);

# %%
eos_trx_qrsum_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-654cb42358db> in <module>()
# ----> 1 eos_trx_qrsum_df
#
# NameError: name 'eos_trx_qrsum_df' is not defined
