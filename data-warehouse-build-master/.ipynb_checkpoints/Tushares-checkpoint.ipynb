# %%
import tushare as ts
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#正常显示画图时出现的中文和负号

from pylab import mpl
mpl.rcParams['font.sans-serif']=['SimHei']
mpl.rcParams['axes.unicode_minus']=False

# %%
#设置token
token='2f31c3932ead9fcc3830879132cc3ec8df3566550f711889d4a30f67'
pro = ts.pro_api(token)

# %%
def get_data(code,start='20190101',end='20190425'):
    df = ts.pro_bar(ts_code=code, adj='qfq', start_date=start, end_date=end)
    return df

#获取当前交易日最新的股票代码和简称
def get_code():
    codes = pro.stock_basic(list_status='L').ts_code.values
    return codes

# %%
# 插入PostgreSQL 数据库操作，函数里使用了try...except...pass是为了避免某些数据出错导致程序崩溃。
from sqlalchemy import create_engine
import psycopg2 

engine=create_engine('postgresql+psycopg2://postgres:123456@localhost:5432/postgres')

# %%
def insert_sql(data,db_name,if_exists='append'):
    #使用try...except..continue避免出现错误，运行崩溃
    try:
        data.to_sql(db_name,engine,index=False,if_exists=if_exists)#print(code+'写入数据库成功')
    except:
        pass

# %%
#下载20190101-20190425数据并插入数据库stock_data

#此步骤比较耗费时间，大致25-35分钟左右

codes = get_code()

for code in codes:
    data=get_data(code)
    insert_sql(data,'stock_data')
# Out:
# 请设置tushare pro的token凭证码，如果没有请访问https://tushare.pro注册申请
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-15-cc21d579eab6> in <module>()
#       6
#       7 for code in codes:
# ----> 8     data=get_data(code)
#       9     insert_sql(data,'stock_data')
#
# <ipython-input-12-74fe44359c89> in get_data(code, start, end)
#       1 def get_data(code,start='20190101',end='20190425'):
# ----> 2     df = ts.pro_bar(ts_code=code, adj='qfq', start_date=start, end_date=end)
#       3     return df
#       4
#       5 #获取当前交易日最新的股票代码和简称
#
# ~/anaconda3/lib/python3.5/site-packages/tushare/pro/data_pro.py in pro_bar(ts_code, api, start_date, end_date, freq, asset, exchange, adj, ma, factors, adjfactor, contract_type, retry_count)
#      81         freq = freq.strip().upper() if asset != 'C' else freq.strip().lower()
#      82     asset = asset.strip().upper()
# ---> 83     api = api if api is not None else pro_api()
#      84     for _ in range(retry_count):
#      85         try:
#
# ~/anaconda3/lib/python3.5/site-packages/tushare/pro/data_pro.py in pro_api(token)
#      31         return pro
#      32     else:
# ---> 33         raise Exception('api init error.')
#      34
#      35
#
# Exception: api init error.

# %% [markdown]
# # New Database Test

# %% [markdown]
# - PostgresSQL info:
#
# - database_host: localhost
#
# - database_user:postgres
#
# - database_pw: 311266
#
# - port：5432
#
# - Pw: 311266

# %%
import psycopg2 #使用的是PostgreSQL数据库
import tushare as ts
import datetime

# %% [markdown]
# # Stocks.py

# %% [markdown]
# ## 1. func1: get_today_all()

# %%
todayall = ts.get_today_all()
# Out:
# [Getting data:]############################################################

# %%
todayall.head()
# nmc
# Out:
#      code  name  changepercent  trade  open   high   low  settlement  \
# 0  603999  读者传媒          1.500   6.09  6.00   6.12  5.96        6.00
# 1  603998  方盛制药          1.316  10.01  9.84  10.30  9.84        9.88
# 2  603997  继峰股份          6.866   9.65  9.03   9.80  8.86        9.03
# 3  603996  中新科技         -8.686   7.99  7.88   8.20  7.88        8.75
# 4  603993  洛阳钼业          0.959   4.21  4.15   4.25  4.12        4.17
#
#        volume  turnoverratio       amount     per     pb        mktcap  \
# 0   3431353.0        0.59572   20766182.0  87.000  2.084  3.507840e+05
# 1  22750376.0        5.35055  228858699.0  58.882  4.055  4.370593e+05
# 2   5556826.0        0.88204   52964769.0  20.243  3.192  6.170337e+05
# 3  11967380.0        3.98713   95599053.0 -30.731  1.774  2.398199e+05
# 4  69401815.0        0.39286  291769895.0  19.581  2.231  9.093280e+06
#
#             nmc
# 0  3.507840e+05
# 1  4.256219e+05
# 2  6.079500e+05
# 3  2.398199e+05
# 4  7.437290e+06

# %%
len(todayall)
# Out:
# 3690

# %% [markdown]
# ## 2. func2: get_codestock_local()

# %%
conn = psycopg2.connect(database="brad_particle", user="postgres", password="311266", host="127.0.0.1",
                        port="5432")
cur = conn.cursor()
# 创建stocks表
# cur.execute('''
#         select * from stocks;
#        ''')
cur.execute(
            """
            SELECT * FROM public.hdata_date
            ORDER BY stock_code ASC, record_date ASC LIMIT 200
            """)
rows =cur.fetchall()
conn.commit()
conn.close()
# Out:
# [('600146', datetime.date(2016, 10, 31), 33.6, 34.26, 33.95, 33.3, 23491.17, -0.11, -0.32, 33.95, 33.95, 33.95, 23491.17, 23491.17, 23491.17, None), ('600146', datetime.date(2016, 11, 1), 33.99, 34.29, 33.8, 33.51, 22933.29, -0.14, -0.41, 33.875, 33.875, 33.875, 23212.23, 23212.23, 23212.23, None), ('600146', datetime.date(2016, 11, 2), 33.99, 33.99, 33.62, 33.33, 21121.47, -0.22, -0.65, 33.79, 33.79, 33.79, 22515.31, 22515.31, 22515.31, None), ('600146', datetime.date(2016, 11, 3), 33.65, 33.7, 33.35, 33.02, 29518.57, -0.27, -0.8, 33.68, 33.68, 33.68, 24266.13, 24266.13, 24266.13, None), ('600146', datetime.date(2016, 11, 4), 33.46, 33.46, 32.63, 32.61, 38154.22, -0.72, -2.16, 33.47, 33.47, 33.47, 27043.74, 27043.74, 27043.74, None), ('600146', datetime.date(2016, 11, 7), 32.51, 33.49, 33.2, 32.51, 21071.1, 0.55, 1.69, 33.32, 33.425, 33.425, 26559.73, 26048.3, 26048.3, None), ('600146', datetime.date(2016, 11, 8), 33.44, 34.85, 34.38, 33.02, 63042.23, 1.11, 3.34, 33.436, 33.561, 33.561, 34581.52, 31333.15, 31333.15, None), ('600146', datetime.date(2016, 11, 9), 34.14, 34.73, 34.13, 33.5, 34132.78, -0.25, -0.73, 33.538, 33.633, 33.633, 37183.78, 31683.1, 31683.1, None), ('600146', datetime.date(2016, 11, 10), 34.0, 34.49, 34.2, 33.96, 25160.51, 0.3, 0.89, 33.708, 33.696, 33.696, 36312.17, 30958.37, 30958.37, None), ('600146', datetime.date(2016, 11, 11), 34.34, 34.47, 33.93, 33.74, 23728.09, -0.28, -0.82, 33.968, 33.719, 33.719, 33426.94, 30235.34, 30235.34, None), ('600146', datetime.date(2016, 11, 14), 34.0, 34.75, 34.49, 33.55, 48394.35, 0.64, 1.89, 34.226, 33.773, 33.789, 38891.59, 32725.66, 31886.16, None), ('600146', datetime.date(2016, 11, 15), 34.5, 37.1, 35.8, 34.49, 86715.5, 1.3, 3.77, 34.51, 33.973, 33.957, 43626.25, 39103.88, 36455.27, None), ('600146', datetime.date(2016, 11, 16), 35.54, 36.46, 35.74, 35.4, 35011.26, -0.04, -0.11, 34.832, 34.185, 34.094, 43801.94, 40492.86, 36344.2, None), ('600146', datetime.date(2016, 11, 17), 35.33, 36.58, 35.91, 35.33, 42344.8, 0.17, 0.48, 35.174, 34.441, 34.224, 47238.8, 41775.48, 36772.81, None), ('600146', datetime.date(2016, 11, 18), 35.85, 36.34, 35.93, 35.49, 41601.0, 0.03, 0.08, 35.574, 34.771, 34.337, 50813.38, 42120.16, 37094.69, None), ('600146', datetime.date(2016, 11, 21), 36.0, 36.45, 35.88, 35.4, 34716.75, -0.05, -0.14, 35.852, 35.039, 34.434, 48077.86, 43484.73, 36946.07, None), ('600146', datetime.date(2016, 11, 22), 35.99, 35.99, 35.46, 35.05, 35911.02, -0.36, -1.0, 35.784, 35.147, 34.494, 37916.97, 40771.61, 36885.18, None), ('600146', datetime.date(2016, 11, 23), 35.38, 35.72, 35.4, 34.51, 37828.5, 0.06, 0.17, 35.716, 35.274, 34.544, 38480.41, 41141.18, 36937.59, None), ('600146', datetime.date(2016, 11, 24), 35.57, 35.99, 35.05, 31.88, 65060.57, -0.37, -1.04, 35.544, 35.359, 34.571, 43023.57, 45131.18, 38417.75, None), ('600146', datetime.date(2016, 11, 25), 34.88, 35.1, 34.87, 33.9, 52410.29, -0.18, -0.51, 35.332, 35.453, 34.586, 45185.43, 47999.4, 39117.37, None), ('600146', datetime.date(2016, 11, 28), 35.3, 35.37, 34.59, 34.44, 15844.01, -0.38, -1.09, 35.074, 35.463, 34.618, 41410.88, 44744.37, 38735.02, None), ('600146', datetime.date(2016, 11, 29), 34.42, 34.8, 33.71, 33.3, 38648.52, -0.87, -2.52, 34.724, 35.254, 34.614, 41958.38, 39937.67, 39520.78, None), ('600146', datetime.date(2016, 11, 30), 33.54, 34.0, 33.65, 33.34, 18085.72, 0.01, 0.03, 34.374, 35.045, 34.615, 38009.82, 38245.12, 39368.99, None), ('600146', datetime.date(2016, 12, 1), 33.8, 33.96, 33.4, 33.02, 23528.33, -0.25, -0.74, 34.044, 34.794, 34.618, 29703.37, 36363.47, 39069.48, None), ('600146', datetime.date(2016, 12, 2), 33.45, 33.85, 33.6, 33.09, 17381.56, 0.23, 0.69, 33.79, 34.561, 34.666, 22697.63, 33941.53, 38030.84, None), ('600146', datetime.date(2016, 12, 5), 33.88, 34.99, 34.47, 33.6, 41105.4, 0.86, 2.56, 33.766, 34.42, 34.73, 27749.91, 34580.39, 39032.56, None), ('600146', datetime.date(2016, 12, 6), 34.5, 34.8, 34.72, 34.2, 19356.04, 0.23, 0.67, 33.968, 34.346, 34.747, 238 ...

# %%
pd.DataFrame(rows).head(5) # all data for each stock
# Out:
#        0           1      2      3      4      5         6     7     8   \
# 0  600146  2016-10-31  33.60  34.26  33.95  33.30  23491.17 -0.11 -0.32
# 1  600146  2016-11-01  33.99  34.29  33.80  33.51  22933.29 -0.14 -0.41
# 2  600146  2016-11-02  33.99  33.99  33.62  33.33  21121.47 -0.22 -0.65
# 3  600146  2016-11-03  33.65  33.70  33.35  33.02  29518.57 -0.27 -0.80
# 4  600146  2016-11-04  33.46  33.46  32.63  32.61  38154.22 -0.72 -2.16
#
#        9       10      11        12        13        14    15
# 0  33.950  33.950  33.950  23491.17  23491.17  23491.17  None
# 1  33.875  33.875  33.875  23212.23  23212.23  23212.23  None
# 2  33.790  33.790  33.790  22515.31  22515.31  22515.31  None
# 3  33.680  33.680  33.680  24266.13  24266.13  24266.13  None
# 4  33.470  33.470  33.470  27043.74  27043.74  27043.74  None

# %% [markdown]
# ## 3. func3: db_perstock_insertsql()

# %%
def db_perstock_insertsql(stock_code,cns_name):
    # func3:
    # #返回的是SQL插入语句
    sql_temp="insert into stocks values("
    sql_temp+="\'"+stock_code+"\'"+","+"\'"+cns_name+"\'"
    sql_temp +=");"
    return sql_temp
    pass

# %%
db_perstock_insertsql("603999", "读者传媒")
# Out:
# "insert into stocks values('603999','读者传媒');"

# %% [markdown]
# ## 4. db_stocks_update(self):

# %%
len(todayall)
# Out:
# 3690

# %%
def db_stocks_update():
    # func4:
    # 功能：根据gettodayall的情况插入原表中没的。。gettodayall中有的源表没的保留不删除#返回新增行数
    # 返回值：股票代码没找到、更新插入的数量：ans
    ans=0
    conn = psycopg2.connect(database="brad_particle", user="postgres", password=311266, host="127.0.0.1", port="5432")
    cur = conn.cursor()
#     self.get_today_all()

    for i in range(0,len(todayall)):
        sql_temp='''select * from stocks where stock_code='''
        sql_temp+="\'"+todayall["code"][i]+"\';"
        print ("sql_temp", sql_temp)
        cur.execute(sql_temp)
        rows=cur.fetchall()
        if(len(rows)==0):
            #如果股票代码没找到就插
            ans+=1
            print("Peeking todayall:", i)
            print("code:", todayall["code"][i])
            print("name:", todayall["name"][i])
            cur.execute(db_perstock_insertsql(todayall["code"][i],todayall["name"][i]))
            pass
    conn.commit()
    conn.close()
    print("db_stocks_update finish")
    return ans

# %%
db_stocks_update()
# Out:
# sql_temp select * from stocks where stock_code='603999';
# sql_temp select * from stocks where stock_code='603998';
# sql_temp select * from stocks where stock_code='603997';
# sql_temp select * from stocks where stock_code='603996';
# sql_temp select * from stocks where stock_code='603993';
# sql_temp select * from stocks where stock_code='603991';
# sql_temp select * from stocks where stock_code='603990';
# sql_temp select * from stocks where stock_code='603989';
# sql_temp select * from stocks where stock_code='603988';
# sql_temp select * from stocks where stock_code='603987';
# sql_temp select * from stocks where stock_code='603986';
# sql_temp select * from stocks where stock_code='603985';
# sql_temp select * from stocks where stock_code='603980';
# sql_temp select * from stocks where stock_code='603979';
# sql_temp select * from stocks where stock_code='603978';
# sql_temp select * from stocks where stock_code='603977';
# sql_temp select * from stocks where stock_code='603976';
# sql_temp select * from stocks where stock_code='603970';
# sql_temp select * from stocks where stock_code='603969';
# sql_temp select * from stocks where stock_code='603968';
# sql_temp select * from stocks where stock_code='603967';
# sql_temp select * from stocks where stock_code='603966';
# sql_temp select * from stocks where stock_code='603963';
# sql_temp select * from stocks where stock_code='603960';
# sql_temp select * from stocks where stock_code='603959';
# sql_temp select * from stocks where stock_code='603958';
# sql_temp select * from stocks where stock_code='603956';
# sql_temp select * from stocks where stock_code='603955';
# sql_temp select * from stocks where stock_code='603939';
# sql_temp select * from stocks where stock_code='603938';
# sql_temp select * from stocks where stock_code='603937';
# sql_temp select * from stocks where stock_code='603936';
# sql_temp select * from stocks where stock_code='603933';
# sql_temp select * from stocks where stock_code='603929';
# sql_temp select * from stocks where stock_code='603928';
# sql_temp select * from stocks where stock_code='603926';
# sql_temp select * from stocks where stock_code='603922';
# sql_temp select * from stocks where stock_code='603920';
# sql_temp select * from stocks where stock_code='603919';
# sql_temp select * from stocks where stock_code='603918';
# sql_temp select * from stocks where stock_code='603917';
# sql_temp select * from stocks where stock_code='603916';
# sql_temp select * from stocks where stock_code='603912';
# sql_temp select * from stocks where stock_code='603909';
# sql_temp select * from stocks where stock_code='603908';
# sql_temp select * from stocks where stock_code='603906';
# sql_temp select * from stocks where stock_code='603903';
# sql_temp select * from stocks where stock_code='603901';
# sql_temp select * from stocks where stock_code='603900';
# sql_temp select * from stocks where stock_code='603899';
# sql_temp select * from stocks where stock_code='603898';
# sql_temp select * from stocks where stock_code='603897';
# sql_temp select * from stocks where stock_code='603896';
# sql_temp select * from stocks where stock_code='603895';
# sql_temp select * from stocks where stock_code='603890';
# sql_temp select * from stocks where stock_code='603889';
# sql_temp select * from stocks where stock_code='603888';
# sql_temp select * from stocks where stock_code='603887';
# sql_temp select * from stocks where stock_code='603886';
# sql_temp select * from stocks where stock_code='603885';
# sql_temp select * from stocks where stock_code='603883';
# sql_temp select * from stocks where stock_code='603882';
# sql_temp select * from stocks where stock_code='603881';
# sql_temp select * from stocks where stock_code='603880';
# sql_temp select * from stocks where stock_code='603879';
# sql_temp select * from stocks where stock_code='603878';
# sql_temp select * from stocks where stock_code='603877';
# sql_temp select * from stocks where stock_code='603876';
# sql_temp select * from stocks where stock_code='603871';
# sql_temp select * from stocks where stock_code='603869';
# sql_temp select * from stocks where stock_code='603868';
# sql_temp select * from stocks where stock_code='603866';
# sql_temp select * from stocks where stock_code='603861';
# sql_temp select * from stocks where stock_code='603860';
# sql_temp select * from stocks where stock_code='603859';
# sql_temp select * from stocks where stock_code='603858';
# sql_temp select * from stocks where stock_code='603856';
# sql_temp select * from stocks where stock_code='603855';
# sql_temp select * from stocks where stock_code='603848';
# sql_temp select * from stocks where stock_code='603843';
# sql_temp select * from stocks where stock_code='603839';
# sql_temp select * from stocks where stock_code='603838';
# sql_temp select * from stocks where stock_code='603833';
# sql_temp select * from stocks where stock_code='603829';
# sql_temp select * from stocks where stock_code='603828';
# sql_temp select * from stocks where stock_code='603826';
# sql_temp select * from stocks where stock_code='603825';
# sql_temp select * from stocks where stock_code='603823';
# sql_temp select * from stocks where stock_code='603822';
# sql_temp select * from stocks where stock_code='603819';
# sql_temp select * from stocks where stock_code='603818';
# sql_temp select * from stocks where stock_code='603817';
# sql_temp select * from stocks where stock_code='603816';
# sql_temp select * from stocks where stock_code='603813';
# sql_temp select * from stocks where stock_code='603811';
# sql_temp select * from stocks where stock_code='603810';
# sql_temp select * from stocks where stock_code='603809';
# sql_temp select * from stocks where stock_code='603808';
# sql_temp select * from stocks where stock_code='603806';
# sql_temp select * from stocks where stock_code='603803';
# sql_temp select * from stocks where stock_code='603801';
# sql_temp select * from stocks where stock_code='603800';
# sql_temp select * from stocks where stock_code='603799';
# sql_temp select * from stocks where stock_code='603798';
# sql_temp select * from stocks where stock_code='603797';
# sql_temp select * from stocks where stock_code='603790';
# sql_temp select * from stocks where stock_code='603789';
# sql_temp select * from stocks where stock_code='603788';
# sql_temp select * from stocks where stock_code='603787';
# sql_temp select * from stocks where stock_code='603779';
# sql_temp select * from stocks where stock_code='603778';
# sql_temp select * from stocks where stock_code='603777';
# sql_temp select * from stocks where stock_code='603776';
# sql_temp select * from stocks where stock_code='603773';
# sql_temp select * from stocks where stock_code='603768';
# sql_temp select * from stocks where stock_code='603767';
# sql_temp select * from stocks where stock_code='603766';
# sql_temp select * from stocks where stock_code='603758';
# sql_temp select * from stocks where stock_code='603757';
# sql_temp select * from stocks where stock_code='603739';
# sql_temp select * from stocks where stock_code='603738';
# sql_temp select * from stocks where stock_code='603737';
# sql_temp select * from stocks where stock_code='603733';
# sql_temp select * from stocks where stock_code='603730';
# sql_temp select * from stocks where stock_code='603729';
# sql_temp select * from stocks where stock_code='603728';
# sql_temp select * from stocks where stock_code='603727';
# sql_temp select * from stocks where stock_code='603726';
# sql_temp select * from stocks where stock_code='603725';
# sql_temp select * from stocks where stock_code='603722';
# sql_temp select * from stocks where stock_code='603721';
# sql_temp select * from stocks where stock_code='603718';
# sql_temp select * from stocks where stock_code='603717';
# sql_temp select * from stocks where stock_code='603716';
# sql_temp select * from stocks where stock_code='603713';
# sql_temp select * from stocks where stock_code='603712';
# sql_temp select * from stocks where stock_code='603711';
# sql_temp select * from stocks where stock_code='603709';
# sql_temp select * from stocks where stock_code='603708';
# sql_temp select * from stocks where stock_code='603707';
# sql_temp select * from stocks where stock_code='603706';
# sql_temp select * from stocks where stock_code='603703';
# sql_temp select * from stocks where stock_code='603701';
# sql_temp select * from stocks where stock_code='603700';
# sql_temp select * from stocks where stock_code='603699';
# sql_temp select * from stocks where stock_code='603698';
# sql_temp select * from stocks where stock_code='603696';
# sql_temp select * from stocks where stock_code='603693';
# sql_temp select * from stocks where stock_code='603690';
# sql_temp select * from stocks where stock_code='603689';
# sql_temp select * from stocks where stock_code='603688';
# sql_temp select * from stocks where stock_code='603686';
# sql_temp select * from stocks where stock_code='603685';
# sql_temp select * from stocks where stock_code='603683';
# sql_temp select * from stocks where stock_code='603681';
# sql_temp select * from stocks where stock_code='603680';
# sql_temp select * from stocks where stock_code='603679';
# sql_temp select * from stocks where stock_code='603678';
# sql_temp select * from stocks where stock_code='603677';
# sql_temp select * from stocks where stock_code='603676';
# sql_temp select * from stocks where stock_code='603669';
# sql_temp select * from stocks where stock_code='603668';
# sql_temp select * from stocks where stock_code='603667';
# sql_temp select * from stocks where stock_code='603666';
# sql_temp select * from stocks where stock_code='603665';
# sql_temp select * from stocks where stock_code='603663';
# sql_temp select * from stocks where stock_code='603661';
# sql_temp select * from stocks where stock_code='603660';
# sql_temp select * from stocks where stock_code='603659';
# sql_temp select * from stocks where stock_code='603658';
# sql_temp select * from stocks where stock_code='603657';
# sql_temp select * from stocks where stock_code='603656';
# sql_temp select * from stocks where stock_code='603655';
# sql_temp select * from stocks where stock_code='603650';
# sql_temp select * from stocks where stock_code='603648';
# sql_temp select * from stocks where stock_code='603639';
# sql_temp select * from stocks where stock_code='603638';
# sql_temp select * from stocks where stock_code='603637';
# sql_temp select * from stocks where stock_code='603636';
# sql_temp select * from stocks where stock_code='603633';
# sql_temp select * from stocks where stock_code='603630';
# sql_temp select * from stocks where stock_code='603629';
# sql_temp select * from stocks where stock_code='603628';
# sql_temp select * from stocks where stock_code='603626';
# sql_temp select * from stocks where stock_code='603619';
# sql_temp select * from stocks where stock_code='603618';
# sql_temp select * from stocks where stock_code='603617';
# sql_temp select * from stocks where stock_code='603616';
# sql_temp select * from stocks where stock_code='603615';
# sql_temp select * from stocks where stock_code='603612';
# sql_temp select * from stocks where stock_code='603611';
# sql_temp select * from stocks where stock_code='603609';
# sql_temp select * from stocks where stock_code='603608';
# sql_temp select * from stocks where stock_code='603607';
# sql_temp select * from stocks where stock_code='603606';
# sql_temp select * from stocks where stock_code='603605';
# sql_temp select * from stocks where stock_code='603603';
# sql_temp select * from stocks where stock_code='603602';
# sql_temp select * from stocks where stock_code='603601';
# sql_temp select * from stocks where stock_code='603600';
# sql_temp select * from stocks where stock_code='603599';
# sql_temp select * from stocks where stock_code='603598';
# sql_temp select * from stocks where stock_code='603596';
# sql_temp select * from stocks where stock_code='603595';
# sql_temp select * from stocks where stock_code='603590';
# sql_temp select * from stocks where stock_code='603589';
# sql_temp select * from stocks where stock_code='603588';
# sql_temp select * from stocks where stock_code='603587';
# sql_temp select * from stocks where stock_code='603586';
# sql_temp select * from stocks where stock_code='603585';
# sql_temp select * from stocks where stock_code='603583';
# sql_temp select * from stocks where stock_code='603580';
# sql_temp select * from stocks where stock_code='603579';
# sql_temp select * from stocks where stock_code='603578';
# sql_temp select * from stocks where stock_code='603577';
# sql_temp select * from stocks where stock_code='603569';
# sql_temp select * from stocks where stock_code='603568';
# sql_temp select * from stocks where stock_code='603567';
# sql_temp select * from stocks where stock_code='603566';
# sql_temp select * from stocks where stock_code='603559';
# sql_temp select * from stocks where stock_code='603558';
# sql_temp select * from stocks where stock_code='603557';
# sql_temp select * from stocks where stock_code='603556';
# sql_temp select * from stocks where stock_code='603555';
# sql_temp select * from stocks where stock_code='603538';
# sql_temp select * from stocks where stock_code='603536';
# sql_temp select * from stocks where stock_code='603535';
# sql_temp select * from stocks where stock_code='603533';
# sql_temp select * from stocks where stock_code='603528';
# sql_temp select * from stocks where stock_code='603527';
# sql_temp select * from stocks where stock_code='603520';
# sql_temp select * from stocks where stock_code='603519';
# sql_temp select * from stocks where stock_code='603518';
# sql_temp select * from stocks where stock_code='603517';
# sql_temp select * from stocks where stock_code='603516';
# sql_temp select * from stocks where stock_code='603515';
# sql_temp select * from stocks where stock_code='603508';
# sql_temp select * from stocks where stock_code='603507';
# sql_temp select * from stocks where stock_code='603506';
# sql_temp select * from stocks where stock_code='603505';
# sql_temp select * from stocks where stock_code='603501';
# sql_temp select * from stocks where stock_code='603500';
# sql_temp select * from stocks where stock_code='603499';
# sql_temp select * from stocks where stock_code='603496';
# sql_temp select * from stocks where stock_code='603488';
# sql_temp select * from stocks where stock_code='603486';
# sql_temp select * from stocks where stock_code='603477';
# sql_temp select * from stocks where stock_code='603466';
# sql_temp select * from stocks where stock_code='603458';
# sql_temp select * from stocks where stock_code='603456';
# sql_temp select * from stocks where stock_code='603444';
# sql_temp select * from stocks where stock_code='603429';
# sql_temp select * from stocks where stock_code='603421';
# sql_temp select * from stocks where stock_code='603416';
# sql_temp select * from stocks where stock_code='603399';
# sql_temp select * from stocks where stock_code='603398';
# sql_temp select * from stocks where stock_code='603396';
# sql_temp select * from stocks where stock_code='603393';
# sql_temp select * from stocks where stock_code='603389';
# sql_temp select * from stocks where stock_code='603388';
# sql_temp select * from stocks where stock_code='603387';
# sql_temp select * from stocks where stock_code='603386';
# sql_temp select * from stocks where stock_code='603385';
# sql_temp select * from stocks where stock_code='603383';
# sql_temp select * from stocks where stock_code='603380';
# sql_temp select * from stocks where stock_code='603379';
# sql_temp select * from stocks where stock_code='603378';
# sql_temp select * from stocks where stock_code='603377';
# sql_temp select * from stocks where stock_code='603369';
# sql_temp select * from stocks where stock_code='603368';
# sql_temp select * from stocks where stock_code='603367';
# sql_temp select * from stocks where stock_code='603366';
# sql_temp select * from stocks where stock_code='603365';
# sql_temp select * from stocks where stock_code='603363';
# sql_temp select * from stocks where stock_code='603360';
# sql_temp select * from stocks where stock_code='603359';
# sql_temp select * from stocks where stock_code='603358';
# sql_temp select * from stocks where stock_code='603357';
# sql_temp select * from stocks where stock_code='603356';
# sql_temp select * from stocks where stock_code='603355';
# sql_temp select * from stocks where stock_code='603351';
# sql_temp select * from stocks where stock_code='603348';
# sql_temp select * from stocks where stock_code='603345';
# sql_temp select * from stocks where stock_code='603339';
# sql_temp select * from stocks where stock_code='603338';
# sql_temp select * from stocks where stock_code='603337';
# sql_temp select * from stocks where stock_code='603336';
# sql_temp select * from stocks where stock_code='603335';
# sql_temp select * from stocks where stock_code='603333';
# sql_temp select * from stocks where stock_code='603332';
# sql_temp select * from stocks where stock_code='603331';
# sql_temp select * from stocks where stock_code='603330';
# sql_temp select * from stocks where stock_code='603329';
# sql_temp select * from stocks where stock_code='603328';
# sql_temp select * from stocks where stock_code='603326';
# sql_temp select * from stocks where stock_code='603323';
# sql_temp select * from stocks where stock_code='603322';
# sql_temp select * from stocks where stock_code='603321';
# sql_temp select * from stocks where stock_code='603320';
# sql_temp select * from stocks where stock_code='603319';
# sql_temp select * from stocks where stock_code='603318';
# sql_temp select * from stocks where stock_code='603317';
# sql_temp select * from stocks where stock_code='603316';
# sql_temp select * from stocks where stock_code='603315';
# sql_temp select * from stocks where stock_code='603313';
# sql_temp select * from stocks where stock_code='603311';
# sql_temp select * from stocks where stock_code='603309';
# sql_temp select * from stocks where stock_code='603308';
# sql_temp select * from stocks where stock_code='603306';
# sql_temp select * from stocks where stock_code='603305';
# sql_temp select * from stocks where stock_code='603303';
# sql_temp select * from stocks where stock_code='603301';
# sql_temp select * from stocks where stock_code='603300';
# sql_temp select * from stocks where stock_code='603299';
# sql_temp select * from stocks where stock_code='603298';
# sql_temp select * from stocks where stock_code='603297';
# sql_temp select * from stocks where stock_code='603289';
# sql_temp select * from stocks where stock_code='603288';
# sql_temp select * from stocks where stock_code='603286';
# sql_temp select * from stocks where stock_code='603283';
# sql_temp select * from stocks where stock_code='603278';
# sql_temp select * from stocks where stock_code='603277';
# sql_temp select * from stocks where stock_code='603269';
# sql_temp select * from stocks where stock_code='603268';
# sql_temp select * from stocks where stock_code='603266';
# sql_temp select * from stocks where stock_code='603260';
# sql_temp select * from stocks where stock_code='603259';
# sql_temp select * from stocks where stock_code='603258';
# sql_temp select * from stocks where stock_code='603239';
# sql_temp select * from stocks where stock_code='603238';
# sql_temp select * from stocks where stock_code='603233';
# sql_temp select * from stocks where stock_code='603232';
# sql_temp select * from stocks where stock_code='603229';
# sql_temp select * from stocks where stock_code='603228';
# sql_temp select * from stocks where stock_code='603227';
# sql_temp select * from stocks where stock_code='603226';
# sql_temp select * from stocks where stock_code='603225';
# sql_temp select * from stocks where stock_code='603223';
# sql_temp select * from stocks where stock_code='603222';
# sql_temp select * from stocks where stock_code='603220';
# sql_temp select * from stocks where stock_code='603218';
# sql_temp select * from stocks where stock_code='603214';
# sql_temp select * from stocks where stock_code='603208';
# sql_temp select * from stocks where stock_code='603203';
# sql_temp select * from stocks where stock_code='603200';
# sql_temp select * from stocks where stock_code='603199';
# sql_temp select * from stocks where stock_code='603198';
# sql_temp select * from stocks where stock_code='603197';
# sql_temp select * from stocks where stock_code='603196';
# sql_temp select * from stocks where stock_code='603192';
# sql_temp select * from stocks where stock_code='603189';
# sql_temp select * from stocks where stock_code='603188';
# sql_temp select * from stocks where stock_code='603187';
# sql_temp select * from stocks where stock_code='603186';
# sql_temp select * from stocks where stock_code='603185';
# sql_temp select * from stocks where stock_code='603183';
# sql_temp select * from stocks where stock_code='603181';
# sql_temp select * from stocks where stock_code='603180';
# sql_temp select * from stocks where stock_code='603179';
# sql_temp select * from stocks where stock_code='603178';
# sql_temp select * from stocks where stock_code='603177';
# sql_temp select * from stocks where stock_code='603169';
# sql_temp select * from stocks where stock_code='603168';
# sql_temp select * from stocks where stock_code='603167';
# sql_temp select * from stocks where stock_code='603166';
# sql_temp select * from stocks where stock_code='603165';
# sql_temp select * from stocks where stock_code='603161';
# sql_temp select * from stocks where stock_code='603160';
# sql_temp select * from stocks where stock_code='603159';
# sql_temp select * from stocks where stock_code='603158';
# sql_temp select * from stocks where stock_code='603157';
# sql_temp select * from stocks where stock_code='603156';
# sql_temp select * from stocks where stock_code='603139';
# sql_temp select * from stocks where stock_code='603138';
# sql_temp select * from stocks where stock_code='603136';
# sql_temp select * from stocks where stock_code='603133';
# sql_temp select * from stocks where stock_code='603131';
# sql_temp select * from stocks where stock_code='603129';
# sql_temp select * from stocks where stock_code='603128';
# sql_temp select * from stocks where stock_code='603127';
# sql_temp select * from stocks where stock_code='603126';
# sql_temp select * from stocks where stock_code='603123';
# sql_temp select * from stocks where stock_code='603121';
# sql_temp select * from stocks where stock_code='603118';
# sql_temp select * from stocks where stock_code='603117';
# sql_temp select * from stocks where stock_code='603116';
# sql_temp select * from stocks where stock_code='603113';
# sql_temp select * from stocks where stock_code='603111';
# sql_temp select * from stocks where stock_code='603110';
# sql_temp select * from stocks where stock_code='603108';
# sql_temp select * from stocks where stock_code='603106';
# sql_temp select * from stocks where stock_code='603105';
# sql_temp select * from stocks where stock_code='603103';
# sql_temp select * from stocks where stock_code='603101';
# sql_temp select * from stocks where stock_code='603100';
# sql_temp select * from stocks where stock_code='603099';
# sql_temp select * from stocks where stock_code='603098';
# sql_temp select * from stocks where stock_code='603096';
# sql_temp select * from stocks where stock_code='603090';
# sql_temp select * from stocks where stock_code='603089';
# sql_temp select * from stocks where stock_code='603088';
# sql_temp select * from stocks where stock_code='603086';
# sql_temp select * from stocks where stock_code='603085';
# sql_temp select * from stocks where stock_code='603083';
# sql_temp select * from stocks where stock_code='603081';
# sql_temp select * from stocks where stock_code='603080';
# sql_temp select * from stocks where stock_code='603079';
# sql_temp select * from stocks where stock_code='603078';
# sql_temp select * from stocks where stock_code='603077';
# sql_temp select * from stocks where stock_code='603076';
# sql_temp select * from stocks where stock_code='603069';
# sql_temp select * from stocks where stock_code='603068';
# sql_temp select * from stocks where stock_code='603067';
# sql_temp select * from stocks where stock_code='603066';
# sql_temp select * from stocks where stock_code='603063';
# sql_temp select * from stocks where stock_code='603060';
# sql_temp select * from stocks where stock_code='603059';
# sql_temp select * from stocks where stock_code='603058';
# sql_temp select * from stocks where stock_code='603056';
# sql_temp select * from stocks where stock_code='603055';
# sql_temp select * from stocks where stock_code='603050';
# sql_temp select * from stocks where stock_code='603045';
# sql_temp select * from stocks where stock_code='603043';
# sql_temp select * from stocks where stock_code='603042';
# sql_temp select * from stocks where stock_code='603041';
# sql_temp select * from stocks where stock_code='603040';
# sql_temp select * from stocks where stock_code='603039';
# sql_temp select * from stocks where stock_code='603038';
# sql_temp select * from stocks where stock_code='603037';
# sql_temp select * from stocks where stock_code='603036';
# sql_temp select * from stocks where stock_code='603035';
# sql_temp select * from stocks where stock_code='603033';
# sql_temp select * from stocks where stock_code='603032';
# sql_temp select * from stocks where stock_code='603031';
# sql_temp select * from stocks where stock_code='603030';
# sql_temp select * from stocks where stock_code='603029';
# sql_temp select * from stocks where stock_code='603028';
# sql_temp select * from stocks where stock_code='603027';
# sql_temp select * from stocks where stock_code='603026';
# sql_temp select * from stocks where stock_code='603025';
# sql_temp select * from stocks where stock_code='603023';
# sql_temp select * from stocks where stock_code='603022';
# sql_temp select * from stocks where stock_code='603021';
# sql_temp select * from stocks where stock_code='603020';
# sql_temp select * from stocks where stock_code='603019';
# sql_temp select * from stocks where stock_code='603018';
# sql_temp select * from stocks where stock_code='603017';
# sql_temp select * from stocks where stock_code='603016';
# sql_temp select * from stocks where stock_code='603015';
# sql_temp select * from stocks where stock_code='603013';
# sql_temp select * from stocks where stock_code='603012';
# sql_temp select * from stocks where stock_code='603011';
# sql_temp select * from stocks where stock_code='603010';
# sql_temp select * from stocks where stock_code='603009';
# sql_temp select * from stocks where stock_code='603008';
# sql_temp select * from stocks where stock_code='603007';
# sql_temp select * from stocks where stock_code='603006';
# sql_temp select * from stocks where stock_code='603005';
# sql_temp select * from stocks where stock_code='603003';
# sql_temp select * from stocks where stock_code='603002';
# sql_temp select * from stocks where stock_code='603001';
# sql_temp select * from stocks where stock_code='603000';
# sql_temp select * from stocks where stock_code='601999';
# sql_temp select * from stocks where stock_code='601998';
# sql_temp select * from stocks where stock_code='601997';
# sql_temp select * from stocks where stock_code='601996';
# sql_temp select * from stocks where stock_code='601992';
# sql_temp select * from stocks where stock_code='601991';
# sql_temp select * from stocks where stock_code='601990';
# sql_temp select * from stocks where stock_code='601989';
# sql_temp select * from stocks where stock_code='601988';
# sql_temp select * from stocks where stock_code='601985';
# sql_temp select * from stocks where stock_code='601975';
# sql_temp select * from stocks where stock_code='601969';
# sql_temp select * from stocks where stock_code='601968';
# sql_temp select * from stocks where stock_code='601966';
# sql_temp select * from stocks where stock_code='601965';
# sql_temp select * from stocks where stock_code='601958';
# sql_temp select * from stocks where stock_code='601952';
# sql_temp select * from stocks where stock_code='601949';
# sql_temp select * from stocks where stock_code='601939';
# sql_temp select * from stocks where stock_code='601933';
# sql_temp select * from stocks where stock_code='601929';
# sql_temp select * from stocks where stock_code='601928';
# sql_temp select * from stocks where stock_code='601919';
# sql_temp select * from stocks where stock_code='601918';
# sql_temp select * from stocks where stock_code='601908';
# sql_temp select * from stocks where stock_code='601901';
# sql_temp select * from stocks where stock_code='601900';
# sql_temp select * from stocks where stock_code='601899';
# sql_temp select * from stocks where stock_code='601898';
# sql_temp select * from stocks where stock_code='601890';
# sql_temp select * from stocks where stock_code='601888';
# sql_temp select * from stocks where stock_code='601886';
# sql_temp select * from stocks where stock_code='601882';
# sql_temp select * from stocks where stock_code='601881';
# sql_temp select * from stocks where stock_code='601880';
# sql_temp select * from stocks where stock_code='601878';
# sql_temp select * from stocks where stock_code='601877';
# sql_temp select * from stocks where stock_code='601872';
# sql_temp select * from stocks where stock_code='601869';
# sql_temp select * from stocks where stock_code='601866';
# sql_temp select * from stocks where stock_code='601865';
# sql_temp select * from stocks where stock_code='601860';
# sql_temp select * from stocks where stock_code='601858';
# sql_temp select * from stocks where stock_code='601857';
# sql_temp select * from stocks where stock_code='601838';
# sql_temp select * from stocks where stock_code='601828';
# sql_temp select * from stocks where stock_code='601818';
# sql_temp select * from stocks where stock_code='601811';
# sql_temp select * from stocks where stock_code='601808';
# sql_temp select * from stocks where stock_code='601801';
# sql_temp select * from stocks where stock_code='601800';
# sql_temp select * from stocks where stock_code='601799';
# sql_temp select * from stocks where stock_code='601798';
# sql_temp select * from stocks where stock_code='601789';
# sql_temp select * from stocks where stock_code='601788';
# sql_temp select * from stocks where stock_code='601777';
# sql_temp select * from stocks where stock_code='601766';
# sql_temp select * from stocks where stock_code='601727';
# sql_temp select * from stocks where stock_code='601718';
# sql_temp select * from stocks where stock_code='601717';
# sql_temp select * from stocks where stock_code='601700';
# sql_temp select * from stocks where stock_code='601699';
# sql_temp select * from stocks where stock_code='601689';
# sql_temp select * from stocks where stock_code='601688';
# sql_temp select * from stocks where stock_code='601678';
# sql_temp select * from stocks where stock_code='601677';
# sql_temp select * from stocks where stock_code='601669';
# sql_temp select * from stocks where stock_code='601668';
# sql_temp select * from stocks where stock_code='601666';
# sql_temp select * from stocks where stock_code='601636';
# sql_temp select * from stocks where stock_code='601633';
# sql_temp select * from stocks where stock_code='601628';
# sql_temp select * from stocks where stock_code='601619';
# sql_temp select * from stocks where stock_code='601618';
# sql_temp select * from stocks where stock_code='601616';
# sql_temp select * from stocks where stock_code='601615';
# sql_temp select * from stocks where stock_code='601611';
# sql_temp select * from stocks where stock_code='601608';
# sql_temp select * from stocks where stock_code='601607';
# sql_temp select * from stocks where stock_code='601606';
# sql_temp select * from stocks where stock_code='601601';
# sql_temp select * from stocks where stock_code='601600';
# sql_temp select * from stocks where stock_code='601599';
# sql_temp select * from stocks where stock_code='601598';
# sql_temp select * from stocks where stock_code='601595';
# sql_temp select * from stocks where stock_code='601588';
# sql_temp select * from stocks where stock_code='601579';
# sql_temp select * from stocks where stock_code='601577';
# sql_temp select * from stocks where stock_code='601567';
# sql_temp select * from stocks where stock_code='601566';
# sql_temp select * from stocks where stock_code='601558';
# sql_temp select * from stocks where stock_code='601555';
# sql_temp select * from stocks where stock_code='601519';
# sql_temp select * from stocks where stock_code='601518';
# sql_temp select * from stocks where stock_code='601515';
# sql_temp select * from stocks where stock_code='601500';
# sql_temp select * from stocks where stock_code='601398';
# sql_temp select * from stocks where stock_code='601390';
# sql_temp select * from stocks where stock_code='601388';
# sql_temp select * from stocks where stock_code='601377';
# sql_temp select * from stocks where stock_code='601375';
# sql_temp select * from stocks where stock_code='601369';
# sql_temp select * from stocks where stock_code='601368';
# sql_temp select * from stocks where stock_code='601366';
# sql_temp select * from stocks where stock_code='601360';
# sql_temp select * from stocks where stock_code='601339';
# sql_temp select * from stocks where stock_code='601336';
# sql_temp select * from stocks where stock_code='601333';
# sql_temp select * from stocks where stock_code='601330';
# sql_temp select * from stocks where stock_code='601328';
# sql_temp select * from stocks where stock_code='601326';
# sql_temp select * from stocks where stock_code='601319';
# sql_temp select * from stocks where stock_code='601318';
# sql_temp select * from stocks where stock_code='601311';
# sql_temp select * from stocks where stock_code='601298';
# sql_temp select * from stocks where stock_code='601288';
# sql_temp select * from stocks where stock_code='601258';
# sql_temp select * from stocks where stock_code='601238';
# sql_temp select * from stocks where stock_code='601233';
# sql_temp select * from stocks where stock_code='601231';
# sql_temp select * from stocks where stock_code='601229';
# sql_temp select * from stocks where stock_code='601228';
# sql_temp select * from stocks where stock_code='601226';
# sql_temp select * from stocks where stock_code='601225';
# sql_temp select * from stocks where stock_code='601222';
# sql_temp select * from stocks where stock_code='601218';
# sql_temp select * from stocks where stock_code='601216';
# sql_temp select * from stocks where stock_code='601212';
# sql_temp select * from stocks where stock_code='601211';
# sql_temp select * from stocks where stock_code='601208';
# sql_temp select * from stocks where stock_code='601200';
# sql_temp select * from stocks where stock_code='601199';
# sql_temp select * from stocks where stock_code='601198';
# sql_temp select * from stocks where stock_code='601188';
# sql_temp select * from stocks where stock_code='601186';
# sql_temp select * from stocks where stock_code='601179';
# sql_temp select * from stocks where stock_code='601177';
# sql_temp select * from stocks where stock_code='601169';
# sql_temp select * from stocks where stock_code='601168';
# sql_temp select * from stocks where stock_code='601166';
# sql_temp select * from stocks where stock_code='601163';
# sql_temp select * from stocks where stock_code='601162';
# sql_temp select * from stocks where stock_code='601158';
# sql_temp select * from stocks where stock_code='601155';
# sql_temp select * from stocks where stock_code='601139';
# sql_temp select * from stocks where stock_code='601138';
# sql_temp select * from stocks where stock_code='601137';
# sql_temp select * from stocks where stock_code='601128';
# sql_temp select * from stocks where stock_code='601127';
# sql_temp select * from stocks where stock_code='601126';
# sql_temp select * from stocks where stock_code='601118';
# sql_temp select * from stocks where stock_code='601117';
# sql_temp select * from stocks where stock_code='601116';
# sql_temp select * from stocks where stock_code='601113';
# sql_temp select * from stocks where stock_code='601111';
# sql_temp select * from stocks where stock_code='601108';
# sql_temp select * from stocks where stock_code='601107';
# sql_temp select * from stocks where stock_code='601106';
# sql_temp select * from stocks where stock_code='601101';
# sql_temp select * from stocks where stock_code='601100';
# sql_temp select * from stocks where stock_code='601099';
# sql_temp select * from stocks where stock_code='601098';
# sql_temp select * from stocks where stock_code='601088';
# sql_temp select * from stocks where stock_code='601086';
# sql_temp select * from stocks where stock_code='601069';
# sql_temp select * from stocks where stock_code='601068';
# sql_temp select * from stocks where stock_code='601066';
# sql_temp select * from stocks where stock_code='601058';
# sql_temp select * from stocks where stock_code='601038';
# sql_temp select * from stocks where stock_code='601028';
# sql_temp select * from stocks where stock_code='601021';
# sql_temp select * from stocks where stock_code='601020';
# sql_temp select * from stocks where stock_code='601019';
# sql_temp select * from stocks where stock_code='601018';
# sql_temp select * from stocks where stock_code='601016';
# sql_temp select * from stocks where stock_code='601015';
# sql_temp select * from stocks where stock_code='601012';
# sql_temp select * from stocks where stock_code='601011';
# sql_temp select * from stocks where stock_code='601010';
# sql_temp select * from stocks where stock_code='601009';
# sql_temp select * from stocks where stock_code='601008';
# sql_temp select * from stocks where stock_code='601007';
# sql_temp select * from stocks where stock_code='601006';
# sql_temp select * from stocks where stock_code='601005';
# sql_temp select * from stocks where stock_code='601003';
# sql_temp select * from stocks where stock_code='601002';
# sql_temp select * from stocks where stock_code='601001';
# sql_temp select * from stocks where stock_code='601000';
# sql_temp select * from stocks where stock_code='600999';
# sql_temp select * from stocks where stock_code='600998';
# sql_temp select * from stocks where stock_code='600997';
# sql_temp select * from stocks where stock_code='600996';
# sql_temp select * from stocks where stock_code='600995';
# sql_temp select * from stocks where stock_code='600993';
# sql_temp select * from stocks where stock_code='600992';
# sql_temp select * from stocks where stock_code='600990';
# sql_temp select * from stocks where stock_code='600988';
# sql_temp select * from stocks where stock_code='600987';
# sql_temp select * from stocks where stock_code='600986';
# sql_temp select * from stocks where stock_code='600985';
# sql_temp select * from stocks where stock_code='600984';
# sql_temp select * from stocks where stock_code='600983';
# sql_temp select * from stocks where stock_code='600982';
# sql_temp select * from stocks where stock_code='600981';
# sql_temp select * from stocks where stock_code='600980';
# sql_temp select * from stocks where stock_code='600979';
# sql_temp select * from stocks where stock_code='600978';
# sql_temp select * from stocks where stock_code='600977';
# sql_temp select * from stocks where stock_code='600976';
# sql_temp select * from stocks where stock_code='600975';
# sql_temp select * from stocks where stock_code='600973';
# sql_temp select * from stocks where stock_code='600971';
# sql_temp select * from stocks where stock_code='600970';
# sql_temp select * from stocks where stock_code='600969';
# sql_temp select * from stocks where stock_code='600967';
# sql_temp select * from stocks where stock_code='600966';
# sql_temp select * from stocks where stock_code='600965';
# sql_temp select * from stocks where stock_code='600963';
# sql_temp select * from stocks where stock_code='600962';
# sql_temp select * from stocks where stock_code='600961';
# sql_temp select * from stocks where stock_code='600960';
# sql_temp select * from stocks where stock_code='600959';
# sql_temp select * from stocks where stock_code='600958';
# sql_temp select * from stocks where stock_code='600939';
# sql_temp select * from stocks where stock_code='600936';
# sql_temp select * from stocks where stock_code='600933';
# sql_temp select * from stocks where stock_code='600929';
# sql_temp select * from stocks where stock_code='600928';
# sql_temp select * from stocks where stock_code='600926';
# sql_temp select * from stocks where stock_code='600919';
# sql_temp select * from stocks where stock_code='600917';
# sql_temp select * from stocks where stock_code='600909';
# sql_temp select * from stocks where stock_code='600908';
# sql_temp select * from stocks where stock_code='600903';
# sql_temp select * from stocks where stock_code='600901';
# sql_temp select * from stocks where stock_code='600900';
# sql_temp select * from stocks where stock_code='600898';
# sql_temp select * from stocks where stock_code='600897';
# sql_temp select * from stocks where stock_code='600896';
# sql_temp select * from stocks where stock_code='600895';
# sql_temp select * from stocks where stock_code='600894';
# sql_temp select * from stocks where stock_code='600893';
# sql_temp select * from stocks where stock_code='600892';
# sql_temp select * from stocks where stock_code='600891';
# sql_temp select * from stocks where stock_code='600890';
# sql_temp select * from stocks where stock_code='600889';
# sql_temp select * from stocks where stock_code='600888';
# sql_temp select * from stocks where stock_code='600887';
# sql_temp select * from stocks where stock_code='600886';
# sql_temp select * from stocks where stock_code='600885';
# sql_temp select * from stocks where stock_code='600884';
# sql_temp select * from stocks where stock_code='600883';
# sql_temp select * from stocks where stock_code='600882';
# sql_temp select * from stocks where stock_code='600881';
# sql_temp select * from stocks where stock_code='600880';
# sql_temp select * from stocks where stock_code='600879';
# sql_temp select * from stocks where stock_code='600877';
# sql_temp select * from stocks where stock_code='600876';
# sql_temp select * from stocks where stock_code='600875';
# sql_temp select * from stocks where stock_code='600874';
# sql_temp select * from stocks where stock_code='600873';
# sql_temp select * from stocks where stock_code='600872';
# sql_temp select * from stocks where stock_code='600871';
# sql_temp select * from stocks where stock_code='600870';
# sql_temp select * from stocks where stock_code='600869';
# sql_temp select * from stocks where stock_code='600868';
# sql_temp select * from stocks where stock_code='600867';
# sql_temp select * from stocks where stock_code='600866';
# sql_temp select * from stocks where stock_code='600865';
# sql_temp select * from stocks where stock_code='600864';
# sql_temp select * from stocks where stock_code='600863';
# sql_temp select * from stocks where stock_code='600862';
# sql_temp select * from stocks where stock_code='600861';
# sql_temp select * from stocks where stock_code='600860';
# sql_temp select * from stocks where stock_code='600859';
# sql_temp select * from stocks where stock_code='600858';
# sql_temp select * from stocks where stock_code='600857';
# sql_temp select * from stocks where stock_code='600856';
# sql_temp select * from stocks where stock_code='600855';
# sql_temp select * from stocks where stock_code='600854';
# sql_temp select * from stocks where stock_code='600853';
# sql_temp select * from stocks where stock_code='600851';
# sql_temp select * from stocks where stock_code='600850';
# sql_temp select * from stocks where stock_code='600848';
# sql_temp select * from stocks where stock_code='600847';
# sql_temp select * from stocks where stock_code='600846';
# sql_temp select * from stocks where stock_code='600845';
# sql_temp select * from stocks where stock_code='600844';
# sql_temp select * from stocks where stock_code='600843';
# sql_temp select * from stocks where stock_code='600841';
# sql_temp select * from stocks where stock_code='600839';
# sql_temp select * from stocks where stock_code='600838';
# sql_temp select * from stocks where stock_code='600837';
# sql_temp select * from stocks where stock_code='600836';
# sql_temp select * from stocks where stock_code='600835';
# sql_temp select * from stocks where stock_code='600834';
# sql_temp select * from stocks where stock_code='600833';
# sql_temp select * from stocks where stock_code='600831';
# sql_temp select * from stocks where stock_code='600830';
# sql_temp select * from stocks where stock_code='600829';
# sql_temp select * from stocks where stock_code='600828';
# sql_temp select * from stocks where stock_code='600827';
# sql_temp select * from stocks where stock_code='600826';
# sql_temp select * from stocks where stock_code='600825';
# sql_temp select * from stocks where stock_code='600824';
# sql_temp select * from stocks where stock_code='600823';
# sql_temp select * from stocks where stock_code='600822';
# sql_temp select * from stocks where stock_code='600821';
# sql_temp select * from stocks where stock_code='600820';
# sql_temp select * from stocks where stock_code='600819';
# sql_temp select * from stocks where stock_code='600818';
# sql_temp select * from stocks where stock_code='600817';
# sql_temp select * from stocks where stock_code='600816';
# sql_temp select * from stocks where stock_code='600815';
# sql_temp select * from stocks where stock_code='600814';
# sql_temp select * from stocks where stock_code='600812';
# sql_temp select * from stocks where stock_code='600811';
# sql_temp select * from stocks where stock_code='600810';
# sql_temp select * from stocks where stock_code='600809';
# sql_temp select * from stocks where stock_code='600808';
# sql_temp select * from stocks where stock_code='600807';
# sql_temp select * from stocks where stock_code='600805';
# sql_temp select * from stocks where stock_code='600804';
# sql_temp select * from stocks where stock_code='600803';
# sql_temp select * from stocks where stock_code='600802';
# sql_temp select * from stocks where stock_code='600801';
# sql_temp select * from stocks where stock_code='600800';
# sql_temp select * from stocks where stock_code='600798';
# sql_temp select * from stocks where stock_code='600797';
# sql_temp select * from stocks where stock_code='600796';
# sql_temp select * from stocks where stock_code='600795';
# sql_temp select * from stocks where stock_code='600794';
# sql_temp select * from stocks where stock_code='600793';
# sql_temp select * from stocks where stock_code='600792';
# sql_temp select * from stocks where stock_code='600791';
# sql_temp select * from stocks where stock_code='600790';
# sql_temp select * from stocks where stock_code='600789';
# sql_temp select * from stocks where stock_code='600787';
# sql_temp select * from stocks where stock_code='600785';
# sql_temp select * from stocks where stock_code='600784';
# sql_temp select * from stocks where stock_code='600783';
# sql_temp select * from stocks where stock_code='600782';
# sql_temp select * from stocks where stock_code='600781';
# sql_temp select * from stocks where stock_code='600780';
# sql_temp select * from stocks where stock_code='600779';
# sql_temp select * from stocks where stock_code='600778';
# sql_temp select * from stocks where stock_code='600777';
# sql_temp select * from stocks where stock_code='600776';
# sql_temp select * from stocks where stock_code='600775';
# sql_temp select * from stocks where stock_code='600774';
# sql_temp select * from stocks where stock_code='600773';
# sql_temp select * from stocks where stock_code='600771';
# sql_temp select * from stocks where stock_code='600770';
# sql_temp select * from stocks where stock_code='600769';
# sql_temp select * from stocks where stock_code='600768';
# sql_temp select * from stocks where stock_code='600767';
# sql_temp select * from stocks where stock_code='600766';
# sql_temp select * from stocks where stock_code='600765';
# sql_temp select * from stocks where stock_code='600764';
# sql_temp select * from stocks where stock_code='600763';
# sql_temp select * from stocks where stock_code='600761';
# sql_temp select * from stocks where stock_code='600760';
# sql_temp select * from stocks where stock_code='600759';
# sql_temp select * from stocks where stock_code='600758';
# sql_temp select * from stocks where stock_code='600757';
# sql_temp select * from stocks where stock_code='600756';
# sql_temp select * from stocks where stock_code='600755';
# sql_temp select * from stocks where stock_code='600754';
# sql_temp select * from stocks where stock_code='600753';
# sql_temp select * from stocks where stock_code='600751';
# sql_temp select * from stocks where stock_code='600750';
# sql_temp select * from stocks where stock_code='600749';
# sql_temp select * from stocks where stock_code='600748';
# sql_temp select * from stocks where stock_code='600747';
# sql_temp select * from stocks where stock_code='600746';
# sql_temp select * from stocks where stock_code='600745';
# sql_temp select * from stocks where stock_code='600744';
# sql_temp select * from stocks where stock_code='600743';
# sql_temp select * from stocks where stock_code='600742';
# sql_temp select * from stocks where stock_code='600741';
# ...
# sql_temp select * from stocks where stock_code='000627';
# sql_temp select * from stocks where stock_code='000626';
# sql_temp select * from stocks where stock_code='000625';
# sql_temp select * from stocks where stock_code='000623';
# sql_temp select * from stocks where stock_code='000622';
# sql_temp select * from stocks where stock_code='000620';
# sql_temp select * from stocks where stock_code='000619';
# sql_temp select * from stocks where stock_code='000617';
# sql_temp select * from stocks where stock_code='000616';
# sql_temp select * from stocks where stock_code='000615';
# sql_temp select * from stocks where stock_code='000613';
# sql_temp select * from stocks where stock_code='000612';
# sql_temp select * from stocks where stock_code='000611';
# sql_temp select * from stocks where stock_code='000610';
# sql_temp select * from stocks where stock_code='000609';
# sql_temp select * from stocks where stock_code='000608';
# sql_temp select * from stocks where stock_code='000607';
# sql_temp select * from stocks where stock_code='000606';
# sql_temp select * from stocks where stock_code='000605';
# sql_temp select * from stocks where stock_code='000603';
# sql_temp select * from stocks where stock_code='000601';
# sql_temp select * from stocks where stock_code='000600';
# sql_temp select * from stocks where stock_code='000599';
# sql_temp select * from stocks where stock_code='000598';
# sql_temp select * from stocks where stock_code='000597';
# sql_temp select * from stocks where stock_code='000596';
# sql_temp select * from stocks where stock_code='000595';
# sql_temp select * from stocks where stock_code='000593';
# sql_temp select * from stocks where stock_code='000592';
# sql_temp select * from stocks where stock_code='000591';
# sql_temp select * from stocks where stock_code='000590';
# sql_temp select * from stocks where stock_code='000589';
# sql_temp select * from stocks where stock_code='000587';
# sql_temp select * from stocks where stock_code='000586';
# sql_temp select * from stocks where stock_code='000585';
# sql_temp select * from stocks where stock_code='000584';
# sql_temp select * from stocks where stock_code='000582';
# sql_temp select * from stocks where stock_code='000581';
# sql_temp select * from stocks where stock_code='000576';
# sql_temp select * from stocks where stock_code='000573';
# sql_temp select * from stocks where stock_code='000572';
# sql_temp select * from stocks where stock_code='000571';
# sql_temp select * from stocks where stock_code='000570';
# sql_temp select * from stocks where stock_code='000568';
# sql_temp select * from stocks where stock_code='000567';
# sql_temp select * from stocks where stock_code='000566';
# sql_temp select * from stocks where stock_code='000565';
# sql_temp select * from stocks where stock_code='000564';
# sql_temp select * from stocks where stock_code='000563';
# sql_temp select * from stocks where stock_code='000561';
# sql_temp select * from stocks where stock_code='000560';
# sql_temp select * from stocks where stock_code='000559';
# sql_temp select * from stocks where stock_code='000558';
# sql_temp select * from stocks where stock_code='000557';
# sql_temp select * from stocks where stock_code='000555';
# sql_temp select * from stocks where stock_code='000554';
# sql_temp select * from stocks where stock_code='000553';
# sql_temp select * from stocks where stock_code='000552';
# sql_temp select * from stocks where stock_code='000551';
# sql_temp select * from stocks where stock_code='000550';
# sql_temp select * from stocks where stock_code='000548';
# sql_temp select * from stocks where stock_code='000547';
# sql_temp select * from stocks where stock_code='000546';
# sql_temp select * from stocks where stock_code='000545';
# sql_temp select * from stocks where stock_code='000544';
# sql_temp select * from stocks where stock_code='000543';
# sql_temp select * from stocks where stock_code='000541';
# sql_temp select * from stocks where stock_code='000540';
# sql_temp select * from stocks where stock_code='000539';
# sql_temp select * from stocks where stock_code='000538';
# sql_temp select * from stocks where stock_code='000537';
# sql_temp select * from stocks where stock_code='000536';
# sql_temp select * from stocks where stock_code='000534';
# sql_temp select * from stocks where stock_code='000533';
# sql_temp select * from stocks where stock_code='000532';
# sql_temp select * from stocks where stock_code='000531';
# sql_temp select * from stocks where stock_code='000530';
# sql_temp select * from stocks where stock_code='000529';
# sql_temp select * from stocks where stock_code='000528';
# sql_temp select * from stocks where stock_code='000526';
# sql_temp select * from stocks where stock_code='000525';
# sql_temp select * from stocks where stock_code='000524';
# sql_temp select * from stocks where stock_code='000523';
# sql_temp select * from stocks where stock_code='000521';
# sql_temp select * from stocks where stock_code='000520';
# sql_temp select * from stocks where stock_code='000519';
# sql_temp select * from stocks where stock_code='000518';
# sql_temp select * from stocks where stock_code='000517';
# sql_temp select * from stocks where stock_code='000516';
# sql_temp select * from stocks where stock_code='000514';
# sql_temp select * from stocks where stock_code='000513';
# sql_temp select * from stocks where stock_code='000510';
# sql_temp select * from stocks where stock_code='000509';
# sql_temp select * from stocks where stock_code='000507';
# sql_temp select * from stocks where stock_code='000506';
# sql_temp select * from stocks where stock_code='000505';
# sql_temp select * from stocks where stock_code='000504';
# sql_temp select * from stocks where stock_code='000503';
# sql_temp select * from stocks where stock_code='000502';
# sql_temp select * from stocks where stock_code='000501';
# sql_temp select * from stocks where stock_code='000498';
# sql_temp select * from stocks where stock_code='000488';
# sql_temp select * from stocks where stock_code='000430';
# sql_temp select * from stocks where stock_code='000429';
# sql_temp select * from stocks where stock_code='000428';
# sql_temp select * from stocks where stock_code='000426';
# sql_temp select * from stocks where stock_code='000425';
# sql_temp select * from stocks where stock_code='000423';
# sql_temp select * from stocks where stock_code='000422';
# sql_temp select * from stocks where stock_code='000421';
# sql_temp select * from stocks where stock_code='000420';
# sql_temp select * from stocks where stock_code='000419';
# sql_temp select * from stocks where stock_code='000418';
# sql_temp select * from stocks where stock_code='000417';
# sql_temp select * from stocks where stock_code='000416';
# sql_temp select * from stocks where stock_code='000415';
# sql_temp select * from stocks where stock_code='000413';
# sql_temp select * from stocks where stock_code='000411';
# sql_temp select * from stocks where stock_code='000410';
# sql_temp select * from stocks where stock_code='000409';
# sql_temp select * from stocks where stock_code='000408';
# sql_temp select * from stocks where stock_code='000407';
# sql_temp select * from stocks where stock_code='000404';
# sql_temp select * from stocks where stock_code='000403';
# sql_temp select * from stocks where stock_code='000402';
# sql_temp select * from stocks where stock_code='000401';
# sql_temp select * from stocks where stock_code='000400';
# sql_temp select * from stocks where stock_code='000338';
# sql_temp select * from stocks where stock_code='000333';
# sql_temp select * from stocks where stock_code='000301';
# sql_temp select * from stocks where stock_code='000166';
# sql_temp select * from stocks where stock_code='000159';
# sql_temp select * from stocks where stock_code='000158';
# sql_temp select * from stocks where stock_code='000157';
# sql_temp select * from stocks where stock_code='000156';
# sql_temp select * from stocks where stock_code='000155';
# sql_temp select * from stocks where stock_code='000153';
# sql_temp select * from stocks where stock_code='000151';
# sql_temp select * from stocks where stock_code='000150';
# sql_temp select * from stocks where stock_code='000100';
# sql_temp select * from stocks where stock_code='000099';
# sql_temp select * from stocks where stock_code='000096';
# sql_temp select * from stocks where stock_code='000090';
# sql_temp select * from stocks where stock_code='000089';
# sql_temp select * from stocks where stock_code='000088';
# sql_temp select * from stocks where stock_code='000078';
# sql_temp select * from stocks where stock_code='000070';
# sql_temp select * from stocks where stock_code='000069';
# sql_temp select * from stocks where stock_code='000068';
# sql_temp select * from stocks where stock_code='000066';
# sql_temp select * from stocks where stock_code='000065';
# sql_temp select * from stocks where stock_code='000063';
# sql_temp select * from stocks where stock_code='000062';
# sql_temp select * from stocks where stock_code='000061';
# sql_temp select * from stocks where stock_code='000060';
# sql_temp select * from stocks where stock_code='000059';
# sql_temp select * from stocks where stock_code='000058';
# sql_temp select * from stocks where stock_code='000056';
# sql_temp select * from stocks where stock_code='000055';
# sql_temp select * from stocks where stock_code='000050';
# sql_temp select * from stocks where stock_code='000049';
# sql_temp select * from stocks where stock_code='000048';
# sql_temp select * from stocks where stock_code='000046';
# sql_temp select * from stocks where stock_code='000045';
# sql_temp select * from stocks where stock_code='000043';
# sql_temp select * from stocks where stock_code='000042';
# sql_temp select * from stocks where stock_code='000040';
# sql_temp select * from stocks where stock_code='000039';
# sql_temp select * from stocks where stock_code='000038';
# sql_temp select * from stocks where stock_code='000037';
# sql_temp select * from stocks where stock_code='000036';
# sql_temp select * from stocks where stock_code='000035';
# sql_temp select * from stocks where stock_code='000034';
# sql_temp select * from stocks where stock_code='000032';
# sql_temp select * from stocks where stock_code='000031';
# sql_temp select * from stocks where stock_code='000030';
# sql_temp select * from stocks where stock_code='000029';
# sql_temp select * from stocks where stock_code='000028';
# sql_temp select * from stocks where stock_code='000027';
# sql_temp select * from stocks where stock_code='000026';
# sql_temp select * from stocks where stock_code='000025';
# sql_temp select * from stocks where stock_code='000023';
# sql_temp select * from stocks where stock_code='000021';
# sql_temp select * from stocks where stock_code='000020';
# sql_temp select * from stocks where stock_code='000019';
# sql_temp select * from stocks where stock_code='000018';
# sql_temp select * from stocks where stock_code='000017';
# sql_temp select * from stocks where stock_code='000016';
# sql_temp select * from stocks where stock_code='000014';
# sql_temp select * from stocks where stock_code='000012';
# sql_temp select * from stocks where stock_code='000011';
# sql_temp select * from stocks where stock_code='000010';
# sql_temp select * from stocks where stock_code='000009';
# sql_temp select * from stocks where stock_code='000008';
# sql_temp select * from stocks where stock_code='000007';
# sql_temp select * from stocks where stock_code='000006';
# sql_temp select * from stocks where stock_code='000005';
# sql_temp select * from stocks where stock_code='000004';
# sql_temp select * from stocks where stock_code='000002';
# sql_temp select * from stocks where stock_code='000001';
# sql_temp select * from stocks where stock_code='900951';
# sql_temp select * from stocks where stock_code='900946';
# sql_temp select * from stocks where stock_code='900937';
# sql_temp select * from stocks where stock_code='900930';
# sql_temp select * from stocks where stock_code='900907';
# sql_temp select * from stocks where stock_code='900906';
# sql_temp select * from stocks where stock_code='601798';
# sql_temp select * from stocks where stock_code='601558';
# sql_temp select * from stocks where stock_code='601268';
# sql_temp select * from stocks where stock_code='600984';
# sql_temp select * from stocks where stock_code='600962';
# sql_temp select * from stocks where stock_code='600891';
# sql_temp select * from stocks where stock_code='600877';
# sql_temp select * from stocks where stock_code='600870';
# sql_temp select * from stocks where stock_code='600817';
# sql_temp select * from stocks where stock_code='600815';
# sql_temp select * from stocks where stock_code='600807';
# sql_temp select * from stocks where stock_code='600793';
# sql_temp select * from stocks where stock_code='600779';
# sql_temp select * from stocks where stock_code='600778';
# sql_temp select * from stocks where stock_code='600767';
# sql_temp select * from stocks where stock_code='600747';
# sql_temp select * from stocks where stock_code='600732';
# sql_temp select * from stocks where stock_code='600726';
# sql_temp select * from stocks where stock_code='600725';
# sql_temp select * from stocks where stock_code='600722';
# sql_temp select * from stocks where stock_code='600721';
# sql_temp select * from stocks where stock_code='600715';
# sql_temp select * from stocks where stock_code='600710';
# sql_temp select * from stocks where stock_code='600701';
# sql_temp select * from stocks where stock_code='600698';
# sql_temp select * from stocks where stock_code='600696';
# sql_temp select * from stocks where stock_code='600691';
# sql_temp select * from stocks where stock_code='600687';
# sql_temp select * from stocks where stock_code='600680';
# sql_temp select * from stocks where stock_code='600666';
# sql_temp select * from stocks where stock_code='600656';
# sql_temp select * from stocks where stock_code='600654';
# sql_temp select * from stocks where stock_code='600644';
# sql_temp select * from stocks where stock_code='600634';
# sql_temp select * from stocks where stock_code='600615';
# sql_temp select * from stocks where stock_code='600614';
# sql_temp select * from stocks where stock_code='600610';
# sql_temp select * from stocks where stock_code='600608';
# sql_temp select * from stocks where stock_code='600556';
# sql_temp select * from stocks where stock_code='600539';
# sql_temp select * from stocks where stock_code='600526';
# sql_temp select * from stocks where stock_code='600485';
# sql_temp select * from stocks where stock_code='600462';
# sql_temp select * from stocks where stock_code='600444';
# sql_temp select * from stocks where stock_code='600423';
# sql_temp select * from stocks where stock_code='600421';
# sql_temp select * from stocks where stock_code='600408';
# sql_temp select * from stocks where stock_code='600401';
# sql_temp select * from stocks where stock_code='600399';
# sql_temp select * from stocks where stock_code='600396';
# sql_temp select * from stocks where stock_code='600385';
# sql_temp select * from stocks where stock_code='600321';
# sql_temp select * from stocks where stock_code='600311';
# sql_temp select * from stocks where stock_code='600301';
# sql_temp select * from stocks where stock_code='600289';
# sql_temp select * from stocks where stock_code='600275';
# sql_temp select * from stocks where stock_code='600265';
# sql_temp select * from stocks where stock_code='600247';
# sql_temp select * from stocks where stock_code='600242';
# sql_temp select * from stocks where stock_code='600240';
# sql_temp select * from stocks where stock_code='600238';
# sql_temp select * from stocks where stock_code='600234';
# sql_temp select * from stocks where stock_code='600228';
# sql_temp select * from stocks where stock_code='600217';
# sql_temp select * from stocks where stock_code='600209';
# sql_temp select * from stocks where stock_code='600193';
# sql_temp select * from stocks where stock_code='600186';
# sql_temp select * from stocks where stock_code='600163';
# sql_temp select * from stocks where stock_code='600149';
# sql_temp select * from stocks where stock_code='600145';
# sql_temp select * from stocks where stock_code='600091';
# sql_temp select * from stocks where stock_code='600087';
# sql_temp select * from stocks where stock_code='600084';
# sql_temp select * from stocks where stock_code='600074';
# db_stocks_update finish
# 0

# %% [markdown]
# # 5. func5: db_stocks_create()

# %%
def db_stocks_create():
    # func5:
    # 
    conn = psycopg2.connect(database="brad_particle", user="postgres", password="311266", host="127.0.0.1", port="5432")
    cur = conn.cursor()
    # 创建stocks表
    cur.execute('''
        drop table if exists stocks;
        create table stocks(stock_code varchar primary key,cns_name varchar);
    ''')
    conn.commit()
    conn.close()
    print("db_stocks_create finish")
    pass

# %%
db_stocks_create()
# Out:
# db_stocks_create finish

# %%
import tushare as ts
import psycopg2
class Stocks(object):#这个类表示"股票们"的整体(不是单元)
    def get_today_all(self):
        # func1:
        # 功能：获取所有tushare股票数据
        """
        返回值说明：

        code：代码
        name:名称
        changepercent:涨跌幅
        trade:现价
        open:开盘价
        high:最高价
        low:最低价
        settlement:昨日收盘价
        volume:成交量
        turnoverratio:换手率
        amount:成交金额
        per:市盈率
        pb:市净率
        mktcap:总市值
        nmc:流通市值
        
        http://tushare.org/trading.html#id7
        
        返回数据格式：
            code	name	changepercent	trade	open	high	low	settlement	volume	turnoverratio	amount	per	pb	mktcap	nmc
        0	603999	读者传媒	1.500	6.09	6.00	6.12	5.96	6.00	3431353.0	0.59572	20766182.0	87.000	2.084	3.507840e+05	3.507840e+05
        1	603998	方盛制药	1.316	10.01	9.84	10.30	9.84	9.88	22750376.0	5.35055	228858699.0	58.882	4.055	4.370593e+05	4.256219e+05
        
        
        """
        # 返回值：
        self.todayall=ts.get_today_all()

    
    def get_codestock_local(self): 
        # func2:
        # 功能：从本地获取所有股票代号和名称
        # 返回值：本地SQL数据库所有股票代码和名称
        
        conn = psycopg2.connect(database="brad_particle", user=self.user, password=self.password, host="127.0.0.1",
                                port="5432")
        cur = conn.cursor()
        # 创建stocks表
        cur.execute('''
                select * from stocks;
               ''')
        rows =cur.fetchall()
        conn.commit()
        conn.close()
        return rows
        pass
    
    
    def __init__(self,user,password):
        # self.aaa = aaa
        self.todayall=[]
        self.user=user
        self.password=password

    def db_perstock_insertsql(self,stock_code,cns_name):
        # func3:
        # #返回的是SQL插入语句
        sql_temp="insert into stocks values("
        sql_temp+="\'"+stock_code+"\'"+","+"\'"+cns_name+"\'"
        sql_temp +=");"
        return sql_temp
        pass

    def db_stocks_update(self):
        # func4:
        # 功能：根据gettodayall的情况插入原表中没的。。gettodayall中有的源表没的保留不删除#返回新增行数
        # 返回值：
        ans=0
        conn = psycopg2.connect(database="brad_particle", user=self.user, password=self.password, host="127.0.0.1", port="5432")
        cur = conn.cursor()
        self.get_today_all()

        for i in range(0,len(self.todayall)):
            sql_temp='''select * from stocks where stock_code='''
            sql_temp+="\'"+self.todayall["code"][i]+"\';"
            cur.execute(sql_temp)
            rows=cur.fetchall()
            if(len(rows)==0):
                #如果股票代码没找到就插
                ans+=1
                cur.execute(self.db_perstock_insertsql(self.todayall["code"][i],self.todayall["name"][i]))
                pass
        conn.commit()
        conn.close()
        print("db_stocks_update finish")
        return ans

    def db_stocks_create(self):
        # func5:
        # 
        conn = psycopg2.connect(database="brad_particle", user=self.user, password=self.password, host="127.0.0.1", port="5432")
        cur = conn.cursor()
        # 创建stocks表
        cur.execute('''
            drop table if exists stocks;
            create table stocks(stock_code varchar primary key,cns_name varchar);
        ''')
        conn.commit()
        conn.close()
        print("db_stocks_create finish")
        pass

# %% [markdown]
# # Hdata.py

# %% [markdown]
# ## func1: db_connect()

# %% [markdown]
# ## func2: db_diconnect()

# %% [markdown]
# ## func3: db_hdata_date_create()

# %%
import psycopg2
import tushare as ts
import pandas as pd
from time import clock

class HData(object):
    def __init__(self,user,password):
        # self.aaa = aaa
        self.hdata_date=[]
        self.user=user
        self.password=password
        self.conn=None
        self.cur=None

    def db_connect(self):
        # func1:
        # 功能：连接数据库
        self.conn = psycopg2.connect(database="brad_particle", user=self.user, password=self.password, host="127.0.0.1",
                                port="5432")
        self.cur = self.conn.cursor()

    def db_disconnect(self):
        # func2:
        # 功能：断开和数据库的连接
        self.conn.close()

    def db_hdata_date_create(self):
        # func3:
        # 功能：创建stocks表，
        """
        表中的cols：
        stock_code,record_date,open,high,close,low,volume,price_change,p_change,
        ma5,ma10,ma20,v_ma5,v_ma10,v_ma20,turnover
        """
        conn = psycopg2.connect(database="brad_particle", user=self.user, password=self.password, host="127.0.0.1",
                                port="5432")
        cur = conn.cursor()
        # 创建stocks表
        cur.execute('''
                drop table if exists hdata_date;
                create table hdata_date(stock_code varchar,record_date date,
                    open float,high float,close float,low float,
                    volume float,
                    price_change float,p_change float,
                    ma5 float,ma10 float,ma20 float,
                    v_ma5 float,v_ma10 float,v_ma20 float,
                    turnover float
                );
                alter table hdata_date add primary key(stock_code,record_date);
                ''')
        conn.commit()
        conn.close()
        print("db_hdata_date_create finish")
        pass

    def db_get_maxdate_of_stock(self,stock_code):#获取某支股票的最晚日期
        # func4:
        # 功能：
        self.cur.execute("select max(record_date) from hdata_date where stock_code="+"\'"+stock_code+"\'"+";")
        ans=self.cur.fetchall()
        if(len(ans)==0):
            return None
        return ans[0][0]
        self.conn.commit()
        pass

    def insert_perstock_hdatadate(self,stock_code,data):#插入一支股票的所有历史数据到数据库#如果有code和index相同的不重复插入
        # func5:
        # 功能：
        t1=clock()

        for i in range(0,len(data)):
            str_temp=""
            str_temp+="\'"+stock_code+"\'"+","
            str_temp+="\'"+data.index[i]+"\'"
            for j in range(0,data.shape[1]):
                str_temp+=","+"\'"+str(data.iloc[i,j])+"\'"
            sql_temp="values"+"("+str_temp+")"
            self.cur.execute("insert into hdata_date "+sql_temp+";")
        self.conn.commit()
        print(clock()-t1)
        print(stock_code+" insert_perstock_hdatadate finish")

    def get_all_hdata_of_stock(self,stock_code):#将数据库中的数据读取并转为dataframe格式返回
        # func6:
        # 功能：
        conn = psycopg2.connect(database="brad_particle", user=self.user, password=self.password, host="127.0.0.1",
                                port="5432")
        cur = conn.cursor()
        sql_temp="select * from hdata_date where stock_code="+"\'"+stock_code+"\';"
        cur.execute(sql_temp)
        rows = cur.fetchall()
        
        conn.commit()
        conn.close()

        dataframe_cols=[tuple[0] for tuple in cur.description]#列名和数据库列一致
        df = pd.DataFrame(rows, columns=dataframe_cols)
        return df
        pass

# %% [markdown]
# # main.py

# %%
import psycopg2 #使用的是PostgreSQL数据库
import tushare as ts
# from Stocks import*
# from HData import*
import  datetime

# %%
stocks=Stocks("postgres","311266")
hdata=HData("postgres","311266")

# %%
stocks.db_stocks_create()#如果还没有表则需要创建
print(stocks.db_stocks_update())#根据todayall的情况更新stocks表

hdata.db_hdata_date_create()
nowdate=datetime.datetime.now().date()
codestock_local=stocks.get_codestock_local()

hdata.db_connect()#由于每次连接数据库都要耗时0.0几秒，故获取历史数据时统一连接
for i in range(0,len(codestock_local)):
    nowcode=codestock_local[i][0]

    #print(hdata.get_all_hdata_of_stock(nowcode))

    print(i,nowcode,codestock_local[i][1])

    maxdate=hdata.db_get_maxdate_of_stock(nowcode)
    print(maxdate, nowdate)
    if(maxdate):
        if(maxdate>=nowdate):#maxdate小的时候说明还有最新的数据没放进去
            continue
        hist_data=ts.get_hist_data(nowcode, str(maxdate+datetime.timedelta(1)),str(nowdate), 'D', 3, 0.001)
        hdata.insert_perstock_hdatadate(nowcode, hist_data)
    else:#说明从未获取过这只股票的历史数据
        hist_data = ts.get_hist_data(nowcode, None, str(nowdate), 'D', 3, 0.001)
        hdata.insert_perstock_hdatadate(nowcode, hist_data)

hdata.db_disconnect()
# Out:
# db_stocks_create finish
# [Getting data:]#
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-28ee24508b2b> in <module>()
#       1 stocks.db_stocks_create()#如果还没有表则需要创建
# ----> 2 print(stocks.db_stocks_update())#根据todayall的情况更新stocks表
#       3
#       4 hdata.db_hdata_date_create()
#       5
#
# <ipython-input-21-f9074fbe2726> in db_stocks_update(self)
#      36         conn = psycopg2.connect(database="brad_particle", user=self.user, password=self.password, host="127.0.0.1", port="5432")
#      37         cur = conn.cursor()
# ---> 38         self.get_today_all()
#      39
#      40         for i in range(0,len(self.todayall)):
#
# <ipython-input-21-f9074fbe2726> in get_today_all(self)
#       3 class Stocks(object):#这个类表示"股票们"的整体(不是单元)
#       4     def get_today_all(self):
# ----> 5         self.todayall=ts.get_today_all()
#       6
#       7     def get_codestock_local(self):#从本地获取所有股票代号和名称
#
# ~/anaconda3/lib/python3.5/site-packages/tushare/stock/trading.py in get_today_all()
#     312     """
#     313     ct._write_head()
# --> 314     df = _parsing_dayprice_json('hs_a', 1)
#     315     if df is not None:
#     316         for i in range(2, ct.PAGE_NUM[1]):
#
# ~/anaconda3/lib/python3.5/site-packages/tushare/stock/trading.py in _parsing_dayprice_json(types, page)
#     114     request = Request(ct.SINA_DAY_PRICE_URL%(ct.P_TYPE['http'], ct.DOMAINS['vsf'],
#     115                                  ct.PAGES['jv'], types, page))
# --> 116     text = urlopen(request, timeout=10).read()
#     117     if text == 'null':
#     118         return None
#
# ~/anaconda3/lib/python3.5/http/client.py in read(self, amt)
#     453
#     454             if self.chunked:
# --> 455                 return self._readall_chunked()
#     456
#     457             if self.length is None:
#
# ~/anaconda3/lib/python3.5/http/client.py in _readall_chunked(self)
#     559                 if chunk_left is None:
#     560                     break
# --> 561                 value.append(self._safe_read(chunk_left))
#     562                 self.chunk_left = 0
#     563             return b''.join(value)
#
# ~/anaconda3/lib/python3.5/http/client.py in _safe_read(self, amt)
#     605         s = []
#     606         while amt > 0:
# --> 607             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     608             if not chunk:
#     609                 raise IncompleteRead(b''.join(s), amt)
#
# ~/anaconda3/lib/python3.5/socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# KeyboardInterrupt:
